# %% [markdown]
# # News Analysis

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import operator
import math
import progressbar
import json as j
from unidecode import unidecode
import networkx as nx
from gb.notebook import *
import gb.synonyms.synonyms as syn
from gb.metrics.hyper_similarity import HyperSimilarity

# %% [markdown]
# ### HyperGraph, etc.

# %%
hg = init_hypergraph('../reddit-worldnews-01012013-01082017-new-inference3.hg')
hs = HyperSimilarity(hg)

# %% [markdown]
# ### Topics

# %%
def is_compound_propn(edge):
    if len(edge) < 3:
        return False
    if edge[0] != '+/gb':
        return False
    for item in edge[1:]:
        if is_symbol(item):
            if symbol_namespace(item)[-5:] != 'propn':
                return False
        elif not is_compound_propn(item):
            return False
    return True

def is_adj(edge):
    if is_edge(edge):
        return False
    return symbol_namespace(edge)[-3:] == 'adj'

def is_noun(edge):
    if is_edge(edge):
        return False
    return symbol_namespace(edge)[-5:] == 'propn' or symbol_namespace(edge)[-4:] == 'noun'

def has_noun(edge):
    if is_edge(edge):
        for item in edge:
            if has_noun(item):
                return True
    else:
        return is_noun(edge)
    return False

def is_adjective_and_noun(edge):
    if len(edge) != 3:
        return False
    if edge[0] != '+/gb':
        return False
    if not is_adj(edge[1]):
        return False
    if not is_noun(edge[2]):
        return False
    return True

def is_cconj(edge):
    if is_edge(edge):
        return False
    return symbol_namespace(edge)[-5:] == 'cconj'

def is_topic(symbol):
    if is_symbol(symbol) and symbol_namespace(symbol)[:3] == 'syn':
        root = symbol_root(symbol)
        return root[0].isalnum() and root[-1].isalnum()
    return False

def subtopics(edge):
    stopics = set()
    if is_edge(edge):
        for item in edge:
            topic = syn.main_synonym(hg, item)
            if is_topic(topic):
                stopics.add(item)
    return stopics

def choose_topic1(edge):
    topic = syn.main_synonym(hg, edge)
    if is_edge(edge):
        if is_compound_propn(edge) or is_adjective_and_noun(edge):
            return topic
        stopics = subtopics(edge)
        if len(stopics) == 1:
            return choose_topic1(next(iter(stopics)))    
    return topic

def is_adp(edge):
    return is_symbol(edge) and symbol_namespace(edge)[-3:] == 'adp'

def choose_topic(edge):
    if is_edge(edge) and edge[0] == '+/gb' and is_adp(edge[1]):
        if len(edge) == 3:
            return choose_topic(edge[2])
        elif len(edge) > 3:
            return choose_topic1(edge)
    return syn.main_synonym(hg, edge)

def atomic_topic(edge):
    atopic = syn.main_synonym(hg, edge)
    if is_topic(atopic):
        return {atopic}
    return set()

def atomic_topics(edge):
    atopics = atomic_topic(edge)
    if is_edge(edge):
        if is_compound_propn(edge) or is_adjective_and_noun(edge):
            return atopics
        for item in edge:
            atopics |= atomic_topics(item)
        # if len(atopics) > 0:
        #     return atopics
        # else:
        #     return atomic_topic(edge)
    return atopics

# %%
e = ('+/gb', 'of/nlp.of.adp', ('pulling/nlp.pull.verb', ('+/gb', 'stunts/nlp.stunt.noun', '–/nlp.–.noun'), ('+/gb', 'after/nlp.after.adp', ('kill/nlp.kill.verb', ('+/gb', 'american/nlp.american.adj', 'forces/nlp.force.noun')), ('+/gb', 'of/nlp.of.adp', 'dozens/nlp.dozen.noun', ('+/gb', 'syrian/nlp.syrian.adj', 'soldiers/nlp.soldier.noun')))))
#e = ('+/gb', 'against/nlp.against.adp', ('+/gb', 'in/nlp.in.adp', ('+/gb', '‘/nlp.‘.det', ('+/gb', 'syria/nlp.syria.propn', 'actions/nlp.action.noun', 'style’/nlp.style’.propn')), ('+/gb', 'n./nlp.n..propn', 'korea/nlp.korea.propn')))
#e = ('+/gb', 'for/nlp.for.adp', ('gone/nlp.go.verb', ('+/gb', 'mistral/nlp.mistral.propn', 'deal/nlp.deal.propn')), 'bad/nlp.bad.adj')
#e = ('+/gb', 'against/nlp.against.adp', ('+/gb', 'on/nlp.on.adp', 'attack/nlp.attack.noun', ('+/gb', 'syrian/nlp.syrian.adj', 'forces/nlp.force.noun')))
atomic_topics(e)
# Out:
# {'after_american_forces_kill_dozens_of_syrian_soldiers/syn1347213',
#  'american_forces/syn137972',
#  'american_forces_kill/syn1347214',
#  'dozens_of_syrian_soldiers/syn1347215',
#  'of_pulling_stunts_–_after_american_forces_kill_dozens_of_syrian_soldiers/syn1347210',
#  'pulling_stunts_–_after_american_forces_kill_dozens_of_syrian_soldiers/syn1347211',
#  'stunt/syn996',
#  'syrian_soldiers/syn13872'}

# %%
e = ('+/gb', 'middle/nlp.middle.propn', 'east/nlp.east.propn')
e = ('annexing/nlp.annex.verb', 'crimea/nlp.crimea.propn')
e = ('+/gb', 'syrian/nlp.syrian.adj', 'forces/nlp.force.noun')
hg.get_label(syn.main_synonym(hg, e))
# Out:
# 'syrian forces'

# %% [markdown]
# ### Synonym funs

# %%
def syn_id(root):
    symbs = hg.symbols_with_root(root)
    for symb in symbs:
        if symbol_namespace(symb)[:3] == 'syn':
            return symb
    return None
        
def syn_label(syn_id):
    symbs = syn.synonyms(hg, syn_id)
    labels = []
    for symb in symbs:
        labels.append(hg.get_label(symb))
    min_size = 999999
    best = None
    for label in labels:
        if len(label) < min_size:
            min_size = len(label)
            best = label
    parts = best.split('|')
    if len(parts) > 1:
        max_size = 0
        for part in parts:
            if len(part) > max_size:
                best = part.strip()
                max_size = len(best)
        
    return unidecode(best)

# %% [markdown]
# ### Actors

# %%
# actors = {}
# for edge in hg.pattern2edges(('is_actor/gb.inf', None)):
#     actor = edge[1]
#     actors[actor] = 0

# %% [markdown]
# ### Entities

# %%
nclaims = 0
nconflicts = 0

actors = {}
entities = {}


def edge2actors(edge, check_actors=True):
    if is_edge(edge) and edge[0] == '+/gb':
        if is_adp(edge[1]) and len(edge) == 3:
            return edge2actors(edge[2])
        elif is_cconj(edge[1]) and len(edge) > 2:
            result = set()
            for item in edge[2:]:
                result |= edge2actors(item)
            return result
    if has_noun(edge):
        synact = syn.main_synonym(hg, edge, in_adp=True)
        if check_actors:
            if synact in actors and actors[synact] > 2:
                return {synact}
        else:
            return {synact}
    return set()


def add_to_table(table, item):
    if item not in table:
        table[item] = 0
    table[item] += 1


def add_entity(entity):
    if entity not in entities:
        entities[entity] = {'mentions': {},
                            'mentioned_by': {},
                            'conflict_towards': {},
                            'conflict_from': {},
                            'conflict_actors': []}

        
def add_mention(actor, concept):
    add_entity(actor)
    add_entity(concept)
    add_to_table(entities[actor]['mentions'], concept)
    add_to_table(entities[concept]['mentioned_by'], actor)
    

def add_conflict(orig, targ, concept):
    add_entity(orig)
    add_entity(targ)
    add_entity(concept)
    add_to_table(entities[orig]['conflict_towards'], targ)
    add_to_table(entities[targ]['conflict_from'], orig)
    entities[concept]['conflict_actors'].append((orig, targ))

    
# find actors
for edge in hg.pattern2edges(('mention/gb.inf', None, None)):
    origs = edge2actors(edge[1], check_actors=False)
    for orig in origs:
        if orig not in actors:
            actors[orig] = 0
        actors[orig] += 1
        
for edge in hg.pattern2edges(('conflict/gb.inf', None, None, None)):
    origs = edge2actors(edge[1], check_actors=False)
    for orig in origs:
        if orig not in actors:
            actors[orig] = 0
        actors[orig] += 1


# conflicts and mentions
for edge in hg.pattern2edges(('mention/gb.inf', None, None)):
    nclaims += 1
    origs = edge2actors(edge[1])
    topics = atomic_topics(edge[2])
    for orig in origs:
        for topic in topics:
            add_mention(orig, topic)
        
for edge in hg.pattern2edges(('conflict/gb.inf', None, None, None)):
    nconflicts += 1
    origs = edge2actors(edge[1])
    targs = edge2actors(edge[2])
    topics = atomic_topics(edge[3])
    for orig in origs:
        for targ in targs:
            for topic in topics:
                add_conflict(orig, targ, topic)

print('claims: %s' % nclaims)
print('conflicts: %s' % nconflicts)
# Out:
# claims: 13100
# conflicts: 2637

# %% [markdown]
# ## Metrics

# %%
def compute_metrics(entity):
    mentioned_by = entities[entity]['mentioned_by']
    weights = [mentioned_by[item] for item in mentioned_by]
    total = sum(weights)
    h = 0.
    if total > 0:
        h_weights = [float(i) / float(total) for i in weights]
        h_weights = [i * i for i in h_weights]
        h = 1. / sum(h_weights)
    entities[entity]['h'] = h
    entities[entity]['total'] = total
    entities[entity]['degree'] = syn.synonyms_degree(hg, entity)
    entities[entity]['c'] = len(entities[entity]['conflict_actors'])
    
def metrics(concept):
    return {'h': entities[concept]['h'],
            'total': entities[concept]['total'],
            'degree': entities[concept]['degree'],
            'c': entities[concept]['c']}

i = 0
with progressbar.ProgressBar(max_value=len(entities)) as bar:
    for entity in entities:
        compute_metrics(entity)
        i += 1
        bar.update(i)
# Out:
# 100% (50615 of 50615) |##################| Elapsed Time: 0:00:27 Time:  0:00:27

# %% [markdown]
# ### Conflicts

# %%
conflicts = {}

for actor in actors:
    conflicts[actor] = []

for edge in hg.pattern2edges(('conflict/gb.inf', None, None, None)):
    orig = edge[1]
    targ = edge[2]
    # topics = {choose_topic(edge[3])}
    topics = atomic_topics(edge[3])
    for topic in topics:
        actors[orig] += 1
        actors[targ] += 1
        source = hg.pattern2edges(('source/gb.inf', edge, None)).pop()[2]
        triplet = (orig, targ, topic, source)
        conflicts[orig].append(triplet)
        conflicts[targ].append(triplet)

# %% [markdown]
# ## One Actor

# %%
actor = syn_id('israel')

lactor = hg.get_label(actor)
json_data = {}

for triplet in conflicts[actor]:
    other = triplet[0]
    direction = 'from'
    if other == actor:
        other = triplet[1]
        direction = 'to'
    topic = triplet[2]
    lother = hg.get_label(other)
    ltopic = syn_label(topic)
    if lother not in json_data:
        json_data[lother] = {}
    if ltopic not in json_data[lother]:
        json_data[lother][ltopic] = metrics(other)
        json_data[lother][ltopic]['from'] = 0
        json_data[lother][ltopic]['to'] = 0
    json_data[lother][ltopic][direction] += 1
    json_data[lother][ltopic]['source'] = triplet[3]

topics = {}

for targ in json_data:
    concepts = set(json_data[targ].keys())
    for concept in concepts:
        if concept not in topics:
            topics[concept] = 0
        topics[concept] += 1
        
for targ in json_data:
    for concept in json_data[targ]:
        json_data[targ][concept]['local_degree'] = topics[concept]
        
with open('%s.json' % lactor, 'wt') as out:
    res = j.dump(json_data, out, sort_keys=False, indent=4, separators=(',', ': '))
    
json_data
# Out:
# {'palestinian authority': {'for killing of palestinian attackers': {'h': 2.0,
#    'total': 2,
#    'degree': 101,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb',
#      'palestinian/nlp.palestinian.propn',
#      'authority/nlp.authority.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'killing/nlp.killing.noun',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'attackers/nlp.attacker.noun')))),
#    'local_degree': 1},
#   'palestinian attacker': {'h': 2.0,
#    'total': 2,
#    'degree': 101,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb',
#      'palestinian/nlp.palestinian.propn',
#      'authority/nlp.authority.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'killing/nlp.killing.noun',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'attackers/nlp.attacker.noun')))),
#    'local_degree': 1},
#   'killing of palestinian attackers': {'h': 2.0,
#    'total': 2,
#    'degree': 101,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb',
#      'palestinian/nlp.palestinian.propn',
#      'authority/nlp.authority.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'killing/nlp.killing.noun',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'attackers/nlp.attacker.noun')))),
#    'local_degree': 1},
#   'killing': {'h': 2.0,
#    'total': 2,
#    'degree': 101,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb',
#      'palestinian/nlp.palestinian.propn',
#      'authority/nlp.authority.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'killing/nlp.killing.noun',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'attackers/nlp.attacker.noun')))),
#    'local_degree': 1},
#   'jerusalem terrorists': {'h': 2.0,
#    'total': 2,
#    'degree': 101,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb',
#      'palestinian/nlp.palestinian.propn',
#      'authority/nlp.authority.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('shooting/nlp.shoot.verb',
#       ('+/gb',
#        'jerusalem/nlp.jerusalem.propn',
#        'terrorists/nlp.terrorists.propn')))),
#    'local_degree': 1},
#   'shooting jerusalem terrorists': {'h': 2.0,
#    'total': 2,
#    'degree': 101,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb',
#      'palestinian/nlp.palestinian.propn',
#      'authority/nlp.authority.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('shooting/nlp.shoot.verb',
#       ('+/gb',
#        'jerusalem/nlp.jerusalem.propn',
#        'terrorists/nlp.terrorists.propn')))),
#    'local_degree': 1},
#   'for shooting jerusalem terrorists': {'h': 2.0,
#    'total': 2,
#    'degree': 101,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb',
#      'palestinian/nlp.palestinian.propn',
#      'authority/nlp.authority.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('shooting/nlp.shoot.verb',
#       ('+/gb',
#        'jerusalem/nlp.jerusalem.propn',
#        'terrorists/nlp.terrorists.propn')))),
#    'local_degree': 1}},
#  'u.n.': {'for violating health of syrians': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'violating/nlp.violating.propn',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'health/nlp.health.propn',
#        'syrians/nlp.syrians.propn')))),
#    'local_degree': 1},
#   'health of syrians': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'violating/nlp.violating.propn',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'health/nlp.health.propn',
#        'syrians/nlp.syrians.propn')))),
#    'local_degree': 1},
#   'violating': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'violating/nlp.violating.propn',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'health/nlp.health.propn',
#        'syrians/nlp.syrians.propn')))),
#    'local_degree': 1},
#   'syrians': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'violating/nlp.violating.propn',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'health/nlp.health.propn',
#        'syrians/nlp.syrians.propn')))),
#    'local_degree': 1},
#   'violating health of syrians': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'violating/nlp.violating.propn',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'health/nlp.health.propn',
#        'syrians/nlp.syrians.propn')))),
#    'local_degree': 1},
#   'home': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'destruction/nlp.destruction.noun',
#       ('+/gb',
#        'jordan/nlp.jordan.propn',
#        'homes/nlp.home.noun',
#        'valley/nlp.valley.propn')))),
#    'local_degree': 1},
#   'over destruction of jordan valley homes': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'destruction/nlp.destruction.noun',
#       ('+/gb',
#        'jordan/nlp.jordan.propn',
#        'homes/nlp.home.noun',
#        'valley/nlp.valley.propn')))),
#    'local_degree': 1},
#   'valley': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'destruction/nlp.destruction.noun',
#       ('+/gb',
#        'jordan/nlp.jordan.propn',
#        'homes/nlp.home.noun',
#        'valley/nlp.valley.propn')))),
#    'local_degree': 1},
#   'destruction of jordan valley homes': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'destruction/nlp.destruction.noun',
#       ('+/gb',
#        'jordan/nlp.jordan.propn',
#        'homes/nlp.home.noun',
#        'valley/nlp.valley.propn')))),
#    'local_degree': 1},
#   'jordan': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'destruction/nlp.destruction.noun',
#       ('+/gb',
#        'jordan/nlp.jordan.propn',
#        'homes/nlp.home.noun',
#        'valley/nlp.valley.propn')))),
#    'local_degree': 1},
#   'jordan valley homes': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'destruction/nlp.destruction.noun',
#       ('+/gb',
#        'jordan/nlp.jordan.propn',
#        'homes/nlp.home.noun',
#        'valley/nlp.valley.propn')))),
#    'local_degree': 1},
#   'school': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'dozens/nlp.dozen.noun',
#       ('+/gb',
#        'gaza/nlp.gaza.propn',
#        ('+/gb', 'school/nlp.school.noun', 'deaths/nlp.death.noun'))))),
#    'local_degree': 1},
#   'for dozens of gaza school deaths': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'dozens/nlp.dozen.noun',
#       ('+/gb',
#        'gaza/nlp.gaza.propn',
#        ('+/gb', 'school/nlp.school.noun', 'deaths/nlp.death.noun'))))),
#    'local_degree': 1},
#   'school deaths': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'dozens/nlp.dozen.noun',
#       ('+/gb',
#        'gaza/nlp.gaza.propn',
#        ('+/gb', 'school/nlp.school.noun', 'deaths/nlp.death.noun'))))),
#    'local_degree': 1},
#   'gaza': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'dozens/nlp.dozen.noun',
#       ('+/gb',
#        'gaza/nlp.gaza.propn',
#        ('+/gb', 'school/nlp.school.noun', 'deaths/nlp.death.noun'))))),
#    'local_degree': 10},
#   'gaza school deaths': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'dozens/nlp.dozen.noun',
#       ('+/gb',
#        'gaza/nlp.gaza.propn',
#        ('+/gb', 'school/nlp.school.noun', 'deaths/nlp.death.noun'))))),
#    'local_degree': 1},
#   'dozens of gaza school deaths': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'dozens/nlp.dozen.noun',
#       ('+/gb',
#        'gaza/nlp.gaza.propn',
#        ('+/gb', 'school/nlp.school.noun', 'deaths/nlp.death.noun'))))),
#    'local_degree': 1},
#   'of spreading propaganda': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('spreading/nlp.spread.verb', 'propaganda/nlp.propaganda.propn'))),
#    'local_degree': 1},
#   'spread propaganda': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('spreading/nlp.spread.verb', 'propaganda/nlp.propaganda.propn'))),
#    'local_degree': 1},
#   'shilo': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'emek/nlp.emek.propn',
#       'settlement/nlp.settlement.noun',
#       'shilo/nlp.shilo.propn'))),
#    'local_degree': 1},
#   'emek': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'emek/nlp.emek.propn',
#       'settlement/nlp.settlement.noun',
#       'shilo/nlp.shilo.propn'))),
#    'local_degree': 1},
#   'emek shilo settlement': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'emek/nlp.emek.propn',
#       'settlement/nlp.settlement.noun',
#       'shilo/nlp.shilo.propn'))),
#    'local_degree': 1},
#   'over emek shilo settlement': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'emek/nlp.emek.propn',
#       'settlement/nlp.settlement.noun',
#       'shilo/nlp.shilo.propn'))),
#    'local_degree': 1},
#   'settlement': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'emek/nlp.emek.propn',
#       'settlement/nlp.settlement.noun',
#       'shilo/nlp.shilo.propn'))),
#    'local_degree': 5},
#   'spanish': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'the/nlp.the.det',
#       ('+/gb',
#        'of/nlp.of.adp',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'death/nlp.death.noun',
#         ('+/gb',
#          'lebanon/nlp.lebanon.propn',
#          ('+/gb', '|/nlp.|.propn', 'news/nlp.news.propn'))),
#        ('+/gb',
#         'spanish/nlp.spanish.adj',
#         ('+/gb',
#          '‘/nlp.‘.noun',
#          ('+/gb', 'blue/nlp.blue.adj', 'helmet’/nlp.helmet’.noun'))))))),
#    'local_degree': 1},
#   "death of spanish ' blue helmet' in lebanon": {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'the/nlp.the.det',
#       ('+/gb',
#        'of/nlp.of.adp',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'death/nlp.death.noun',
#         ('+/gb',
#          'lebanon/nlp.lebanon.propn',
#          ('+/gb', '|/nlp.|.propn', 'news/nlp.news.propn'))),
#        ('+/gb',
#         'spanish/nlp.spanish.adj',
#         ('+/gb',
#          '‘/nlp.‘.noun',
#          ('+/gb', 'blue/nlp.blue.adj', 'helmet’/nlp.helmet’.noun'))))))),
#    'local_degree': 1},
#   "for the death of spanish ' blue helmet' in lebanon": {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'the/nlp.the.det',
#       ('+/gb',
#        'of/nlp.of.adp',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'death/nlp.death.noun',
#         ('+/gb',
#          'lebanon/nlp.lebanon.propn',
#          ('+/gb', '|/nlp.|.propn', 'news/nlp.news.propn'))),
#        ('+/gb',
#         'spanish/nlp.spanish.adj',
#         ('+/gb',
#          '‘/nlp.‘.noun',
#          ('+/gb', 'blue/nlp.blue.adj', 'helmet’/nlp.helmet’.noun'))))))),
#    'local_degree': 1},
#   'lebanon': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'the/nlp.the.det',
#       ('+/gb',
#        'of/nlp.of.adp',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'death/nlp.death.noun',
#         ('+/gb',
#          'lebanon/nlp.lebanon.propn',
#          ('+/gb', '|/nlp.|.propn', 'news/nlp.news.propn'))),
#        ('+/gb',
#         'spanish/nlp.spanish.adj',
#         ('+/gb',
#          '‘/nlp.‘.noun',
#          ('+/gb', 'blue/nlp.blue.adj', 'helmet’/nlp.helmet’.noun'))))))),
#    'local_degree': 2},
#   "the death of spanish ' blue helmet' in lebanon": {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'the/nlp.the.det',
#       ('+/gb',
#        'of/nlp.of.adp',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'death/nlp.death.noun',
#         ('+/gb',
#          'lebanon/nlp.lebanon.propn',
#          ('+/gb', '|/nlp.|.propn', 'news/nlp.news.propn'))),
#        ('+/gb',
#         'spanish/nlp.spanish.adj',
#         ('+/gb',
#          '‘/nlp.‘.noun',
#          ('+/gb', 'blue/nlp.blue.adj', 'helmet’/nlp.helmet’.noun'))))))),
#    'local_degree': 1},
#   'death in lebanon': {'h': 0.0,
#    'total': 0,
#    'degree': 2851,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'the/nlp.the.det',
#       ('+/gb',
#        'of/nlp.of.adp',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'death/nlp.death.noun',
#         ('+/gb',
#          'lebanon/nlp.lebanon.propn',
#          ('+/gb', '|/nlp.|.propn', 'news/nlp.news.propn'))),
#        ('+/gb',
#         'spanish/nlp.spanish.adj',
#         ('+/gb',
#          '‘/nlp.‘.noun',
#          ('+/gb', 'blue/nlp.blue.adj', 'helmet’/nlp.helmet’.noun'))))))),
#    'local_degree': 1}},
#  'amnesty': {'war crime': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 2,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'amnesty/nlp.amnesty.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      'palestinians/nlp.palestinians.propn',
#      ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun'))),
#    'local_degree': 3},
#   'gaza war crime': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'amnesty/nlp.amnesty.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'gaza/nlp.gaza.propn',
#       ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun')))),
#    'local_degree': 1},
#   'gaza': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'amnesty/nlp.amnesty.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'gaza/nlp.gaza.propn',
#       ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun')))),
#    'local_degree': 10},
#   'of gaza war crimes': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'amnesty/nlp.amnesty.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'gaza/nlp.gaza.propn',
#       ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun')))),
#    'local_degree': 1},
#   'war': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 2,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'amnesty/nlp.amnesty.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      'palestinians/nlp.palestinians.propn',
#      ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun'))),
#    'local_degree': 6},
#   'use of force in land day demonstrations': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     ('+/gb',
#      'amnesty/nlp.amnesty.propn',
#      'international/nlp.international.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'of/nlp.of.adp', 'use/nlp.use.noun', 'force/nlp.force.noun'),
#       ('+/gb',
#        'land/nlp.land.propn',
#        'demonstrations/nlp.demonstration.noun',
#        'day/nlp.day.propn')))),
#    'local_degree': 1},
#   'land day demonstrations': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     ('+/gb',
#      'amnesty/nlp.amnesty.propn',
#      'international/nlp.international.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'of/nlp.of.adp', 'use/nlp.use.noun', 'force/nlp.force.noun'),
#       ('+/gb',
#        'land/nlp.land.propn',
#        'demonstrations/nlp.demonstration.noun',
#        'day/nlp.day.propn')))),
#    'local_degree': 1},
#   'demonstration': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     ('+/gb',
#      'amnesty/nlp.amnesty.propn',
#      'international/nlp.international.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'of/nlp.of.adp', 'use/nlp.use.noun', 'force/nlp.force.noun'),
#       ('+/gb',
#        'land/nlp.land.propn',
#        'demonstrations/nlp.demonstration.noun',
#        'day/nlp.day.propn')))),
#    'local_degree': 1},
#   'use of force': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     ('+/gb',
#      'amnesty/nlp.amnesty.propn',
#      'international/nlp.international.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'of/nlp.of.adp', 'use/nlp.use.noun', 'force/nlp.force.noun'),
#       ('+/gb',
#        'land/nlp.land.propn',
#        'demonstrations/nlp.demonstration.noun',
#        'day/nlp.day.propn')))),
#    'local_degree': 1},
#   'against use of force in land day demonstrations': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     ('+/gb',
#      'amnesty/nlp.amnesty.propn',
#      'international/nlp.international.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'of/nlp.of.adp', 'use/nlp.use.noun', 'force/nlp.force.noun'),
#       ('+/gb',
#        'land/nlp.land.propn',
#        'demonstrations/nlp.demonstration.noun',
#        'day/nlp.day.propn')))),
#    'local_degree': 1},
#   'palestinians': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'amnesty/nlp.amnesty.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      'palestinians/nlp.palestinians.propn',
#      ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun'))),
#    'local_degree': 8},
#   'palestinians of war crimes': {'h': 4.0,
#    'total': 4,
#    'degree': 500,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'amnesty/nlp.amnesty.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      'palestinians/nlp.palestinians.propn',
#      ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun'))),
#    'local_degree': 1}},
#  'syria': {'of bombing damascus airport': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('bombing/nlp.bomb.verb',
#       ('+/gb', 'damascus/nlp.damascus.propn', 'airport/nlp.airport.noun')))),
#    'local_degree': 1},
#   'airport': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('bombing/nlp.bomb.verb',
#       ('+/gb', 'damascus/nlp.damascus.propn', 'airport/nlp.airport.noun')))),
#    'local_degree': 1},
#   'bombing damascus airport': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('bombing/nlp.bomb.verb',
#       ('+/gb', 'damascus/nlp.damascus.propn', 'airport/nlp.airport.noun')))),
#    'local_degree': 1},
#   'damascus': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 3,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'fiery/nlp.fiery.propn',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'attack/nlp.attack.propn',
#        'damascus/nlp.damascus.propn')))),
#    'local_degree': 1},
#   'damascus airport': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('bombing/nlp.bomb.verb',
#       ('+/gb', 'damascus/nlp.damascus.propn', 'airport/nlp.airport.noun')))),
#    'local_degree': 1},
#   'predawn blasts near damascus': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'near/nlp.near.adp',
#       ('+/gb', 'predawn/nlp.predawn.adj', 'blasts/nlp.blast.noun'),
#       'damascus/nlp.damascus.propn'))),
#    'local_degree': 1},
#   'predawn blasts': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'near/nlp.near.adp',
#       ('+/gb', 'predawn/nlp.predawn.adj', 'blasts/nlp.blast.noun'),
#       'damascus/nlp.damascus.propn'))),
#    'local_degree': 1},
#   'for predawn blasts near damascus': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'near/nlp.near.adp',
#       ('+/gb', 'predawn/nlp.predawn.adj', 'blasts/nlp.blast.noun'),
#       'damascus/nlp.damascus.propn'))),
#    'local_degree': 1},
#   'attack on a military airbase': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'overnight/nlp.overnight.adj',
#       ('+/gb',
#        'on/nlp.on.adp',
#        'attack/nlp.attack.noun',
#        ('+/gb',
#         'a/nlp.a.det',
#         ('+/gb', 'military/nlp.military.adj', 'airbase/nlp.airbase.noun')))))),
#    'local_degree': 1},
#   'a military airbase': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'overnight/nlp.overnight.adj',
#       ('+/gb',
#        'on/nlp.on.adp',
#        'attack/nlp.attack.noun',
#        ('+/gb',
#         'a/nlp.a.det',
#         ('+/gb', 'military/nlp.military.adj', 'airbase/nlp.airbase.noun')))))),
#    'local_degree': 1},
#   'military airbase': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'overnight/nlp.overnight.adj',
#       ('+/gb',
#        'on/nlp.on.adp',
#        'attack/nlp.attack.noun',
#        ('+/gb',
#         'a/nlp.a.det',
#         ('+/gb', 'military/nlp.military.adj', 'airbase/nlp.airbase.noun')))))),
#    'local_degree': 1},
#   'for overnight attack on a military airbase': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'overnight/nlp.overnight.adj',
#       ('+/gb',
#        'on/nlp.on.adp',
#        'attack/nlp.attack.noun',
#        ('+/gb',
#         'a/nlp.a.det',
#         ('+/gb', 'military/nlp.military.adj', 'airbase/nlp.airbase.noun')))))),
#    'local_degree': 1},
#   'overnight attack on a military airbase': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'overnight/nlp.overnight.adj',
#       ('+/gb',
#        'on/nlp.on.adp',
#        'attack/nlp.attack.noun',
#        ('+/gb',
#         'a/nlp.a.det',
#         ('+/gb', 'military/nlp.military.adj', 'airbase/nlp.airbase.noun')))))),
#    'local_degree': 1},
#   'clash': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'israel/nlp.israel.propn',
#     'syria/nlp.syria.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'golan/nlp.golan.propn',
#       'clashes/nlp.clash.noun',
#       'heights/nlp.heights.propn'))),
#    'local_degree': 1},
#   'golan heights clashes': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'israel/nlp.israel.propn',
#     'syria/nlp.syria.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'golan/nlp.golan.propn',
#       'clashes/nlp.clash.noun',
#       'heights/nlp.heights.propn'))),
#    'local_degree': 1},
#   'over golan heights clashes': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'israel/nlp.israel.propn',
#     'syria/nlp.syria.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'golan/nlp.golan.propn',
#       'clashes/nlp.clash.noun',
#       'heights/nlp.heights.propn'))),
#    'local_degree': 1},
#   'golan': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'israel/nlp.israel.propn',
#     'syria/nlp.syria.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'golan/nlp.golan.propn',
#       'clashes/nlp.clash.noun',
#       'heights/nlp.heights.propn'))),
#    'local_degree': 1},
#   'latest air raids': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'after/nlp.after.adp',
#      ('+/gb',
#       'latest/nlp.late.adj',
#       ('+/gb', 'air/nlp.air.noun', 'raids/nlp.raid.noun')))),
#    'local_degree': 1},
#   'after latest air raids': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'after/nlp.after.adp',
#      ('+/gb',
#       'latest/nlp.late.adj',
#       ('+/gb', 'air/nlp.air.noun', 'raids/nlp.raid.noun')))),
#    'local_degree': 1},
#   'air raid': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'after/nlp.after.adp',
#      ('+/gb',
#       'latest/nlp.late.adj',
#       ('+/gb', 'air/nlp.air.noun', 'raids/nlp.raid.noun')))),
#    'local_degree': 1},
#   'air': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'after/nlp.after.adp',
#      ('+/gb',
#       'latest/nlp.late.adj',
#       ('+/gb', 'air/nlp.air.noun', 'raids/nlp.raid.noun')))),
#    'local_degree': 2},
#   'raid': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'after/nlp.after.adp',
#      ('+/gb',
#       'latest/nlp.late.adj',
#       ('+/gb', 'air/nlp.air.noun', 'raids/nlp.raid.noun')))),
#    'local_degree': 2},
#   'deadly attack': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb', 'deadly/nlp.deadly.adj', 'attacks/nlp.attack.noun')),
#    'local_degree': 1},
#   'of bombardment': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb', 'of/nlp.of.adp', 'bombardment/nlp.bombardment.noun')),
#    'local_degree': 1},
#   'bombardment': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb', 'of/nlp.of.adp', 'bombardment/nlp.bombardment.noun')),
#    'local_degree': 1},
#   'surprise': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'surprise/nlp.surprise.noun',
#       'retaliation/nlp.retaliation.noun'))),
#    'local_degree': 1},
#   'retaliation': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'surprise/nlp.surprise.noun',
#       'retaliation/nlp.retaliation.noun'))),
#    'local_degree': 1},
#   'surprise retaliation': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'surprise/nlp.surprise.noun',
#       'retaliation/nlp.retaliation.noun'))),
#    'local_degree': 1},
#   'of surprise retaliation': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'surprise/nlp.surprise.noun',
#       'retaliation/nlp.retaliation.noun'))),
#    'local_degree': 1},
#   'fiery attack in damascus': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'fiery/nlp.fiery.propn',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'attack/nlp.attack.propn',
#        'damascus/nlp.damascus.propn')))),
#    'local_degree': 1},
#   'for fiery attack in damascus': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'fiery/nlp.fiery.propn',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'attack/nlp.attack.propn',
#        'damascus/nlp.damascus.propn')))),
#    'local_degree': 1},
#   'attack in damascus': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'fiery/nlp.fiery.propn',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'attack/nlp.attack.propn',
#        'damascus/nlp.damascus.propn')))),
#    'local_degree': 1},
#   'fiery': {'h': 48.510403397027446,
#    'total': 478,
#    'degree': 2277,
#    'c': 50,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'fiery/nlp.fiery.propn',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'attack/nlp.attack.propn',
#        'damascus/nlp.damascus.propn')))),
#    'local_degree': 1}},
#  'jordan': {'prayer': {'h': 10.714285714285712,
#    'total': 15,
#    'degree': 342,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'jordan/nlp.jordan.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'western/nlp.western.propn',
#       ('+/gb', 'prayer/nlp.prayer.noun', 'platform/nlp.platform.noun'),
#       'wall/nlp.wall.propn'))),
#    'local_degree': 2},
#   'western wall prayer platform': {'h': 10.714285714285712,
#    'total': 15,
#    'degree': 342,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'jordan/nlp.jordan.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'western/nlp.western.propn',
#       ('+/gb', 'prayer/nlp.prayer.noun', 'platform/nlp.platform.noun'),
#       'wall/nlp.wall.propn'))),
#    'local_degree': 1},
#   'prayer platform': {'h': 10.714285714285712,
#    'total': 15,
#    'degree': 342,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'jordan/nlp.jordan.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'western/nlp.western.propn',
#       ('+/gb', 'prayer/nlp.prayer.noun', 'platform/nlp.platform.noun'),
#       'wall/nlp.wall.propn'))),
#    'local_degree': 1},
#   'wall': {'h': 10.714285714285712,
#    'total': 15,
#    'degree': 342,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'jordan/nlp.jordan.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'western/nlp.western.propn',
#       ('+/gb', 'prayer/nlp.prayer.noun', 'platform/nlp.platform.noun'),
#       'wall/nlp.wall.propn'))),
#    'local_degree': 1},
#   'for western wall prayer platform': {'h': 10.714285714285712,
#    'total': 15,
#    'degree': 342,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'jordan/nlp.jordan.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'western/nlp.western.propn',
#       ('+/gb', 'prayer/nlp.prayer.noun', 'platform/nlp.platform.noun'),
#       'wall/nlp.wall.propn'))),
#    'local_degree': 1}},
#  'u.s.': {'palestinian': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('condemns/nlp.condemn.verb',
#     'israel/nlp.israel.propn',
#     'us/nlp.us.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('backing/nlp.back.verb',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'unity/nlp.unity.noun',
#        'government/nlp.government.noun')))),
#    'local_degree': 1},
#   'for backing palestinian unity government': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('condemns/nlp.condemn.verb',
#     'israel/nlp.israel.propn',
#     'us/nlp.us.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('backing/nlp.back.verb',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'unity/nlp.unity.noun',
#        'government/nlp.government.noun')))),
#    'local_degree': 1},
#   'unity': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('condemns/nlp.condemn.verb',
#     'israel/nlp.israel.propn',
#     'us/nlp.us.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('backing/nlp.back.verb',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'unity/nlp.unity.noun',
#        'government/nlp.government.noun')))),
#    'local_degree': 1},
#   'palestinian unity government': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('condemns/nlp.condemn.verb',
#     'israel/nlp.israel.propn',
#     'us/nlp.us.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('backing/nlp.back.verb',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'unity/nlp.unity.noun',
#        'government/nlp.government.noun')))),
#    'local_degree': 1},
#   'backing palestinian unity government': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('condemns/nlp.condemn.verb',
#     'israel/nlp.israel.propn',
#     'us/nlp.us.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('backing/nlp.back.verb',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'unity/nlp.unity.noun',
#        'government/nlp.government.noun')))),
#    'local_degree': 1},
#   'of systematically seizing palestinian land': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('systematically_seizing/nlp.systematically.adv+nlp.seize.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'land/nlp.land.noun')))),
#    'local_degree': 1},
#   'systematically seizing palestinian land': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('systematically_seizing/nlp.systematically.adv+nlp.seize.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'land/nlp.land.noun')))),
#    'local_degree': 1},
#   'palestinian land': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('systematically_seizing/nlp.systematically.adv+nlp.seize.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'land/nlp.land.noun')))),
#    'local_degree': 1},
#   'systematically seizing': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('systematically_seizing/nlp.systematically.adv+nlp.seize.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'land/nlp.land.noun')))),
#    'local_degree': 1},
#   'demolish': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 2,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('demolishing/nlp.demolish.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'village/nlp.village.noun'),
#       ('+/gb',
#        'in/nlp.in.adp',
#        ('+/gb', 'west/nlp.west.propn', 'bank/nlp.bank.propn'))))),
#    'local_degree': 1},
#   'against demolishing palestinian town': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('demolishing/nlp.demolish.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'town/nlp.town.noun')))),
#    'local_degree': 1},
#   'palestinian town': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('demolishing/nlp.demolish.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'town/nlp.town.noun')))),
#    'local_degree': 1},
#   'demolishing palestinian town': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('demolishing/nlp.demolish.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'town/nlp.town.noun')))),
#    'local_degree': 1},
#   'murdered teen': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('targeting/nlp.target.verb',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'family/nlp.family.noun',
#        ('+/gb',
#         'palestine/nlp.palestine.propn',
#         ('murdered/nlp.murder.verb', 'teen/nlp.teen.noun')))))),
#    'local_degree': 1},
#   'palestine': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('targeting/nlp.target.verb',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'family/nlp.family.noun',
#        ('+/gb',
#         'palestine/nlp.palestine.propn',
#         ('murdered/nlp.murder.verb', 'teen/nlp.teen.noun')))))),
#    'local_degree': 4},
#   'targeting family of murdered palestine teen': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('targeting/nlp.target.verb',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'family/nlp.family.noun',
#        ('+/gb',
#         'palestine/nlp.palestine.propn',
#         ('murdered/nlp.murder.verb', 'teen/nlp.teen.noun')))))),
#    'local_degree': 1},
#   'of targeting family of murdered palestine teen': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('targeting/nlp.target.verb',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'family/nlp.family.noun',
#        ('+/gb',
#         'palestine/nlp.palestine.propn',
#         ('murdered/nlp.murder.verb', 'teen/nlp.teen.noun')))))),
#    'local_degree': 1},
#   'family of murdered palestine teen': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('targeting/nlp.target.verb',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'family/nlp.family.noun',
#        ('+/gb',
#         'palestine/nlp.palestine.propn',
#         ('murdered/nlp.murder.verb', 'teen/nlp.teen.noun')))))),
#    'local_degree': 1},
#   'murdered palestine teen': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('targeting/nlp.target.verb',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'family/nlp.family.noun',
#        ('+/gb',
#         'palestine/nlp.palestine.propn',
#         ('murdered/nlp.murder.verb', 'teen/nlp.teen.noun')))))),
#    'local_degree': 1},
#   'targeting kin of murdered palestinian teen': {'h': 0.0,
#    'total': 0,
#    'degree': 7917,
#    'c': 0,
#    'from': 1,
# ...
#    'degree': 110,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'unesco/nlp.unesco.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('restricting/nlp.restrict.verb',
#       'worship/nlp.worship.noun',
#       ('+/gb',
#        'at/nlp.at.adp',
#        ('+/gb', 'al/nlp.al.propn', 'aqsa/nlp.aqsa.propn'))))),
#    'local_degree': 1},
#   'restrict': {'h': 2.0,
#    'total': 2,
#    'degree': 110,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'unesco/nlp.unesco.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('restricting/nlp.restrict.verb',
#       'worship/nlp.worship.noun',
#       ('+/gb',
#        'at/nlp.at.adp',
#        ('+/gb', 'al/nlp.al.propn', 'aqsa/nlp.aqsa.propn'))))),
#    'local_degree': 1}},
#  'un agency': {'apartheid regime': {'h': 0.0,
#    'total': 0,
#    'degree': 103,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'agency/nlp.agency.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('imposing/nlp.impose.verb',
#       ('+/gb', 'apartheid/nlp.apartheid.noun', 'regime/nlp.regime.noun'),
#       ('+/gb', 'on/nlp.on.adp', 'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1},
#   'imposing apartheid regime on palestinians': {'h': 0.0,
#    'total': 0,
#    'degree': 103,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'agency/nlp.agency.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('imposing/nlp.impose.verb',
#       ('+/gb', 'apartheid/nlp.apartheid.noun', 'regime/nlp.regime.noun'),
#       ('+/gb', 'on/nlp.on.adp', 'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1},
#   'regime': {'h': 0.0,
#    'total': 0,
#    'degree': 103,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'agency/nlp.agency.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('imposing/nlp.impose.verb',
#       ('+/gb', 'apartheid/nlp.apartheid.noun', 'regime/nlp.regime.noun'),
#       ('+/gb', 'on/nlp.on.adp', 'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1},
#   'on palestinians': {'h': 0.0,
#    'total': 0,
#    'degree': 103,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'agency/nlp.agency.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('imposing/nlp.impose.verb',
#       ('+/gb', 'apartheid/nlp.apartheid.noun', 'regime/nlp.regime.noun'),
#       ('+/gb', 'on/nlp.on.adp', 'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1},
#   'palestinians': {'h': 0.0,
#    'total': 0,
#    'degree': 103,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'agency/nlp.agency.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('imposing/nlp.impose.verb',
#       ('+/gb', 'apartheid/nlp.apartheid.noun', 'regime/nlp.regime.noun'),
#       ('+/gb', 'on/nlp.on.adp', 'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 8},
#   'of imposing apartheid regime on palestinians': {'h': 0.0,
#    'total': 0,
#    'degree': 103,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'agency/nlp.agency.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('imposing/nlp.impose.verb',
#       ('+/gb', 'apartheid/nlp.apartheid.noun', 'regime/nlp.regime.noun'),
#       ('+/gb', 'on/nlp.on.adp', 'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1},
#   'impose': {'h': 0.0,
#    'total': 0,
#    'degree': 103,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'agency/nlp.agency.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('imposing/nlp.impose.verb',
#       ('+/gb', 'apartheid/nlp.apartheid.noun', 'regime/nlp.regime.noun'),
#       ('+/gb', 'on/nlp.on.adp', 'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1},
#   'apartheid': {'h': 0.0,
#    'total': 0,
#    'degree': 103,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'agency/nlp.agency.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('imposing/nlp.impose.verb',
#       ('+/gb', 'apartheid/nlp.apartheid.noun', 'regime/nlp.regime.noun'),
#       ('+/gb', 'on/nlp.on.adp', 'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1}},
#  'un chief': {'quartet': {'h': 0.0,
#    'total': 0,
#    'degree': 172,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'u.n./nlp.u.n..propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'settlement/nlp.settlement.noun', 'plans/nlp.plan.noun'),
#       ('+/gb',
#        'of/nlp.of.adp',
#        'wake/nlp.wake.noun',
#        ('+/gb', 'quartet/nlp.quartet.propn', 'report/nlp.report.noun'))))),
#    'local_degree': 1},
#   'wake of quartet report': {'h': 0.0,
#    'total': 0,
#    'degree': 172,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'u.n./nlp.u.n..propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'settlement/nlp.settlement.noun', 'plans/nlp.plan.noun'),
#       ('+/gb',
#        'of/nlp.of.adp',
#        'wake/nlp.wake.noun',
#        ('+/gb', 'quartet/nlp.quartet.propn', 'report/nlp.report.noun'))))),
#    'local_degree': 1},
#   'settlement plans in wake of quartet report': {'h': 0.0,
#    'total': 0,
#    'degree': 172,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'u.n./nlp.u.n..propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'settlement/nlp.settlement.noun', 'plans/nlp.plan.noun'),
#       ('+/gb',
#        'of/nlp.of.adp',
#        'wake/nlp.wake.noun',
#        ('+/gb', 'quartet/nlp.quartet.propn', 'report/nlp.report.noun'))))),
#    'local_degree': 1},
#   'settlement': {'h': 0.0,
#    'total': 0,
#    'degree': 172,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'u.n./nlp.u.n..propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'settlement/nlp.settlement.noun', 'plans/nlp.plan.noun'),
#       ('+/gb',
#        'of/nlp.of.adp',
#        'wake/nlp.wake.noun',
#        ('+/gb', 'quartet/nlp.quartet.propn', 'report/nlp.report.noun'))))),
#    'local_degree': 5},
#   'plan': {'h': 0.0,
#    'total': 0,
#    'degree': 172,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'u.n./nlp.u.n..propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'settlement/nlp.settlement.noun', 'plans/nlp.plan.noun'),
#       ('+/gb',
#        'of/nlp.of.adp',
#        'wake/nlp.wake.noun',
#        ('+/gb', 'quartet/nlp.quartet.propn', 'report/nlp.report.noun'))))),
#    'local_degree': 1},
#   'over settlement plans in wake of quartet report': {'h': 0.0,
#    'total': 0,
#    'degree': 172,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'u.n./nlp.u.n..propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'settlement/nlp.settlement.noun', 'plans/nlp.plan.noun'),
#       ('+/gb',
#        'of/nlp.of.adp',
#        'wake/nlp.wake.noun',
#        ('+/gb', 'quartet/nlp.quartet.propn', 'report/nlp.report.noun'))))),
#    'local_degree': 1},
#   'settlement plan': {'h': 0.0,
#    'total': 0,
#    'degree': 172,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'u.n./nlp.u.n..propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'settlement/nlp.settlement.noun', 'plans/nlp.plan.noun'),
#       ('+/gb',
#        'of/nlp.of.adp',
#        'wake/nlp.wake.noun',
#        ('+/gb', 'quartet/nlp.quartet.propn', 'report/nlp.report.noun'))))),
#    'local_degree': 1},
#   'wake': {'h': 0.0,
#    'total': 0,
#    'degree': 172,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'u.n./nlp.u.n..propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'settlement/nlp.settlement.noun', 'plans/nlp.plan.noun'),
#       ('+/gb',
#        'of/nlp.of.adp',
#        'wake/nlp.wake.noun',
#        ('+/gb', 'quartet/nlp.quartet.propn', 'report/nlp.report.noun'))))),
#    'local_degree': 1}},
#  'europe': {'gaza': {'h': 29.137931034482772,
#    'total': 65,
#    'degree': 895,
#    'c': 5,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'europe/nlp.europe.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ("'s/nlp.'s.part",
#       ('+/gb',
#        'humanitarian/nlp.humanitarian.adj',
#        'situation/nlp.situation.noun'),
#       'gaza/nlp.gaza.propn'))),
#    'local_degree': 10},
#   "gaza 's humanitarian situation": {'h': 29.137931034482772,
#    'total': 65,
#    'degree': 895,
#    'c': 5,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'europe/nlp.europe.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ("'s/nlp.'s.part",
#       ('+/gb',
#        'humanitarian/nlp.humanitarian.adj',
#        'situation/nlp.situation.noun'),
#       'gaza/nlp.gaza.propn'))),
#    'local_degree': 1},
#   'humanitarian situation': {'h': 29.137931034482772,
#    'total': 65,
#    'degree': 895,
#    'c': 5,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'europe/nlp.europe.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ("'s/nlp.'s.part",
#       ('+/gb',
#        'humanitarian/nlp.humanitarian.adj',
#        'situation/nlp.situation.noun'),
#       'gaza/nlp.gaza.propn'))),
#    'local_degree': 1},
#   "for gaza 's humanitarian situation": {'h': 29.137931034482772,
#    'total': 65,
#    'degree': 895,
#    'c': 5,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'europe/nlp.europe.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ("'s/nlp.'s.part",
#       ('+/gb',
#        'humanitarian/nlp.humanitarian.adj',
#        'situation/nlp.situation.noun'),
#       'gaza/nlp.gaza.propn'))),
#    'local_degree': 1}},
#  'brazilian president': {'carrying out': {'h': 0.0,
#    'total': 0,
#    'degree': 26,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'brazilian/nlp.brazilian.adj', 'president/nlp.president.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('carrying_out/nlp.carry.verb+nlp.out.part',
#       ('+/gb',
#        'a/nlp.a.det',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'massacre/nlp.massacre.propn',
#         'gaza/nlp.gaza.propn'))))),
#    'local_degree': 1},
#   'massacre': {'h': 0.0,
#    'total': 0,
#    'degree': 26,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'brazilian/nlp.brazilian.adj', 'president/nlp.president.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('carrying_out/nlp.carry.verb+nlp.out.part',
#       ('+/gb',
#        'a/nlp.a.det',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'massacre/nlp.massacre.propn',
#         'gaza/nlp.gaza.propn'))))),
#    'local_degree': 1},
#   'carrying out a massacre in gaza': {'h': 0.0,
#    'total': 0,
#    'degree': 26,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'brazilian/nlp.brazilian.adj', 'president/nlp.president.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('carrying_out/nlp.carry.verb+nlp.out.part',
#       ('+/gb',
#        'a/nlp.a.det',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'massacre/nlp.massacre.propn',
#         'gaza/nlp.gaza.propn'))))),
#    'local_degree': 1},
#   'gaza': {'h': 0.0,
#    'total': 0,
#    'degree': 26,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'brazilian/nlp.brazilian.adj', 'president/nlp.president.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('carrying_out/nlp.carry.verb+nlp.out.part',
#       ('+/gb',
#        'a/nlp.a.det',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'massacre/nlp.massacre.propn',
#         'gaza/nlp.gaza.propn'))))),
#    'local_degree': 10},
#   'of carrying out a massacre in gaza': {'h': 0.0,
#    'total': 0,
#    'degree': 26,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'brazilian/nlp.brazilian.adj', 'president/nlp.president.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('carrying_out/nlp.carry.verb+nlp.out.part',
#       ('+/gb',
#        'a/nlp.a.det',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'massacre/nlp.massacre.propn',
#         'gaza/nlp.gaza.propn'))))),
#    'local_degree': 1},
#   'a massacre in gaza': {'h': 0.0,
#    'total': 0,
#    'degree': 26,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'brazilian/nlp.brazilian.adj', 'president/nlp.president.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('carrying_out/nlp.carry.verb+nlp.out.part',
#       ('+/gb',
#        'a/nlp.a.det',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'massacre/nlp.massacre.propn',
#         'gaza/nlp.gaza.propn'))))),
#    'local_degree': 1},
#   'massacre in gaza': {'h': 0.0,
#    'total': 0,
#    'degree': 26,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'brazilian/nlp.brazilian.adj', 'president/nlp.president.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('carrying_out/nlp.carry.verb+nlp.out.part',
#       ('+/gb',
#        'a/nlp.a.det',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'massacre/nlp.massacre.propn',
#         'gaza/nlp.gaza.propn'))))),
#    'local_degree': 1}},
#  'islamic jihad': {'gaza escalation': {'h': 0.0,
#    'total': 0,
#    'degree': 30,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'islamic/nlp.islamic.propn', 'jihad/nlp.jihad.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb', 'gaza/nlp.gaza.propn', 'escalation/nlp.escalation.noun'))),
#    'local_degree': 1},
#   'gaza': {'h': 0.0,
#    'total': 0,
#    'degree': 30,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'islamic/nlp.islamic.propn', 'jihad/nlp.jihad.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb', 'gaza/nlp.gaza.propn', 'escalation/nlp.escalation.noun'))),
#    'local_degree': 10},
#   'for gaza escalation': {'h': 0.0,
#    'total': 0,
#    'degree': 30,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'islamic/nlp.islamic.propn', 'jihad/nlp.jihad.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb', 'gaza/nlp.gaza.propn', 'escalation/nlp.escalation.noun'))),
#    'local_degree': 1},
#   'escalation': {'h': 0.0,
#    'total': 0,
#    'degree': 30,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'islamic/nlp.islamic.propn', 'jihad/nlp.jihad.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb', 'gaza/nlp.gaza.propn', 'escalation/nlp.escalation.noun'))),
#    'local_degree': 1}}}

# %% [markdown]
# ## Two Actors

# %%
def syn_label(syn_id):
    return hg.get_label(syn_id)

def mentions_intersection(actors):
    intersection = None
    for actor in actors:
        concepts = set(entities[actor]['mentions'].keys())
        if intersection is None:
            intersection = concepts
        else:
            intersection &= concepts
    return intersection


def mentions_outside(actor, concepts):
    return set(entities[actor]['mentions'].keys()).difference(concepts)


def actors_from_concepts(concepts):
    actors = {}
    for concept in concepts:
        h = entities[concept]['h']
        for actor in entities[concept]['mentioned_by']:
            if actor in actors:
                if actors[actor] > h:
                    actors[actor] = h
            else:
                actors[actor] = h
    return actors


def show_by_h(concepts, decreasing=True):
    concepts_h = {}
    for concept in concepts:
        concepts_h[concept] = entities[concept]['h']

    sorted_h = sorted(concepts_h.items(), key=operator.itemgetter(1), reverse=decreasing)

    for concept, h in sorted_h:
        print('%s [%s]' % (syn_label(concept), h))


def metrics_with_similarities(concept, actor1, actor2):
    m = metrics(concept)
    sim1 = hs.similarity(actor1, concept)
    sim2 = hs.similarity(actor2, concept)
    m['similarity1'] = sim1
    m['similarity2'] = sim2
    if sim1 > 0 and sim2 > 0:
        m['sim_ratio'] = sim1 / sim2
        m['log_sim_ratio'] = math.log(sim1 / sim2)
    else:
        m['sim_ratio'] = 0
        m['log_sim_ratio'] = 0
    return m


actor1 = syn_id('russia')
actor2 = syn_id('china')

actor1_name = hg.get_label(actor1)
actor2_name = hg.get_label(actor2)

inter = mentions_intersection([actor1, actor2])
actor1_only = mentions_outside(actor1, inter)
actor2_only = mentions_outside(actor2, inter)
common_actors = actors_from_concepts(inter)

data = {'actors': [actor1_name, actor2_name],
        'common_concepts': {},
        'individual_concepts': {actor1_name: {}, actor2_name: {}},
        'common_actors': {}}

for concept in inter:
    data['common_concepts'][syn_label(concept)] = metrics_with_similarities(concept, actor1, actor2)

for concept in actor1_only:
    if entities[concept]['h'] > 1.:
        data['individual_concepts'][actor1_name][syn_label(concept)] = metrics_with_similarities(concept, actor1, actor2)

for concept in actor2_only:
    if entities[concept]['h'] > 1.:
        data['individual_concepts'][actor2_name][syn_label(concept)] = metrics_with_similarities(concept, actor1, actor2)
        
for actor in common_actors:
    if entities[concept]['h'] > 1.:
        data['individual_concepts'][actor2_name][syn_label(concept)] = metrics(concept)

for actor in common_actors:
    data['common_actors'][syn_label(actor)] = metrics(concept)

with open('china-russia.json', 'wt') as out:
    res = j.dump(data, out, sort_keys=False, indent=4, separators=(',', ': '))

print('INTER')
show_by_h(inter, decreasing=False)
print()

print(actor1)
show_by_h(actor1_only)
print()

print(actor2)
show_by_h(actor2_only)
print()

print('COMMON_ACTORS')
show_actors_by_h(common_actors, decreasing=False)
print()
# Out:
# INTER
# no proof [1.7999999999999998]
# vietnam [2.0]
# own interests [2.0]
# to consider [2.0]
# infected with [3.0]
# natural gas [3.0]
# doubts [3.0]
# has detained [3.2]
# missile system [3.571428571428571]
# workings [4.0]
# proxy [4.0]
# proofs [4.499999999999999]
# kerry [4.5]
# warships [4.571428571428571]
# naval [5.333333333333333]
# no plans [5.999999999999999]
# submarine [6.230769230769231]
# should be [6.4]
# found in [6.4]
# cutest [6.4]
# to attack [7.0]
# air force [7.0]
# 3,000 [7.0]
# resolutions [7.999999999999998]
# selves [8.0]
# aircraft carrier [8.066666666666666]
# mh17 [8.257142857142858]
# 2020 [8.894736842105262]
# drills [8.999999999999998]
# last month [8.999999999999998]
# defenses [9.090909090909088]
# exercising [9.941176470588234]
# as it [9.999999999999996]
# nukes [11.842105263157894]
# violating [12.249999999999998]
# has killed [12.959999999999992]
# tensions [13.235294117647058]
# zika [13.333333333333329]
# summit [14.0]
# investigations [14.28571428571428]
# united states [14.2972972972973]
# activists [14.44]
# internets [15.11428571428572]
# explosives [15.125]
# climates [15.201005025125637]
# bombed [15.558979808714119]
# aircrafts [16.025641025641033]
# requesting [16.133333333333333]
# turkeys [16.562939297124597]
# protesting [17.2857142857143]
# viruses [17.857142857142865]
# march [18.181818181818173]
# ukraine [19.535420098846735]
# righted [19.6122448979592]
# sanctions [19.736842105263158]
# australia [19.800000000000008]
# militaries [20.45454545454545]
# zoning [20.63157894736841]
# seas [20.790393013100427]
# russia [21.070100902814698]
# seized [21.16000000000001]
# japan [22.04999999999999]
# korean [22.27272727272726]
# tying [22.442622950819654]
# suspected [23.018264840182628]
# korea [23.333333333333307]
# agreements [24.499999999999986]
# offic­ials [24.49999999999999]
# north korea [24.89655172413795]
# powering [27.37894736842106]
# iran [28.95876288659788]
# gases [29.400000000000002]
# militants [29.405727923627705]
# casing [30.422222222222224]
# oils [31.268907563025206]
# the country [32.666666666666686]
# russian [33.65369649805452]
# planing [34.7222222222222]
# troop [39.47407407407411]
# securities [40.01666666666666]
# china [41.86632124352339]
# warring [42.349056603773505]
# bordering [42.37089201877937]
# airing [42.372881355932236]
# syria [48.510403397027446]
# islamic [53.78151260504214]
# countrys [59.22064056939487]
#
# russia/syn11969
# striking [40.969696969696955]
# threating [40.909090909090956]
# isis [36.85955056179771]
# eu [36.74732334047116]
# uk [34.179775280898895]
# syrian [33.843373493975896]
# timed [32.013333333333335]
# will be [31.99999999999998]
# rebels [31.867469879518037]
# armies [31.13513513513515]
# killed in [30.80530973451327]
# assad [30.42105263157893]
# evidences [29.454545454545443]
# asylum [27.523809523809533]
# france [25.30630630630631]
# schooling [25.1304347826087]
# policing [24.337620578778182]
# raids [24.008547008546987]
# weaponed [23.999999999999982]
# conflicts [23.862385321100927]
# in syria [23.17021276595745]
# air strikes [23.058823529411757]
# qaeda [23.047619047619065]
# crises [23.02739726027399]
# aiding [22.55151515151519]
# islamist [22.533333333333328]
# arming [22.413333333333345]
# chief [22.090909090909104]
# spying [22.043478260869573]
# security forces [21.428571428571427]
# european [21.16000000000001]
# egypt [20.51162790697672]
# oppositions [20.24999999999998]
# partying [19.173913043478272]
# jets [19.058823529411747]
# basing [18.843137254901972]
# embassy [18.692307692307697]
# putin [18.612403100775193]
# carried out [18.181818181818173]
# theresa [18.0]
# regimes [18.0]
# united [18.0]
# nato [17.753623188405786]
# afghanistan [17.63999999999999]
# first time [17.19047619047619]
# pressures [17.19047619047619]
# probe [16.666666666666657]
# aleppo [16.558620689655168]
# yemen [15.817275747508305]
# snowden [15.754098360655746]
# ceasefire [15.51063829787235]
# massed [15.384615384615378]
# trials [14.727272727272728]
# airstrikes [14.537634408602143]
# damascus [14.53488372093023]
# bombings [14.343283582089565]
# obama [14.086956521739115]
# that it [14.0]
# peace talks [13.761904761904765]
# supplying [13.564102564102566]
# moscow [13.564102564102562]
# régions [13.5]
# satellite [13.5]
# cuba [13.235294117647058]
# greece [12.902439024390244]
# networked [12.8]
# would be [12.736842105263165]
# washington [12.600000000000003]
# tuesday [12.570247933884303]
# warnings [12.249999999999998]
# termed [11.999999999999996]
# bbc [11.999999999999996]
# cupping [11.999999999999996]
# debts [11.56]
# chemical attack [11.266666666666664]
# fleeing [11.266666666666664]
# eastern ukraine [10.888888888888888]
# guarding [10.888888888888888]
# terrorist attack [10.888888888888888]
# futures [10.714285714285714]
# jordan [10.714285714285712]
# offensives [10.285714285714285]
# was killed [10.285714285714285]
# mines [10.285714285714285]
# helicopter [10.285714285714285]
# international law [10.285714285714283]
# breach [9.999999999999996]
# arctic [9.941176470588234]
# shootings [9.799999999999997]
# a year [9.529411764705882]
# turkish [9.322580645161292]
# siege [9.307692307692307]
# disasters [9.142857142857142]
# contacting [9.0]
# constructions [9.0]
# hezbollah [9.0]
# cease [9.0]
# november [9.0]
# reuters [9.0]
# parliament [8.999999999999998]
# incidents [8.999999999999998]
# crimea [8.68794326241135]
# war crimes [8.396825396825395]
# facilities [8.33333333333333]
# will have [8.33333333333333]
# militia [8.066666666666666]
# crosses [8.0]
# government forces [8.0]
# urges [8.0]
# historic [8.0]
# white house [8.0]
# to use [8.0]
# shifting [8.0]
# icing [7.758620689655173]
# gunmen [7.4081632653061265]
# foiled [7.363636363636364]
# civil war [7.363636363636364]
# interventions [7.363636363636364]
# isis leader [7.363636363636364]
# imaged [7.363636363636364]
# must stop [7.363636363636364]
# piloted [7.347826086956521]
# teamed [7.347826086956521]
# bridges [7.142857142857141]
# police officers [7.117647058823529]
# treaty [7.111111111111111]
# standoff [7.0]
# unprecedented [7.0]
# researched [7.0]
# ambassador [7.0]
# reasoned [7.0]
# withdrawal [6.4]
# plane crash [6.4]
# graves [6.4]
# swiss [6.4]
# airspace [6.249999999999999]
# ballistic [6.2439024390243905]
# sinai [6.230769230769229]
# stationed [6.095238095238095]
# missile test [5.999999999999999]
# to deploy [5.999999999999999]
# mortar [5.999999999999999]
# radars [5.999999999999999]
# deploys [5.999999999999999]
# geneva [5.999999999999999]
# tehran [5.999999999999999]
# conferences [5.999999999999999]
# stadiums [5.999999999999999]
# 24 hours [5.999999999999999]
# truce [5.82758620689655]
# to syria [5.764705882352939]
# kiev [5.553846153846154]
# will keep [5.444444444444445]
# eras [5.444444444444445]
# smuggling [5.444444444444445]
# baghdadi [5.333333333333333]
# islamists [4.999999999999999]
# a week [4.999999999999999]
# monitoring [4.999999999999999]
# affairs [4.999999999999999]
# to prevent [4.999999999999999]
# peninsula [4.999999999999999]
# contracted [4.999999999999999]
# involved in [4.999999999999999]
# will respond [4.999999999999999]
# arsenal [4.999999999999999]
# because it [4.999999999999999]
# traces [4.999999999999999]
# sanctions [4.999999999999999]
# deployment [4.999999999999999]
# a month [4.999999999999999]
# is using [4.999999999999999]
# nears [4.999999999999999]
# deadline [4.999999999999999]
# special forces [4.999999999999999]
# syrian army [4.8]
# idlib [4.571428571428571]
# to ukraine [4.545454545454544]
# syrian government [4.545454545454544]
# chemical arms [4.5]
# in ukraine [4.5]
# extensions [4.5]
# the region [4.5]
# opened fire [4.5]
# us soldiers [4.499999999999999]
# shells [4.499999999999999]
# aggressions [4.499999999999999]
# debris [4.454545454545455]
# earths [4.166666666666666]
# insurgency [4.0]
# accusation [4.0]
# coordinated [4.0]
# terror attack [4.0]
# secretary [4.0]
# downing [4.0]
# to deliver [4.0]
# vows [4.0]
# military base [4.0]
# surge [4.0]
# was carrying [4.0]
# accord [4.0]
# criticisms [4.0]
# us strike [4.0]
# operation in syria [4.0]
# detained by [4.0]
# will consider [4.0]
# strike in syria [4.0]
# fleets [4.0]
# monkeys [4.0]
# border guards [4.0]
# soviet [4.0]
# will build [3.7692307692307696]
# us sanctions [3.666666666666667]
# poland [3.5999999999999996]
# brink [3.5999999999999996]
# to enforce [3.571428571428571]
# shelling [3.571428571428571]
# u.s. military [3.571428571428571]
# to turkey [3.571428571428571]
# flown [3.571428571428571]
# grenade [3.571428571428571]
# representatives [3.0]
# peace conference [3.0]
# celebrations [3.0]
# approvals [3.0]
# will face [3.0]
# past 24 hours [3.0]
# the plane [3.0]
# to include [3.0]
# has agreed [3.0]
# syrian city [3.0]
# trio [3.0]
# loaned [3.0]
# sinai plane crash [3.0]
# the future [3.0]
# invitation [3.0]
# will defend [3.0]
# spokesman [3.0]
# its borders [3.0]
# gps [3.0]
# the internet [3.0]
# suspends [3.0]
# truths [3.0]
# criticises [3.0]
# the right [3.0]
# in crimea [3.0]
# are missing [3.0]
# 3 billion [3.0]
# un resolution [3.0]
# kremlin [3.0]
# to bomb [3.0]
# armenia [3.0]
# asylum applications [3.0]
# intensifies [3.0]
# so called [3.0]
# crash site [3.0]
# to extend [3.0]
# eight others [3.0]
# wells [3.0]
# voiced [3.0]
# anniversary [3.0]
# government troops [3.0]
# telephone [3.0]
# act of terrorism [3.0]
# were found [3.0]
# can use [3.0]
# military exercises [3.0]
# world news [3.0]
# annexation [3.0]
# stalls [2.9999999999999996]
# owes [2.9999999999999996]
# to sell [2.6666666666666665]
# dagestan [2.6666666666666665]
# faiths [2.6666666666666665]
# to attend [2.6666666666666665]
# focuses [2.6666666666666665]
# does not want [2.6666666666666665]
# in may [2.6666666666666665]
# eastern syria [2.6666666666666665]
# blaze [2.2727272727272725]
# cancels [2.0]
# could build [2.0]
# may abandon [2.0]
# could hit [2.0]
# must fulfil [2.0]
# syria 's idlib [2.0]
# are killed [2.0]
# may have killed [2.0]
# was caused [2.0]
# complicit [2.0]
# invites [2.0]
# secretary of state [2.0]
# scorched [2.0]
# syria ’s [2.0]
# shot down is [2.0]
# climbs [2.0]
# will recognise [2.0]
# evading [2.0]
# russian military [2.0]
# syrian conflict [2.0]
# base in syria [2.0]
# airlift [2.0]
# in past 24 hours [2.0]
# a terrorist attack [2.0]
# could jeopardize [2.0]
# would violate [2.0]
# iran missile test [2.0]
# phosphorus [2.0]
# no fly [2.0]
# arrival [2.0]
# not responsible [2.0]
# situation in [2.0]
# compatriots [2.0]
# nuclear arms [2.0]
# fight against [2.0]
# weapons attack [2.0]
# trawler [2.0]
# central asia [2.0]
# muslim world [2.0]
# russian territory [2.0]
# traces of explosives [2.0]
# u.s. officials [2.0]
# intelligence mission [2.0]
# mistral [2.0]
# yanukovych [2.0]
# its influence [2.0]
# military presence [2.0]
# behind chemical attack [2.0]
# peace efforts [2.0]
# deal with us [2.0]
# kuril islands [2.0]
# romania [2.0]
# will act [2.0]
# spyware [2.0]
# air strike in syria [2.0]
# caucasus [2.0]
# hospital strike [2.0]
# by strike [2.0]
# space station [2.0]
# truce deal [2.0]
# is conducting [2.0]
# wo n’t intervene [2.0]
# to resolve [2.0]
# frontline [2.0]
# scraps [2.0]
# 72 [2.0]
# should be done [2.0]
# nukes [2.0]
# should pay [2.0]
# stranded in [2.0]
# self defense [2.0]
# proposed by [2.0]
# estonian [2.0]
# has fallen [2.0]
# cessation [2.0]
# turkish operation in syria [2.0]
# attack helicopters [2.0]
# would consider [2.0]
# hostilities [2.0]
# was investigating [2.0]
# ukraine elections [2.0]
# nemtsov [2.0]
# will attend [2.0]
# has accepted [2.0]
# f-16 [2.0]
# brink of civil war [2.0]
# plane disaster [2.0]
# astronauts [2.0]
# should stay [2.0]
# u.s. policies [2.0]
# escalation [2.0]
# government officials [2.0]
# does n't have [1.7999999999999998]
# cold war [1.7999999999999998]
# will expand [1.7999999999999998]
# to share [1.7999999999999998]
# fishermen [1.7999999999999998]
# to crimea [1.7999999999999998]
# facto [1.7999999999999998]
# blacked [1.7999999999999998]
# syria gas incident caused by rebels ' own chemical arsenal [1.0]
# should push [1.0]
# the black sea crimea region [1.0]
# cut off over crimea [1.0]
# it does n't mind if assad stays or steps down [1.0]
# own mistral warships [1.0]
# iskander m ballistic missile during training exercise [1.0]
# tourists [1.0]
# new uk aircraft carrier convenient target [1.0]
# ukraine 's fugitive president viktor yanukovych asked putin to use russian military in ukraine [1.0]
# to almost $ 2 billion [1.0]
# isis recruiters [1.0]
# back from near ukraine 's eastern border [1.0]
# are imposed [1.0]
# them a terrorist organization [1.0]
# was investigating cross border crime [1.0]
# black sea peninsula 's [1.0]
# ties with washington ria [1.0]
# special forces in egypt interfax [1.0]
# a spy [1.0]
# military force in syria [1.0]
# systems for syria [1.0]
# assad ready to share power with opposition [1.0]
# are claimed by japan [1.0]
# are deeply [1.0]
# in most intense raids [1.0]
# us protecting al qaeda in syria [1.0]
# which lie off japan 's northern coast and are claimed by japan [1.0]
# to get to [1.0]
# he was investigating cross border crime [1.0]
# will not drop [1.0]
# that a us official called preposterous [1.0]
# crisis trio talks [1.0]
# war crimes in former yugoslavia [1.0]
# what it called attempts to undermine peace efforts [1.0]
# syrian army planning offensives on deir al zor raqqa ria [1.0]
# coercing [1.0]
# it could close its airspace to western airlines if new eu sanctions are imposed [1.0]
# sinai plane crash was caused by a terrorist attack [1.0]
# government approval [1.0]
# united states on syria [1.0]
# the arrival of more than 3,000 us soldiers in poland [1.0]
# its neighbors [1.0]
# international community [1.0]
# terrorism | reuters [1.0]
# f-16 fighter jets [1.0]
# should control [1.0]
# ukraine monitors biased [1.0]
# it will defend the rights of its compatriots in crimea after russia gunmen seize parliament [1.0]
# exxon strikes oil [1.0]
# myth serbs [1.0]
# air strikes in syria would be act of aggression without u.n. vote [1.0]
# must become [1.0]
# may have been liquidated [1.0]
# 2021 [1.0]
# us secretary of state john kerry [1.0]
# direct contacts [1.0]
# of ukrainian affairs [1.0]
# satellite images kiev published carry altered time stamps and are from days after the mh17 tragedy [1.0]
# patriot [1.0]
# in response to us strike [1.0]
# ukraine on brink of civil war [1.0]
# un vote [1.0]
# in a temporary lull in fighting declared by the syrian army in some western parts of the country [1.0]
# missile deployment [1.0]
# an act of terror [1.0]
# after traces of explosives were found in debris at crash site [1.0]
# an air strike [1.0]
# registers first case [1.0]
# foils plot [1.0]
# to pay for [1.0]
# to bomb syrian militants [1.0]
# fires iskander m ballistic missile during training exercise [1.0]
# if u.s. supplies lethal aid to ukraine [1.0]
# altering [1.0]
# were n't pointing [1.0]
# its airspace to western airlines [1.0]
# tragedy [1.0]
# air force has not hit civilian targets in syria [1.0]
# it would consider asylum for edward snowden [1.0]
# if assad stays [1.0]
# hurt in blaze on nuclear sub [1.0]
# world war two anniversary celebrations [1.0]
# us missile system breaches [1.0]
# us led air attack in eastern syria [1.0]
# ukraine must become a federation allowing regional autonomy [1.0]
# by international community not ukraine [1.0]
# syrian army troops [1.0]
# one north korean fisherman was killed [1.0]
# after us led strikes kill regime troops [1.0]
# conflict with turkey iran [1.0]
# regional autonomy [1.0]
# ready to move fast to fix ties with washington ria [1.0]
# hezbollah not a terrorist group:''we maintain contacts and relations with them because we do not consider them a terrorist organization [1.0]
# 24 targets [1.0]
# the syrian government has agreed in principle to attend an international peace conference proposed by russia and the us [1.0]
# turkey shot down plane for is oil [1.0]
# soviet era military bases [1.0]
# to share power with opposition [1.0]
# is suspending [1.0]
# turkish leadership involved in illegal oil trade with isis [1.0]
# air units [1.0]
# them terrorist organization [1.0]
# its jets and syrian army troops [1.0]
# to travel to [1.0]
# detained by north korea [1.0]
# to support ceasefire [1.0]
# dissatisfied [1.0]
# air attack in eastern syria [1.0]
# to greece [1.0]
# military mission in ukraine is there at kiev 's request [1.0]
# using coordinates supplied by “ opposition representatives [1.0]
# power with opposition [1.0]
# east of aleppo syria [1.0]
# to normalize [1.0]
# money to pay for gas within a week [1.0]
# solely to blame for [1.0]
# at crash site [1.0]
# ukraine ’s debt [1.0]
# airbus [1.0]
# illegal drugs [1.0]
# opposition representatives [1.0]
# serbs [1.0]
# the syrian government has agreed in principle to attend an international peace conference proposed by russia and the us and criticised what it called attempts to undermine peace efforts [1.0]
# the black sea peninsula 's annexation [1.0]
# 300 militants [1.0]
# image editor [1.0]
# arms treaty concerns [1.0]
# of more than 3,000 us soldiers in poland [1.0]
# nato troop rotations [1.0]
# it loses billions to oil slump sanctions [1.0]
# a321 [1.0]
# may be cut [1.0]
# separatist elections [1.0]
# monkey with grenade [1.0]
# damascus act of terrorism | reuters [1.0]
# eu criticism over ukraine shift inappropriate [1.0]
# convenient target [1.0]
# response to us strike [1.0]
# islamist insurgency chief [1.0]
# army plan [1.0]
# international peace conference [1.0]
# kiev published [1.0]
# when russian border guards opened fire on a fishing trawler [1.0]
# greenpeace activists ' ship [1.0]
# yemen ambassador was not shot [1.0]
# all st petersburg metro bombing suspects [1.0]
# construction stopped at world cup stadium in city of samara no reason given [1.0]
# us inviting terror attack by de facto support for terrorism in syria [1.0]
# syria ceasefire under threat after us led strikes kill regime troops [1.0]
# no fly zone over syria would be illegal [1.0]
# only proxy talks [1.0]
# should find [1.0]
# isis leader abu bakr al baghdadi [1.0]
# new uk aircraft carrier a convenient target bbc news [1.0]
# phosphorus bombs [1.0]
# slump [1.0]
# if new eu sanctions are imposed [1.0]
# downed jet [1.0]
# missile systems for syria will deter intervention [1.0]
# to undermine [1.0]
# probe should be done [1.0]
# deploying south to ashuluk for drills [1.0]
# new tragedies [1.0]
# standoff since the cold war [1.0]
# gps stations [1.0]
# us gps stations [1.0]
# security cameras [1.0]
# it will be a month before de escalation zones are fully established as syrian opposition voices concern [1.0]
# crash in sinai [1.0]
# time stamps [1.0]
# air link with egypt will be restored soon [1.0]
# stranded in ice [1.0]
# foreign minister sergey lavrov and u.s. secretary of state john kerry have held a telephone discussion on the syrian conflict [1.0]
# good faith talks with ukraine over the $ 3 billion debt it owes [1.0]
# unperturbed by [1.0]
# kiev 's request [1.0]
# telephone discussion on the syrian conflict [1.0]
# could close [1.0]
# which lie off japan 's northern coast [1.0]
# a year ago [1.0]
# downing of plane [1.0]
# mission teams [1.0]
# iran talks [1.0]
# would worsen [1.0]
# future of truce in doubt [1.0]
# was not shot [1.0]
# back from near 's [1.0]
# it may abandon space station by 2020 [1.0]
# soldier who killed armenian family [1.0]
# to nato troop rotations in east [1.0]
# can deploy [1.0]
# syria airstrike an aggression by us [1.0]
# links with egypt [1.0]
# nato complicit in downing of plane [1.0]
# syria cease fire [1.0]
# to prevent mid air incidents over syria in response to us strike [1.0]
# it 's compiled 100-page report blaming syrian rebels for a chemical weapons attack [1.0]
# ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region [1.0]
# opens fire in dagestan [1.0]
# it will respond to nato troop rotations in east [1.0]
# in south [1.0]
# as a threat to its own security [1.0]
# talks with united states on syria [1.0]
# foreign minister sergey lavrov and u.s. secretary of state john kerry [1.0]
# 2 mission teams [1.0]
# eu relations facing moment of truth over ukraine [1.0]
# led kill [1.0]
# turkey should pay compensation for downed jet [1.0]
# no direct contacts yet [1.0]
# urges ceasefire [1.0]
# teams up with turkey for first time to bomb syrian militants [1.0]
# kiev forces [1.0]
# hostilities in syria [1.0]
# to normalize situation in syria 's aleppo [1.0]
# ukraine should find money to pay for gas within a week [1.0]
# its controversial contract [1.0]
# one of its airstrikes in syria [1.0]
# the mh17 tragedy [1.0]
# f-16 fighter jets and [1.0]
# fugitive president [1.0]
# st petersburg suspects [1.0]
# joint isis operations with france [1.0]
# a claim that a us official called preposterous [1.0]
# damascus act [1.0]
# turkish troops entrenched in syria [1.0]
# crimea power plant [1.0]
# over the future of the black sea crimea region [1.0]
# on slavyansk [1.0]
# support of terrorism [1.0]
# to deploy security forces to syria [1.0]
# the worst standoff since the cold war [1.0]
# its attack helicopters [1.0]
# are claimed by [1.0]
# de facto support for terrorism in syria [1.0]
# other states ' affairs [1.0]
# in some western parts of the country [1.0]
# is struggling [1.0]
# are from [1.0]
# isis spokesman mohammad al adnani [1.0]
# as its jets and syrian army troops fight off an is offensive in the historic syrian city [1.0]
# were taking [1.0]
# lull [1.0]
# will honor [1.0]
# using f-16 fighter jets and patriot missiles from jordan [1.0]
# 2 billion [1.0]
# in fighting to aleppo [1.0]
# missile for first time [1.0]
# inviting terror attack [1.0]
# from snowden [1.0]
# could destabilize [1.0]
# all of aleppo has fallen to syrian government control [1.0]
# are from days after the mh17 tragedy [1.0]
# could be hurt [1.0]
# us led strikes kill [1.0]
# near on syria flights [1.0]
# not responsible for strike on school in syria 's idlib [1.0]
# within a week [1.0]
# selling gas [1.0]
# any attempt to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan would violate international law [1.0]
# are fully established [1.0]
# to attack chemical arms facility [1.0]
# for 72 hours [1.0]
# mulls [1.0]
# loan terms [1.0]
# four militants killed in dagestan siege [1.0]
# more ways [1.0]
# days after the mh17 tragedy [1.0]
# it will recognise the results of controversial separatist elections in eastern ukraine [1.0]
# new us sanctions leave relations in uncharted territory | world news [1.0]
# openly tourists [1.0]
# after the u.s. military carried out an air strike on assad militia last month [1.0]
# 15 hurt in blaze on nuclear sub [1.0]
# obama hurting himself by canceling summit over snowden [1.0]
# it will have armed drones by 2020 [1.0]
# truce to hold [1.0]
# kazan crash [1.0]
# with bombs [1.0]
# strikes would harm [1.0]
# 100-page report blaming syrian rebels for a chemical weapons attack [1.0]
# so called islamic state [1.0]
# embassy naval base in syria working as normal [1.0]
# eu should be ashamed over sanctions [1.0]
# cut over crimea [1.0]
# syria 's aleppo [1.0]
# eston kohver for undercover intelligence mission [1.0]
# selling missiles to syria [1.0]
# viktor [1.0]
# u.s. backs party of war in kiev [1.0]
# is protecting [1.0]
# fleet of warships [1.0]
# eu relations [1.0]
# acting in muslim world like monkey with grenade [1.0]
# as civilians flee bombs [1.0]
# no country [1.0]
# islamic state [1.0]
# u.s. missiles in poland [1.0]
# a move that could ease tension in the worst east west standoff since the cold war [1.0]
# off australia [1.0]
# eu sanctions [1.0]
# syria to ship chemical arms as civilians flee bombs [1.0]
# as syrian opposition voices concern [1.0]
# truce extended for 72 hours in aleppo latakia [1.0]
# may aggravate crisis [1.0]
# armenian family [1.0]
# out of ukrainian affairs [1.0]
# plane crash in sinai was terrorist attack vows vengeance [1.0]
# shelling of its embassy in damascus act of terrorism | reuters [1.0]
# for scientists stranded in ice [1.0]
# protest of ukraine sanctions [1.0]
# syrian army planning offensives [1.0]
# by canceling summit over snowden [1.0]
# insurgency chief [1.0]
# eston [1.0]
# entrenched in syria [1.0]
# to oil slump sanctions [1.0]
# it could sell missile defense systems to turkey [1.0]
# u.s georgian military exercises [1.0]
# anniversary celebrations [1.0]
# source gas turbines [1.0]
# in schools [1.0]
# china ’s missile deployment [1.0]
# tension in the worst east west standoff since the cold war [1.0]
# us astronauts could be hurt by ukraine sanctions [1.0]
# attack in eastern syria [1.0]
# altered time stamps [1.0]
# ceasefire under threat [1.0]
# forbids [1.0]
# government forces in syria [1.0]
# by march [1.0]
# oddest [1.0]
# support for terrorism in syria [1.0]
# it may have killed islamic state leader al baghdadi [1.0]
# missiles in poland [1.0]
# world cup stadium in city of samara [1.0]
# an invitation [1.0]
# ballistic missile during training exercise [1.0]
# its airstrikes in syria [1.0]
# a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan [1.0]
# school in syria 's idlib [1.0]
# caused by rebels ' own chemical arsenal [1.0]
# some western parts of the country [1.0]
# already shaky [1.0]
# following an official request from kiev [1.0]
# no reason given [1.0]
# to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan [1.0]
# are deeply worried [1.0]
# ashuluk for drills [1.0]
# satellite images kiev published carry altered time stamps [1.0]
# mortar shells [1.0]
# new tragedies possible if u.s. supplies lethal aid to ukraine [1.0]
# will arrest [1.0]
# well drilled [1.0]
# chemical arsenal [1.0]
# first case [1.0]
# threat from turkey [1.0]
# no fly zone over syria [1.0]
# is fully mobilized [1.0]
# assad ready [1.0]
# in iran talks [1.0]
# fire in dagestan [1.0]
# the rights of its compatriots in crimea [1.0]
# uk aircraft carrier [1.0]
# mulling coal cut off over crimea [1.0]
# it does n't have special forces in egypt interfax [1.0]
# reason given [1.0]
# federation [1.0]
# it will honor its controversial contract to deliver s-300 air defense missile systems to syria [1.0]
# peninsula 's [1.0]
# has not hit [1.0]
# by ukraine sanctions [1.0]
# may aggravate [1.0]
# at nemtsov shooting [1.0]
# kohver [1.0]
# it will keep out of ukrainian affairs [1.0]
# it is struggling to source gas turbines for crimea power plant [1.0]
# in protest of ukraine sanctions [1.0]
# plane crash in sinai [1.0]
# its jets and syrian army troops fight off [1.0]
# de escalation zones [1.0]
# will be restored [1.0]
# pushing world toward new cold war [1.0]
# may not be met [1.0]
# international community not ukraine [1.0]
# in downing of plane [1.0]
# us inviting terror attack [1.0]
# syria hospital strike fake [1.0]
# it has not received asylum application from snowden [1.0]
# without government approval [1.0]
# aid to ukraine [1.0]
# airbus a321 plane over egypt [1.0]
# its own security [1.0]
# inflation could hit 17 % by march [1.0]
# mistral contract [1.0]
# ratcheting up [1.0]
# 29 times [1.0]
# to travel to moscow in may for world war two anniversary celebrations [1.0]
# an international peace conference proposed by russia and the us [1.0]
# despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago [1.0]
# criticism over ukraine shift [1.0]
# eight others injured when russian border guards opened fire on a fishing trawler [1.0]
# u.s. withdrawal from afghanistan would worsen situation ifax [1.0]
# moment of truth over ukraine [1.0]
# putin is fully mobilized to tackle unprecedented threat from turkey [1.0]
# to good faith talks with ukraine over the $ 3 billion debt it owes [1.0]
# working as normal [1.0]
# eastern border [1.0]
# attempts to undermine peace efforts [1.0]
# its embassy in damascus act of terrorism [1.0]
# to halt gas supplies to ukraine mulling coal cut off over crimea [1.0]
# nov. 24 deadline may not be met in iran talks interfax [1.0]
# nov. 24 deadline [1.0]
# terrorist organization [1.0]
# beyond diplomatic ethics [1.0]
# commercial capital [1.0]
# solely to blame for war crimes in former yugoslavia [1.0]
# group:''we [1.0]
# regime troops [1.0]
# criticised what it called attempts to undermine peace efforts [1.0]
# to pay for gas within a week [1.0]
# myths [1.0]
# syria flights [1.0]
# all of aleppo [1.0]
# trade with islamic state [1.0]
# that could ease tension in the worst east west standoff since the cold war [1.0]
# any attempt to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan [1.0]
# damascus act of terrorism [1.0]
# a convenient target [1.0]
# as close [1.0]
# infected with zika virus [1.0]
# temporary lull in fighting [1.0]
# to resolve syria conflict with turkey iran [1.0]
# ukrainian leader [1.0]
# would worsen situation [1.0]
# ukrainian saboteurs [1.0]
# with submarine launched missile for first time [1.0]
# fight off [1.0]
# it will build bridge to crimea [1.0]
# an aggression by us [1.0]
# own security [1.0]
# syria 's assad is ready to share power with opposition [1.0]
# crash investigation [1.0]
# iran missile test does not contravene un resolution [1.0]
# lethal aid to ukraine [1.0]
# armed drones [1.0]
# on friday ria [1.0]
# the $ 3 billion debt it owes [1.0]
# registers [1.0]
# of intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# to enforce syria cease fire [1.0]
# steps down [1.0]
# sinai plane disaster was an act of terror after traces of explosives were found in debris at crash site [1.0]
# preposterous [1.0]
# vows vengeance [1.0]
# cross border crime [1.0]
# because we do not consider them a terrorist organization [1.0]
# resolution proposal unacceptable [1.0]
# its compatriots in crimea [1.0]
# stamp [1.0]
# mid air incidents [1.0]
# turkey iran [1.0]
# within their borders [1.0]
# for climate research [1.0]
# toward new cold war [1.0]
# for world war two anniversary celebrations [1.0]
# ready to share power with opposition [1.0]
# its military presence on the kuril islands which lie off japan 's northern coast and are claimed by japan [1.0]
# it had pulled some troops back from near ukraine 's eastern border a move that could ease tension in the worst east west standoff since the cold war [1.0]
# crimean [1.0]
# terrorist group:''we [1.0]
# aleppo syria [1.0]
# withdrawal from afghanistan [1.0]
# air links with egypt [1.0]
# gunman opens fire in dagestan focus of isis recruiters [1.0]
# controversial separatist elections in eastern ukraine [1.0]
# plane for [1.0]
# has not received [1.0]
# supplied by “ opposition representatives [1.0]
# us satellite photos [1.0]
# contacts and relations with them [1.0]
# us sanctions extension against tehran could jeopardize accord [1.0]
# militants seized with bomb in south [1.0]
# a surge of violence in its former commercial capital [1.0]
# all st petersburg suspects [1.0]
# isis operations [1.0]
# to halt a surge of violence in its former commercial capital [1.0]
# u.s. withdrawal from afghanistan would worsen situation [1.0]
# it is drafting roadmap to resolve syria conflict with turkey iran [1.0]
# ukraine truce to hold [1.0]
# ukraine monitors [1.0]
# to source gas turbines for crimea power plant [1.0]
# it may reopen soviet era military bases in cuba and vietnam [1.0]
# oil smuggling [1.0]
# us astronauts [1.0]
# it would not hand back crimea to ukraine despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago [1.0]
# sinai plane disaster [1.0]
# u.s. talks over arms treaty concerns [1.0]
# a month before de escalation zones are fully established as syrian opposition voices concern [1.0]
# does n't mind [1.0]
# international monitors [1.0]
# in principle [1.0]
# 24 targets in syria [1.0]
# experts can examine syrian base [1.0]
# ukraine ’s natural gas debt climbed to almost $ 2 billion and signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region [1.0]
# syrian lull [1.0]
# as civilians [1.0]
# uncharted territory [1.0]
# estonian police officer [1.0]
# sanctions ' destructive will act in own interests [1.0]
# four militants [1.0]
# ukraine election may aggravate crisis [1.0]
# one of its airstrikes in syria killed isis spokesman mohammad al adnani a claim that a us official called preposterous [1.0]
# one north korean fisherman [1.0]
# kerry ’s accusation [1.0]
# is offensive [1.0]
# civilian targets [1.0]
# it has detained ukrainian saboteurs in crimea [1.0]
# friday ria [1.0]
# new uk aircraft carrier a convenient target [1.0]
# party of war in kiev [1.0]
# pilot of kazan crash [1.0]
# nuclear inf treaty [1.0]
# aggression by us [1.0]
# at kiev 's request [1.0]
# ancient palmyra [1.0]
# foreign minister sergey lavrov [1.0]
# controversial separatist elections [1.0]
# relations in uncharted territory [1.0]
# will resume selling gas to ukraine following an official request from kiev [1.0]
# gas incident [1.0]
# yacht detained by north korea [1.0]
# sanctions over the black sea peninsula 's annexation [1.0]
# threat to its own security [1.0]
# a fishing trawler [1.0]
# its strikes [1.0]
# wills [1.0]
# ukraine crisis trio talks [1.0]
# unperturbed by china ’s missile deployment [1.0]
# ukrainian affairs [1.0]
# ashamed over sanctions [1.0]
# would not hand back [1.0]
# reduce oil smuggling [1.0]
# planned in [1.0]
# missile systems for syria [1.0]
# a temporary lull in fighting declared by the syrian army in some western parts of the country [1.0]
# undercover [1.0]
# arms treaty [1.0]
# international monitors should stay in ukraine where 2 mission teams are missing [1.0]
# force in syria [1.0]
# extension against tehran [1.0]
# one of its attack helicopters [1.0]
# satellite photos [1.0]
# its jets [1.0]
# facing moment of truth over ukraine [1.0]
# 300 militants are killed as its jets and syrian army troops fight off an is offensive in the historic syrian city [1.0]
# airlift is planned for scientists stranded in ice [1.0]
# greenpeace activists ' ship was carrying illegal drugs [1.0]
# syrian army fulfil truce deal [1.0]
# had pulled [1.0]
# intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# is drafting roadmap [1.0]
# evidence of war crimes found in east of aleppo syria [1.0]
# bomb did down airbus a321 plane over egypt last month [1.0]
# had put the plane [1.0]
# ready to consider more ways to normalize situation in syria 's aleppo [1.0]
# vengeance [1.0]
# ukraine ’s natural gas debt climbed to almost $ 2 billion [1.0]
# ukraine has violated loan terms no decision on repayment [1.0]
# detained estonian police officer is a spy | moscow holds eston kohver for undercover intelligence mission while tallinn says he was investigating cross border crime [1.0]
# it owes [1.0]
# government ifax [1.0]
# it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month [1.0]
# would violate treaty [1.0]
# no direct contacts yet between white house and kremlin [1.0]
# it hit islamic state with submarine launched missile for first time [1.0]
# must fulfil mistral contract [1.0]
# u.s. is conducting scorched earth policy [1.0]
# missile during training exercise [1.0]
# cuba and vietnam [1.0]
# for edward snowden [1.0]
# russia gunmen [1.0]
# one of its attack helicopters crashes [1.0]
# air defense system [1.0]
# situation in syria 's aleppo [1.0]
# cynical [1.0]
# kills 300 militants in syria in most intense raids yet [1.0]
# support in syria [1.0]
# where 2 mission teams are missing [1.0]
# to halt [1.0]
# s-300 air defense missile systems [1.0]
# return money agency [1.0]
# trial in armenia [1.0]
# kazan [1.0]
# dealer bout [1.0]
# nuclear sub [1.0]
# unprecedented threat from turkey [1.0]
# dissatisfied with u.s. talks over arms treaty concerns [1.0]
# lull in fighting [1.0]
# will resume selling [1.0]
# to ship [1.0]
# white phosphorus bombs [1.0]
# as close to civil war [1.0]
# it views the arrival of more than 3,000 us soldiers in poland as a threat to its own security [1.0]
# supplies may be cut [1.0]
# the future of the black sea crimea region [1.0]
# by a terrorist attack [1.0]
# government control [1.0]
# state computer networks [1.0]
# un resolution proposal ' unacceptable [1.0]
# ceasefire deal [1.0]
# destructive [1.0]
# in ukraine where 2 mission teams are missing [1.0]
# a terrorist group:''we [1.0]
# samara [1.0]
# tallinn [1.0]
# coal cut off over crimea [1.0]
# chemical arms facility [1.0]
# army troops [1.0]
# killed in dagestan siege [1.0]
# can not order crimean ' self defense units back to base [1.0]
# an invitation to travel to moscow in may for world war two anniversary celebrations [1.0]
# it is suspending deal with u.s. to prevent mid air incidents over syria in response to us strike [1.0]
# that they will not drop sanctions over the black sea peninsula 's annexation a year ago [1.0]
# reports of syria hospital strike fake [1.0]
# some troops [1.0]
# images carry [1.0]
# a federation [1.0]
# arms facility [1.0]
# interfax [1.0]
# no plans to sell air defense system to syria agency [1.0]
# in own interests [1.0]
# kiev altered us satellite photos with image editor | satellite images kiev published carry altered time stamps and are from days after the mh17 tragedy [1.0]
# request from kiev [1.0]
# they are deeply worried by turkish operation in syria [1.0]
# pilot of kazan crash had put the plane into nosedive [1.0]
# it may act alone to enforce syria cease fire [1.0]
# military mission in ukraine [1.0]
# to move fast to fix ties with washington ria [1.0]
# north korea 's leader [1.0]
# to consider more ways to normalize situation in syria 's aleppo [1.0]
# may act [1.0]
# proposed by russia and the us [1.0]
# an air strike on assad militia [1.0]
# who killed armenian family [1.0]
# f-16 fighter jets and patriot missiles from jordan [1.0]
# u.s. should push ukrainian leader to halt violence [1.0]
# relations with them [1.0]
# to deliver s-300 air defense missile systems to syria [1.0]
# on brink of civil war [1.0]
# cleared mines [1.0]
# deir al zor raqqa ria [1.0]
# to extend syrian lull in fighting to aleppo [1.0]
# detained is [1.0]
# military agreement near with u.s. on syria flights [1.0]
# its planes are carrying military goods to syria [1.0]
# declared by the syrian army in some western parts of the country [1.0]
# turkish leadership [1.0]
# its jets bombed 24 targets in syria tuesday using coordinates supplied by “ opposition representatives [1.0]
# party in kiev [1.0]
# gay athletes [1.0]
# kerry ’s accusation moscow is lying “ beyond diplomatic ethics [1.0]
# us airstrike war crime [1.0]
# worst standoff since the cold war [1.0]
# us missile system breaches nuclear inf treaty [1.0]
# could ease [1.0]
# u.s. withdrawal from afghanistan [1.0]
# islamic state leader al baghdadi [1.0]
# ifax [1.0]
# syrian government and opposition in talks ifax [1.0]
# cynical u.s. policy pushing world toward new cold war [1.0]
# a sign of intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# to use russian military in ukraine [1.0]
# climate research [1.0]
# into nosedive [1.0]
# will deter intervention [1.0]
# u.s. coerces kiev and violates arms treaties [1.0]
# open to good faith talks with ukraine over the $ 3 billion debt it owes [1.0]
# flee bombs [1.0]
# meddling in [1.0]
# most intense raids [1.0]
# over the $ 3 billion debt it owes [1.0]
# no discrimination for gay athletes [1.0]
# western parts [1.0]
# planned in geneva interfax [1.0]
# no country can use military force in syria without government approval [1.0]
# to halt violence [1.0]
# mh17 crash investigation stalled [1.0]
# it will consider financial help to greece [1.0]
# states on syria [1.0]
# diplomatic ethics [1.0]
# it will have radar evading nukes by 2021 [1.0]
# to include aleppo in a temporary lull in fighting declared by the syrian army in some western parts of the country a sign of intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# to sell air defense system to syria [1.0]
# could sell [1.0]
# russia gunmen seize parliament [1.0]
# historic syrian city [1.0]
# s-300 systems [1.0]
# source gas turbines for crimea power plant [1.0]
# some western parts [1.0]
# zone over syria [1.0]
# for a chemical weapons attack [1.0]
# it 's set to deploy security forces to syria [1.0]
# syrian opposition voices [1.0]
# national governments [1.0]
# russia and the us [1.0]
# ukraine sanctions [1.0]
# 40 mortar shells hit russian territory on friday ria [1.0]
# only proxy talks on syria planned in geneva interfax [1.0]
# cessation of hostilities in syria violated 29 times in past 24 hours [1.0]
# altered [1.0]
# a threat to its own security [1.0]
# submarine launched missile for first time [1.0]
# mission in ukraine [1.0]
# will deter [1.0]
# of aleppo [1.0]
# coordinates supplied by “ opposition representatives [1.0]
# dozens of government troops [1.0]
# us satellite photos with image editor [1.0]
# it will expand its military presence on the kuril islands which lie off japan 's northern coast and are claimed by japan [1.0]
# declared by [1.0]
# talks were taking place to include aleppo in a temporary lull in fighting declared by the syrian army in some western parts of the country a sign of intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# acting in [1.0]
# entrenched in [1.0]
# it could build its own mistral warships [1.0]
# to ashuluk for drills [1.0]
# tackling [1.0]
# its own mistral warships [1.0]
# naval base in syria [1.0]
# the kuril islands which lie off japan 's northern coast and are claimed by japan [1.0]
# have held [1.0]
# its strikes reduce oil smuggling to turkey [1.0]
# fulfil truce deal [1.0]
# syrian government ifax [1.0]
# oil slump sanctions [1.0]
# the worst east west standoff since the cold war [1.0]
# western airlines [1.0]
# a us led air attack in eastern syria that killed dozens of government troops fighting so called islamic state has endangered an already shaky ceasefire deal [1.0]
# training exercise [1.0]
# the united states and european union [1.0]
# openly gay tourists [1.0]
# surge in its former commercial capital [1.0]
# it 's planning joint isis operations with france [1.0]
# egypt interfax [1.0]
# security cameras were n't pointing at nemtsov shooting [1.0]
# yemen ambassador [1.0]
# it will arrest openly gay tourists [1.0]
# gas supplies [1.0]
# a us led air attack in eastern syria that killed dozens of government troops fighting [1.0]
# japan 's northern coast [1.0]
# surge of violence in its former commercial capital [1.0]
# dagestan siege [1.0]
# to get syrian army to fulfil truce deal [1.0]
# fulfilling [1.0]
# syrian government control [1.0]
# were taking place [1.0]
# west acting in muslim world like monkey with grenade [1.0]
# the debt [1.0]
# the results of controversial separatist elections in eastern ukraine [1.0]
# ready for talks with united states on syria [1.0]
# isis leader may have been liquidated by strike [1.0]
# mass graves and evidence of war crimes found in east of aleppo syria [1.0]
# for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month [1.0]
# slavyansk [1.0]
# yacht [1.0]
# more than 3,000 us soldiers [1.0]
# financial help [1.0]
# to undermine peace efforts [1.0]
# it will keep selling missiles to syria [1.0]
# oil trade with islamic state [1.0]
# us talks [1.0]
# discrimination for gay athletes [1.0]
# scientists stranded in ice [1.0]
# near with u.s. on syria flights [1.0]
# greenpeace [1.0]
# france must fulfil mistral contract [1.0]
# off japan 's northern coast [1.0]
# to syrian government control [1.0]
# it may have killed isis leader abu bakr al baghdadi [1.0]
# russian border guards opened fire [1.0]
# money agency [1.0]
# had put [1.0]
# as they scrap over the future of the black sea crimea region [1.0]
# not maintain [1.0]
# roadmap [1.0]
# sea crimea [1.0]
# illegal oil trade with isis [1.0]
# shaky [1.0]
# moment over ukraine [1.0]
# all st petersburg metro bombing suspects from central asia [1.0]
# did down [1.0]
# while tallinn says he was investigating cross border crime [1.0]
# in aleppo latakia [1.0]
# allowing regional autonomy [1.0]
# by turkish operation in syria [1.0]
# forbid us gps stations within its borders in protest of ukraine sanctions [1.0]
# with exxon strikes oil [1.0]
# geneva interfax [1.0]
# north korea 's leader has accepted an invitation to travel to moscow in may for world war two anniversary celebrations [1.0]
# more ways to normalize situation in syria 's aleppo [1.0]
# optimistic about ukraine crisis trio talks [1.0]
# it can deploy nuclear arms to crimea [1.0]
# that killed dozens of government troops fighting [1.0]
# seize parliament [1.0]
# soviet era military bases in cuba and vietnam [1.0]
# involved in illegal oil trade with isis [1.0]
# eu criticism over ukraine shift [1.0]
# nemtsov shooting [1.0]
# a month before [1.0]
# an is offensive [1.0]
# protecting al qaeda in syria [1.0]
# international tribunal [1.0]
# aggression without u.n. vote [1.0]
# may reopen [1.0]
# of terror [1.0]
# do not consider [1.0]
# turkish troops [1.0]
# embassy naval base in syria [1.0]
# teams up with turkey [1.0]
# a chemical weapons attack [1.0]
# focus of isis recruiters [1.0]
# city of samara [1.0]
# inf treaty [1.0]
# geneva peace talks [1.0]
# for downed jet [1.0]
# it is using its influence to get syrian army to fulfil truce deal [1.0]
# eu does not want ukraine truce to hold [1.0]
# missile defense systems [1.0]
# mh17 probe should be done by international community not ukraine [1.0]
# turkey is protecting oil trade with islamic state [1.0]
# his plane [1.0]
# air units deploying south to ashuluk for drills [1.0]
# russian border guards [1.0]
# back to base [1.0]
# national governments should control the internet [1.0]
# it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month [1.0]
# u.s. missiles in poland romania would violate treaty [1.0]
# white house and kremlin [1.0]
# for undercover intelligence mission [1.0]
# strike on school in syria 's idlib [1.0]
# decision on repayment [1.0]
# computer networks [1.0]
# found in state computer networks [1.0]
# u.s georgian military exercises could destabilize caucasus [1.0]
# of its attack helicopters [1.0]
# ukraine where 2 mission teams are missing [1.0]
# supplied by [1.0]
# syria 's ancient palmyra cleared mines [1.0]
# violates arms treaties [1.0]
# war crimes found in east of aleppo syria [1.0]
# the results [1.0]
# syrian militants [1.0]
# 40 mortar shells [1.0]
# it has killed islamist insurgency chief [1.0]
# with turkey [1.0]
# syrian base [1.0]
# mid air incidents over syria [1.0]
# talks to extend syrian lull in fighting to aleppo [1.0]
# will resume selling gas to ukraine following an official request from kiev [1.0]
# a u.s. official [1.0]
# any attempt [1.0]
# iskander [1.0]
# u.s. strikes on syrian army would harm fight against islamists [1.0]
# it may abandon space station by 2020 and forbid us gps stations within its borders in protest of ukraine sanctions [1.0]
# joint isis operations [1.0]
# nosedive [1.0]
# soldier who killed armenian family will face trial in armenia [1.0]
# discussion on the syrian conflict [1.0]
# is lying [1.0]
# georgian [1.0]
# spyware found in state computer networks [1.0]
# its embassy [1.0]
# it wo n't intervene in ukraine [1.0]
# mistral warships [1.0]
# scorched earth policy [1.0]
# situation ifax [1.0]
# found in east of aleppo syria [1.0]
# of war crimes found in east of aleppo syria [1.0]
# fight against islamists [1.0]
# repayment [1.0]
# northern coast [1.0]
# international tribunal creates myth serbs solely to blame for war crimes in former yugoslavia [1.0]
# nato troop rotations in east [1.0]
# metro [1.0]
# one north korean fisherman was killed and eight others injured when russian border guards opened fire on a fishing trawler [1.0]
# opposition in talks [1.0]
# person infected with zika virus [1.0]
# a telephone discussion on the syrian conflict [1.0]
# does not contravene un resolution [1.0]
# 300 militants in syria [1.0]
# hurt on nuclear sub [1.0]
# on syrian army [1.0]
# yemen ambassador was not shot and killed [1.0]
# canceling summit over snowden [1.0]
# to tackle unprecedented threat from turkey [1.0]
# foils plot to attack chemical arms facility [1.0]
# pressure on its neighbor [1.0]
# to attend an international peace conference proposed by russia and the us [1.0]
# at world cup stadium in city of samara [1.0]
# signaled [1.0]
# registers first case of person infected with zika virus [1.0]
# signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region [1.0]
# trade with isis [1.0]
# future in doubt [1.0]
# turkey must stop meddling in other states ' affairs end support of terrorism [1.0]
# end support of terrorism [1.0]
# after russia gunmen seize parliament [1.0]
# civilian targets in syria [1.0]
# cessation of hostilities in syria [1.0]
# meddling in other states ' affairs [1.0]
# kiev forces dropped white phosphorus bombs on slavyansk [1.0]
# 100-page report [1.0]
# are carrying [1.0]
# like monkey with grenade [1.0]
# on a fishing trawler [1.0]
# washington ria [1.0]
# radar evading nukes [1.0]
# former commercial capital [1.0]
# undercover intelligence mission [1.0]
# act of aggression without u.n. vote [1.0]
# should control the internet [1.0]
# in the historic syrian city [1.0]
# can examine [1.0]
# no proof assad was behind chemical attack [1.0]
# syria conflict with turkey iran [1.0]
# has endangered [1.0]
# more than 3,000 us soldiers in poland [1.0]
# unperturbed [1.0]
# sanctions ' destructive [1.0]
# missiles from jordan [1.0]
# france must fulfil mistral contract or return money agency [1.0]
# fabricated by [1.0]
# plane over egypt [1.0]
# for washington strike government forces in syria [1.0]
# ukraine shift [1.0]
# if assad stays or steps down [1.0]
# of isis recruiters [1.0]
# fleet of warships is off australia for climate research [1.0]
# ...
# sony cyberattack [1.0]
# any way it can [1.0]
# denies caused [1.0]
# it will participate actively in trade deals regardless of tpp rcep direction [1.0]
# air defense zone in south china sea [1.0]
# detained in connection with tiananmen attack [1.0]
# wo n't budge [1.0]
# its largest order xinhua [1.0]
# 21 of its nationals in singapore infected with zika [1.0]
# it 'll have a meltdown proof nuclear reactor ready by next year [1.0]
# consumption growth will remain fast in 2016 [1.0]
# philippines ' mingling on disputed isle a farce [1.0]
# by 60 percent [1.0]
# its working with latin america for a new world order [1.0]
# missing plane [1.0]
# has stopped [1.0]
# it has been restrained by not seizing more islands in south china sea [1.0]
# one china ' principle [1.0]
# it 's up to us to drive global economy [1.0]
# it is building second aircraft carrier [1.0]
# nuclear reactor ready by next year [1.0]
# the us is militarizing the south china sea [1.0]
# he warned [1.0]
# zone in south china sea [1.0]
# routinely hacks [1.0]
# last week tonight [1.0]
# will shut down [1.0]
# by philippines ' request for un arbitration- calls international dispute resolution illegal and unreasonable [1.0]
# who have entered its territory to escape from myanmar fighting [1.0]
# as shanghai infections rise [1.0]
# no proof north korea hacked sony [1.0]
# its ivory trade [1.0]
# really needs [1.0]
# iran joins aiib as founder member [1.0]
# new strain of deadly bird flu [1.0]
# it would not bend the rules and allow india membership as it had not signed the proliferation treaty npt [1.0]
# south china sea sovereignty [1.0]
# ready to engage us as envoys meet [1.0]
# any conflict’ in south china sea [1.0]
# more foreign [1.0]
# power sector emissions [1.0]
# japan ties should be based on cooperation not confrontation [1.0]
# restricting their production and publicly naming them if they fail to meet fuel consumption requirements on passenger vehicles set for 2015 [1.0]
# trouble on disputed shoal [1.0]
# japan ties [1.0]
# fight in tibet [1.0]
# some land reclamation in south china sea [1.0]
# philippines must heal rift over south china sea as indonesia speaks out [1.0]
# more worthy [1.0]
# it fired 2 flares at vietnamese fishing boats but denies action caused any damage [1.0]
# clash in western region [1.0]
# able to attack the us homeland with conventional weapons using nuclear submarines [1.0]
# turn source code [1.0]
# wo n't take [1.0]
# after swimmer mack horton attacks sun yang [1.0]
# to extract resources from waters claimed by several nations [1.0]
# meltdown proof nuclear reactor ready by next year [1.0]
# it will punish carmakers by restricting their production and publicly naming them if they fail to meet fuel consumption requirements on passenger vehicles set for 2015 [1.0]
# as relations worsen between beijing and taipei [1.0]
# it will ignore south china sea lawsuit decision [1.0]
# in reference to the recently announced russian maritime doctrine [1.0]
# its recent gas discovery in the politically volatile south china sea [1.0]
# interpol [1.0]
# lee [1.0]
# of its new large military transport aircraft [1.0]
# discovery in the politically volatile south china sea [1.0]
# india membership [1.0]
# over agreement [1.0]
# north korea nuke program on its own [1.0]
# if they fail [1.0]
# it warned and tracked u.s. warship in south china sea [1.0]
# apparent suicide blast [1.0]
# naval cooperation important for relations with russia in reference to the recently announced russian maritime doctrine [1.0]
# it could set up air defense zone in south china sea [1.0]
# regional peace [1.0]
# will never stand [1.0]
# dangerous and irresponsible [1.0]
# earth next year [1.0]
# a deceptive actor [1.0]
# 31 nationals detained in zambia for illegal mining [1.0]
# mack [1.0]
# 14.5 billion [1.0]
# on cooperation not confrontation [1.0]
# should not focus [1.0]
# acres [1.0]
# the price for thaad missile system [1.0]
# percent of government vehicle purchases [1.0]
# will punish carmakers [1.0]
# u.s. a practical reality [1.0]
# brain comments in last week tonight with john oliver [1.0]
# sues [1.0]
# regardless of tpp rcep direction [1.0]
# scene of an increasingly ugly spat with vietnam over an oil rig in the south china sea [1.0]
# fortress against separatism [1.0]
# panchen lama living a normal life 20 years after disappearance [1.0]
# to lift the sector 's contribution to economic growth [1.0]
# human rights activist on suspicion of endangering national security [1.0]
# since 19 march lee ming cheh held on suspicion of endangering national security as relations worsen between beijing and taipei [1.0]
# restricting [1.0]
# civilisation [1.0]
# nobel laureate cremated and his wife is free [1.0]
# proxy war in syria [1.0]
# graft fight in tibet [1.0]
# electrics [1.0]
# 315 [1.0]
# will shut [1.0]
# 12,000 troops 200 aircraft [1.0]
# dalai lama obama meeting will damage bilateral ties [1.0]
# stealth aircraft [1.0]
# by restricting their production and publicly naming them if they fail to meet fuel consumption requirements on passenger vehicles set for 2015 [1.0]
# last week 's xinjiang violence that killed 25 [1.0]
# immigration policy [1.0]
# u.s. tariffs [1.0]
# civil society [1.0]
# top us diplomat [1.0]
# weak data [1.0]
# the philippines is ignoring a maritime talks proposal [1.0]
# several nations [1.0]
# at slowest pace [1.0]
# searches for pregnancy tips [1.0]
# from injuries [1.0]
# 2 flares [1.0]
# in the latest show of tension between the two [1.0]
# cleans [1.0]
# funeral strippers [1.0]
# philippine fishermen [1.0]
# 5 trillion [1.0]
# fuel consumption requirements on passenger vehicles set for 2015 [1.0]
# most of the south china sea through which $ 5 trillion in ship borne trade passes every year [1.0]
# killed 21 [1.0]
# through which $ 5 trillion in ship borne trade passes every year [1.0]
# the recently announced russian maritime doctrine [1.0]
# kerry 's call for internet freedom naive [1.0]
# found in last week 's xinjiang violence that killed 25 [1.0]
# it easier for environmental groups to sue polluters [1.0]
# horton [1.0]
# any damage [1.0]
# its shendiao drone [1.0]
# hopes u.s. vietnam ties benefit regional peace [1.0]
# consumption growth [1.0]
# it will promote trade deals regardless of tpp rcep direction [1.0]
# in submarine power systems [1.0]
# to escape from [1.0]
# it will stop taking organs from executed inmates npr [1.0]
# us summit [1.0]
# safety of its ships [1.0]
# is fighters back from syria caught in xinjiang [1.0]
# swimmer mack horton [1.0]
# caihong-4 [1.0]
# russia u.s. must avoid fighting proxy war in syria [1.0]
# tycoon guo wengui [1.0]
# the world ’s best [1.0]
# tiangong-1 space lab will fall to earth next year [1.0]
# it will produce over 300 of its new large military transport aircraft y-20 within 10 years surpassing the us in technology [1.0]
# turkey will decide in its own interests on missile system [1.0]
# allow india membership [1.0]
# defense budget will top $ 145 billion a record high [1.0]
# u.s. solar ruling will hurt clean energy development [1.0]
# it has handed over u.s drone taken in south china sea [1.0]
# linked to terrorism [1.0]
# its nationals in singapore [1.0]
# at religion [1.0]
# at vietnamese fishing boats [1.0]
# leadership in submarine power system [1.0]
# nukes for halt in us drills [1.0]
# will absolutely not experience [1.0]
# myanmar fighting [1.0]
# religious schools [1.0]
# a taiwanese ngo worker and human rights activist on suspicion of endangering national security [1.0]
# homegrown aircraft carrier [1.0]
# the self ruled island 's new government [1.0]
# assessing [1.0]
# warns on [1.0]
# sea defenses against us [1.0]
# the sector 's contribution to economic growth [1.0]
# us homeland [1.0]
# more islands in south china sea [1.0]
# in joint crackdown [1.0]
# will give rights [1.0]
# u.s. warship in south china sea [1.0]
# recent gas discovery in the politically volatile south china sea [1.0]
# about to finish some land reclamation in south china sea [1.0]
# u.s. practical reality [1.0]
# regional tensions [1.0]
# first recovery from bird flu [1.0]
# it will make it easier for environmental groups to sue polluters [1.0]
# as it looks [1.0]
# war in south china sea [1.0]
# vigilance [1.0]
# north korea hacked sony [1.0]
# provocation in south china sea [1.0]
# 100 billion cubic meters of natural gas [1.0]
# hiring funeral strippers [1.0]
# disputed south china sea [1.0]
# a deceptive actor after brain comments in last week tonight with john oliver [1.0]
# south china sea among world 's freest shipping lanes [1.0]
# illegal mining [1.0]
# to sue polluters [1.0]
# 60 percent [1.0]
# the refusal of the self ruled island 's new government to recognize the one china principle [1.0]
# cooperation not confrontation [1.0]
# u.s. solar ruling [1.0]
# worsening relations between beijing and taipei and an ongoing crackdown on civil society [1.0]
# an increasingly ugly spat with vietnam over an oil rig in the south china sea [1.0]
# its own interests on missile system [1.0]
# to stop blocking [1.0]
# pregnancy tips [1.0]
# cuts in overcapacity wo n't cause massive layoffs [1.0]
# 2 extremists detonated explosives in xinjiang in apparent suicide blast [1.0]
# four dies [1.0]
# issued for tycoon guo wengui [1.0]
# adjustment in south china sea [1.0]
# tpp rcep direction [1.0]
# nanjing [1.0]
# to celebrate ramadan [1.0]
# homegrown [1.0]
# will pay the price for thaad missile system [1.0]
# philippines ' 600-kg drug seizure was largest in joint crackdown [1.0]
# on south china sea sovereignty [1.0]
# pterosaur [1.0]
# to undocumented children [1.0]
# build back doors [1.0]
# expands [1.0]
# is back [1.0]
# to make up at least 30 percent of government vehicle purchases by 2016 [1.0]
# as ties warm up [1.0]
# counter thaad exercise with new weapons [1.0]
# during anti china protests [1.0]
# peace prize [1.0]
# punitive [1.0]
# rig in the south china sea [1.0]
# should bring [1.0]
# south china sea history [1.0]
# to turn over source code [1.0]
# that web censorship is not a trade barrier [1.0]
# xi and trump [1.0]
# constructive role [1.0]
# drug seizure [1.0]
# web censorship [1.0]
# to do list [1.0]
# muslim uighurs have joined islamic state group [1.0]
# about 3,000 refugees who have entered its territory to escape from myanmar fighting [1.0]
# will punish journalists [1.0]
# it 's making efforts to stop torture in the country [1.0]
# serious polluters will get the death penalty [1.0]
# set for [1.0]
# a maritime talks proposal [1.0]
# not seizing [1.0]
# a trade barrier [1.0]
# recently announced russian maritime doctrine [1.0]
# increasingly ugly [1.0]
# web site [1.0]
# last week 's violence [1.0]
# its new pterosaur ii drone [1.0]
# with conventional weapons using nuclear submarines [1.0]
# despite weak data [1.0]
# claimed by several nations [1.0]
# john oliver [1.0]
# cardiac arrest [1.0]
# it wo n't take any more foreign garbage [1.0]
# please stop hiring funeral strippers [1.0]
# reference to the recently announced russian maritime doctrine [1.0]
# to attack the us homeland with conventional weapons using nuclear submarines [1.0]
# tiangong-1 [1.0]
# defense system [1.0]
# u.s. missile defense system [1.0]
# hostile forces [1.0]
# needs attitude [1.0]
# will decide [1.0]
# that requires them to turn over source code and build back doors [1.0]
# nuke program [1.0]
# to celebrate [1.0]
# to meet fuel consumption requirements on passenger vehicles set for 2015 [1.0]
# doubting his reincarnation [1.0]
# it ca n't end north korea nuke program on its own [1.0]
# thaad missile system [1.0]
# top judge under investigation for corruption [1.0]
# red notice [1.0]
# it can [1.0]
# talking about [1.0]
# south china sea defenses against us [1.0]
# as japan and hong kong stepped up vigilance against the virus and vietnam banned imports of chinese poultry [1.0]
# 8 million acres of farmland [1.0]
# the self ruled island 's [1.0]
# not seizing more islands in south china sea [1.0]
# will top $ 145 billion [1.0]
# united states should brush up on south china sea history [1.0]
# no such thing as man made islands in south china sea [1.0]
# foreign link [1.0]
# resources from waters [1.0]
# none of its citizens on missing plane were hijackers [1.0]
# cremated [1.0]
# stepped up [1.0]
# global war on terror [1.0]
# investment in tourism [1.0]
# 18 suspects surrender over xinjiang attack that led to nearly 100 deaths [1.0]
# april | afp.com [1.0]
# agreement with asean over disputed south china sea [1.0]
# defense budget [1.0]
# for xinjiang mine attackers [1.0]
# military parade will involve 12,000 troops 200 aircraft [1.0]
# 28 foreign led terrorists [1.0]
# its largest foreign drone order xinhua [1.0]
# south china sea defences [1.0]
# security at n. korean border – top us diplomat [1.0]
# 600-kg drug seizure [1.0]
# oil rig in the south china sea [1.0]
# flight a [1.0]
# chinese airspace [1.0]
# world leadership in submarine power system [1.0]
# philippines violating south china sea code [1.0]
# maritime doctrine [1.0]
# ties with united states [1.0]
# judge under investigation for corruption [1.0]
# by 2017 and further military reforms on way [1.0]
# to finish [1.0]
# south china sea lawsuit decision [1.0]
# infections rise [1.0]
# will involve [1.0]
# deadly bird flu [1.0]
# seizure of drone [1.0]
# hong kong protests [1.0]
# largest order xinhua [1.0]
# north korea syria [1.0]
# refusal of the self ruled island 's new government [1.0]
# a meltdown proof nuclear reactor ready by next year [1.0]
# one child policy [1.0]
# up to us [1.0]
# space lab [1.0]
# panchen lama [1.0]
# because of the refusal of the self ruled island 's new government to recognize the one china principle [1.0]
# aiib [1.0]
# recoveries [1.0]
# would not bend [1.0]
# impact of possible punitive u.s. tariffs [1.0]
# nkorea could suspend nukes for halt in us drills [1.0]
# has handed over [1.0]
# infected with zika [1.0]
# a new world order [1.0]
# massive layoffs [1.0]
# disputed islands [1.0]
# to help iraq in any way it can [1.0]
# normal life [1.0]
# remembrance [1.0]
# it has arrested more terrorism suspects after clash in western region killed 21 [1.0]
# navy carries out drills in sea of japan [1.0]
# its caihong-4 drone [1.0]
# passenger vehicles [1.0]
# would impact [1.0]
# wo n't cause [1.0]
# u.s. needs attitude adjustment in south china sea [1.0]
# could suspend [1.0]
# speaks out [1.0]
# punitive u.s. tariffs [1.0]
# philippine fishermen used fire bombs in south china sea [1.0]
# must respect constitution [1.0]
# rustbelt regions [1.0]
# ming [1.0]
# imprisoned died [1.0]
# an oil rig in the south china sea [1.0]
# a farce [1.0]
# communication mechanism with taiwan [1.0]
# by doubting his reincarnation [1.0]
# mh17 attack [1.0]
# to turn over source code and build back doors [1.0]
# foreign tech firms [1.0]
# north korea was behind sony cyberattack [1.0]
# tibet officials [1.0]
# afp.com [1.0]
# 18 suspects [1.0]
# steady progress [1.0]
# new world order [1.0]
# will punish [1.0]
# stirs up [1.0]
# joint crackdown [1.0]
# it 's building new homegrown aircraft carrier [1.0]
# beijing attack [1.0]
# can manage [1.0]
# conflict’ in south china sea [1.0]
# for treatment source [1.0]
# handling of ukraine [1.0]
# swimmer mack horton attacks [1.0]
# to the scene of an increasingly ugly spat with vietnam over an oil rig in the south china sea [1.0]
# no link between north korea and china u.s. trade [1.0]
# taiwanese activist [1.0]
# global war on terror should also target uighur militants [1.0]
# it really needs south china sea defenses against us [1.0]
# is melting [1.0]
# it will shut down its ivory trade in 2017 [1.0]
# it has reached agreement with asean over disputed south china sea [1.0]
# new north korea nuclear test [1.0]
# one child policy remains in effect for now searches for pregnancy tips soar [1.0]
# jailed winning can not be moved [1.0]
# troop cuts will happen by 2017 and further military reforms on way [1.0]
# its people will never stand for taiwan independence [1.0]
# due to climate change [1.0]
# its new large aircraft [1.0]
# a normal life [1.0]
# rcep direction [1.0]
# tech firms [1.0]
# rift over south china sea [1.0]
# buddhism [1.0]
# graft fight in tibet also aimed at religion [1.0]
# attitudes [1.0]
# u.s. and south korea will pay the price for thaad missile system [1.0]
#
# COMMON_ACTORS
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b56b3c2916a3> in <module>()
#     106
#     107 print('COMMON_ACTORS')
# --> 108 show_actors_by_h(common_actors, decreasing=False)
#     109 print()
#
# NameError: name 'show_actors_by_h' is not defined

# %% [markdown]
# ## Conflict Topics

# %%
sorted_conflict_topics = sorted([(entity, entities[entity]['c']) for entity in entities], key=operator.itemgetter(1), reverse=True)

sorted_conflict_topics
# Out:
# [('syria/syn11910', 45),
#  ('ukraine/syn25', 23),
#  ('warring/syn39477', 22),
#  ('airing/syn17937', 17),
#  ('gaza/syn199', 17),
#  ('china/syn11901', 13),
#  ('bordering/syn1880', 13),
#  ('seas/syn98', 13),
#  ('tensions/syn90', 12),
#  ('eu/syn50', 11),
#  ('south_china_sea/syn4186', 11),
#  ('weaponed/syn7185033', 10),
#  ('russia/syn11969', 10),
#  ('aiding/syn71225', 9),
#  ('bombings/syn330', 8),
#  ('defenses/syn32607', 8),
#  ('sanctions/syn311', 8),
#  ('righted/syn558914', 8),
#  ('palestinians/syn103', 7),
#  ('iran/syn11989', 7),
#  ('conflicts/syn84', 7),
#  ('crises/syn19292', 7),
#  ('war_crimes/syn12185', 7),
#  ('human_rights/syn4210', 7),
#  ('violating/syn13843', 7),
#  ('cyber/syn30', 7),
#  ('dispute/syn11', 7),
#  ('crimea/syn476', 6),
#  ('childs/syn1484485', 6),
#  ('isis/syn8', 6),
#  ('oils/syn764525', 6),
#  ('paris/syn52', 6),
#  ('islamic/syn148', 6),
#  ('killings/syn236', 6),
#  ('arming/syn30107', 6),
#  ('droning/syn7176563', 6),
#  ('planing/syn7181148', 6),
#  ('visits/syn20453', 6),
#  ('provocation/syn27243', 6),
#  ('striking/syn46256', 5),
#  ('refugees/syn130', 5),
#  ('europe/syn12199', 5),
#  ('violations/syn31134', 5),
#  ('securities/syn63086', 5),
#  ('countrys/syn1125949', 5),
#  ('bbc/syn40', 5),
#  ('middle_east/syn4229', 5),
#  ('settlement/syn447', 5),
#  ('worsening/syn47032', 5),
#  ('damascus/syn16877', 5),
#  ('genocides/syn1506676', 5),
#  ('lama/syn1813', 5),
#  ('leaks/syn987', 5),
#  ('deploys/syn18076', 5),
#  ('israel/syn12009', 4),
#  ('embassy/syn76', 4),
#  ('aleppo/syn12321', 4),
#  ('syrian/syn12358', 4),
#  ('gases/syn977', 4),
#  ('jets/syn821', 4),
#  ('climates/syn311545', 4),
#  ('turkeys/syn146090', 4),
#  ('tying/syn593305', 4),
#  ('remarks/syn132', 4),
#  ('abuses/syn196', 4),
#  ('rebels/syn13', 4),
#  ('zoning/syn2496290', 4),
#  ('rises/syn36759', 4),
#  ('sovereignty/syn51394', 4),
#  ('warships/syn13533', 4),
#  ('middled/syn1445355', 4),
#  ('walled/syn6871104', 4),
#  ('palestine/syn19210', 4),
#  ('kashmir/syn13200', 4),
#  ('escalating/syn14258', 4),
#  ('declares/syn72369', 4),
#  ('sabotage/syn13792', 4),
#  ('undermining/syn59134', 4),
#  ('assad/syn15', 3),
#  ('chemical_weapons/syn13157', 3),
#  ('peopled/syn2346635', 3),
#  ('taliban/syn42', 3),
#  ('airstrikes/syn325', 3),
#  ('hamas/syn12784', 3),
#  ('risking/syn136405', 3),
#  ('kabul/syn18954', 3),
#  ('govt/syn397', 3),
#  ('nato/syn17744', 3),
#  ('spying/syn12441', 3),
#  ('plotting/syn41926', 3),
#  ('taiwan/syn12598', 3),
#  ('convoy/syn265', 3),
#  ('raids/syn273', 3),
#  ('resolutions/syn101959', 3),
#  ('nazi/syn110', 3),
#  ('coup/syn16', 3),
#  ('amid/syn13089', 3),
#  ('palestinian/syn218', 3),
#  ('defences/syn125804', 3),
#  ('battling/syn28900', 3),
#  ('treaty/syn1341', 3),
#  ('prayers/syn1516', 3),
#  ('eastern_ukraine/syn49567', 3),
#  ('deliveries/syn1134', 3),
#  ('jerusalem/syn400', 3),
#  ('protesters/syn77', 3),
#  ('kurds/syn175', 3),
#  ('tunnels/syn2606', 3),
#  ('priests/syn2096', 3),
#  ('annexed/syn775', 3),
#  ('hong/syn456', 3),
#  ('rulings/syn41604', 3),
#  ('rows/syn117671', 3),
#  ('over_ukraine/syn166407', 3),
#  ('deployment/syn1457', 3),
#  ('invites/syn81143', 3),
#  ('cleansing/syn209', 3),
#  ('expansions/syn524017', 3),
#  ('civilian_deaths/syn186926', 3),
#  ('rising_tensions/syn6267', 3),
#  ('air_defenses/syn5597', 3),
#  ('double_standards/syn80656', 3),
#  ('hypocrisy/syn25487', 3),
#  ('implementing/syn58290', 3),
#  ('our_enemies/syn93042', 3),
#  ('for_rising_tensions_in_south_china_sea/syn1447503', 3),
#  ('rising_tensions_in_south_china_sea/syn1447504', 3),
#  ('hyping_up/syn1345451', 3),
#  ('on_law_violations/syn4633422', 3),
#  ('law_violations/syn1360745', 3),
#  ('ceasefire/syn109', 2),
#  ('bombed/syn33827', 2),
#  ('north_korea/syn15019', 2),
#  ('waters/syn257', 2),
#  ('tanking/syn1474012', 2),
#  ('africa/syn230', 2),
#  ('the_president/syn941', 2),
#  ('erdogan/syn17', 2),
#  ('peace_talks/syn4228', 2),
#  ('homing/syn582825', 2),
#  ('régions/syn2309076', 2),
#  ('militants/syn28', 2),
#  ('blasts/syn772', 2),
#  ('militaries/syn347316', 2),
#  ('troop/syn17930', 2),
#  ('probe/syn123', 2),
#  ('ba.n/syn3055183', 2),
#  ('yemen/syn14513', 2),
#  ('prisons/syn1053', 2),
#  ('washington/syn135', 2),
#  ('summit/syn171', 2),
#  ('venezuela/syn12558', 2),
#  ('kurdish/syn12409', 2),
#  ('deadly_attack/syn4880', 2),
#  ('massacre/syn410', 2),
#  ('return\xaded/syn7182291', 2),
#  ('afghanistan/syn14280', 2),
#  ('russian/syn12438', 2),
#  ('india/syn12041', 2),
#  ('agreements/syn27415', 2),
#  ('beirut/syn63156', 2),
#  ('flights/syn35787', 2),
#  ('hostage/syn155', 2),
#  ('kidnapped/syn18019', 2),
#  ('threating/syn122844', 2),
#  ('in_syria/syn48330', 2),
#  ('shia/syn66886', 2),
#  ('militia/syn999', 2),
#  ('delays/syn12074', 2),
#  ('chemical_attack/syn4180', 2),
#  ('gulf/syn465', 2),
#  ('european/syn44', 2),
#  ('uk/syn10', 2),
#  ('protesting/syn77392', 2),
#  ('tortured/syn69648', 2),
#  ('regimes/syn2763', 2),
#  ('collapses/syn56448', 2),
#  ('incidents/syn1704', 2),
#  ('airspace/syn223', 2),
#  ('diplomat/syn64', 2),
#  ('strains/syn49034', 2),
#  ('shielding/syn451923', 2),
#  ('peninsula/syn54', 2),
#  ('abducted/syn93126', 2),
#  ('fossil/syn14', 2),
#  ('memberships/syn138518', 2),
#  ('islands/syn191', 2),
#  ('assaults/syn1696', 2),
#  ('territories/syn975', 2),
#  ('pilgrims/syn19336', 2),
#  ('oppositions/syn386795', 2),
#  ('pact/syn780', 2),
#  ('liu/syn1530', 2),
#  ('referendum/syn728', 2),
#  ('to_make/syn17901', 2),
#  ('stoking/syn16869', 2),
#  ('arrests/syn39', 2),
#  ('nukes/syn16442', 2),
#  ('east_ukraine/syn15141', 2),
#  ('abandoning/syn12066', 2),
#  ('stampede/syn1858', 2),
#  ('debts/syn1162', 2),
#  ('gaza_conflict/syn5685', 2),
#  ('jihadists/syn278', 2),
#  ('bodyguards/syn306', 2),
#  ('international_waters/syn61296', 2),
#  ('seizure/syn1486', 2),
#  ('world_news/syn4235', 2),
#  ('unity/syn895', 2),
#  ('crimean/syn34179', 2),
#  ('to_retake/syn57206', 2),
#  ('sparks/syn16980', 2),
#  ('commitments/syn1958', 2),
#  ('humanities/syn419570', 2),
#  ('islamabad/syn13541', 2),
#  ('expands/syn27144', 2),
#  ('targeted_by/syn73384', 2),
#  ('imposes/syn18764', 2),
#  ('russia_sanctions/syn4251', 2),
#  ('separatists/syn976', 2),
#  ('deportation/syn129', 2),
#  ('south_china_sea_ruling/syn664132', 2),
#  ('proxy/syn1414', 2),
#  ('demolishes/syn30039', 2),
#  ('crossings/syn1537', 2),
#  ('vows/syn44226', 2),
#  ('budgets/syn1647', 2),
#  ('visas/syn33604', 2),
#  ('exits/syn235123', 2),
#  ('buddhist/syn520', 2),
#  ('state_in_syria/syn4934', 2),
#  ('bookseller/syn121389', 2),
#  ('convoy_in_syria/syn736416', 2),
#  ('aid_convoy_in_syria/syn1448422', 2),
#  ('syrian_forces/syn149173', 2),
#  ('demonstrations/syn120', 2),
#  ('pursuing/syn60649', 2),
#  ('sisi/syn121', 2),
#  ('sea_dispute/syn5276', 2),
#  ('against_backing_kurdish_militia_in_syria/syn2613501', 2),
#  ('militia_in_syria/syn533862', 2),
#  ('backing_kurdish_militia_in_syria/syn2613502', 2),
#  ('kurdish_militia_in_syria/syn533861', 2),
#  ('grave_situation/syn1447423', 2),
#  ("peninsula_'s_grave_situation/syn1447422", 2),
#  ("for_peninsula_'s_grave_situation/syn1447421", 2),
#  ('back_aid_to_islamabad/syn1448164', 2),
#  ('aid_to_islamabad/syn1448165', 2),
#  ('of_giving_israel_codes_for_syrian_air_defense/syn1345972', 2),
#  ('codes_for_syrian_air_defense/syn1345974', 2),
#  ('giving_israel_codes_for_syrian_air_defenses/syn1345973', 2),
#  ('invite_to_dalai_lama/syn595371', 2),
#  ('all_of_syria/syn15160', 2),
#  ('on_vow_to_retake_all_of_syria/syn4652619', 2),
#  ('to_retake_all_of_syria/syn4652621', 2),
#  ('vow_to_retake_all_of_syria/syn4652620', 2),
#  ('of_syria/syn15161', 2),
#  ('isolation/syn71791', 2),
#  ('kabul_blast/syn660216', 2),
#  ('for_kabul_blast/syn1447858', 2),
#  ('of_double_standards_over_syria/syn1346605', 2),
#  ('double_standards_over_syria/syn1346606', 2),
#  ('for_new_violence_in_eastern_ukraine/syn1447771', 2),
#  ('violence_in_eastern_ukraine/syn335887', 2),
#  ('new_violence_in_eastern_ukraine/syn1447772', 2),
#  ('plotting_against/syn1344750', 2),
#  ('1987/syn3506', 2),
#  ('cleansing_in_syria/syn8409', 2),
#  ("violating_'s/syn586445", 2),
#  ('lure/syn143812', 2),
#  ('working_with/syn15977', 2),
#  ('nuke_test/syn317223', 2),
#  ('dividing/syn108773', 2),
#  ('drill_provocative/syn1470162', 2),
#  ('over_provocative_drills/syn4745788', 2),
#  ('pulling_out_of/syn432590', 2),
#  ('video_message/syn170970', 2),
#  ('in_video_message/syn3881835', 2),
#  ('alarming_provocations/syn1347165', 2),
#  ('to_its_enemies/syn1346784', 2),
#  ('war_crimes_in_gaza/syn604461', 2),
#  ('violating_budapest_memorandum/syn1346518', 2),
#  ('memorandum/syn1910', 2),
#  ('of_violating_budapest_memorandum/syn1346517', 2),
#  ('interfering_in/syn97538', 2),
#  ('force_against_palestinians/syn7756', 2),
#  ('eu_exit/syn5206', 2),
#  ('against_eu_exit/syn2605596', 2),
#  ('over_expanded_russia_sanctions/syn4752019', 2),
#  ('expanded_russia_sanctions/syn4752020', 2),
#  ('against_joining_nato/syn2614013', 2),
#  ('joining_nato/syn639705', 2),
#  ('east_china_sea_dispute/syn1633012', 2),
#  ('china_sea/syn107818', 2),
#  ('aggressive’_acts/syn1512103', 2),
#  ('security_in_turkey/syn1447866', 2),
#  ('worsening_security_in_turkey/syn1447865', 2),
#  ('for_worsening_security_in_turkey/syn1447864', 2),
#  ('militarization/syn66241', 2),
#  ('commonwealth/syn88', 2),
#  ('their_budget_plans/syn4748913', 2),
#  ('over_their_budget_plans/syn4748912', 2),
#  ('budget_plan/syn2388282', 2),
#  ('chemical_weapons_use/syn100802', 2),
#  ('revenge_massacres/syn1346218', 2),
#  ('of_revenge_massacres/syn1346217', 2),
#  ('over_workers_rights/syn4751151', 2),
#  ('worker_rights/syn599773', 2),
#  ('making_up_spy_drone_report/syn1344623', 2),
#  ('making_spy_drone_report/syn1344624', 2),
#  ('of_making_up_spy_drone_report/syn1344622', 2),
#  ('spy_drone_report/syn1344625', 2),
#  ('commander/syn167', 1),
#  ('mosul/syn14253', 1),
#  ('air_strikes/syn4179', 1),
#  ('britain/syn12592', 1),
#  ('evidences/syn23812', 1),
#  ('democracies/syn3581', 1),
#  ('schooling/syn2819645', 1),
#  ('armies/syn51950', 1),
#  ('vienna/syn13670', 1),
#  ('nuclear_talks/syn4329', 1),
#  ('projected/syn56328', 1),
#  ('pipeline/syn149', 1),
#  ('israeli/syn15183', 1),
#  ('bomber/syn305', 1),
#  ('thursday/syn14753', 1),
#  ('suicides/syn31639', 1),
#  ('at_least/syn30663', 1),
#  ('killed_in/syn12927', 1),
#  ('drugged/syn274992', 1),
#  ('fifa/syn18631', 1),
#  ('bailout/syn185', 1),
#  ('airports/syn77355', 1),
#  ('in_gaza/syn141430', 1),
#  ('truce/syn12286', 1),
#  ('poisoning/syn132435', 1),
#  ('un_agency/syn5746', 1),
#  ('citizenship/syn13341', 1),
#  ('offic\xadials/syn1033461', 1),
#  ('lifes/syn3840341', 1),
#  ('darfur/syn77590', 1),
#  ('pms/syn538991', 1),
#  ('france/syn12543', 1),
#  ('west_bank/syn4205', 1),
#  ('crematorium/syn103021', 1),
#  ('iraq/syn12801', 1),
#  ('rocketing/syn449506', 1),
#  ('intercepted/syn117', 1),
#  ('baltic_sea/syn7001', 1),
#  ('mh370/syn1258', 1),
#  ('saudi/syn75', 1),
#  ('campaigns/syn40083', 1),
#  ('jordan/syn16781', 1),
#  ('daesh/syn13933', 1),
#  ('pollution/syn48', 1),
#  ('trump/syn202', 1),
#  ('to_fight/syn14208', 1),
#  ('greece/syn12855', 1),
#  ('afghan/syn12258', 1),
#  ('ebola/syn12314', 1),
#  ('grounded/syn49176', 1),
#  ('ukraine_conflict/syn31936', 1),
#  ('casing/syn528671', 1),
#  ('extradition/syn39688', 1),
#  ('south_korea/syn13748', 1),
#  ('climate_deal/syn4458', 1),
#  ('seized/syn23279', 1),
#  ('netherlands/syn331', 1),
#  ('exports/syn17252', 1),
#  ('advances/syn69004', 1),
#  ('womans/syn406208', 1),
#  ('pyongyang/syn24605', 1),
#  ('finances/syn477', 1),
#  ('sons/syn1527', 1),
#  ('smugglers/syn12795', 1),
#  ('costing/syn12508', 1),
#  ('sexes/syn2277', 1),
#  ('programmed/syn418371', 1),
#  ('migrants/syn41', 1),
#  ('pledge/syn17097', 1),
#  ('victories/syn189556', 1),
#  ('toxic_gas/syn444984', 1),
#  ('videoed/syn1488346', 1),
#  ('documented/syn26484', 1),
#  ('dictatorship/syn1549', 1),
#  ('tunisia/syn13918', 1),
#  ('isil/syn91', 1),
#  ('ngo/syn22984', 1),
#  ('climate_change/syn13467', 1),
#  ('breach/syn25762', 1),
#  ('nazis/syn119', 1),
#  ('far_right/syn5289', 1),
#  ('prosecutor/syn319', 1),
#  ('setback/syn17955', 1),
#  ('programme/syn219', 1),
#  ('defectors/syn1360', 1),
#  ('streamed/syn320866', 1),
#  ('philippines/syn19', 1),
#  ('its_ships/syn117738', 1),
#  ('its_citizens/syn108893', 1),
#  ('detained/syn48580', 1),
#  ('armenian/syn189', 1),
#  ('residents/syn614', 1),
#  ('casualties/syn671', 1),
#  ('interfered/syn132864', 1),
#  ('ukrainian/syn16194', 1),
#  ('networked/syn7180273', 1),
#  ('processed/syn353683', 1),
#  ('rally/syn111', 1),
#  ('dangers/syn1658', 1),
#  ('in_airstrike/syn51312', 1),
#  ('japan/syn13284', 1),
#  ('jewish/syn11845', 1),
#  ('lebanon/syn13741', 1),
#  ('hackings/syn990852', 1),
#  ('to_change/syn32588', 1),
#  ('congresses/syn130626', 1),
#  ('detention/syn186', 1),
#  ('navy/syn404', 1),
#  ('turkish/syn12357', 1),
#  ('warplanes/syn83', 1),
#  ('on_ukraine/syn93806', 1),
#  ('the_country/syn14249', 1),
#  ('detailing/syn55741', 1),
#  ('manned/syn677', 1),
#  ('russian_hackers/syn112559', 1),
#  ('libya/syn11883', 1),
#  ('permits/syn84226', 1),
#  ('alliances/syn58650', 1),
#  ('istanbul/syn13084', 1),
#  ('tripoli/syn31073', 1),
#  ('landslide/syn743', 1),
#  ('cruise_missiles/syn30902', 1),
#  ('terrorist_group/syn5088', 1),
#  ('brexit/syn49', 1),
#  ('gibraltar/syn25555', 1),
#  ('clashes/syn277', 1),
#  ('storms/syn13878', 1),
#  ('treatments/syn119236', 1),
#  ('maduro/syn619', 1),
#  ('to_start/syn58555', 1),
#  ('hitler/syn12630', 1),
#  ('malaysia/syn13223', 1),
#  ('tourists/syn24058', 1),
#  ('clinton/syn179', 1),
#  ('snowden/syn378', 1),
#  ('underwater_drone/syn579566', 1),
#  ('air_raids/syn202757', 1),
#  ('latest_air_raids/syn2088065', 1),
#  ('camped/syn234328', 1),
#  ('academy/syn18638', 1),
#  ('sail/syn61553', 1),
#  ('its_people/syn34903', 1),
#  ('more_sanctions/syn69253', 1),
#  ('aircrafts/syn143378', 1),
#  ('laden/syn93', 1),
#  ('nuclear_test/syn15701', 1),
#  ('messaging/syn601607', 1),
#  ('planted/syn2160', 1),
#  ('servicemen/syn25610', 1),
#  ('halts/syn13974', 1),
#  ('billed/syn3686', 1),
#  ('spanish/syn20084', 1),
#  ('imports/syn12663', 1),
#  ('tillerson/syn725', 1),
#  ('nuclear_threat/syn34806', 1),
#  ('internets/syn1256159', 1),
#  ('collision/syn1793', 1),
#  ('tanker/syn372', 1),
#  ('syrians/syn2251', 1),
#  ('israelis/syn222', 1),
#  ('ransom/syn152601', 1),
#  ('smuggling/syn29572', 1),
#  ('jazeera/syn14916', 1),
#  ('refugee_crisis/syn4569', 1),
#  ('in_tunisia/syn370467', 1),
#  ('hacks/syn2361', 1),
#  ('stalemate/syn31', 1),
#  ('derails/syn102780', 1),
#  ('wakes/syn587414', 1),
#  ('floods/syn272', 1),
#  ('blockade/syn988', 1),
#  ('conducts/syn52434', 1),
#  ('investigations/syn35534', 1),
#  ('soaring/syn24111', 1),
#  ('the_border/syn25510', 1),
#  ('dreaming/syn671436', 1),
#  ('leaving_eu/syn6977', 1),
#  ('prisoners/syn81', 1),
#  ('to_press/syn84390', 1),
#  ('murders/syn1218', 1),
#  ('asia/syn12203', 1),
#  ('killing_civilians/syn476649', 1),
#  ('executes/syn101009', 1),
#  ('beheading/syn134', 1),
#  ('sectors/syn1145', 1),
#  ('coursing/syn2304719', 1),
#  ('kiev/syn25759', 1),
#  ('pacific/syn395', 1),
#  ('nsa/syn63', 1),
#  ('engaging_in/syn1123', 1),
#  ('reuters/syn243', 1),
#  ('jet_crash/syn41028', 1),
#  ('migrant_crisis/syn4359', 1),
#  ('election_victory/syn4645', 1),
#  ('three_soldiers/syn329770', 1),
#  ('to_stop/syn14142', 1),
#  ('cairo/syn18489', 1),
#  ('muslims/syn113620', 1),
#  ('withdrawing_from/syn157630', 1),
#  ('direct_contacts/syn1092277', 1),
#  ('xi/syn343', 1),
#  ('his_family/syn16105', 1),
#  ('swedish/syn13340', 1),
#  ('rapes/syn39014', 1),
#  ('anniversary/syn558', 1),
#  ('spying/syn61', 1),
#  ('ramming/syn12414', 1),
#  ('cold_war/syn4317', 1),
#  ('kaesong/syn2564', 1),
#  ('fatah/syn60493', 1),
#  ('pkk/syn113', 1),
#  ('civil_war/syn4300', 1),
#  ('assange/syn86', 1),
#  ('terror_attack/syn4261', 1),
#  ('new_report/syn61844', 1),
#  ('natural_gas/syn24120', 1),
#  ('fronts/syn20317', 1),
#  ('to_war/syn15517', 1),
#  ('surveillance/syn174', 1),
#  ('harassing/syn92941', 1),
#  ('root/syn22067', 1),
#  ('duties/syn55590', 1),
#  ('raqqa/syn13030', 1),
#  ('declaration/syn14775', 1),
#  ('kunar/syn603620', 1),
#  ('peacekeepers/syn1945', 1),
#  ('golan/syn38', 1),
#  ('harbour/syn3252', 1),
#  ('lined/syn246707', 1),
#  ('centres/syn613', 1),
#  ('rejects/syn52744', 1),
#  ('accuses/syn27891', 1),
#  ('sending_in/syn157225', 1),
#  ('expels/syn97531', 1),
#  ('anthrax/syn2494', 1),
#  ('servicing/syn532600', 1),
#  ('holy_site/syn4778', 1),
#  ('declaration_of_war/syn171504', 1),
#  ('selves/syn704652', 1),
#  ('terror_group/syn4188', 1),
#  ('in_crimea/syn63940', 1),
#  ('asia_pacific/syn5691', 1),
#  ('suburb/syn978', 1),
#  ('people_smugglers/syn57110', 1),
#  ('plane_crash/syn4231', 1),
#  ('eras/syn113196', 1),
#  ('affairs/syn986', 1),
#  ('sponsored/syn2015', 1),
#  ('crimes_against_humanity/syn36635', 1),
#  ('fomenting/syn49194', 1),
#  ('coldest/syn434', 1),
#  ('peshmerga/syn2439', 1),
#  ('palestinian_authority/syn5586', 1),
#  ('usa/syn2326', 1),
#  ('sanctions/syn16910', 1),
#  ('gaza_residents/syn116049', 1),
#  ('new_sanctions/syn62458', 1),
#  ('refugees/syn488', 1),
#  ('missing_in/syn243641', 1),
#  ('barbarism/syn494199', 1),
#  ('with_iran/syn193947', 1),
#  ('a_month/syn37676', 1),
#  ('cruise/syn15145', 1),
#  ('retaliation/syn15671', 1),
#  ('ukraine_crisis/syn4381', 1),
#  ('blames/syn43440', 1),
#  ('as_deepens/syn30354', 1),
#  ('worshippers/syn149568', 1),
#  ('marines/syn2224', 1),
#  ('practiced/syn520860', 1),
#  ('horrors/syn445', 1),
#  ('to_control/syn85199', 1),
#  ('over_kashmir/syn4760294', 1),
#  ('to_demand/syn131909', 1),
#  ('tokyo/syn13287', 1),
#  ('fight_isis/syn265190', 1),
#  ('its_leaders/syn48342', 1),
#  ('gamed/syn6027109', 1),
#  ('paris_climate_deal/syn60400', 1),
#  ('stalls/syn16912', 1),
#  ('syria_army/syn105974', 1),
#  ('air_defense_zone/syn4438', 1),
#  ('at_risk/syn22813', 1),
#  ('istanbul_bombing/syn690909', 1),
#  ('emailed/syn141450', 1),
#  ('deteriorating/syn58446', 1),
#  ('intensifies/syn31443', 1),
#  ('settlement_plan/syn300374', 1),
#  ('oceans/syn1077', 1),
#  ('oil_prices/syn4462', 1),
#  ('killing_of/syn59460', 1),
#  ('interviewed/syn3512', 1),
#  ('proposal/syn736', 1),
#  ('air_defence_zone/syn216963', 1),
#  ('taliban_militants/syn183699', 1),
#  ('beheaded/syn37893', 1),
#  ('over_syria/syn102484', 1),
#  ('syrian_troops/syn84197', 1),
#  ('its_troops/syn104985', 1),
#  ('eu_deal/syn53053', 1),
#  ('unilateral/syn16434', 1),
#  ('embassy_to_jerusalem/syn490290', 1),
#  ('napalm/syn227974', 1),
#  ('rights_violations/syn5793', 1),
#  ('valley/syn616', 1),
#  ('to_iran/syn110536', 1),
#  ('failing_to/syn102500', 1),
#  ('nobel_laureate/syn62708', 1),
#  ('laureate/syn51599', 1),
#  ('nobel/syn15224', 1),
#  ('kurdish_fighters/syn5582', 1),
#  ('9_11/syn861', 1),
#  ('syrian_regime/syn5603', 1),
#  ('palestinian_unity_government/syn577483', 1),
#  ('its_interests/syn125528', 1),
#  ('buildup/syn2488', 1),
#  ('nuclear_strike/syn6941', 1),
#  ('of_genocide/syn80234', 1),
#  ('creations/syn478100', 1),
#  ('shelters/syn2605', 1),
#  ('syria_troops/syn243814', 1),
#  ('cia/syn446', 1),
#  ('24_hours/syn4421', 1),
#  ('turkey_border/syn165049', 1),
#  ('descends/syn215817', 1),
#  ('a_war_crime/syn9517', 1),
#  ('manchester/syn26705', 1),
#  ('paedophile/syn65', 1),
#  ('living_in/syn16501', 1),
#  ('scrambles/syn33989', 1),
#  ('palestinian_state/syn30473', 1),
#  ('blacklist/syn2169', 1),
#  ('criticisms/syn3589', 1),
#  ('south_china_sea_islands/syn479556', 1),
#  ('on_south_china_sea_islands/syn479555', 1),
#  ('sea_islands/syn184304', 1),
#  ('barred/syn44124', 1),
#  ('supporting_terrorism/syn25827', 1),
#  ('1989/syn144264', 1),
#  ('tiananmen/syn883', 1),
#  ('mentally_ill/syn14095', 1),
#  ('manchester_suicide_bomber/syn407525', 1),
#  ('row_bbc_news/syn506820', 1),
#  ('national_interests/syn4809', 1),
#  ('bail/syn268', 1),
#  ('to_form/syn74046', 1),
#  ('unlawful/syn43061', 1),
#  ('shifting/syn122530', 1),
#  ('rabbi/syn286', 1),
#  ('devastating/syn12620', 1),
#  ('historic/syn18695', 1),
#  ('on_syria/syn58903', 1),
#  ('sneaked/syn142617', 1),
#  ("gov't/syn512", 1),
#  ('south_china_sea_dispute/syn6955', 1),
#  ('assassination/syn972', 1),
#  ('dutch/syn3', 1),
#  ('accession/syn1199', 1),
#  ('airlines/syn13419', 1),
#  ('over_700/syn738503', 1),
#  ('fresh_attack/syn214064', 1),
#  ('syria_crisis/syn30232', 1),
#  ('cleric/syn341', 1),
#  ('harbor/syn1372', 1),
#  ('reef/syn12', 1),
#  ('border_fence/syn2709', 1),
#  ('escalation/syn1534', 1),
#  ('failures/syn29298', 1),
#  ('undesirable/syn60954', 1),
#  ('caucasus/syn180', 1),
#  ('laundering/syn2431', 1),
#  ('meddling/syn1262', 1),
#  ('interference/syn983', 1),
#  ('tightens/syn26933', 1),
#  ('tehran/syn11987', 1),
#  ('accord/syn1324', 1),
#  ('evil_ways/syn2150595', 1),
#  ('aegean/syn1226', 1),
#  ('peace_efforts/syn110003', 1),
#  ('global_conflict/syn477877', 1),
#  ('shuts/syn1946', 1),
#  ('hong_kong_booksellers/syn5819', 1),
#  ('acknowledges/syn16218', 1),
#  ('2_billion/syn5111', 1),
#  ('un_sanctions/syn64372', 1),
#  ('bins/syn68809', 1),
#  ('wannacry/syn3430', 1),
#  ('peace_hopes/syn535235', 1),
#  ('nuclear_scientists/syn6729', 1),
#  ('greats/syn1316052', 1),
#  ('brawl/syn27015', 1),
#  ('jesuit/syn2375', 1),
#  ('defense_spending/syn89231', 1),
#  ('air_attacks/syn195221', 1),
#  ('destructive/syn81956', 1),
#  ('meats/syn259155', 1),
#  ('new_settlement/syn123820', 1),
#  ('diamonds/syn21045', 1),
#  ('roma/syn810', 1),
#  ('web_site/syn5295', 1),
#  ('authorises/syn123732', 1),
#  ('deserts/syn56762', 1),
#  ('nuclear_missile/syn15673', 1),
#  ('founder/syn727', 1),
#  ('chased/syn143843', 1),
#  ('troubles/syn1551', 1),
#  ('stirring_up/syn174605', 1),
#  ('syrian_soldiers/syn13872', 1),
#  ('fruits/syn2818', 1),
#  ('shameful/syn47223', 1),
#  ('border_security/syn344734', 1),
#  ('his_election/syn6051', 1),
#  ('mosul_civilian_deaths/syn2536029', 1),
#  ('ops/syn78319', 1),
#  ('meddling_in/syn66259', 1),
#  ('dc/syn2553', 1),
#  ('regional_peace/syn171481', 1),
#  ('slain/syn33964', 1),
#  ('missile_deployment/syn1177085', 1),
#  ('incitement/syn13983', 1),
#  ('racists/syn113754', 1),
#  ("shi'ite_pilgrims/syn185632", 1),
#  ('jihadi/syn320', 1),
#  ('youths/syn12532', 1),
#  ('syria_peace_talks/syn59074', 1),
#  ('hardliners/syn89621', 1),
#  ('gaza_border/syn191966', 1),
#  ('palestinian_teen/syn4362', 1),
#  ('their_president/syn28030', 1),
#  ('emptive/syn263132', 1),
#  ('surprises/syn539573', 1),
#  ('syrian_kurdish_fighters/syn415076', 1),
#  ('apartheid/syn14475', 1),
#  ('footballer/syn44344', 1),
#  ('in_west_bank/syn147567', 1),
#  ('military_crackdown/syn253499', 1),
#  ('acrimony/syn227146', 1),
#  ('deal_with_russia/syn5734', 1),
#  ('american_forces/syn137972', 1),
#  ('upi.com/syn484479', 1),
#  ('reveals/syn40496', 1),
#  ('bombardment/syn20257', 1),
#  ('ignites/syn79025', 1),
#  ('identities/syn1023', 1),
#  ('nerves/syn360838', 1),
#  ('using_chemical_weapons/syn101998', 1),
#  ('advices/syn487959', 1),
#  ('paris_climate_agreement/syn9413', 1),
#  ('turmoil/syn436', 1),
#  ('intensified_conflicts/syn1448263', 1),
#  ('instigating/syn282714', 1),
#  ('montenegro/syn11894', 1),
#  ('drone_experts/syn8078', 1),
#  ('roping/syn2526354', 1),
#  ('palestinian_land/syn4734', 1),
#  ('eastern_province/syn4468', 1),
#  ('adding_to/syn54630', 1),
#  ('turkish_airspace/syn195383', 1),
#  ('fingered/syn60086', 1),
#  ('engagement/syn26642', 1),
#  ('wto/syn799', 1),
#  ('french_society/syn877645', 1),
#  ('provoking/syn87308', 1),
#  ('of_illegal_isis_oil_trading/syn1346564', 1),
#  ('illegal_oil_trading/syn1346566', 1),
#  ('oil_trading/syn1346567', 1),
#  ('illegal_isis_oil_trading/syn1346565', 1),
#  ('nuclear_technicians/syn1448022', 1),
#  ('five_nuclear_technicians/syn1448021', 1),
#  ('death_of_five_nuclear_technicians_in_syria/syn1448018', 1),
#  ('for_death_of_five_nuclear_technicians_in_syria/syn1448017', 1),
#  ('five_nuclear_technicians_in_syria/syn1448020', 1),
#  ('of_five_nuclear_technicians_in_syria/syn1448019', 1),
#  ('of_ethnic_cleansing/syn76512', 1),
#  ('over_sanctions/syn1605708', 1),
#  ('against_use_of_excessive_force/syn2609288', 1),
#  ('excessive_force/syn497141', 1),
#  ('use_of_excessive_force/syn2609289', 1),
#  ('powerful_cyber_attack/syn1344580', 1),
#  ('of_powerful_cyber_attacks/syn1344579', 1),
#  ('ship_seizure/syn3283536', 1),
#  ('over_ship_seizure/syn4746832', 1),
#  ('al_sisi_’s_popularity/syn1510811', 1),
#  ('supporting_terrorists/syn58486', 1),
#  ('of_supporting_terrorists/syn1345107', 1),
#  ('shilo/syn2266193', 1),
#  ('emek_shilo_settlement/syn3351014', 1),
#  ('over_emek_shilo_settlement/syn4738074', 1),
#  ('emek/syn2266190', 1),
#  ('hosting_secret_cia_prisons/syn1510777', 1),
#  ('for_hosting_secret_cia_prisons/syn1510776', 1),
#  ('cia_prisons/syn4958', 1),
#  ('remarks_on_nsg_south_china_sea/syn4683507', 1),
#  ('nsg_south_china_sea/syn4366196', 1),
#  ('over_remarks_on_nsg_south_china_sea/syn4744756', 1),
#  ('deadly_sneak_attack/syn1448045', 1),
#  ('sneak_attack/syn1448046', 1),
#  ('for_deadly_sneak_attack_on_soldiers_in_kashmir/syn1448043', 1),
#  ('deadly_sneak_attack_on_soldiers_in_kashmir/syn1448044', 1),
#  ('soldier_in_kashmir/syn13941', 1),
#  ('magnitsk/syn2614287', 1),
#  ('publicising/syn982649', 1),
#  ('against_publicising_magnitsk/syn2614285', 1),
#  ('publicising_magnitsk/syn2614286', 1),
#  ('deportations/syn1512056', 1),
#  ('deportations_to_china/syn1512055', 1),
#  ('over_deportations_to_china/syn1512054', 1),
#  ('for_‘_alarming’_reports_of_human_rights_abuses/syn3473193', 1),
#  ('alarming’_reports/syn8670', 1),
#  ('over_airstrike_on_syria_troops/syn4744633', 1),
#  ('airstrike_on_syria_troops/syn4659431', 1),
#  ('being_behind/syn2245', 1),
#  ('beirut_bombings/syn192809', 1),
#  ('of_being_behind_beirut_bombings/syn1345965', 1),
#  ('being_behind_beirut_bombings/syn1345966', 1),
#  ('for_latest_south_china_sea_incident_|_reuters/syn1447939', 1),
#  ('latest_incident/syn92111', 1),
#  ('latest_south_china_sea_incident_|_reuters/syn1447940', 1),
#  ('syria_style’_actions/syn2606925', 1),
#  ('against_‘_syria_style’_actions_in_n._korea/syn2606922', 1),
#  ('missile_defence_programme_against_north_korea/syn4246275', 1),
#  ('over_missile_defence_programme_against_north_korea/syn4742331', 1),
#  ('programme_against_north_korea/syn2621551', 1),
#  ('defence_programme_against_north_korea/syn3274378', 1),
#  ("intervening_in_'s/syn4656017", 1),
#  ("intervening_in_syria_'s_civil_war/syn4656016", 1),
#  ("on_intervening_in_syria_'s_civil_war/syn4656015", 1),
#  ('backtracking_on_migrant_commitments/syn2613506', 1),
#  ('on_migrant_commitments/syn2613507', 1),
#  ('backtracks/syn31346', 1),
#  ('against_backtracking_on_migrant_commitments/syn2613505', 1),
#  ('migrant_commitments/syn2613508', 1),
#  ('terror_expansion/syn1447884', 1),
#  ('wrong_policies/syn1136715', 1),
#  ('wrong_policies_for_terror_expansion/syn1447883', 1),
#  ('reports_of_arbitrary_new_sanctions/syn1345992', 1),
#  ('of_illegal_meddling_over_reports_of_arbitrary_new_sanctions/syn1345989', 1),
#  ('arbitrary_new_sanctions/syn1345993', 1),
#  ('illegal_meddling_over_reports_of_arbitrary_new_sanctions/syn1345990', 1),
#  ('meddling_over_reports_of_arbitrary_new_sanctions/syn1345991', 1),
#  ('for_global_wannacry_ransomware_attack/syn1447573', 1),
#  ('global_wannacry_ransomware_attack/syn1447574', 1),
#  ('global_ransomware_attack/syn805611', 1),
#  ('ransomware/syn2608', 1),
#  ("helping_overthrow_'s/syn1346797", 1),
#  ('islamist_president/syn35868', 1),
#  ("helping_overthrow_cairo_'s_islamist_president/syn1346796", 1),
#  ("of_helping_overthrow_cairo_'s_islamist_president/syn1346795", 1),
#  ('climate_change_deal/syn6642', 1),
#  ('abandoning_climate_change_deal/syn596045', 1),
#  ('against_abandoning_climate_change_deal/syn596044', 1),
#  ('rise_of_islamic_state/syn131691', 1),
#  ('for_tying_rise_of_islamic_state_to_israeli_palestinian_conflict/syn3511119',
#   1),
#  ('to_israeli_palestinian_conflict/syn3511121', 1),
#  ('tying_rise_of_islamic_state_to_israeli_palestinian_conflict/syn3511120', 1),
#  ('israeli_palestinian_conflict/syn6081', 1),
#  ('as_us_holds_back_aid_to_islamabad/syn1448163', 1),
#  ('two_senior_military_commanders/syn4060169', 1),
#  ('military_commander/syn4832', 1),
#  ("two_islamic_state_'_senior_military_commanders/syn4060168", 1),
#  ('senior_military_commanders/syn2306916', 1),
#  ('ukraine_agreement/syn4750050', 1),
#  ('over_ukraine_agreement/syn4750049', 1),
#  ('of_bringing_chaos_to_middle_east/syn1346613', 1),
#  ('bringing_chaos_to_middle_east/syn1346614', 1),
#  ('to_middle_east/syn444348', 1),
#  ('of_conducting_rocket_test/syn1346901', 1),
#  ('conducting_rocket_test/syn1346902', 1),
#  ('detected_near/syn4101536', 1),
#  ('detected_near_syria_–_lebanon_border/syn4101535', 1),
#  ('over_jets_detected_near_syria_–_lebanon_border/syn4741469', 1),
#  ('syria_–_lebanon_border/syn4101537', 1),
#  ('jets_detected_near_syria_–_lebanon_border/syn4101534', 1),
#  ('gaza_bombing/syn529500', 1),
#  ('for_gaza_bombings/syn1447974', 1),
#  ('using_chemical_weapons_again/syn4753058', 1),
#  ('over_using_chemical_weapons_again/syn4753057', 1),
#  ('death_of_peacekeeper/syn1448297', 1),
#  ('for_death_of_peacekeeper/syn1448296', 1),
#  ('slain_terrorists/syn135901', 1),
#  ('assassination_of_slain_hamas_terrorist/syn1448025', 1),
#  ('for_assassination_of_slain_hamas_terrorist/syn1448024', 1),
#  ('slain_hamas_terrorist/syn1448026', 1),
#  ('debt_commitments/syn3271040', 1),
#  ('over_debt_commitments/syn4737582', 1),
#  ('carry_out_terror_attacks_against_it/syn1345937', 1),
#  ('carry_terror_attacks_against_it/syn1345938', 1),
#  ('training_terrorists_to_carry_out_terror_attacks_against_it/syn1345935', 1),
#  ('to_carry_out_terror_attacks_against_it/syn1345936', 1),
#  ('terror_attacks_against_it/syn1345939', 1),
#  ('of_training_terrorists_to_carry_out_terror_attacks_against_it/syn1345934',
#   1),
#  ('secretly_breaching_u.n._nuclear_sanctions/syn1346905', 1),
#  ('u.n._nuclear_sanctions/syn1346907', 1),
#  ('of_secretly_breaching_u.n._nuclear_sanctions/syn1346904', 1),
#  ('secretly_breaching/syn1346906', 1),
#  ('rights_violations_against_kurds/syn1347117', 1),
#  ('of_rights_violations_against_kurds/syn1347116', 1),
#  ('dalai_lama_border_visit/syn2605259', 1),
#  ('against_dalai_lama_border_visit/syn2605258', 1),
#  ('border_visit/syn2605260', 1),
#  ('hinkley/syn2369', 1),
#  ('that_relations_hang_on_hinkley_point/syn5148209', 1),
#  ('on_hinkley_point/syn4628743', 1),
#  ('if_breached/syn696263', 1),
#  ('if_ukraine_pact_breached/syn3538526', 1),
#  ('necessary_steps/syn934217', 1),
#  ('ukraine_pact/syn563901', 1),
#  ('ready_for_necessary_steps_if_ukraine_pact_breached/syn3538525', 1),
#  ('gulf_crisis/syn174069', 1),
#  ('new_york/syn13178', 1),
#  ('supporting_9_11_attacks_in_new_york_as_gulf_crisis_deepens/syn1346454', 1),
#  ('9_11_attacks_in_new_york/syn1346455', 1),
#  ('of_supporting_9_11_attacks_in_new_york_as_gulf_crisis_deepens/syn1346453',
#   1),
#  ('as_gulf_crisis_deepens/syn1346456', 1),
#  ('of_serious_provocation_by_flying_bombers/syn1345623', 1),
#  ('serious_provocation_by_flying_bombers/syn1345624', 1),
#  ('flying_bombers/syn1345541', 1),
#  ('provocation_by_flying_bombers/syn1345625', 1),
#  ('deliberate_provocations/syn194414', 1),
#  ('of_deliberate_provocations/syn1345548', 1),
#  ('of_sending_in_tanks/syn1347039', 1),
#  ('sending_in_tanks/syn1347040', 1),
#  ('sea_collisions/syn587078', 1),
#  ('for_sea_collisions/syn1447951', 1),
#  ('for_ukraine_crisis/syn162054', 1),
#  ('hostages_in_raid/syn1447110', 1),
#  ('death_of_hostages_in_raid/syn1447109', 1),
#  ('for_death_of_hostages_in_raid/syn1447108', 1),
#  ('starting_the_global_conflict/syn1346588', 1),
#  ('the_global_conflict/syn1346589', 1),
#  ('of_starting_the_global_conflict/syn1346587', 1),
#  ('exporting_polish_fruit/syn1346592', 1),
#  ('of_exporting_polish_fruit/syn1346591', 1),
#  ('times_of_india/syn4331', 1),
#  ('buddhist_meet_times_of_india/syn3081411', 1),
#  ('meet_times_of_india/syn3081412', 1),
#  ('over_invite_to_dalai_lama_to_buddhist_meet_times_of_india/syn4749167', 1),
#  ('invite_to_dalai_lama_to_buddhist_meet_times_of_india/syn4749168', 1),
#  ('top_un_court/syn297481', 1),
#  ('terrorism_in_top_un_court/syn1346997', 1),
#  ('of_terrorism_in_top_un_court/syn1346996', 1),
#  ('closed_door_meeting/syn579083', 1),
#  ('in_closed_door_meeting/syn579082', 1),
#  ('ukraine_’s_hardliners/syn2614837', 1),
#  ('against_ukraine_’s_hardliners/syn2614836', 1),
#  ('a_money_laundering_state/syn2426267', 1),
#  ('as_a_money_laundering_state/syn2885523', 1),
#  ('labelling_it_as_a_money_laundering_state/syn3503218', 1),
#  ('money_laundering_state/syn2426268', 1),
#  ('labelled/syn81664', 1),
#  ('for_labelling_it_as_a_money_laundering_state/syn3503217', 1),
#  ('more_support/syn38759', 1),
#  ("syria_'s_opposition/syn386794", 1),
#  ("more_support_for_syria_'s_opposition/syn2605850", 1),
#  ("against_more_support_for_syria_'s_opposition/syn2605849", 1),
#  ('bringing_back/syn390979', 1),
#  ('bringing_back_the_cold_war/syn1346225', 1),
#  ('of_bringing_back_the_cold_war/syn1346224', 1),
#  ('for_â\x80\x98forcedâ\x80\x99_afghan_refugee_returns/syn3494444', 1),
#  ('â\x80\x98forcedâ\x80\x99_afghan_refugee_returns/syn3494445', 1),
#  ('afghan_refugee_returns/syn2548791', 1),
#  ('refugee_return/syn2508265', 1),
#  ('for_beirut_suburb_bombing/syn1448000', 1),
#  ('beirut_suburb_bombing/syn1448001', 1),
#  ('extraordinary_rendition/syn69348', 1),
#  ('for_extraordinary_rendition/syn69347', 1),
#  ('stoking_irish_nationalism_to_make_brexit_difficult/syn1344606', 1),
#  ('to_make_brexit_difficult/syn1344608', 1),
#  ('of_stoking_irish_nationalism_to_make_brexit_difficult/syn1344605', 1),
#  ('brexit_difficult/syn1344609', 1),
#  ('irish_nationalism/syn1344607', 1),
#  ('regional_air_safety/syn1347289', 1),
#  ('air_safety/syn346187', 1),
#  ('of_threatening_regional_air_safety/syn1347287', 1),
#  ('threatening_regional_air_safety/syn1347288', 1),
#  ('path_to_isolation/syn3256568', 1),
#  ('on_dark_path_to_isolation/syn4624191', 1),
#  ('dark_path_to_isolation/syn3256567', 1),
#  ('sending_spies_into_eastern_ukraine_to_create_chaos/syn1347218', 1),
#  ('to_create/syn27083', 1),
#  ('of_sending_spies_into_eastern_ukraine_to_create_chaos/syn1347217', 1),
#  ('into_eastern_ukraine/syn204646', 1),
#  ('to_create_chaos/syn1072069', 1),
#  ('of_spreading_propaganda/syn1346024', 1),
#  ('spreading_propaganda/syn1346025', 1),
#  ('defaulting_on_gas_debts/syn2613659', 1),
#  ('defaulting_on/syn29309', 1),
#  ('against_defaulting_on_gas_debts/syn2613658', 1),
#  ...]

# %%
conflict_pairs = entities['syria/syn11910']['conflict_actors']
cactors = set()
for pair in conflict_pairs:
    cactors.add(syn_label(pair[0]))
    cactors.add(syn_label(pair[1]))

G = nx.DiGraph()
for actor in cactors:
    G.add_node(actor)
for edge in conflict_pairs:
    G.add_edge(syn_label(edge[0]), syn_label(edge[1]))
    
nx.write_gml(G, 'syria.gml')

# %% [markdown]
# ## Factions

# %%
conflict_pairs = entities['syria/syn11910']['conflict_actors']

edges = {}
degrees = {}

for pair in conflict_pairs:
    edge = tuple(sorted(pair))
    if edge not in edges:
        edges[edge] = 0
    actor1, actor2 = edge
    if actor1 not in degrees:
        degrees[actor1] = 0
    degrees[actor1] += 1
    if actor2 not in degrees:
        degrees[actor2] = 0
    degrees[actor2] += 1
    
for edge in edges:
    edges[edge] = min([degrees[actor] for actor in edge])

sorted_edges = sorted([(edge[0], edge[1], edges[edge]) for edge in edges], key=operator.itemgetter(2), reverse=True)

factions = []
assigned = set()

def belongs_to_faction(actor, faction):
    for actor2 in faction:
        edge = tuple(sorted((actor, actor2)))
        if edge in edges:
            return False
    return True

def assign_faction(actor):
    if actor in assigned:
        return
    for faction in factions:
        if belongs_to_faction(actor, faction):
            faction.add(actor)
            assigned.add(actor)
            return
    factions.append({actor})
    assigned.add(actor)

for edge in sorted_edges:
    if len(factions) == 0:
        factions.append({edge[0]})
        factions.append({edge[1]})
        assigned.add(edge[0])
        assigned.add(edge[1])
    else:
        assign_faction(edge[0])
        assign_faction(edge[1])
        
factions
# Out:
# [{'ankara/syn20285',
#   'china/syn11901',
#   'damascus/syn16877',
#   'hezbollah/syn13331',
#   'iran/syn11989',
#   'kerry/syn157',
#   'moscow/syn12798',
#   'putin/syn339',
#   'russia/syn11969',
#   'saudi/syn75',
#   'saudi_king/syn54253',
#   'u.n./syn370'},
#  {'france/syn12543',
#   'germany/syn12662',
#   'israel/syn12009',
#   'netanyahu/syn210',
#   'obama/syn14636',
#   'syria_opposition/syn387334',
#   'turkey_pm/syn15206',
#   'turkish_pm/syn40467',
#   'u.s./syn26',
#   'united_states/syn4267'},
#  {'assad/syn15', 'turkeys/syn146090'}]

# %%
json_data = {}

for entity in entities:
    c = entities[entity]['c']
    if c > 1:
        cactors = {}
        for pair in entities[entity]['conflict_actors']:
            orig = syn_label(pair[0])
            targ = syn_label(pair[1])
            if orig not in cactors:
                cactors[orig] = 0
            if targ not in cactors:
                cactors[targ] = 0
            cactors[orig] -= 1
            cactors[targ] += 1
        topic = syn_label(entity)
        json_data[topic] = {'conflictuality': c, 'actors': cactors}
        
json_data
# Out:
# {'israel': {'conflictuality': 4,
#   'actors': {'iran': -2,
#    'russia': 2,
#    'hamas': -1,
#    'palestinian authority': 1,
#    'u.s.': -1,
#    'icc': 1}},
#  'syria': {'conflictuality': 50,
#   'actors': {'russia': -2,
#    'u.s.': 10,
#    'putin': -1,
#    'iran': -5,
#    'syria opposition': -1,
#    'bomber': -1,
#    'monitoring': 1,
#    'hezbollah': -3,
#    'israel': 4,
#    'kerry': -1,
#    'assad': 4,
#    'turkeys': 0,
#    'us and russia': 1,
#    'damascus': -1,
#    'west': 2,
#    'turkey pm': -1,
#    'turkish pm': -1,
#    'saudi king': -1,
#    'ankara': -1,
#    'moscow': 0,
#    'germany': -1,
#    'obama': -1,
#    'france': -1,
#    'netanyahu': 1,
#    'islamists': 1,
#    'united states': 1,
#    'president assad': -1,
#    'u.n.': -1,
#    'china': -1,
#    'saudi': -1,
#    'ukraine': 1}},
#  'peopled': {'conflictuality': 3,
#   'actors': {'pope': -1,
#    'europe': 1,
#    'amnesty': -1,
#    'australia': 1,
#    'u.n.': -1,
#    'germany': 1}},
#  'collapses': {'conflictuality': 2,
#   'actors': {'eu': -1, 'china': 1, 'kerry': -1, 'israel': 1}},
#  'bombings': {'conflictuality': 9,
#   'actors': {'qaeda': -1,
#    'hezbollah': 1,
#    'taliban': -1,
#    'isis': 2,
#    'hariri': -1,
#    'israel': 2,
#    'turkeys': -2,
#    'council': -1,
#    'somalia': 1,
#    'abbas': -1,
#    'hamas': 2,
#    'fatah': -1,
#    'islamic': 1,
#    'iran': -1}},
#  'iran': {'conflictuality': 8,
#   'actors': {'israel': -1,
#    'eu': 1,
#    'kerry': -1,
#    'netanyahu': -1,
#    'saudi': -1,
#    'u.s.': -1,
#    'iraqi officials': 1,
#    'west': 1,
#    'obama': 1,
#    'france': 1,
#    'u.n.': -1,
#    'australia': 1}},
#  'striking': {'conflictuality': 8,
#   'actors': {'u.s.': -1,
#    'russia': 3,
#    'israel': -1,
#    'hamas': 1,
#    'north korea': -1,
#    'assad': -1,
#    'united states': -1,
#    'syrian military': 1,
#    'karzai': -1,
#    'nato': 1}},
#  'air strikes': {'conflictuality': 2,
#   'actors': {'united states': -1,
#    'syrian military': 1,
#    'karzai': -1,
#    'nato': 1}},
#  'airing': {'conflictuality': 18,
#   'actors': {'u.s.': -7,
#    'china': 4,
#    'iran': -2,
#    'russia': 5,
#    'japan': 1,
#    'russian diplomats': -1,
#    'nato': 2,
#    'syria': -1,
#    'israel': 2,
#    'farage': -1,
#    'germany': 1,
#    'syrian regime': -1,
#    'united states': -1,
#    'syrian military': 1,
#    'vietnam': -1,
#    'karzai': -1,
#    'kerry': -1,
#    'beijing': 1}},
#  'russia': {'conflictuality': 10,
#   'actors': {'kurds': -1,
#    'turkeys': 1,
#    'pope': 0,
#    'lavrov': -1,
#    'west': 1,
#    'poland': -1,
#    'france': 1,
#    'putin': -1,
#    'eu': 0,
#    'moscow': -2,
#    'u.s.': 2,
#    'armenia': 1,
#    'assad': -1,
#    'washington': 1}},
#  'obama': {'conflictuality': 2, 'actors': {'u.s.': -2, 'pakistan': 2}},
#  'migrants': {'conflictuality': 2,
#   'actors': {'calais mayor': -1, 'uk': 2, 'germany': -1}},
#  'bookseller': {'conflictuality': 2, 'actors': {'china': 0, 'britain': 0}},
#  'hong': {'conflictuality': 3,
#   'actors': {'china': 0, 'britain': 0, 'chinese newspaper': -1, 'u.s.': 1}},
#  'china': {'conflictuality': 14,
#   'actors': {'obama': 0,
#    'china': -1,
#    'xi': -1,
#    'beijing': 1,
#    'u.s.': 1,
#    'pentagon chief': -1,
#    'taiwan': -1,
#    'armenia': 1,
#    'lawsuit': -1,
#    'ibm': 1,
#    'philippines': 2,
#    'state media': -1,
#    'trump': 1,
#    'duterte': -1}},
#  'droning': {'conflictuality': 4,
#   'actors': {'trump': -1,
#    'china': 0,
#    'courting': -1,
#    'pakistan': 1,
#    'japan': 1,
#    'hamas': -1,
#    'israel': 1}},
#  'armies': {'conflictuality': 2,
#   'actors': {'car bomb': -1, 'offic\xadials': 1, 'iran': -1, 'u.s.': 1}},
#  'bordering': {'conflictuality': 13,
#   'actors': {'turkeys': -1,
#    'russia': 1,
#    'china': -2,
#    'india': 2,
#    'moscow': -1,
#    'u.s.': 3,
#    'ukraine': -1,
#    'mexico': -2,
#    'israel': 1,
#    'iraq': -1,
#    'iran': 1,
#    'ankara': -1,
#    'assad': 1,
#    'eu': -1,
#    'bulgaria': 1,
#    'hamas': -1,
#    'egypt': 1,
#    'sudan': 0}},
#  'childs': {'conflictuality': 6,
#   'actors': {'un report': -2,
#    'israel': 2,
#    'u.n.': -2,
#    'britain': 1,
#    'vatican': 1,
#    'germany': -1,
#    'france': 1,
#    'afghan president': -1,
#    'u.s.': 1}},
#  'raids': {'conflictuality': 4,
#   'actors': {'qaeda in yemen': -1,
#    'u.s.': 1,
#    'turkish president erdogan': -1,
#    'eu': 1,
#    'israel': 0,
#    'hamas official': 1,
#    'syria': -1}},
#  'palestinian': {'conflictuality': 4,
#   'actors': {'israel': -1,
#    'u.s.': 0,
#    'israel police': 1,
#    'israeli minister': -1,
#    'kerry': 1,
#    'fatah': -1,
#    'hamas': 1}},
#  'the president': {'conflictuality': 2,
#   'actors': {'mexico': -1, 'u.s.': 2, 'china': -1}},
#  'dispute': {'conflictuality': 7,
#   'actors': {'eu': -1,
#    'turkeys': 1,
#    'china': 4,
#    'u.s.': 0,
#    'japan': -2,
#    'duterte': -1,
#    'obama': -1}},
#  'countrys': {'conflictuality': 5,
#   'actors': {'german chancellor angela merkel': -1,
#    'russia': 1,
#    'moscow': -1,
#    'kiev': 1,
#    'russian president vladimir putin': -1,
#    'u.s.': 1,
#    'china': -1,
#    'philippines': 1,
#    'saudi': -1,
#    'iran': 1}},
#  'aleppo': {'conflictuality': 5,
#   'actors': {'u.s.': -2,
#    'russia': 2,
#    'france': -2,
#    'assad': 1,
#    'syria': 1,
#    'united states': -1,
#    'syrian military': 1}},
#  'seas': {'conflictuality': 13,
#   'actors': {'obama': -2,
#    'china': 0,
#    'beijing': 1,
#    'u.s.': 0,
#    'pentagon chief': -1,
#    'philippines': 2,
#    'vietnam': 1,
#    'duterte': -1}},
#  'isis': {'conflictuality': 6,
#   'actors': {'u.s.': 1,
#    'russia': -2,
#    'turkeys': 0,
#    'iraq': 1,
#    'erdogan': 1,
#    'iran': -1}},
#  'india': {'conflictuality': 4,
#   'actors': {'u.s.': -2, 'pakistan': 3, 'modi': -1, 'china': -1, 'india': 1}},
#  'south china sea': {'conflictuality': 11,
#   'actors': {'u.s.': 0,
#    'china': -1,
#    'philippines': 1,
#    'obama administration': -1,
#    'beijing': 2,
#    'kerry': -1}},
#  'righted': {'conflictuality': 7,
#   'actors': {'european parliament': -1,
#    'turkeys': 2,
#    'un report': -1,
#    'israel': 1,
#    'north korea': -1,
#    'u.s.': 2,
#    'china': -1,
#    'u.n.': 0,
#    'watchdog': -1,
#    'russia': -1,
#    'uk': 1}},
#  'troop': {'conflictuality': 4,
#   'actors': {'russia': 1, 'u.s.': 0, 'bomber': -1, 'mali': 1, 'ukraine': -1}},
#  'bombed': {'conflictuality': 3,
#   'actors': {'ankara': -1,
#    'assad': 1,
#    'un inquiry': -1,
#    'syrian military': 1,
#    'sudan': 0}},
#  'turkeys': {'conflictuality': 2,
#   'actors': {'ankara': -1, 'assad': 1, 'eu': -1, 'bulgaria': 1}},
#  'climates': {'conflictuality': 4,
#   'actors': {'north korea': -2, 'trump': 4, 'corbyn': -1, 'china': -1}},
#  'rulings': {'conflictuality': 3,
#   'actors': {'obama': -1,
#    'china': 0,
#    'u.s.': 1,
#    'european court': -1,
#    'poland': 1}},
#  'islamic': {'conflictuality': 8,
#   'actors': {'damascus': -1,
#    'u.s.': 0,
#    'saudi king': -1,
#    'assad': 1,
#    'iran': -1,
#    'united states': 0,
#    'syria': 1,
#    'syrian military': 1,
#    'air strikes': -1,
#    'pentagon': 1,
#    'watchdog': -1,
#    'syrian government': 1,
#    'israeli minister': -1,
#    'kerry': 1}},
#  'leaks': {'conflictuality': 6,
#   'actors': {'israel': -1,
#    'palestinians': 1,
#    'u.s.': -1,
#    'russia': 1,
#    'white house': -1,
#    'moscow': 1,
#    'snowden': -1,
#    'uk': 1,
#    'britain': -1,
#    'united states': 1,
#    'assange': -1,
#    'cia': 1}},
#  'nsa': {'conflictuality': 2,
#   'actors': {'mexico': -1, 'u.s.': 1, 'lawsuit': -1, 'ibm': 1}},
#  'ukraine': {'conflictuality': 26,
#   'actors': {'the president': -1,
#    'oppositions': 1,
#    'u.s.': -1,
#    'russia': 3,
#    'poland': -1,
#    'eu': 0,
#    'west': 0,
#    'putin': 0,
#    'europe': 1,
#    'washington': -1,
#    'moscow': 3,
#    'nato': -2,
#    'white house': -1,
#    'gorbachev': -1,
#    'sweden': 1,
#    'merkel': -1}},
#  'refugees': {'conflictuality': 5,
#   'actors': {'policing': -1,
#    'sweden': 1,
#    'hungary': -1,
#    'austria': 1,
#    'rights group': -1,
#    'pakistan': 1,
#    'eu': -1,
#    'poland': 1,
#    'unhcr': -1,
#    'denmark': 1}},
#  'europe': {'conflictuality': 5,
#   'actors': {'german foreign minister': -1,
#    'russia': 2,
#    'moscow': -1,
#    'u.s.': 1,
#    'ukraine': -1,
#    'germany': -1,
#    'france': 0,
#    'united states': 1}},
#  'abuses': {'conflictuality': 4,
#   'actors': {'uk': -1,
#    'sri': 1,
#    'u.n.': -2,
#    'turkeys': 2,
#    'russia': 1,
#    'amnesty': -1}},
#  'lacked': {'conflictuality': 2,
#   'actors': {'china paper': -1, 'japan': 2, 'chinese paper': -1}},
#  'commitments': {'conflictuality': 2,
#   'actors': {'germany': -1, 'greece': 1, 'u.s.': -1, 'syria': 1}},
#  'syrian': {'conflictuality': 4,
#   'actors': {'iran': -2,
#    'russia': 2,
#    'turkish president': -1,
#    'u.s.': 2,
#    'erdogan': -1}},
#  'militants': {'conflictuality': 3,
#   'actors': {'afghanistan': -1,
#    'pakistan': 1,
#    'nigeria': -1,
#    'militaries': 1,
#    'putin': -1,
#    'u.s.': 1}},
#  'battling': {'conflictuality': 3,
#   'actors': {'iran': -1,
#    'saudi prince': 1,
#    'iran minister': -1,
#    'saudi': 1,
#    'u.s.': -1,
#    'moscow': 1}},
#  'eastern ukraine': {'conflictuality': 4,
#   'actors': {'u.s.': -1,
#    'russia': 1,
#    'kiev': 2,
#    'german fm': -1,
#    'us ambassador to un': -1}},
#  'assad': {'conflictuality': 4,
#   'actors': {'syria': -1,
#    'west': 1,
#    'saudi prince': -1,
#    'putin': 1,
#    'iran': -1,
#    'united states': 1,
#    'u.s.': -1,
#    'russia': 1}},
#  'arming': {'conflictuality': 6,
#   'actors': {'russia': -1,
#    'uk': 1,
#    'saudi prince': -1,
#    'putin': 0,
#    'israel': 0,
#    'turkeys': -1,
#    'u.s.': 1,
#    'germany': 1}},
#  'venezuela': {'conflictuality': 2,
#   'actors': {'maduro': -2, 'biden': 1, 'obama': 1}},
#  'sanctions': {'conflictuality': 6,
#   'actors': {'russia': -1,
#    'norway': 1,
#    'council': -1,
#    'north korea': 0,
#    'south': 1,
#    'eu': -1,
#    'u.s.': 2,
#    'russian diplomats': -1,
#    'kiev': 1,
#    'venezuela': -1}},
#  'european': {'conflictuality': 2,
#   'actors': {'german chancellor angela merkel': -1,
#    'russia': 1,
#    'u.s.': -1,
#    'britain': 1}},
#  'afghanistan': {'conflictuality': 2,
#   'actors': {'taliban': -1, 'isis': 1, 'amnesty': -1, 'u.s.': 1}},
#  'threating': {'conflictuality': 3,
#   'actors': {'north korea': 0,
#    'u.s.': 1,
#    'russia': -1,
#    'reporters without borders': -1,
#    'egypt': 1}},
#  'kiev': {'conflictuality': 2,
#   'actors': {'putin': -1,
#    'israel': 1,
#    'ukraine pm': -1,
#    'security forces': 1}},
#  'kidnapped': {'conflictuality': 2,
#   'actors': {'moscow': -1, 'u.s.': 2, 'venezuela': -1}},
#  'rebels': {'conflictuality': 5,
#   'actors': {'u.s.': -1,
#    'russia': 0,
#    'uk': 1,
#    'ukraine': -1,
#    'syrian army': -1,
#    'damascus': 1,
#    'kiev': 1}},
#  'at least': {'conflictuality': 2,
#   'actors': {'amnesty': -1, 'nigeria': 1, 'bomber': -1, 'offic\xadials': 1}},
#  'uk': {'conflictuality': 2,
#   'actors': {'david': -1, 'pms': 1, 'farage': -1, 'germany': 1}},
#  'convoy': {'conflictuality': 3,
#   'actors': {'u.s.': -2, 'russia': 3, 'merkel': -1}},
#  'north korea': {'conflictuality': 2,
#   'actors': {'china': -1, 'u.s.': 1, 'theresa': -1, 'trump': 1}},
#  'warring': {'conflictuality': 24,
#   'actors': {'ukraine': -1,
#    'russia': 0,
#    'amnesty': -2,
#    'israel': 7,
#    'courting': -1,
#    'pakistan': 2,
#    'syria': 0,
#    'france': 0,
#    'rights chief': -2,
#    'human rights watch': -1,
#    'sri': 1,
#    'nato': 1,
#    'obama': -1,
#    'iran': 1,
#    'north korea': -2,
#    'u.s.': -1,
#    'modi': -1,
#    'un chief': -1,
#    'assad': 2,
#    'south korea': 1,
#    'moscow': 1,
#    'un body': -1,
#    'u.n.': -1,
#    'abbas': -1,
#    'johnson': -1,
#    'saudi': 1,
#    'syrian regime': -1,
#    'icc': 1}},
#  'zoning': {'conflictuality': 4,
#   'actors': {'china': 1, 'japan': 1, 'u.s.': -2, 'kerry': -1, 'beijing': 1}},
#  'oppositions': {'conflictuality': 2,
#   'actors': {'russia': -1, 'u.s.': 2, 'venezuela': -1}},
#  'agreements': {'conflictuality': 2,
#   'actors': {'eu': -1, 'russia': 1, 'corbyn': -1, 'trump': 1}},
#  'human rights': {'conflictuality': 7,
#   'actors': {'ecuador': -1,
#    'uk': 0,
#    'u.n.': -3,
#    'turkeys': 1,
#    'sri': 1,
#    'russia': 1,
#    'u.s.': 1,
#    'amnesty': -1,
#    'spanish police': 1}},
#  'palestine': {'conflictuality': 4,
#   'actors': {'israel': 2, 'sweden': 1, 'eu': -1, 'carter': -1, 'u.s.': -1}},
#  'eu': {'conflictuality': 10,
#   'actors': {'german chancellor angela merkel': -1,
#    'russia': 0,
#    'putin': -3,
#    'ukraine': 4,
#    'germany': -1,
#    'uk': 3,
#    'white house': -1,
#    'moscow': 1,
#    'turkeys': -1,
#    'german defence minister': -1}},
#  'war crimes': {'conflictuality': 7,
#   'actors': {'amnesty': -2,
#    'israel': 4,
#    'courting': -1,
#    'pakistan': 1,
#    'rights chief': -1,
#    'human rights watch': -1,
#    'france': -1,
#    'assad': 2,
#    'u.n.': -1}},
#  'kurds': {'conflictuality': 3,
#   'actors': {'turkeys': 0, 'u.s.': 1, 'erdogan': -1, 'russia': 1, 'u.n.': -1}},
#  'debts': {'conflictuality': 2,
#   'actors': {'germany': -1, 'greece': 1, 'putin': -1, 'kiev': 1}},
#  'crimea': {'conflictuality': 6,
#   'actors': {'russia': 4,
#    'ukraine': 0,
#    'u.n.': -1,
#    'g7': -1,
#    'u.s.': -1,
#    'nato chief': -1}},
#  'prayers': {'conflictuality': 3,
#   'actors': {'jordan': -1,
#    'israel': 2,
#    'hamas': -1,
#    'ukraine': -1,
#    'churchs': 1}},
#  'priests': {'conflictuality': 3,
#   'actors': {'u.n.': -1,
#    'vatican': 1,
#    'judge': -1,
#    'churchs': 1,
#    'gunmen': -1,
#    'syria': 1}},
#  'visits': {'conflictuality': 6,
#   'actors': {'russia': -1,
#    'u.s.': 3,
#    'china': -1,
#    'india': 2,
#    'obama': -1,
#    'ukrainian president': -1,
#    'turkeys': -1}},
#  'yemen': {'conflictuality': 3,
#   'actors': {'uae': -1,
#    'pakistan': 1,
#    'iran': -1,
#    'saudi': 1,
#    'bomber': -1,
#    'offic\xadials': 1}},
#  'régions': {'conflictuality': 2,
#   'actors': {'china': -1, 'u.s.': 2, 'north korea': -1}},
#  'hostage': {'conflictuality': 2,
#   'actors': {'qaeda in yemen': -1,
#    'u.s.': 1,
#    'malaysia': -1,
#    'north korea': 1}},
#  'ba.n': {'conflictuality': 2,
#   'actors': {'france': -1, 'israel': 1, 'blatter': -1, 'united states': 1}},
#  'kashmir': {'conflictuality': 4, 'actors': {'pakistan': 0, 'india': 0}},
#  'peace talks': {'conflictuality': 2,
#   'actors': {'israel': -1, 'palestinians': 1, 'kerry': -1, 'assad': 1}},
#  'arrests': {'conflictuality': 2,
#   'actors': {'france': -1, 'turkeys': 1, 'amnesty': -1, 'egypt': 1}},
#  'militaries': {'conflictuality': 2,
#   'actors': {'china': -1, 'u.s.': 1, 'iran': -1, 'west': 1}},
#  'spying': {'conflictuality': 2,
#   'actors': {'u.s.': -1, 'russia': 1, 'lawsuit': -1, 'ibm': 1}},
#  'killings': {'conflictuality': 7,
#   'actors': {'palestinian authority': -1,
#    'israel': 1,
#    'north korea': -1,
#    'malaysia': 1,
#    'report': -1,
#    'obama': 1,
#    'u.n.': -1,
#    'turkeys': 1,
#    'ukraine': -1,
#    'russia': 1,
#    'un chief': -1,
#    'duterte': 1,
#    'egypt': -1,
#    'hamas': 1}},
#  'violations': {'conflictuality': 2,
#   'actors': {'japan': -1, 'china': 1, 'u.n.': -1, 'turkeys': 1}},
#  'rejects': {'conflictuality': 2,
#   'actors': {'syria': -1, 'west': 1, 'kremlin': -1, 'poroshenko': 1}},
#  'unity': {'conflictuality': 2,
#   'actors': {'israel': -1, 'u.s.': 1, 'abbas': -1, 'hamas': 1}},
#  'conflicts': {'conflictuality': 7,
#   'actors': {'un report': -1,
#    'israel': 1,
#    'saudi prince': -1,
#    'putin': 1,
#    'nato': -1,
#    'moscow': 1,
#    'german foreign minister': -1,
#    'u.s.': 2,
#    'russia': -1,
#    'israeli minister': -1,
#    'kerry': 1,
#    'amnesty': -1,
#    'hamas': 1}},
#  'ceasefire': {'conflictuality': 2,
#   'actors': {'ukraine pm': -1, 'putin': 1, 'russia': -1, 'u.s.': 1}},
#  'probe': {'conflictuality': 3,
#   'actors': {'rights chief': -1,
#    'sri': 1,
#    'brazil': -1,
#    'policing': 1,
#    'u.s.': -1,
#    'icc': 1}},
#  'tortured': {'conflictuality': 2,
#   'actors': {'amnesty': -1, 'china': 1, 'un report': -1, 'israel': 1}},
#  'erdogan': {'conflictuality': 2,
#   'actors': {'turkeys': -2, 'germany': 1, 'u.s.': 1}},
#  'lama': {'conflictuality': 5, 'actors': {'china': -5, 'india': 4, 'u.s.': 1}},
#  'jerusalem': {'conflictuality': 3,
#   'actors': {'turkeys': -1,
#    'israel': 2,
#    'hamas': -1,
#    'trump': 1,
#    'abbas': -1}},
#  'return\xaded': {'conflictuality': 2,
#   'actors': {'rights group': -1, 'pakistan': 1, 'china': -1, 'taiwan': 1}},
#  'japan': {'conflictuality': 2,
#   'actors': {'china': -2, 'tokyo': 1, 'u.s.': 1}},
#  'defences': {'conflictuality': 3, 'actors': {'china': 1, 'u.s.': -1}},
#  'islands': {'conflictuality': 2,
#   'actors': {'china': -1, 'u.s.': 0, 'beijing': 1}},
#  'securities': {'conflictuality': 4,
#   'actors': {'turkeys': -1,
#    'russia': 0,
#    'u.s.': 1,
#    'saudi': -1,
#    'iran': 1,
#    'german defence minister': -1,
#    'uk': 1}},
#  'summit': {'conflictuality': 2,
#   'actors': {'uk': -1, 'sri': 1, 'theresa': -1, 'sturgeon': 1}},
#  'in syria': {'conflictuality': 2,
#   'actors': {'syria opposition': -1, 'russia': 0, 'u.s.': 1}},
#  'russian': {'conflictuality': 2,
#   'actors': {'moscow': -1, 'germany': 1, 'russian diplomats': -1, 'kiev': 1}},
#  'taiwan': {'conflictuality': 3,
#   'actors': {'state media': -1, 'trump': 1, 'china': -2, 'u.s.': 2}},
#  'chemical weapons': {'conflictuality': 5,
#   'actors': {'amnesty': -2,
#    'sudan': 2,
#    'watchdog': -1,
#    'syrian government': 1,
#    'washington': -1,
#    'assad': 2,
#    'u.s.': -1}},
#  'nato': {'conflictuality': 3,
#   'actors': {'moscow': -1,
#    'u.s.': 1,
#    'kremlin': -1,
#    'ukraine': 1,
#    'russia': -1,
#    'finland': 1}},
#  'genocides': {'conflictuality': 7,
#   'actors': {'rwandan president': -1,
#    'france': 1,
#    'turkeys': -2,
#    'belgium': 1,
#    'croatia': -1,
#    'serbia': 1,
#    'abbas': -1,
#    'israel': 1,
#    'germany': 1,
#    'russia': -1,
#    'ukraine': 1,
#    'saudi': -1,
#    'syria': 1}},
#  'armenian': {'conflictuality': 2,
#   'actors': {'turkeys': -2, 'belgium': 1, 'germany': 1}},
#  'memberships': {'conflictuality': 2,
#   'actors': {'russia': -1, 'nato': 1, 'eu leaders': -1, 'david': 1}},
#  'pact': {'conflictuality': 2,
#   'actors': {'eu': -1, 'russia': 1, 'north korea': -1, 'trump': 1}},
#  'hamas': {'conflictuality': 3,
#   'actors': {'hezbollah': -1, 'israel': 1, 'rights chief': -1, 'abbas': 1}},
#  'libya': {'conflictuality': 2,
#   'actors': {'car bomb': -1, 'offic\xadials': 1, 'u.s.': -1, 'moscow': 1}},
#  'oils': {'conflictuality': 6,
#   'actors': {'u.s.': -1,
#    'venezuela': 0,
#    'u.n.': -1,
#    'saudi': 0,
#    'russia': -1,
#    'erdogan': 1,
#    'moscow': 1,
#    'trump': 1}},
#  'palestinians': {'conflictuality': 9,
#   'actors': {'hrw': -1,
#    'israel': 8,
#    'palestinian authority president mahmoud abbas': -1,
#    'world powers': -1,
#    'un rights expert': -1,
#    'france': -1,
#    'amnesty': -2,
#    'hamas': 1,
#    'u.s.': -1,
#    'un agency': -1}},
#  'paris': {'conflictuality': 6,
#   'actors': {'david': -1,
#    'pms': 1,
#    'french president': -1,
#    'islamic': 1,
#    'north korea': -2,
#    'trump': 3,
#    'french president francois hollande': -1,
#    'isis': 1,
#    'corbyn': -1}},
#  'embassy': {'conflictuality': 4,
#   'actors': {'russia': -1,
#    'uk': 1,
#    'iran': -2,
#    'saudi': 1,
#    'hamas': -1,
#    'trump': 1,
#    'saudis': 1}},
#  'jets': {'conflictuality': 4,
#   'actors': {'russia': 0, 'israel': 1, 'china': 0, 'japan': 0, 'poland': -1}},
#  'gaza': {'conflictuality': 20,
#   'actors': {'amnesty': -2,
#    'israel': 6,
#    'u.n.': -2,
#    'hamas': 7,
#    'rights chief': -1,
#    'un report': -1,
#    'human rights watch': -2,
#    'egypt': 2,
#    'un body': -1,
#    'harper': -1,
#    'abbas': -1,
#    'fatah': -1,
#    'europe': -1,
#    'brazilian president': -1,
#    'islamic jihad': -1}},
#  'aiding': {'conflictuality': 10,
#   'actors': {'pakistan': -2,
#    'india': 2,
#    'west': -1,
#    'russia': 4,
#    'u.s.': -5,
#    'kerry': -1,
#    'sudan': 1,
#    'eu': -1,
#    'palestinians': 1,
#    'moscow': 1,
#    'iraqi officials': 1}},
#  'tunnels': {'conflictuality': 3,
#   'actors': {'u.n.': -1, 'hamas': 1, 'un agency': -1, 'egypt': 1}},
#  'cyber': {'conflictuality': 8,
#   'actors': {'malta': -1,
#    'russia': 1,
#    'russian president vladimir putin': -1,
#    'u.s.': 4,
#    'obama': -1,
#    'china': 2,
#    'saudi': -1,
#    'iran': 1,
#    'north korea': -2,
#    'n.': -1,
#    'canada': -1}},
#  'deportation': {'conflictuality': 2,
#   'actors': {'eu': -1, 'sweden': 1, 'ukraine': -1, 'russia': 1}},
#  'worsening': {'conflictuality': 3,
#   'actors': {'u.s.': 0, 'moscow': 1, 'iran': -1, 'japan': -1, 'china': 1}},
#  'damascus': {'conflictuality': 5,
#   'actors': {'syria': -2,
#    'israel': 3,
#    'syrian opposition': -1,
#    'assad': 1,
#    'u.s.': -1}},
#  'coldest': {'conflictuality': 2,
#   'actors': {'russia': -2, 'nato': 1, 'ukraine': 1}},
#  'walled': {'conflictuality': 4,
#   'actors': {'jordan': -1,
#    'israel': 1,
#    'carter': -1,
#    'china': 1,
#    'mexico': -2,
#    'u.s.': 2}},
#  'homing': {'conflictuality': 2,
#   'actors': {'u.n.': -1, 'israel': 1, 'abbas': -1, 'hamas': 1}},
#  'planing': {'conflictuality': 5,
#   'actors': {'putin': -1,
#    'eu': 1,
#    'syria': -1,
#    'west': 1,
#    'u.s.': -1,
#    'europe': 1,
#    'china': -1,
#    'japan': 1,
#    'un chief': -1,
#    'israel': 1}},
#  'settlement': {'conflictuality': 5,
#   'actors': {'israel': 3,
#    'britain': 1,
#    'eu': -1,
#    'white house': -1,
#    'u.n.': -1,
#    'un chief': -1}},
#  'airstrikes': {'conflictuality': 3,
#   'actors': {'russia': -1,
#    'u.s.': 2,
#    'iran': -1,
#    'saudi': 1,
#    'afghan president': -1}},
#  'nukes': {'conflictuality': 2,
#   'actors': {'south korea': -1, 'north korea': 2, 'kerry': -1}},
#  'deliveries': {'conflictuality': 3,
#   'actors': {'putin': -1, 'israel': 0, 'russia': 2, 'ukraine': -1}},
#  'rows': {'conflictuality': 3,
#   'actors': {'bahrain': -1,
#    'qatar': 1,
#    'germany': -1,
#    'turkeys': 2,
#    'eu': -1}},
#  'seizure': {'conflictuality': 3,
#   'actors': {'japan': -1,
#    'china': 0,
#    'u.s.': 1,
#    'israelis': -1,
#    'archbishop': 1}},
#  'rises': {'conflictuality': 5,
#   'actors': {'the president': -1,
#    'oppositions': 1,
#    'british lawmakers': -2,
#    'israel': 2,
#    'saudi king': -1,
#    'assad': 1,
#    'israeli minister': -1,
#    'kerry': 1}},
#  'jihadists': {'conflictuality': 3,
#   'actors': {'tunisia': -1,
#    'turkeys': 1,
#    'iraqi pm': -1,
#    'kurds': 1,
#    'french forces': -1,
#    'offic\xadials': 1}},
#  'treaty': {'conflictuality': 3,
#   'actors': {'u.s.': -2, 'russia': 2, 'britain': -1, 'china': 1}},
#  'jong un': {'conflictuality': 2, 'actors': {'north korea': -2, 'cia': 2}},
#  'incidents': {'conflictuality': 2,
#   'actors': {'china': -1, 'britain': 1, 'russia': -1, 'turkeys': 1}},
#  'risking': {'conflictuality': 5,
#   'actors': {'saudi': -1,
#    'trump': 1,
#    'russia': -1,
#    'u.s.': 2,
#    'china': -1,
#    'iran': -1,
#    'west': 1,
#    'egypt official': -1,
#    'hamas': 1}},
#  'to make': {'conflictuality': 2,
#   'actors': {'farage': -1, 'eu': 1, 'snowden': -1, 'uk': 1}},
#  'islamabad': {'conflictuality': 2, 'actors': {'pakistan': -2, 'india': 2}},
#  'referendum': {'conflictuality': 2,
#   'actors': {'eu leaders': -1, 'david': 1, 'germany': -1, 'turkeys': 1}},
#  'coup': {'conflictuality': 3,
#   'actors': {'maduro': -1,
#    'obama': 1,
#    'venezuela': -1,
#    'u.s.': 1,
#    'turkeys': -1,
#    'germany': 1}},
#  'deadly attack': {'conflictuality': 2,
#   'actors': {'iran': -1, 'saudi': 1, 'syria': -1, 'israel': 1}},
#  'fossil': {'conflictuality': 4,
#   'actors': {'saudi prince': -1,
#    'putin': 1,
#    'west': -1,
#    'russia': 1,
#    'nepal': -1,
#    'india': 1,
#    'russian diplomats': -1,
#    'kiev': 1}},
#  'taliban': {'conflictuality': 3,
#   'actors': {'afghanistan': -2,
#    'pakistan': 1,
#    'india': -1,
#    'united nations': 1,
#    'iran': 1}},
#  'amid': {'conflictuality': 6,
#   'actors': {'china': -1,
#    'tokyo': 1,
#    'lawsuit': -1,
#    'ibm': 1,
#    'nepal': -1,
#    'india': 1,
#    'hungary': -1,
#    'croatia': 1,
#    'iran': -1,
#    'u.s.': 0,
#    'russia': 1}},
#  'prisons': {'conflictuality': 2,
#   'actors': {'amnesty': -1, 'china': 1, 'european court': -1, 'poland': 1}},
#  'africa': {'conflictuality': 2,
#   'actors': {'\xadgovernment': -1, 'shells': 1, 'north korea': -1, 'u.s.': 1}},
#  'gulf': {'conflictuality': 2,
#   'actors': {'bahrain': -1, 'qatar': 0, 'uae': 1}},
#  'escalation': {'conflictuality': 2,
#   'actors': {'u.s.': -1, 'iran': 1, 'islamic jihad': -1, 'israel': 1}},
#  'violating': {'conflictuality': 8,
#   'actors': {'ukraine': -1,
#    'russia': 2,
#    'britain': -1,
#    'spain': 1,
#    'u.s.': -2,
#    'un committee': -1,
#    'germany': 1,
#    'china': -1,
#    'coca': 1,
#    'us and uk': 1,
#    'amnesty': -1,
#    'spanish police': 1}},
#  'declares': {'conflictuality': 4,
#   'actors': {'ukraine': -1,
#    'russia': 1,
#    'china': 0,
#    'soros': 1,
#    'u.s.': -1,
#    'syrian regime': -1,
#    'israel': 1}},
#  'waters': {'conflictuality': 2,
#   'actors': {'pakistan': -1, 'india': 1, 'canada': -1, 'abbas': 1}},
#  'failures': {'conflictuality': 2,
#   'actors': {'iran': -1, 'west': 1, 'eu': -1, 'greece': 1}},
#  'washington': {'conflictuality': 2,
#   'actors': {'putin': -1, 'u.s.': 1, 'white house': -1, 'russia': 1}},
#  'invites': {'conflictuality': 3, 'actors': {'china': -3, 'india': 3}},
#  'gases': {'conflictuality': 4,
#   'actors': {'putin': -3,
#    'eu': 1,
#    'syria': -1,
#    'france': 1,
#    'ukraine': 1,
#    'kiev': 1}},
#  'hackings': {'conflictuality': 2,
#   'actors': {'china': -1, 'u.s.': 2, 'bolivian': -1}},
#  'stampede': {'conflictuality': 2, 'actors': {'iran': -2, 'saudi': 2}},
#  'deploys': {'conflictuality': 5,
#   'actors': {'china': -2,
#    's.': 1,
#    'india': 1,
#    'north korea': -1,
#    'united states': 1,
#    'russia': 0,
#    'u.s.': 1,
#    'ukraine': -1}},
#  'tensions': {'conflictuality': 12,
#   'actors': {'u.s.': -1,
#    'china': 0,
#    'russia': 1,
#    'sweden': 1,
#    'syrian army': -1,
#    'turkeys': 1,
#    'japan': 1,
#    'beijing': 1,
#    'obama administration': -1,
#    'ukraine': -1,
#    'iran': -1}},
#  'tying': {'conflictuality': 4,
#   'actors': {'german chancellor angela merkel': -1,
#    'russia': 1,
#    'japan': -2,
#    'china': 2,
#    'israeli minister': -1,
#    'kerry': 1}},
#  'territories': {'conflictuality': 2,
#   'actors': {'putin': -1, 'ukraine': 1, 'white house': -1, 'russia': 1}},
#  'international waters': {'conflictuality': 2,
#   'actors': {'u.s.': -1, 'china': 2, 'trump': -1}},
#  'demolishes': {'conflictuality': 2, 'actors': {'u.s.': -2, 'israel': 2}},
#  'crises': {'conflictuality': 8,
#   'actors': {'russia': -1,
#    'u.s.': 1,
#    'iran': -1,
#    'israel': 1,
#    'ukraine': -1,
#    'hungary': -1,
#    'austria': 1,
#    'nepal': -1,
#    'india': 1,
#    'qatar': -1,
#    'uae': 1,
#    'sweden': 1,
#    'russian diplomats': -1,
#    'kiev': 1}},
#  'weaponed': {'conflictuality': 11,
#   'actors': {'u.s.': -1,
#    'syria': 2,
#    'russia': 0,
#    'turkeys': 0,
#    'yemen': -1,
#    'iran': 2,
#    'ukraine': -1,
#    'u.n.': 1,
#    'north korea': -1,
#    'trump': -1,
#    'watchdog': -1,
#    'syrian government': 1}},
#  'diplomat': {'conflictuality': 2, 'actors': {'u.s.': -2, 'russia': 2}},
#  'tanking': {'conflictuality': 2, 'actors': {'ukraine': -2, 'russia': 2}},
#  'shia': {'conflictuality': 2,
#   'actors': {'bombings': -1, 'iraq': 1, 'iran': -1, 'bahrain': 1}},
#  'deployment': {'conflictuality': 3,
#   'actors': {'u.s.': 1, 'china': 0, 'moscow': -1}},
#  'protesting': {'conflictuality': 4,
#   'actors': {'the president': -1,
#    'oppositions': 1,
#    'amnesty': -1,
#    'turkeys': 1,
#    'israelis': -1,
#    'archbishop': 1,
#    'chinese newspaper': -1,
#    'u.s.': 1}},
#  'airspace': {'conflictuality': 2,
#   'actors': {'ukraine': -1, 'russia': 1, 'japan': -1, 'china': 1}},
#  'baltic sea': {'conflictuality': 2,
#   'actors': {'lithuania': -1, 'russia': 0, 'sweden': 1}},
#  'middle east': {'conflictuality': 5,
#   'actors': {'saudi prince': -1,
#    'putin': 1,
#    'turkish president': -1,
#    'iran': 2,
#    'abbas': -1,
#    'israel': 1,
#    'saudi': -1,
#    'russia': -1,
#    'u.s.': 1}},
#  'liu': {'conflictuality': 2, 'actors': {'malala': -2, 'china': 2}},
#  'assaults': {'conflictuality': 2,
#   'actors': {'turkeys': -1, 'u.s.': 1, 'manned': -1, 'womans': 1}},
#  'bbc': {'conflictuality': 5,
#   'actors': {'china': -1,
#    'india': 1,
#    'germany': -1,
#    'turkeys': 1,
#    'u.s.': 0,
#    'iran': 1,
#    'johnson': -1,
#    'saudi': 1,
#    'mexico': -1}},
#  'rising tensions': {'conflictuality': 3,
#   'actors': {'u.s.': 0, 'china': 1, 'obama administration': -1}},
#  'regimes': {'conflictuality': 4,
#   'actors': {'lavrov': -1,
#    'west': 2,
#    'venezuela': -1,
#    'u.s.': 1,
#    'russia': -1,
#    'un agency': -1,
#    'israel': 1}},
#  'plotting': {'conflictuality': 5,
#   'actors': {'north korea': -3,
#    'cia': 2,
#    'policing': -1,
#    'sweden': 1,
#    'u.s.': 1,
#    'kiev': -1,
#    'moscow': 1}},
#  'flights': {'conflictuality': 2,
#   'actors': {'ukraine': -1, 'russia': 1, 'damascus': -1, 'turkeys': 1}},
#  'resolutions': {'conflictuality': 3,
#   'actors': {'israel': -1,
#    'britain': 1,
#    'turkeys': -1,
#    'belgium': 1,
#    'china': -1,
#    'japan': 1}},
#  'abducted': {'conflictuality': 2,
#   'actors': {'ukraine': -1, 'russia': 1, 'taiwan': -1, 'china': 1}},
#  'shielding': {'conflictuality': 2,
#   'actors': {'ukraine': -1, 'moscow': 0, 'u.s.': 1}},
#  'expansions': {'conflictuality': 3,
#   'actors': {'eu': -1,
#    'israel': 1,
#    'assad': -1,
#    'france': 1,
#    'russia': -1,
#    'turkeys': 1}},
#  'protesters': {'conflictuality': 3,
#   'actors': {'policing': -1,
#    'hong': 1,
#    'ukraine': -1,
#    'churchs': 1,
#    'china': -1,
#    'u.s.': 1}},
#  'defenses': {'conflictuality': 9,
#   'actors': {'iran': -2,
#    'russia': 3,
#    'china': -3,
#    'japan': 1,
#    's.': 1,
#    'tokyo': 1,
#    'russian diplomats': -1,
#    'nato': 2,
#    'obama': -1,
#    'u.s.': -1,
#    'kerry': -1,
#    'beijing': 1}},
#  'pledge': {'conflictuality': 2,
#   'actors': {'israel': -1, 'sweden': 1, 'netanyahu': -1, 'west': 1}},
#  'remarks': {'conflictuality': 4,
#   'actors': {'turkish president erdogan': -1,
#    'eu': 1,
#    'venezuela': -1,
#    'u.s.': 2,
#    'turkeys': -1,
#    'germany': 1,
#    'china': -1}},
#  'chemical attack': {'conflictuality': 2, 'actors': {'u.s.': -2, 'syria': 2}},
#  'cleansing': {'conflictuality': 3,
#   'actors': {'turkey pm': -1, 'russia': 3, 'turkish pm': -1, 'turkeys': -1}},
#  'lifes': {'conflictuality': 2,
#   'actors': {'russia': -1,
#    'united states': 1,
#    'egypt official': -1,
#    'hamas': 1}},
#  'democracies': {'conflictuality': 2,
#   'actors': {'european parliament': -1,
#    'turkeys': 1,
#    'policing': -1,
#    'hong': 1}},
#  'delays': {'conflictuality': 2,
#   'actors': {'russia': -1, 'uk': 1, 'kurdish official': -1, 'turkeys': 1}},
#  'nazi': {'conflictuality': 3,
#   'actors': {'erdogan': -1, 'germany': 0, 'turkeys': 2, 'eu': -1}},
#  'tripped': {'conflictuality': 2, 'actors': {'u.s.': -2, 'pakistan': 2}},
#  'warships': {'conflictuality': 4,
#   'actors': {'poland': -1,
#    'france': 1,
#    'u.s.': 0,
#    'iran': 1,
#    'china': -1,
#    'russia': -1,
#    'turkeys': 1}},
#  'govt': {'conflictuality': 3,
#   'actors': {'cuba': -1,
#    'u.s.': 1,
#    'malala': -1,
#    'china': 1,
#    'un chief': -1,
#    'syria': 1}},
#  'separatists': {'conflictuality': 2,
#   'actors': {'amnesty': -1, 'nigeria': 1, 'u.s.': -1, 'russia': 1}},
#  'buddhist': {'conflictuality': 2, 'actors': {'china': -2, 'india': 2}},
#  'strains': {'conflictuality': 2,
#   'actors': {'ukraine pm': -1, 'putin': 1, 'saudi': -1, 'u.s.': 1}},
#  'imposes': {'conflictuality': 2,
#   'actors': {'north korea': -1, 'u.n.': 1, 'un agency': -1, 'israel': 1}},
#  'demonstrations': {'conflictuality': 2,
#   'actors': {'austria': -1, 'turkeys': 1, 'amnesty': -1, 'israel': 1}},
#  'beirut': {'conflictuality': 2,
#   'actors': {'hariri': -1, 'israel': 2, 'iran': -1}},
#  'world news': {'conflictuality': 2,
#   'actors': {'beijing': -1, 'u.s.': 1, 'syrian regime': -1, 'israel': 1}},
#  'provocation': {'conflictuality': 7,
#   'actors': {'china': -3,
#    'u.s.': 3,
#    'russia': -1,
#    'trump administration': -1,
#    'north korea': 2,
#    'serbia': -1,
#    'albania': 1}},
#  'gaza conflict': {'conflictuality': 2,
#   'actors': {'un report': -1, 'israel': 1, 'amnesty': -1, 'hamas': 1}},
#  'sovereignty': {'conflictuality': 4,
#   'actors': {'xi': -1,
#    'obama': 1,
#    'britain': -1,
#    'spain': 1,
#    'china': -1,
#    'u.s.': 1,
#    'nato': -1,
#    'russia': 1}},
#  'humanities': {'conflictuality': 2,
#   'actors': {'turkish minister': -1, 'germany': 1, 'moscow': -1, 'kiev': 1}},
#  'escalating': {'conflictuality': 4,
#   'actors': {'eu': -1,
#    'turkeys': 2,
#    'russia': -1,
#    'sweden': 1,
#    'syrian army': -1,
#    'nato': -1,
#    'moscow': 1}},
#  'blockade': {'conflictuality': 2,
#   'actors': {'nepal': -1, 'india': 1, 'russia': -1, 'kiev': 1}},
#  'sparks': {'conflictuality': 2,
#   'actors': {'china': -1, 'u.s.': 1, 'eu': -1, 'turkeys': 1}},
#  'equipments': {'conflictuality': 2, 'actors': {'china': -2, 'coca': 2}},
#  'civilian deaths': {'conflictuality': 3,
#   'actors': {'u.s.': 1, 'russia': 0, 'amnesty': -1}},
#  'dividing': {'conflictuality': 2,
#   'actors': {'german foreign minister': -1,
#    'russia': 1,
#    'sarkozy': -1,
#    'hollande': 1}},
#  'crossings': {'conflictuality': 2,
#   'actors': {'israel': -1, 'hamas': 1, 'iraq': -1, 'iran': 1}},
#  'devastating': {'conflictuality': 2,
#   'actors': {'russia': -1, 'rebels': 1, 'assange': -1, 'cia': 1}},
#  'visas': {'conflictuality': 2,
#   'actors': {'russia': -1, 'uk': 1, 'turkeys': -1, 'eu': 1}},
#  'terror attack': {'conflictuality': 2,
#   'actors': {'u.s.': -1, 'pakistan': 1, 'iran': -1, 'saudi': 1}},
#  'undermining': {'conflictuality': 4,
#   'actors': {'turkeys': -1,
#    'iraq': 1,
#    'italy': -1,
#    'germany': 1,
#    'theresa': -1,
#    'sturgeon': 1,
#    'saudi': -1,
#    'iran': 1}},
#  'abandoning': {'conflictuality': 2,
#   'actors': {'putin': -1, 'eu': 1, 'china': -1, 'trump': 1}},
#  'stoking': {'conflictuality': 2,
#   'actors': {'farage': -1, 'eu': 1, 'china': -1, 'u.s.': 1}},
#  'destabilising': {'conflictuality': 2,
#   'actors': {'china': -1, 'u.s.': 1, 'president assad': -1, 'israel': 1}},
#  'east ukraine': {'conflictuality': 2,
#   'actors': {'ukraine pm': -1, 'putin': 1, 'kiev': -1, 'russia': 1}},
#  'bodyguards': {'conflictuality': 2, 'actors': {'turkeys': -2, 'u.s.': 2}},
#  'middled': {'conflictuality': 4,
#   'actors': {'philippine president': -1,
#    'u.s.': 3,
#    'obama': -1,
#    'iran': 0,
#    'german foreign minister': -1}},
#  'annexed': {'conflictuality': 3,
#   'actors': {'g7': -1, 'russia': 2, 'u.s.': -1, 'putin': -1, 'ukraine': 1}},
#  'carrying out': {'conflictuality': 2,
#   'actors': {'united states': -1,
#    'syrian military': 1,
#    'brazilian president': -1,
#    'israel': 1}},
#  'misinformation': {'conflictuality': 2,
#   'actors': {'malaysia': -2, 'switzerland': 2}},
#  'targeted by': {'conflictuality': 2, 'actors': {'u.s.': -2, 'russia': 2}},
#  'sisi': {'conflictuality': 2,
#   'actors': {'ministry': -1, 'egypt': 0, 'hamas': 1}},
#  'proxy': {'conflictuality': 2,
#   'actors': {'modi': -1, 'pakistan': 1, 'johnson': -1, 'saudi': 1}},
#  'sabotage': {'conflictuality': 4,
#   'actors': {'rights chief': -1,
#    'sri': 1,
#    'putin': -1,
#    'ukraine': 1,
#    'israel': -1,
#    'abbas': 1,
#    'north korea': -1,
#    'u.s.': 1}},
#  'crimean': {'conflictuality': 2,
#   'actors': {'ukraine': -1,
#    'russia': 1,
#    'ukrainian president': -1,
#    'india': 1}},
#  'pursuing': {'conflictuality': 2,
#   'actors': {'yemen': -1, 'iran': 2, 'trump': -1}},
#  'harassing': {'conflictuality': 2,
#   'actors': {'lithuania': -1, 'russia': 2, 'u.s.': -1}},
#  'meddling in': {'conflictuality': 2,
#   'actors': {'german defence minister': -1,
#    'uk': 1,
#    'france': -1,
#    'russia': 1}},
#  'at risk': {'conflictuality': 2,
#   'actors': {'china': -1, 'u.s.': 1, 'egypt official': -1, 'hamas': 1}},
#  'convoy in syria': {'conflictuality': 2, 'actors': {'u.s.': -2, 'russia': 2}},
#  'aid convoy in syria': {'conflictuality': 2,
#   'actors': {'u.s.': -2, 'russia': 2}},
#  'south china sea ruling': {'conflictuality': 2,
#   'actors': {'obama': -1, 'china': 0, 'u.s.': 1}},
#  'sea dispute': {'conflictuality': 2,
#   'actors': {'u.s.': -1, 'china': 2, 'obama': -1}},
#  'barack': {'conflictuality': 2, 'actors': {'u.s.': -2, 'pakistan': 2}},
#  'state in syria': {'conflictuality': 2,
#   'actors': {'damascus': -1, 'u.s.': 1, 'iran': -1, 'united states': 1}},
#  "barack obama 's trip": {'conflictuality': 2,
#   'actors': {'u.s.': -2, 'pakistan': 2}},
#  "barack obama 's india trip": {'conflictuality': 2,
#   'actors': {'u.s.': -2, 'pakistan': 2}},
#  'schoolchildren': {'conflictuality': 2,
#   'actors': {'air strikes': -1, 'monitoring': 1, 'eu': -1, 'hungary': 1}},
#  'use of force': {'conflictuality': 2,
#   'actors': {'japanese pm': -1, 'china': 1, 'amnesty': -1, 'israel': 1}},
#  'plotting against': {'conflictuality': 2,
#   'actors': {'bolivia': -1,
#    'united states': 1,
#    'palestinian authority': -1,
#    'hamas': 1}},
#  'for rising tensions in south china sea': {'conflictuality': 3,
#   'actors': {'u.s.': 0, 'china': 1, 'obama administration': -1}},
#  'rising tensions in south china sea': {'conflictuality': 3,
#   'actors': {'u.s.': 0, 'china': 1, 'obama administration': -1}},
#  'invite to dalai lama': {'conflictuality': 2,
#   'actors': {'china': -2, 'india': 2}},
#  "violating 's": {'conflictuality': 2,
#   'actors': {'ecuador': -1, 'uk': 1, 'nato': -1, 'russia': 1}},
#  'interfering in': {'conflictuality': 2,
#   'actors': {'german chancellor angela merkel': -1,
#    'russia': 1,
#    'bulgaria': -1,
#    'turkeys': 1}},
#  'hyping up': {'conflictuality': 3,
#   'actors': {'beijing': -1, 'u.s.': 3, 'china': -2}},
#  'back aid to islamabad': {'conflictuality': 2,
#   'actors': {'pakistan': -2, 'india': 2}},
#  'aid to islamabad': {'conflictuality': 2,
#   'actors': {'pakistan': -2, 'india': 2}},
#  'air defenses': {'conflictuality': 3,
#   'actors': {'iran': -2, 'russia': 2, 'russian diplomats': -1, 'nato': 1}},
#  'of giving israel codes for syrian air defense': {'conflictuality': 2,
#   'actors': {'iran': -2, 'russia': 2}},
#  'codes for syrian air defense': {'conflictuality': 2,
#   'actors': {'iran': -2, 'russia': 2}},
#  'giving israel codes for syrian air defenses': {'conflictuality': 2,
#   'actors': {'iran': -2, 'russia': 2}},
#  'militarization': {'conflictuality': 2,
#   'actors': {'pentagon chief': -1, 'beijing': 2, 'u.s.': -1}},
#  'commonwealth': {'conflictuality': 2,
#   'actors': {'sri': 0, 'canada': 1, 'uk': -1}},
#  'implementing': {'conflictuality': 3, 'actors': {'putin': -3, 'ukraine': 3}},
#  'killed by us led strikes': {'conflictuality': 2,
#   'actors': {'u.s.': -2, 'russia': 2}},
#  'killed by led': {'conflictuality': 2, 'actors': {'u.s.': -2, 'russia': 2}},
#  'war crimes in gaza': {'conflictuality': 2,
#   'actors': {'rights chief': -1, 'israel': 2, 'human rights watch': -1}},
#  'our enemies': {'conflictuality': 3,
#   'actors': {'turkeys': -2, 'germany': 2, 'n.': -1, 'malaysia': 1}},
#  'to its enemies': {'conflictuality': 2,
#   'actors': {'turkeys': -2, 'germany': 2}},
#  'cleansing in syria': {'conflictuality': 2,
#   'actors': {'turkey pm': -1, 'russia': 2, 'turkish pm': -1}},
#  'chemical weapons use': {'conflictuality': 2,
#   'actors': {'u.s.': -2, 'syria': 2}},
#  'alarming provocations': {'conflictuality': 2,
#   'actors': {'u.s.': -2, 'iran': 2}},
#  'isolation': {'conflictuality': 2,
#   'actors': {'carter': -1, 'china': 1, 'biden': -1, 'russia': 1}},
#  'new violence in eastern ukraine': {'conflictuality': 2,
#   'actors': {'russia': 0, 'kiev': 1, 'us ambassador to un': -1}},
#  'violence in eastern ukraine': {'conflictuality': 2,
#   'actors': {'russia': 0, 'kiev': 1, 'us ambassador to un': -1}},
#  'for new violence in eastern ukraine': {'conflictuality': 2,
#   'actors': {'russia': 0, 'kiev': 1, 'us ambassador to un': -1}},
#  'video message': {'conflictuality': 2, 'actors': {'isil': -2, 'hamas': 2}},
#  'in video message': {'conflictuality': 2, 'actors': {'isil': -2, 'hamas': 2}},
#  'of promoting terrorism': {'conflictuality': 2,
#   'actors': {'indian pm modi': -1, 'pakistan': 1, 'iran': -1, 'saudi': 1}},
#  'promoting terrorism': {'conflictuality': 2,
#   'actors': {'indian pm modi': -1, 'pakistan': 1, 'iran': -1, 'saudi': 1}},
#  'contrition': {'conflictuality': 2,
#   'actors': {'china paper': -1, 'japan': 2, 'chinese paper': -1}},
#  'hypocrisy': {'conflictuality': 4,
#   'actors': {'johnson': -1,
#    'barack obama': 1,
#    'russia': -1,
#    'uk': 1,
#    'erdogan': -1,
#    'paris': 1,
#    'china': -1,
#    'u.s.': 1}},
#  'china sea': {'conflictuality': 2, 'actors': {'japan': -2, 'china': 2}},
#  'east china sea dispute': {'conflictuality': 2,
#   'actors': {'japan': -2, 'china': 2}},
#  'lure': {'conflictuality': 2,
#   'actors': {'obama': -1, 'iran': 1, 'bahrain': -1, 'qatar': 1}},
#  'joining nato': {'conflictuality': 2,
#   'actors': {'kremlin': -1, 'ukraine': 1, 'russia': -1, 'finland': 1}},
#  'against joining nato': {'conflictuality': 2,
#   'actors': {'kremlin': -1, 'ukraine': 1, 'russia': -1, 'finland': 1}},
#  '1987': {'conflictuality': 2, 'actors': {'u.s.': -2, 'russia': 2}},
#  'bio': {'conflictuality': 2,
#   'actors': {'north korea': -2, 'cia': 1, 'u.s.': 1}},
#  'pulling out of': {'conflictuality': 2,
#   'actors': {'north korea': -2, 'trump': 2}},
#  'force against palestinians': {'conflictuality': 2,
#   'actors': {'un rights expert': -1, 'israel': 2, 'u.s.': -1}},
#  'aggressive’ acts': {'conflictuality': 2,
#   'actors': {'turkeys': -2, 'u.s.': 2}},
#  'double standards': {'conflictuality': 2,
#   'actors': {'russia': -2, 'eu': 1, 'u.s.': 1}},
#  'nuke test': {'conflictuality': 2,
#   'actors': {'south korea': -1, 'north korea': 2, 'kerry': -1}},
#  'working with': {'conflictuality': 2,
#   'actors': {'netanyahu': -1, 'obama': 1, 'n.': -1, 'malaysia': 1}}}

# %%
syn.synonyms(hg, 'us_and_russia/syn145926')
syn.synonyms(hg, 'turkeys/syn146090')
syn_label('turkeys/syn146090')
# Out:
# 'turkey'
