# %% [markdown]
# # News Analysis

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import operator
import math
import progressbar
import json as j
from unidecode import unidecode
import networkx as nx
from gb.notebook import *
import gb.synonyms.synonyms as syn
import gb.nlp.parser as par
from gb.metrics.hyper_similarity import HyperSimilarity

# %% [markdown]
# ### HyperGraph, etc.

# %%
MAX_PROB = -12
hg = init_hypergraph('../reddit-worldnews-01012013-01082017-new-inference3.hg')
hs = HyperSimilarity(hg)
parser = par.Parser()

# %% [markdown]
# ### NLP funs

# %%
def is_compound_propn(edge):
    if len(edge) < 3:
        return False
    if edge[0] != '+/gb':
        return False
    for item in edge[1:]:
        if is_symbol(item):
            if symbol_namespace(item)[-5:] != 'propn':
                return False
        elif not is_compound_propn(item):
            return False
    return True

def is_adj(edge):
    if is_edge(edge):
        return False
    return symbol_namespace(edge)[-3:] == 'adj'

def is_adp(edge):
    return is_symbol(edge) and symbol_namespace(edge)[-3:] == 'adp'

def is_noun(edge):
    if is_edge(edge):
        return False
    return symbol_namespace(edge)[-5:] == 'propn' or symbol_namespace(edge)[-4:] == 'noun'

def has_noun(edge):
    if is_edge(edge):
        for item in edge:
            if has_noun(item):
                return True
    else:
        return is_noun(edge)
    return False

def is_adjective_and_noun(edge):
    if len(edge) != 3:
        return False
    if edge[0] != '+/gb':
        return False
    if not is_adj(edge[1]):
        return False
    if not is_noun(edge[2]):
        return False
    return True

def is_cconj(edge):
    if is_edge(edge):
        return False
    return symbol_namespace(edge)[-5:] == 'cconj'

# %% [markdown]
# ### Synonym funs

# %%
def syn_id(root):
    symbs = hg.symbols_with_root(root)
    for symb in symbs:
        if symbol_namespace(symb)[:3] == 'syn':
            return symb
    return None
        
def syn_label(syn_id):
    symbs = syn.synonyms(hg, syn_id)
    labels = []
    for symb in symbs:
        labels.append(hg.get_label(symb))
    best = None
    for label in labels:
        if best is None or len(label) < len(best):
            best = label
    parts = best.split('|')
    if len(parts) > 1:
        max_size = 0
        for part in parts:
            if len(part) > max_size:
                best = part.strip()
                max_size = len(best)
        
    return unidecode(best)

# %% [markdown]
# ### Topic funs

# %%
def is_topic(symbol):
    if is_symbol(symbol) and symbol_namespace(symbol)[:3] == 'syn':
        root = symbol_root(symbol)
        return root[0].isalnum() and root[-1].isalnum()
    return False

def subtopics(edge):
    stopics = set()
    if is_edge(edge):
        for item in edge:
            topic = syn.main_synonym(hg, item)
            if is_topic(topic):
                stopics.add(item)
    return stopics

def choose_topic1(edge):
    topic = syn.main_synonym(hg, edge)
    if is_edge(edge):
        if is_compound_propn(edge) or is_adjective_and_noun(edge):
            return topic
        stopics = subtopics(edge)
        if len(stopics) == 1:
            return choose_topic1(next(iter(stopics)))    
    return topic

def choose_topic(edge):
    if is_edge(edge) and edge[0] == '+/gb' and is_adp(edge[1]):
        if len(edge) == 3:
            return choose_topic(edge[2])
        elif len(edge) > 3:
            return choose_topic1(edge)
    return syn.main_synonym(hg, edge)

def common_word(edge):
    syns = syn.synonyms(hg, edge)
    for s in syns:
        label = symbol2str(s)
        if ' ' in label:
            return False
        word = parser.make_word(label)
        if word.prob > MAX_PROB:
            return True
    return False

def atomic_topic(edge):
    atopic = syn.main_synonym(hg, edge)
    if is_topic(atopic) and not common_word(atopic):
        return {atopic}
    return set()

def atomic_topics(edge):
    atopics = atomic_topic(edge)
    if is_edge(edge):
        if len(edge) == 3 and edge[0] == '+/gb' and is_adp(edge[1]):
            return atomic_topics(edge[2])
        elif is_compound_propn(edge) or is_adjective_and_noun(edge):
            return atopics
        else:
            subtopics = set()
            for item in edge:
                subtopics |= atomic_topics(item)
            if len(subtopics) == 1:
                atopics = subtopics
            else:
                atopics |= subtopics
    return atopics

def atomic_topics_old(edge):
    atopics = atomic_topic(edge)
    if is_edge(edge):
        if is_compound_propn(edge) or is_adjective_and_noun(edge):
            return atopics
        for item in edge:
            atopics |= atomic_topics(item)
        # if len(atopics) > 0:
        #     return atopics
        # else:
        #     return atomic_topic(edge)
    return atopics

# %%
e = ('+/gb', 'of/nlp.of.adp', ('pulling/nlp.pull.verb', ('+/gb', 'stunts/nlp.stunt.noun', '–/nlp.–.noun'), ('+/gb', 'after/nlp.after.adp', ('kill/nlp.kill.verb', ('+/gb', 'american/nlp.american.adj', 'forces/nlp.force.noun')), ('+/gb', 'of/nlp.of.adp', 'dozens/nlp.dozen.noun', ('+/gb', 'syrian/nlp.syrian.adj', 'soldiers/nlp.soldier.noun')))))
#e = ('+/gb', 'against/nlp.against.adp', ('+/gb', 'in/nlp.in.adp', ('+/gb', '‘/nlp.‘.det', ('+/gb', 'syria/nlp.syria.propn', 'actions/nlp.action.noun', 'style’/nlp.style’.propn')), ('+/gb', 'n./nlp.n..propn', 'korea/nlp.korea.propn')))
#e = ('+/gb', 'for/nlp.for.adp', ('gone/nlp.go.verb', ('+/gb', 'mistral/nlp.mistral.propn', 'deal/nlp.deal.propn')), 'bad/nlp.bad.adj')
#e = ('+/gb', 'against/nlp.against.adp', ('+/gb', 'on/nlp.on.adp', 'attack/nlp.attack.noun', ('+/gb', 'syrian/nlp.syrian.adj', 'forces/nlp.force.noun')))
atomic_topics(e)
# Out:
# {'after_american_forces_kill_dozens_of_syrian_soldiers/syn1347213',
#  'american_forces/syn137972',
#  'pulling_stunts_–_after_american_forces_kill_dozens_of_syrian_soldiers/syn1347211',
#  'stunt/syn996',
#  'syrian_soldiers/syn13872'}

# %%
e = ('+/gb', 'middle/nlp.middle.propn', 'east/nlp.east.propn')
e = ('annexing/nlp.annex.verb', 'crimea/nlp.crimea.propn')
e = ('+/gb', 'syrian/nlp.syrian.adj', 'forces/nlp.force.noun')
hg.get_label(syn.main_synonym(hg, e))
# Out:
# 'syrian forces'

# %% [markdown]
# ### Entities, Actors and Conflicts

# %%
entities = {}
actors = {}
conflicts = {}


def edge2actors(edge, check_actors=True):
    if is_edge(edge) and edge[0] == '+/gb':
        if is_adp(edge[1]) and len(edge) == 3:
            return edge2actors(edge[2])
        elif is_cconj(edge[1]) and len(edge) > 2:
            result = set()
            for item in edge[2:]:
                result |= edge2actors(item)
            return result
    if has_noun(edge):
        synact = syn.main_synonym(hg, edge, in_adp=True)
        if check_actors:
            if synact in actors and actors[synact] > 2:
                return {synact}
        else:
            return {synact}
    return set()


def add_to_table(table, item):
    if item not in table:
        table[item] = 0
    table[item] += 1


def add_entity(entity):
    if entity not in entities:
        entities[entity] = {'mentions': {},
                            'mentioned_by': {},
                            'conflict_towards': {},
                            'conflict_from': {},
                            'conflict_actors': []}

        
def add_mention(actor, concept):
    add_entity(actor)
    add_entity(concept)
    add_to_table(entities[actor]['mentions'], concept)
    add_to_table(entities[concept]['mentioned_by'], actor)
    

def add_conflict(orig, targ, concept):
    add_entity(orig)
    add_entity(targ)
    add_entity(concept)
    add_to_table(entities[orig]['conflict_towards'], targ)
    add_to_table(entities[targ]['conflict_from'], orig)
    entities[concept]['conflict_actors'].append((orig, targ))
   

def add_conflict_tuple(orig, targ, concept, source):
    if orig not in conflicts:
        conflicts[orig] = []
    if targ not in conflicts:
        conflicts[targ] = []
    conflict_tuple = (orig, targ, concept, source)
    conflicts[orig].append(conflict_tuple)
    conflicts[targ].append(conflict_tuple)

mention_edges = hg.pattern2edges(('mention/gb.inf', None, None))
conflict_edges = hg.pattern2edges(('conflict/gb.inf', None, None, None))
nclaims = len(mention_edges)
nconflicts = len(conflict_edges)
N = (nclaims + nconflicts) * 2

i = 0
with progressbar.ProgressBar(max_value=N) as bar:
    # find actors
    for edge in hg.pattern2edges(('mention/gb.inf', None, None)):
        origs = edge2actors(edge[1], check_actors=False)
        for orig in origs:
            if orig not in actors:
                actors[orig] = 0
            actors[orig] += 1
        i += 1
        bar.update(i)
        
    for edge in hg.pattern2edges(('conflict/gb.inf', None, None, None)):
        origs = edge2actors(edge[1], check_actors=False)
        for orig in origs:
            if orig not in actors:
                actors[orig] = 0
            actors[orig] += 1
        i += 1
        bar.update(i)


    # conflicts and mentions
    for edge in hg.pattern2edges(('mention/gb.inf', None, None)):
        origs = edge2actors(edge[1])
        topics = atomic_topics(edge[2])
        for orig in origs:
            for topic in topics:
                add_mention(orig, topic)
        i += 1
        bar.update(i)
        
    for edge in hg.pattern2edges(('conflict/gb.inf', None, None, None)):
        origs = edge2actors(edge[1])
        targs = edge2actors(edge[2])
        topics = atomic_topics(edge[3])
        detailed_topic = choose_topic(edge[3])
        source = hg.pattern2edges(('source/gb.inf', edge, None)).pop()[2]
        for orig in origs:
            for targ in targs:
                add_conflict_tuple(orig, targ, detailed_topic, source)
                for topic in topics:
                    add_conflict(orig, targ, topic)
        i += 1
        bar.update(i)

print('claims: %s' % nclaims)
print('conflicts: %s' % nconflicts)
# Out:
# 100% (31474 of 31474) |##################| Elapsed Time: 0:01:32 Time:  0:01:32
# claims: 13100
# conflicts: 2637

# %% [markdown]
# ### Metrics

# %%
def compute_metrics(entity):
    mentioned_by = entities[entity]['mentioned_by']
    weights = [mentioned_by[item] for item in mentioned_by]
    total = sum(weights)
    h = 0.
    if total > 0:
        h_weights = [float(i) / float(total) for i in weights]
        h_weights = [i * i for i in h_weights]
        h = 1. / sum(h_weights)
    entities[entity]['h'] = h
    entities[entity]['total'] = total
    entities[entity]['degree'] = syn.synonyms_degree(hg, entity)
    entities[entity]['c'] = len(entities[entity]['conflict_actors'])
    
def metrics(concept):
    return {'h': entities[concept]['h'],
            'total': entities[concept]['total'],
            'degree': entities[concept]['degree'],
            'c': entities[concept]['c']}

i = 0
with progressbar.ProgressBar(max_value=len(entities)) as bar:
    for entity in entities:
        compute_metrics(entity)
        i += 1
        bar.update(i)
# Out:
# 100% (35662 of 35662) |##################| Elapsed Time: 0:00:13 Time:  0:00:13

# %% [markdown]
# ### One Actor

# %%
actor = syn_id('israel')

lactor = hg.get_label(actor)
json_data = {}

for conflict_tuple in conflicts[actor]:
    other = conflict_tuple[0]
    direction = 'from'
    if other == actor:
        other = conflict_tuple[1]
        direction = 'to'
    topic = conflict_tuple[2]
    lother = hg.get_label(other)
    ltopic = syn_label(topic)
    if lother not in json_data:
        json_data[lother] = {}
    if ltopic not in json_data[lother]:
        json_data[lother][ltopic] = metrics(other)
        json_data[lother][ltopic]['from'] = 0
        json_data[lother][ltopic]['to'] = 0
    json_data[lother][ltopic][direction] += 1
    json_data[lother][ltopic]['source'] = conflict_tuple[3]

topics = {} 

for targ in json_data:
    concepts = set(json_data[targ].keys())
    for concept in concepts:
        if concept not in topics:
            topics[concept] = 0
        topics[concept] += 1
        
for targ in json_data:
    for concept in json_data[targ]:
        json_data[targ][concept]['local_degree'] = topics[concept]
        
with open('%s.json' % lactor, 'wt') as out:
    res = j.dump(json_data, out, sort_keys=False, indent=4, separators=(',', ': '))
    
json_data
# Out:
# {'iran': {'syria crisis': {'h': 25.491620111731795,
#    'total': 117,
#    'degree': 4042,
#    'c': 6,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'iran/nlp.iran.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb', 'syria/nlp.syria.propn', 'crisis/nlp.crisis.noun'))),
#    'local_degree': 1},
#   'hiring assassins to take out nuclear scientists': {'h': 25.491620111731795,
#    'total': 117,
#    'degree': 4042,
#    'c': 6,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'iran/nlp.iran.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('hiring/nlp.hire.verb',
#       'assassins/nlp.assassin.noun',
#       ('to_take_out/nlp.to.part+nlp.take.verb+nlp.out.part',
#        ('+/gb',
#         'nuclear/nlp.nuclear.adj',
#         'scientists/nlp.scientist.noun'))))),
#    'local_degree': 1},
#   'damaging nuclear talks': {'h': 25.491620111731795,
#    'total': 117,
#    'degree': 4042,
#    'c': 6,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'iran/nlp.iran.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'damaging/nlp.damaging.adj',
#       ('+/gb', 'nuclear/nlp.nuclear.adj', 'talks/nlp.talk.noun')))),
#    'local_degree': 1},
#   'being behind beirut bombings': {'h': 25.491620111731795,
#    'total': 117,
#    'degree': 4042,
#    'c': 6,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'iran/nlp.iran.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('being_behind/nlp.be.verb+nlp.behind.adp',
#       ('+/gb', 'beirut/nlp.beirut.propn', 'bombings/nlp.bombing.noun')))),
#    'local_degree': 1}},
#  'syria': {'overnight attack on a military airbase': {'h': 42.281290322580645,
#    'total': 256,
#    'degree': 2283,
#    'c': 19,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'overnight/nlp.overnight.adj',
#       ('+/gb',
#        'on/nlp.on.adp',
#        'attack/nlp.attack.noun',
#        ('+/gb',
#         'a/nlp.a.det',
#         ('+/gb', 'military/nlp.military.adj', 'airbase/nlp.airbase.noun')))))),
#    'local_degree': 1},
#   'fiery attack in damascus': {'h': 42.281290322580645,
#    'total': 256,
#    'degree': 2283,
#    'c': 19,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'fiery/nlp.fiery.propn',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'attack/nlp.attack.propn',
#        'damascus/nlp.damascus.propn')))),
#    'local_degree': 1},
#   'surprise retaliation': {'h': 42.281290322580645,
#    'total': 256,
#    'degree': 2283,
#    'c': 19,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'surprise/nlp.surprise.noun',
#       'retaliation/nlp.retaliation.noun'))),
#    'local_degree': 1},
#   'bombardment': {'h': 42.281290322580645,
#    'total': 256,
#    'degree': 2283,
#    'c': 19,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb', 'of/nlp.of.adp', 'bombardment/nlp.bombardment.noun')),
#    'local_degree': 1},
#   'deadly attack': {'h': 42.281290322580645,
#    'total': 256,
#    'degree': 2283,
#    'c': 19,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb', 'deadly/nlp.deadly.adj', 'attacks/nlp.attack.noun')),
#    'local_degree': 1},
#   'predawn blasts near damascus': {'h': 42.281290322580645,
#    'total': 256,
#    'degree': 2283,
#    'c': 19,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'near/nlp.near.adp',
#       ('+/gb', 'predawn/nlp.predawn.adj', 'blasts/nlp.blast.noun'),
#       'damascus/nlp.damascus.propn'))),
#    'local_degree': 1},
#   'bombing damascus airport': {'h': 42.281290322580645,
#    'total': 256,
#    'degree': 2283,
#    'c': 19,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('bombing/nlp.bomb.verb',
#       ('+/gb', 'damascus/nlp.damascus.propn', 'airport/nlp.airport.noun')))),
#    'local_degree': 1},
#   'latest air raids': {'h': 42.281290322580645,
#    'total': 256,
#    'degree': 2283,
#    'c': 19,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'syria/nlp.syria.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'after/nlp.after.adp',
#      ('+/gb',
#       'latest/nlp.late.adj',
#       ('+/gb', 'air/nlp.air.noun', 'raids/nlp.raid.noun')))),
#    'local_degree': 1},
#   'golan heights clashes': {'h': 42.281290322580645,
#    'total': 256,
#    'degree': 2283,
#    'c': 19,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'israel/nlp.israel.propn',
#     'syria/nlp.syria.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'golan/nlp.golan.propn',
#       'clashes/nlp.clash.noun',
#       'heights/nlp.heights.propn'))),
#    'local_degree': 1}},
#  'u.s.': {'targeting kin of murdered palestinian teen': {'h': 0.0,
#    'total': 0,
#    'degree': 7960,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('targeting/nlp.target.verb',
#       ('+/gb',
#        ('+/gb', 'of/nlp.of.adp', 'kin/nlp.kin.noun'),
#        ('murdered/nlp.murder.verb',
#         ('+/gb', 'palestinian/nlp.palestinian.adj', 'teen/nlp.teen.noun')))))),
#    'local_degree': 1},
#   'targeting family of murdered palestine teen': {'h': 0.0,
#    'total': 0,
#    'degree': 7960,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('targeting/nlp.target.verb',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'family/nlp.family.noun',
#        ('+/gb',
#         'palestine/nlp.palestine.propn',
#         ('murdered/nlp.murder.verb', 'teen/nlp.teen.noun')))))),
#    'local_degree': 1},
#   'backing palestinian unity government': {'h': 0.0,
#    'total': 0,
#    'degree': 7960,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('condemns/nlp.condemn.verb',
#     'israel/nlp.israel.propn',
#     'us/nlp.us.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('backing/nlp.back.verb',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'unity/nlp.unity.noun',
#        'government/nlp.government.noun')))),
#    'local_degree': 1},
#   'demolishing palestinian town': {'h': 0.0,
#    'total': 0,
#    'degree': 7960,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('demolishing/nlp.demolish.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'town/nlp.town.noun')))),
#    'local_degree': 1},
#   'demolishing palestinian village in west bank': {'h': 0.0,
#    'total': 0,
#    'degree': 7960,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('demolishing/nlp.demolish.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'village/nlp.village.noun'),
#       ('+/gb',
#        'in/nlp.in.adp',
#        ('+/gb', 'west/nlp.west.propn', 'bank/nlp.bank.propn'))))),
#    'local_degree': 1},
#   'using excessive force against palestinians': {'h': 0.0,
#    'total': 0,
#    'degree': 7960,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('using/nlp.use.verb',
#       ('+/gb',
#        'excessive/nlp.excessive.adj',
#        ('+/gb',
#         'against/nlp.against.adp',
#         'force/nlp.force.noun',
#         'palestinians/nlp.palestinians.propn'))))),
#    'local_degree': 1},
#   'systematically seizing palestinian land': {'h': 0.0,
#    'total': 0,
#    'degree': 7960,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'us/nlp.us.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('systematically_seizing/nlp.systematically.adv+nlp.seize.verb',
#       ('+/gb', 'palestinian/nlp.palestinian.adj', 'land/nlp.land.noun')))),
#    'local_degree': 1}},
#  'abbas': {'sabotaging peace efforts as palestinian president moves to form government with hamas': {'h': 4.5,
#    'total': 6,
#    'degree': 285,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     'abbas/nlp.abbas.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('sabotaging/nlp.sabotage.verb',
#       ('+/gb', 'peace/nlp.peace.noun', 'efforts/nlp.effort.noun'),
#       ('+/gb',
#        'as/nlp.as.adp',
#        ('moves/nlp.move.verb',
#         ('+/gb',
#          'palestinian/nlp.palestinian.adj',
#          'president/nlp.president.noun')),
#        ('to_form/nlp.to.part+nlp.form.verb',
#         'government/nlp.government.noun',
#         ('+/gb', 'with/nlp.with.adp', 'hamas/nlp.hamas.propn')))))),
#    'local_degree': 1},
#   'religious war middle east': {'h': 4.5,
#    'total': 6,
#    'degree': 285,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'abbas/nlp.abbas.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'religious/nlp.religious.adj',
#       'war/nlp.war.noun',
#       ('+/gb', 'middle/nlp.middle.propn', 'east/nlp.east.propn')))),
#    'local_degree': 1},
#   'committed genocide': {'h': 4.5,
#    'total': 6,
#    'degree': 285,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'abbas/nlp.abbas.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('committing/nlp.commit.verb', 'genocide/nlp.genocide.noun'))),
#    'local_degree': 1},
#   "igniting ' religious war' over jerusalem holy site": {'h': 4.5,
#    'total': 6,
#    'degree': 285,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'abbas/nlp.abbas.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('igniting/nlp.ignite.verb',
#       ('+/gb',
#        'over/nlp.over.adp',
#        ('+/gb',
#         '‘/nlp.‘.pron',
#         ('+/gb', 'religious/nlp.religious.adj', 'war’/nlp.war’.noun')),
#        ('+/gb',
#         'jerusalem/nlp.jerusalem.propn',
#         ('+/gb', 'holy/nlp.holy.adj', 'site/nlp.site.noun')))))),
#    'local_degree': 1}},
#  'british lawmakers': {'causing the rise of extreme islamism and daesh': {'h': 0.0,
#    'total': 0,
#    'degree': 37,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'british/nlp.british.adj', 'lawmaker/nlp.lawmaker.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('causing/nlp.cause.verb',
#       ('+/gb',
#        'the/nlp.the.det',
#        ('+/gb',
#         'of/nlp.of.adp',
#         'rise/nlp.rise.noun',
#         ('+/gb',
#          'and/nlp.and.cconj',
#          ('+/gb', 'extreme/nlp.extreme.adj', 'islamism/nlp.islamism.propn'),
#          'daesh/nlp.daesh.propn')))))),
#    'local_degree': 1},
#   'causing rise in jihadism': {'h': 0.0,
#    'total': 0,
#    'degree': 37,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'british/nlp.british.adj', 'lawmaker/nlp.lawmaker.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('causing/nlp.cause.verb',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'rise/nlp.rise.noun',
#        'jihadism/nlp.jihadism.noun')))),
#    'local_degree': 1}},
#  'un rights expert': {'force against palestinians': {'h': 0.0,
#    'total': 0,
#    'degree': 18,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb',
#      'u.n./nlp.u.n..propn',
#      ('+/gb', 'rights/nlp.right.noun', 'expert/nlp.expert.noun')),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'excessive/nlp.excessive.adj',
#       ('+/gb',
#        'against/nlp.against.adp',
#        'force/nlp.force.noun',
#        'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1}},
#  'europe': {"gaza 's humanitarian situation": {'h': 23.000000000000014,
#    'total': 46,
#    'degree': 897,
#    'c': 3,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'europe/nlp.europe.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ("'s/nlp.'s.part",
#       ('+/gb',
#        'humanitarian/nlp.humanitarian.adj',
#        'situation/nlp.situation.noun'),
#       'gaza/nlp.gaza.propn'))),
#    'local_degree': 1}},
#  'hamas': {'killing its drone expert in tunisia': {'h': 10.645569620253166,
#    'total': 29,
#    'degree': 726,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'hamas/nlp.hamas.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('killing/nlp.kill.verb',
#       ('+/gb',
#        'its/nlp.-pron-.adj',
#        ('+/gb', 'drone/nlp.drone.noun', 'expert/nlp.expert.noun')),
#       ('+/gb', 'in/nlp.in.adp', 'tunisia/nlp.tunisia.propn')))),
#    'local_degree': 1},
#   'abusing permits issued to gaza residents': {'h': 10.645569620253166,
#    'total': 29,
#    'degree': 726,
#    'c': 1,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     'hamas/nlp.hamas.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('abusing/nlp.abuse.verb',
#       ('+/gb',
#        'permits/nlp.permit.noun',
#        ('issued_to/nlp.issue.verb+nlp.to.adp',
#         ('+/gb', 'gaza/nlp.gaza.propn', 'residents/nlp.resident.noun')))))),
#    'local_degree': 1},
#   'keeping gaza crossing shut': {'h': 10.645569620253166,
#    'total': 29,
#    'degree': 726,
#    'c': 1,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     'hamas/nlp.hamas.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('keeping/nlp.keep.verb',
#       ('+/gb', 'gaza/nlp.gaza.propn', 'crossing/nlp.crossing.noun'),
#       'shut/nlp.shut.noun'))),
#    'local_degree': 1},
#   'recent ban on muslim calls to prayer': {'h': 10.645569620253166,
#    'total': 29,
#    'degree': 726,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'hamas/nlp.hamas.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'about/nlp.about.adp',
#      ('+/gb',
#       'on/nlp.on.adp',
#       ('+/gb', 'recent/nlp.recent.adj', 'ban/nlp.ban.noun'),
#       ('+/gb',
#        'to/nlp.to.adp',
#        ('+/gb', 'muslim/nlp.muslim.propn', 'calls/nlp.call.noun'),
#        'prayer/nlp.prayer.noun')))),
#    'local_degree': 1},
#   'gaza hospital strike': {'h': 10.645569620253166,
#    'total': 29,
#    'degree': 726,
#    'c': 1,
#    'from': 0,
#    'to': 1,
#    'source': ('blames/nlp.blame.verb',
#     'israel/nlp.israel.propn',
#     'hamas/nlp.hamas.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'hospital/nlp.hospital.propn',
#       ('+/gb', 'gaza/nlp.gaza.propn', 'strike/nlp.strike.noun')))),
#    'local_degree': 1}},
#  'jordan': {'western wall prayer platform': {'h': 9.999999999999996,
#    'total': 10,
#    'degree': 340,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'jordan/nlp.jordan.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'western/nlp.western.propn',
#       ('+/gb', 'prayer/nlp.prayer.noun', 'platform/nlp.platform.noun'),
#       'wall/nlp.wall.propn'))),
#    'local_degree': 1}},
#  'hrw': {'violence against palestinians in annual world report': {'h': 1.0,
#    'total': 1,
#    'degree': 83,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'hrw/nlp.hrw.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'against/nlp.against.adp',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'violence/nlp.violence.noun',
#        ('+/gb',
#         'annual/nlp.annual.adj',
#         ('+/gb', 'world/nlp.world.noun', 'report/nlp.report.noun'))),
#       'palestinians/nlp.palestinians.propn'))),
#    'local_degree': 1}},
#  'rights chief': {'hamas of committing war crimes in gaza': {'h': 0.0,
#    'total': 0,
#    'degree': 54,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb',
#      'un/nlp.un.propn',
#      ('+/gb', 'rights/nlp.right.noun', 'chief/nlp.chief.noun')),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'hamas/nlp.hamas.propn',
#      ('+/gb',
#       'of/nlp.of.adp',
#       ('committing/nlp.commit.verb',
#        ('+/gb',
#         'in/nlp.in.adp',
#         ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun'),
#         'gaza/nlp.gaza.propn'))))),
#    'local_degree': 1}},
#  'amnesty': {'gaza war crime': {'h': 3.0,
#    'total': 3,
#    'degree': 506,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'amnesty/nlp.amnesty.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'gaza/nlp.gaza.propn',
#       ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun')))),
#    'local_degree': 1},
#   'palestinians of war crimes': {'h': 3.0,
#    'total': 3,
#    'degree': 506,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'amnesty/nlp.amnesty.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      'palestinians/nlp.palestinians.propn',
#      ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun'))),
#    'local_degree': 1},
#   'use of force in land day demonstrations': {'h': 3.0,
#    'total': 3,
#    'degree': 506,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     ('+/gb',
#      'amnesty/nlp.amnesty.propn',
#      'international/nlp.international.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'of/nlp.of.adp', 'use/nlp.use.noun', 'force/nlp.force.noun'),
#       ('+/gb',
#        'land/nlp.land.propn',
#        'demonstrations/nlp.demonstration.noun',
#        'day/nlp.day.propn')))),
#    'local_degree': 1}},
#  'kerry': {'collapse of palestinian authority': {'h': 3.571428571428571,
#    'total': 5,
#    'degree': 985,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     ('+/gb', 'john/nlp.john.propn', 'kerry/nlp.kerry.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'about/nlp.about.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'collapse/nlp.collapse.noun',
#       ('+/gb',
#        'palestinian/nlp.palestinian.propn',
#        'authority/nlp.authority.propn')))),
#    'local_degree': 1}},
#  'turkeys': {"helping overthrow cairo 's islamist president": {'h': 0.0,
#    'total': 0,
#    'degree': 3268,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'turkey/nlp.turkey.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ("helping_overthrow_'s/nlp.help.verb+nlp.overthrow.verb+nlp.'s.part",
#       ('+/gb', 'islamist/nlp.islamist.adj', 'president/nlp.president.noun'),
#       'cairo/nlp.cairo.propn'))),
#    'local_degree': 1},
#   'new settlements in east jerusalem': {'h': 0.0,
#    'total': 0,
#    'degree': 3268,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'turkey/nlp.turkey.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'new/nlp.new.adj', 'settlements/nlp.settlement.noun'),
#       ('+/gb', 'east/nlp.east.propn', 'jerusalem/nlp.jerusalem.propn')))),
#    'local_degree': 1}},
#  'u.n.': {'gaza school deaths': {'h': 0.0,
#    'total': 0,
#    'degree': 2873,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'dozens/nlp.dozen.noun',
#       ('+/gb',
#        'gaza/nlp.gaza.propn',
#        ('+/gb', 'school/nlp.school.noun', 'deaths/nlp.death.noun'))))),
#    'local_degree': 1},
#   'emek shilo settlement': {'h': 0.0,
#    'total': 0,
#    'degree': 2873,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'emek/nlp.emek.propn',
#       'settlement/nlp.settlement.noun',
#       'shilo/nlp.shilo.propn'))),
#    'local_degree': 1},
#   'jordan valley homes': {'h': 0.0,
#    'total': 0,
#    'degree': 2873,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'destruction/nlp.destruction.noun',
#       ('+/gb',
#        'jordan/nlp.jordan.propn',
#        'homes/nlp.home.noun',
#        'valley/nlp.valley.propn')))),
#    'local_degree': 1},
#   'spread propaganda': {'h': 0.0,
#    'total': 0,
#    'degree': 2873,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('spreading/nlp.spread.verb', 'propaganda/nlp.propaganda.propn'))),
#    'local_degree': 1},
#   "the death of spanish ' blue helmet' in lebanon": {'h': 0.0,
#    'total': 0,
#    'degree': 2873,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'the/nlp.the.det', 'un/nlp.un.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'the/nlp.the.det',
#       ('+/gb',
#        'of/nlp.of.adp',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'death/nlp.death.noun',
#         ('+/gb',
#          'lebanon/nlp.lebanon.propn',
#          ('+/gb', '|/nlp.|.propn', 'news/nlp.news.propn'))),
#        ('+/gb',
#         'spanish/nlp.spanish.adj',
#         ('+/gb',
#          '‘/nlp.‘.noun',
#          ('+/gb', 'blue/nlp.blue.adj', 'helmet’/nlp.helmet’.noun'))))))),
#    'local_degree': 1},
#   'violating health of syrians': {'h': 0.0,
#    'total': 0,
#    'degree': 2873,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     'un/nlp.un.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'violating/nlp.violating.propn',
#       ('+/gb',
#        'of/nlp.of.adp',
#        'health/nlp.health.propn',
#        'syrians/nlp.syrians.propn')))),
#    'local_degree': 1}},
#  'googling': {'dashing peace hopes': {'h': 0.0,
#    'total': 0,
#    'degree': 752,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     'google/nlp.google.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('dashing/nlp.dash.verb',
#       ('+/gb', 'peace/nlp.peace.noun', 'hopes/nlp.hope.noun')))),
#    'local_degree': 1}},
#  'putin': {'possible lethal arms delivery to kiev': {'h': 15.280991735537192,
#    'total': 43,
#    'degree': 2914,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'putin/nlp.putin.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'on/nlp.on.adp',
#      ('+/gb',
#       'possible/nlp.possible.adj',
#       ('+/gb',
#        'lethal/nlp.lethal.adj',
#        ('+/gb',
#         'arms/nlp.arm.noun',
#         ('+/gb',
#          'to/nlp.to.adp',
#          'delivery/nlp.delivery.noun',
#          'kiev/nlp.kiev.propn')))))),
#    'local_degree': 1}},
#  'un report': {'child torture': {'h': 0.0,
#    'total': 0,
#    'degree': 181,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'report/nlp.report.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb', 'child/nlp.child.noun', 'torture/nlp.torture.noun'))),
#    'local_degree': 1},
#   "violator of children 's rights over gaza conflict": {'h': 0.0,
#    'total': 0,
#    'degree': 181,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb', 'un/nlp.un.propn', 'report/nlp.report.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'as/nlp.as.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'violator/nlp.violator.noun',
#       ('+/gb',
#        'over/nlp.over.adp',
#        ("'s/nlp.'s.part", 'rights/nlp.right.noun', 'children/nlp.child.noun'),
#        ('+/gb', 'gaza/nlp.gaza.propn', 'conflict/nlp.conflict.noun'))))),
#    'local_degree': 1}},
#  'spain': {'peacekeeper': {'h': 7.142857142857141,
#    'total': 10,
#    'degree': 713,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'spain/nlp.spain.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'death/nlp.death.propn',
#       'peacekeeper/nlp.peacekeeper.propn'))),
#    'local_degree': 1}},
#  'sweden': {'palestine pledge': {'h': 4.499999999999999,
#    'total': 6,
#    'degree': 439,
#    'c': 0,
#    'from': 0,
#    'to': 1,
#    'source': ('slams/nlp.slam.verb',
#     'israel/nlp.israel.propn',
#     'sweden/nlp.sweden.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb', 'palestine/nlp.palestine.propn', 'pledge/nlp.pledge.noun'))),
#    'local_degree': 1}},
#  'hezbollah': {'assassination of slain hamas terrorist': {'h': 8.999999999999998,
#    'total': 15,
#    'degree': 350,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'hezbollah/nlp.hezbollah.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'assassination/nlp.assassination.noun',
#       ('+/gb',
#        'hamas/nlp.hamas.propn',
#        ('slain/nlp.slay.verb', 'terrorist/nlp.terrorist.noun'))))),
#    'local_degree': 1},
#   'killing of five nuclear engineers in syria': {'h': 8.999999999999998,
#    'total': 15,
#    'degree': 350,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'hezbollah/nlp.hezbollah.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('killing_of/nlp.kill.verb+nlp.of.adp',
#       ('+/gb',
#        'in/nlp.in.adp',
#        ('+/gb',
#         'five/nlp.five.num',
#         ('+/gb', 'nuclear/nlp.nuclear.adj', 'engineers/nlp.engineer.noun')),
#        'syria/nlp.syria.propn')))),
#    'local_degree': 1},
#   'assassinating commander': {'h': 8.999999999999998,
#    'total': 15,
#    'degree': 350,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'hezbollah/nlp.hezbollah.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('assassinating/nlp.assassinate.verb', 'commander/nlp.commander.noun'))),
#    'local_degree': 1},
#   'death of five nuclear technicians in syria': {'h': 8.999999999999998,
#    'total': 15,
#    'degree': 350,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'hezbollah/nlp.hezbollah.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'death/nlp.death.noun',
#       ('+/gb',
#        'of/nlp.of.adp',
#        ('+/gb',
#         'in/nlp.in.adp',
#         ('+/gb',
#          'five/nlp.five.num',
#          ('+/gb',
#           'nuclear/nlp.nuclear.adj',
#           'technicians/nlp.technician.noun')),
#         'syria/nlp.syria.propn'))))),
#    'local_degree': 1}},
#  'palestinians': {'leaking news from peace talks': {'h': 11.636363636363637,
#    'total': 16,
#    'degree': 541,
#    'c': 3,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     'palestinians/nlp.palestinians.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('leaking/nlp.leak.verb',
#       ('+/gb',
#        'from/nlp.from.adp',
#        'news/nlp.news.noun',
#        ('+/gb', 'peace/nlp.peace.noun', 'talks/nlp.talk.noun'))))),
#    'local_degree': 1},
#   'incitement': {'h': 11.636363636363637,
#    'total': 16,
#    'degree': 541,
#    'c': 3,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     'palestinians/nlp.palestinians.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'over/nlp.over.adp',
#       'incitement/nlp.incitement.noun',
#       'talks/nlp.talk.noun'))),
#    'local_degree': 1},
#   'stalemate': {'h': 11.636363636363637,
#    'total': 16,
#    'degree': 541,
#    'c': 3,
#    'from': 0,
#    'to': 1,
#    'source': ('blames/nlp.blame.verb',
#     'israel/nlp.israel.propn',
#     'palestinians/nlp.palestinians.propn',
#     ('+/gb', 'for/nlp.for.adp', 'stalemate/nlp.stalemate.noun')),
#    'local_degree': 1}},
#  'un agency': {'imposing apartheid regime on palestinians': {'h': 0.0,
#    'total': 0,
#    'degree': 103,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'un/nlp.un.propn', 'agency/nlp.agency.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('imposing/nlp.impose.verb',
#       ('+/gb', 'apartheid/nlp.apartheid.noun', 'regime/nlp.regime.noun'),
#       ('+/gb', 'on/nlp.on.adp', 'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1}},
#  'hariri': {'beirut suburb bombing': {'h': 0.0,
#    'total': 0,
#    'degree': 19,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     'hariri/nlp.hariri.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'beirut/nlp.beirut.propn',
#       'bombing/nlp.bombing.noun',
#       'suburb/nlp.suburb.noun'))),
#    'local_degree': 1}},
#  'carter': {'pro palestine op ed': {'h': 0.0,
#    'total': 0,
#    'degree': 72,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'jimmy/nlp.jimmy.propn', 'carter/nlp.carter.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'in/nlp.in.adp',
#      ('+/gb',
#       'pro/nlp.pro.adj',
#       ('+/gb', 'op/nlp.op.noun', 'ed/nlp.ed.noun'),
#       'palestine/nlp.palestine.propn'))),
#    'local_degree': 1}},
#  'white house': {'settlement': {'h': 4.0,
#    'total': 4,
#    'degree': 364,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     ('+/gb', 'white/nlp.white.propn', 'house/nlp.house.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb', 'on/nlp.on.adp', 'settlements/nlp.settlement.noun')),
#    'local_degree': 1}},
#  'nasrallah': {'any stupid moves in lebanon syria': {'h': 0.0,
#    'total': 0,
#    'degree': 50,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'nasrallah/nlp.nasrallah.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb',
#        'any/nlp.any.det',
#        ('+/gb', 'stupid/nlp.stupid.adj', 'moves/nlp.move.noun')),
#       ('+/gb', 'lebanon/nlp.lebanon.propn', 'syria/nlp.syria.propn')))),
#    'local_degree': 1}},
#  'france': {'its ban on palestinians could escalate violence': {'h': 15.3820224719101,
#    'total': 37,
#    'degree': 2146,
#    'c': 1,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'france/nlp.france.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      ('could_escalate/nlp.could.verb+nlp.escalate.verb',
#       'violence/nlp.violence.noun'),
#      ('+/gb',
#       'its/nlp.-pron-.adj',
#       ('+/gb',
#        'on/nlp.on.adp',
#        'ban/nlp.ban.noun',
#        'palestinians/nlp.palestinians.propn')))),
#    'local_degree': 1}},
#  'eu': {'latest settlement expansion in palestine': {'h': 23.844884488448884,
#    'total': 85,
#    'degree': 2085,
#    'c': 7,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'eu/nlp.eu.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'settlement/nlp.settlement.propn',
#       ('+/gb',
#        'latest/nlp.latest.propn',
#        ('+/gb',
#         'in/nlp.in.adp',
#         'expansion/nlp.expansion.noun',
#         'palestine/nlp.palestine.propn'))))),
#    'local_degree': 1},
#   'bad deal on iran': {'h': 23.844884488448884,
#    'total': 85,
#    'degree': 2085,
#    'c': 7,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'israel/nlp.israel.propn',
#     'eu/nlp.eu.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'bad/nlp.bad.adj',
#       ('+/gb',
#        'on/nlp.on.adp',
#        'deal/nlp.deal.noun',
#        'iran/nlp.iran.propn')))),
#    'local_degree': 1}},
#  'russia': {'jets detected near syria - lebanon border': {'h': 16.60558051548827,
#    'total': 265,
#    'degree': 7510,
#    'c': 5,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'russia/nlp.russia.propn',
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'jets/nlp.jet.noun',
#       ('detected_near/nlp.detect.verb+nlp.near.adp',
#        ('+/gb',
#         'syria/nlp.syria.propn',
#         'border/nlp.border.noun',
#         ('+/gb', '–/nlp.–.noun', 'lebanon/nlp.lebanon.propn')))))),
#    'local_degree': 1},
#   'syria arms delivery': {'h': 16.60558051548827,
#    'total': 265,
#    'degree': 7510,
#    'c': 5,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'israel/nlp.israel.propn',
#     'russia/nlp.russia.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'syria/nlp.syria.propn',
#       ('+/gb', 'arms/nlp.arm.noun', 'delivery/nlp.delivery.noun')))),
#    'local_degree': 1}},
#  'un chief': {'settlement plans in wake of quartet report': {'h': 0.0,
#    'total': 0,
#    'degree': 175,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'u.n./nlp.u.n..propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'settlement/nlp.settlement.noun', 'plans/nlp.plan.noun'),
#       ('+/gb',
#        'of/nlp.of.adp',
#        'wake/nlp.wake.noun',
#        ('+/gb', 'quartet/nlp.quartet.propn', 'report/nlp.report.noun'))))),
#    'local_degree': 1}},
#  'palestinian authority': {'killing of palestinian attackers': {'h': 2.0,
#    'total': 2,
#    'degree': 99,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb',
#      'palestinian/nlp.palestinian.propn',
#      'authority/nlp.authority.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'of/nlp.of.adp',
#       'killing/nlp.killing.noun',
#       ('+/gb',
#        'palestinian/nlp.palestinian.adj',
#        'attackers/nlp.attacker.noun')))),
#    'local_degree': 1},
#   'shooting jerusalem terrorists': {'h': 2.0,
#    'total': 2,
#    'degree': 99,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('condemns/nlp.condemn.verb',
#     ('+/gb',
#      'palestinian/nlp.palestinian.propn',
#      'authority/nlp.authority.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('shooting/nlp.shoot.verb',
#       ('+/gb',
#        'jerusalem/nlp.jerusalem.propn',
#        'terrorists/nlp.terrorists.propn')))),
#    'local_degree': 1}},
#  'syrian regime': {'declaring war after further air strikes': {'h': 2.0,
#    'total': 2,
#    'degree': 55,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'syrian/nlp.syrian.adj', 'regime/nlp.regime.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('declaring/nlp.declare.verb',
#       'war/nlp.war.noun',
#       'after/nlp.after.adp',
#       ('+/gb',
#        ('+/gb', 'world/nlp.world.propn', 'news/nlp.news.noun'),
#        ('+/gb',
#         '|/nlp.|.propn',
#         ('+/gb',
#          'further/nlp.further.adj',
#          'air/nlp.air.noun',
#          'strikes/nlp.strike.verb')))))),
#    'local_degree': 1}},
#  'chief hezbollah': {'attack': {'h': 0.0,
#    'total': 0,
#    'degree': 31,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     ('+/gb', 'hezbollah/nlp.hezbollah.propn', 'chief/nlp.chief.noun'),
#     'israel/nlp.israel.propn',
#     ('+/gb', 'against/nlp.against.adp', 'attack/nlp.attack.noun')),
#    'local_degree': 1}},
#  'britain': {'secretly playing lead role in un resolution on settlements': {'h': 9.818181818181811,
#    'total': 36,
#    'degree': 1279,
#    'c': 1,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'israel/nlp.israel.propn',
#     'britain/nlp.britain.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('secretly_playing/nlp.secretly.adv+nlp.play.verb',
#       ('+/gb',
#        'in/nlp.in.adp',
#        ('+/gb', 'lead/nlp.lead.adj', 'role/nlp.role.noun'),
#        ('+/gb',
#         'un/nlp.un.propn',
#         ('+/gb',
#          'on/nlp.on.adp',
#          'resolution/nlp.resolution.noun',
#          'settlements/nlp.settlement.noun')))))),
#    'local_degree': 1}},
#  'human rights watch': {'war crimes in gaza': {'h': 1.0,
#    'total': 1,
#    'degree': 171,
#    'c': 0,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb',
#      'human/nlp.human.propn',
#      'watch/nlp.watch.propn',
#      'rights/nlp.rights.propn'),
#     'israel/nlp.israel.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'war/nlp.war.noun', 'crimes/nlp.crime.noun'),
#       'gaza/nlp.gaza.propn'))),
#    'local_degree': 1}}}

# %% [markdown]
# ## Two Actors

# %%
def syn_label(syn_id):
    return hg.get_label(syn_id)

def mentions_intersection(actors):
    intersection = None
    for actor in actors:
        concepts = set(entities[actor]['mentions'].keys())
        if intersection is None:
            intersection = concepts
        else:
            intersection &= concepts
    return intersection


def mentions_outside(actor, concepts):
    return set(entities[actor]['mentions'].keys()).difference(concepts)


def actors_from_concepts(concepts):
    actors = {}
    for concept in concepts:
        h = entities[concept]['h']
        for actor in entities[concept]['mentioned_by']:
            if actor in actors:
                if actors[actor] > h:
                    actors[actor] = h
            else:
                actors[actor] = h
    return actors


def show_by_h(concepts, decreasing=True):
    concepts_h = {}
    for concept in concepts:
        concepts_h[concept] = entities[concept]['h']

    sorted_h = sorted(concepts_h.items(), key=operator.itemgetter(1), reverse=decreasing)

    for concept, h in sorted_h:
        print('%s [%s]' % (syn_label(concept), h))


def metrics_with_similarities(concept, actor1, actor2):
    m = metrics(concept)
    sim1 = hs.similarity(actor1, concept)
    sim2 = hs.similarity(actor2, concept)
    m['similarity1'] = sim1
    m['similarity2'] = sim2
    if sim1 > 0 and sim2 > 0:
        m['sim_ratio'] = sim1 / sim2
        m['log_sim_ratio'] = math.log(sim1 / sim2)
    else:
        m['sim_ratio'] = 0
        m['log_sim_ratio'] = 0
    return m


actor1 = syn_id('russia')
actor2 = syn_id('china')

actor1_name = hg.get_label(actor1)
actor2_name = hg.get_label(actor2)

inter = mentions_intersection([actor1, actor2])
actor1_only = mentions_outside(actor1, inter)
actor2_only = mentions_outside(actor2, inter)
common_actors = actors_from_concepts(inter)

data = {'actors': [actor1_name, actor2_name],
        'common_concepts': {},
        'individual_concepts': {actor1_name: {}, actor2_name: {}},
        'common_actors': {}}

for concept in inter:
    data['common_concepts'][syn_label(concept)] = metrics_with_similarities(concept, actor1, actor2)

for concept in actor1_only:
    if entities[concept]['h'] > 1.:
        data['individual_concepts'][actor1_name][syn_label(concept)] = metrics_with_similarities(concept, actor1, actor2)

for concept in actor2_only:
    if entities[concept]['h'] > 1.:
        data['individual_concepts'][actor2_name][syn_label(concept)] = metrics_with_similarities(concept, actor1, actor2)
        
for actor in common_actors:
    if entities[concept]['h'] > 1.:
        data['individual_concepts'][actor2_name][syn_label(concept)] = metrics(concept)

for actor in common_actors:
    data['common_actors'][syn_label(actor)] = metrics(concept)

with open('china-russia.json', 'wt') as out:
    res = j.dump(data, out, sort_keys=False, indent=4, separators=(',', ': '))

print('INTER')
show_by_h(inter, decreasing=False)
print()

print(actor1)
show_by_h(actor1_only)
print()

print(actor2)
show_by_h(actor2_only)
print()

print('COMMON_ACTORS')
show_actors_by_h(common_actors, decreasing=False)
print()
# Out:
# INTER
# no proof [1.7999999999999998]
# vietnam [2.0]
# to consider [2.0]
# own interests [2.0]
# missile system [2.6666666666666665]
# doubts [3.0]
# infected with [3.0]
# natural gas [3.0]
# has detained [3.2]
# kerry [3.571428571428571]
# proxy [4.0]
# workings [4.0]
# proofs [4.499999999999999]
# cutest [4.5]
# warships [4.571428571428571]
# naval [5.333333333333333]
# should be [5.444444444444445]
# selves [5.999999999999999]
# no plans [5.999999999999999]
# submarine [6.230769230769231]
# 2020 [6.249999999999997]
# found in [6.4]
# resolutions [6.759999999999998]
# 3,000 [7.0]
# to attack [7.0]
# air force [7.0]
# mh17 [7.529411764705882]
# aircraft carrier [8.066666666666666]
# drills [8.999999999999998]
# last month [9.0]
# as it [9.0]
# defenses [9.090909090909088]
# exercising [9.941176470588232]
# violating [10.285714285714285]
# has killed [10.57232704402516]
# nukes [11.842105263157894]
# internets [12.499999999999998]
# summit [12.999999999999996]
# tensions [13.235294117647058]
# zika [13.333333333333329]
# investigations [13.370370370370368]
# united states [13.44444444444445]
# climates [14.11557788944723]
# activists [14.44]
# turkeys [14.663022508038548]
# bombed [14.767112509834785]
# explosives [15.125]
# aircrafts [15.157894736842108]
# australia [15.679999999999996]
# requesting [16.133333333333336]
# protesting [16.516129032258064]
# viruses [17.857142857142854]
# suspected [17.875862068965503]
# militants [17.964417177914083]
# march [18.18181818181817]
# sanctions [18.382978723404243]
# righted [18.75]
# zoning [18.77777777777777]
# ukraine [19.14063777596076]
# seized [19.173913043478272]
# seas [19.775330396475756]
# russia [19.98159292035404]
# korea [21.145631067961187]
# japan [21.278481012658236]
# militaries [21.35555555555557]
# tying [21.599999999999977]
# offic­ials [22.72972972972974]
# korean [23.142857142857114]
# north korea [23.379506641366234]
# agreements [24.02857142857144]
# powering [27.37894736842106]
# iran [27.432967032967067]
# casing [27.523809523809533]
# oils [27.847999999999967]
# gases [28.451612903225804]
# the country [32.666666666666686]
# russian [33.39130434782611]
# securities [33.8169014084507]
# planing [34.679999999999964]
# troop [35.29139072847684]
# bordering [37.76855895196511]
# warring [38.13002364066201]
# airing [38.435294117647096]
# china [40.133402275077486]
# syria [46.39400249895871]
# islamic [47.310940499040264]
# countrys [48.322147651006674]
#
# russia/syn11969
# threating [36.44578313253016]
# striking [36.05333333333333]
# syrian [32.980392156862784]
# isis [31.34340991535666]
# eu [30.48775055679285]
# armies [29.224719101123586]
# uk [29.16666666666666]
# will be [29.127659574468083]
# assad [29.039999999999992]
# rebels [28.669724770642162]
# timed [28.521126760563355]
# killed in [27.847999999999974]
# evidences [26.999999999999982]
# policing [23.87697160883286]
# asylum [23.684210526315788]
# in syria [23.17021276595745]
# schooling [23.12]
# air strikes [23.058823529411757]
# arming [22.51162790697676]
# qaeda [22.439252336448597]
# raids [22.23076923076926]
# aiding [21.595505617977555]
# france [21.446601941747588]
# weaponed [21.407407407407412]
# chief [21.124999999999993]
# conflicts [20.80800000000002]
# crises [20.628571428571426]
# spying [19.63636363636362]
# egypt [19.592592592592613]
# islamist [18.749999999999996]
# putin [18.612403100775193]
# jets [18.5142857142857]
# basing [18.28358208955223]
# partying [18.181818181818173]
# carried out [18.18181818181817]
# security forces [18.062500000000004]
# afghanistan [17.95145631067961]
# aleppo [17.456375838926185]
# oppositions [17.2857142857143]
# united [17.190476190476186]
# european [17.190476190476186]
# theresa [17.064516129032263]
# that it [17.000000000000004]
# embassy [16.8918918918919]
# massed [16.33333333333334]
# yemen [16.22471910112361]
# pressures [16.2]
# regimes [16.2]
# nato [16.0]
# probe [14.727272727272728]
# airstrikes [14.382978723404252]
# bombings [14.124137931034483]
# ceasefire [13.888888888888888]
# trials [13.761904761904765]
# first time [13.761904761904765]
# satellite [13.5]
# offensives [13.235294117647058]
# obama [12.844444444444445]
# snowden [12.789473684210533]
# moscow [12.736842105263165]
# supplying [12.736842105263165]
# washington [12.600000000000005]
# damascus [12.100000000000003]
# cuba [11.999999999999996]
# peace talks [11.842105263157894]
# networked [11.842105263157894]
# tuesday [11.804878048780495]
# régions [11.571428571428573]
# chemical attack [11.266666666666664]
# fleeing [11.266666666666664]
# was killed [11.0]
# guarding [10.88888888888889]
# futures [10.714285714285714]
# greece [10.526315789473681]
# a year [10.314285714285715]
# facilities [10.285714285714285]
# warnings [10.285714285714283]
# parliament [10.285714285714283]
# bbc [9.999999999999996]
# cupping [9.999999999999996]
# terrorist attack [9.941176470588234]
# eastern ukraine [9.941176470588232]
# shootings [9.799999999999997]
# jordan [9.799999999999997]
# hezbollah [9.756756756756758]
# would be [9.322580645161292]
# siege [9.307692307692307]
# government forces [9.307692307692307]
# arctic [9.307692307692307]
# cease [9.0]
# militia [9.0]
# termed [9.0]
# constructions [9.0]
# november [9.0]
# incidents [8.999999999999998]
# debts [8.909090909090907]
# turkish [8.533333333333333]
# will have [8.33333333333333]
# mines [8.33333333333333]
# international law [8.33333333333333]
# helicopter [8.166666666666666]
# contacting [8.0]
# white house [8.0]
# crosses [8.0]
# urges [8.0]
# reuters [8.0]
# crimea [7.834532374100718]
# war crimes [7.806451612903228]
# sinai [7.7368421052631575]
# disasters [7.5384615384615365]
# imaged [7.363636363636364]
# isis leader [7.363636363636364]
# smuggling [7.363636363636364]
# foiled [7.363636363636364]
# civil war [7.363636363636364]
# chemical arms [7.363636363636364]
# interventions [7.363636363636364]
# teamed [7.347826086956521]
# piloted [7.347826086956521]
# airspace [7.117647058823529]
# police officers [7.117647058823529]
# historic [7.0]
# geneva [7.0]
# to use [7.0]
# researched [7.0]
# gunmen [6.621621621621619]
# treaty [6.428571428571429]
# graves [6.4]
# withdrawal [6.4]
# must stop [6.4]
# ballistic [6.2439024390243905]
# plane crash [6.230769230769231]
# stationed [6.095238095238095]
# icing [6.081081081081081]
# deploys [5.999999999999999]
# to deploy [5.999999999999999]
# insurgency [5.999999999999999]
# mortar [5.999999999999999]
# breach [5.999999999999999]
# unprecedented [5.999999999999999]
# shifting [5.999999999999999]
# conferences [5.999999999999999]
# missile test [5.999999999999999]
# ambassador [5.999999999999999]
# standoff [5.999999999999999]
# stadiums [5.999999999999999]
# radars [5.999999999999999]
# islamists [5.999999999999999]
# to syria [5.764705882352939]
# idlib [5.761904761904763]
# shells [5.444444444444445]
# swiss [5.444444444444445]
# u.s. military [5.444444444444445]
# eras [5.444444444444445]
# baghdadi [5.333333333333333]
# bridges [5.333333333333333]
# truce [5.142857142857142]
# traces [4.999999999999999]
# a week [4.999999999999999]
# will respond [4.999999999999999]
# peninsula [4.999999999999999]
# 24 hours [4.999999999999999]
# government troops [4.999999999999999]
# reasoned [4.999999999999999]
# approvals [4.999999999999999]
# red line [4.999999999999999]
# tehran [4.999999999999999]
# deadline [4.999999999999999]
# is using [4.999999999999999]
# nears [4.999999999999999]
# sanctions [4.999999999999999]
# contracted [4.999999999999999]
# affairs [4.999999999999999]
# arsenal [4.999999999999999]
# because it [4.999999999999999]
# syrian army [4.8]
# kiev [4.587301587301588]
# to ukraine [4.545454545454544]
# aggressions [4.5]
# syrian government [4.499999999999999]
# us soldiers [4.499999999999999]
# opened fire [4.499999999999999]
# extensions [4.499999999999999]
# debris [4.454545454545455]
# earths [4.454545454545454]
# us strike [4.0]
# deployment [4.0]
# operation in syria [4.0]
# was carrying [4.0]
# was caused [4.0]
# u.s. officials [4.0]
# fleets [4.0]
# strike in syria [4.0]
# terror attack [4.0]
# surge [4.0]
# accusation [4.0]
# military base [4.0]
# special forces [4.0]
# downing [4.0]
# coordinated [4.0]
# detained by [4.0]
# to deliver [4.0]
# soviet [4.0]
# monitoring [4.0]
# border guards [4.0]
# involved in [4.0]
# sinai plane crash [4.0]
# to prevent [4.0]
# a month [4.0]
# grenade [3.857142857142857]
# will build [3.7692307692307696]
# us sanctions [3.666666666666667]
# brink [3.5999999999999996]
# poland [3.5999999999999996]
# air base [3.571428571428571]
# shelling [3.571428571428571]
# in ukraine [3.571428571428571]
# will keep [3.571428571428571]
# to enforce [3.571428571428571]
# the right [3.0]
# crash site [3.0]
# peace conference [3.0]
# anniversary [3.0]
# gps [3.0]
# representatives [3.0]
# can use [3.0]
# criticises [3.0]
# northern coast [3.0]
# are missing [3.0]
# intensifies [3.0]
# vows [3.0]
# secretary [3.0]
# act of terrorism [3.0]
# monkeys [3.0]
# annexation [3.0]
# military exercises [3.0]
# were found [3.0]
# in crimea [3.0]
# criticisms [3.0]
# celebrations [3.0]
# trio [3.0]
# the future [3.0]
# asylum applications [3.0]
# the plane [3.0]
# kremlin [3.0]
# voiced [3.0]
# will face [3.0]
# has agreed [3.0]
# past 24 hours [3.0]
# will consider [3.0]
# suspends [3.0]
# telephone [3.0]
# to extend [3.0]
# to bomb [3.0]
# un resolution [3.0]
# will defend [3.0]
# to include [3.0]
# eight others [3.0]
# loaned [3.0]
# owes [2.9999999999999996]
# stalls [2.9999999999999996]
# to turkey [2.6666666666666665]
# to sell [2.6666666666666665]
# syrian city [2.6666666666666665]
# faiths [2.6666666666666665]
# eastern syria [2.6666666666666665]
# flown [2.6666666666666665]
# in may [2.6666666666666665]
# does not want [2.6666666666666665]
# to attend [2.6666666666666665]
# dagestan [2.6666666666666665]
# blaze [2.2727272727272725]
# wells [2.0]
# scorched [2.0]
# accord [2.0]
# by strike [2.0]
# phosphorus [2.0]
# will recognise [2.0]
# 3 billion [2.0]
# so called [2.0]
# must fulfil [2.0]
# truths [2.0]
# invitation [2.0]
# military presence [2.0]
# complicit [2.0]
# compatriots [2.0]
# syrian conflict [2.0]
# not responsible [2.0]
# armenia [2.0]
# wo n’t intervene [2.0]
# climbs [2.0]
# traces of explosives [2.0]
# russian military [2.0]
# may abandon [2.0]
# u.s. policies [2.0]
# in past 24 hours [2.0]
# will attend [2.0]
# may have killed [2.0]
# evading [2.0]
# proposed by [2.0]
# romania [2.0]
# nemtsov [2.0]
# its influence [2.0]
# would violate [2.0]
# its borders [2.0]
# strike on syrian air base [2.0]
# nukes [2.0]
# truce deal [2.0]
# was investigating [2.0]
# the region [2.0]
# mistral [2.0]
# 72 [2.0]
# should be done [2.0]
# kuril islands [2.0]
# fight against [2.0]
# will act [2.0]
# arrival [2.0]
# cessation [2.0]
# frontline [2.0]
# no fly [2.0]
# would consider [2.0]
# ukraine elections [2.0]
# hostilities [2.0]
# u.s. crossed [2.0]
# f-16 [2.0]
# iran missile test [2.0]
# russian territory [2.0]
# escalation [2.0]
# u.s. crossed red lines [2.0]
# base in syria [2.0]
# turkish operation in syria [2.0]
# could build [2.0]
# syria ’s [2.0]
# air strike in syria [2.0]
# shot down is [2.0]
# syria 's idlib [2.0]
# muslim world [2.0]
# should stay [2.0]
# astronauts [2.0]
# stranded in [2.0]
# weapons attack [2.0]
# has accepted [2.0]
# estonian [2.0]
# spyware [2.0]
# situation in [2.0]
# central asia [2.0]
# peace efforts [2.0]
# hospital strike [2.0]
# government officials [2.0]
# intelligence mission [2.0]
# has fallen [2.0]
# airlift [2.0]
# invites [2.0]
# attack helicopters [2.0]
# could hit [2.0]
# is conducting [2.0]
# behind chemical attack [2.0]
# plane disaster [2.0]
# a terrorist attack [2.0]
# u.s. crossed red lines with strike on syrian air base [2.0]
# are killed [2.0]
# space station [2.0]
# syrian air base [2.0]
# scraps [2.0]
# caucasus [2.0]
# self defense [2.0]
# deal with us [2.0]
# could jeopardize [2.0]
# spokesman [2.0]
# secretary of state [2.0]
# should pay [2.0]
# yanukovych [2.0]
# world news [2.0]
# brink of civil war [2.0]
# will expand [1.7999999999999998]
# to share [1.7999999999999998]
# to crimea [1.7999999999999998]
# cold war [1.7999999999999998]
# fishermen [1.7999999999999998]
# does n't have [1.7999999999999998]
# focuses [1.7999999999999998]
# facto [1.7999999999999998]
# blacked [1.7999999999999998]
# it will honor its controversial contract to deliver s-300 air defense missile systems to syria [1.0]
# it will defend the rights of its compatriots in crimea after russia gunmen seize parliament [1.0]
# fire in dagestan [1.0]
# east of aleppo syria [1.0]
# u.s georgian military exercises [1.0]
# it has not received asylum application from snowden [1.0]
# for downed jet [1.0]
# fleet of warships is off australia for climate research [1.0]
# forbids [1.0]
# to resolve [1.0]
# the syrian government has agreed in principle to attend an international peace conference proposed by russia and the us [1.0]
# talks with united states on syria [1.0]
# focus of isis recruiters [1.0]
# discrimination for gay athletes [1.0]
# for undercover intelligence mission [1.0]
# us airstrike war crime [1.0]
# myth serbs [1.0]
# found in east of aleppo syria [1.0]
# evidence of war crimes found in east of aleppo syria [1.0]
# it will recognise the results of controversial separatist elections in eastern ukraine [1.0]
# can not order crimean ' self defense units back to base [1.0]
# construction stopped at world cup stadium in city of samara no reason given [1.0]
# following an official request from kiev [1.0]
# had put the plane [1.0]
# by ukraine sanctions [1.0]
# government forces in syria [1.0]
# gas supplies [1.0]
# foreign minister sergey lavrov [1.0]
# missile systems for syria [1.0]
# money agency [1.0]
# international community [1.0]
# in response to us strike [1.0]
# all of aleppo [1.0]
# kiev altered us satellite photos with image editor | satellite images kiev published carry altered time stamps and are from days after the mh17 tragedy [1.0]
# return money agency [1.0]
# turkey shot down plane for is oil [1.0]
# the syrian government has agreed in principle to attend an international peace conference proposed by russia and the us and criticised what it called attempts to undermine peace efforts [1.0]
# criticised what it called attempts to undermine peace efforts [1.0]
# joint isis operations with france [1.0]
# back from near ukraine 's eastern border [1.0]
# air links with egypt [1.0]
# that killed dozens of government troops fighting [1.0]
# former commercial capital [1.0]
# iran missile test does not contravene un resolution [1.0]
# are carrying [1.0]
# kazan crash [1.0]
# power with opposition [1.0]
# sinai plane disaster [1.0]
# ukraine must become a federation allowing regional autonomy [1.0]
# yacht [1.0]
# nosedive [1.0]
# one of its attack helicopters crashes [1.0]
# new uk aircraft carrier convenient target [1.0]
# western parts [1.0]
# four militants [1.0]
# no discrimination for gay athletes [1.0]
# a month before [1.0]
# deploying south to ashuluk for drills [1.0]
# in downing of plane [1.0]
# mh17 probe should be done by international community not ukraine [1.0]
# military force in syria [1.0]
# nuclear arms [1.0]
# some troops [1.0]
# withdrawal from afghanistan [1.0]
# an is offensive [1.0]
# the worst east west standoff since the cold war [1.0]
# it is using its influence to get syrian army to fulfil truce deal [1.0]
# does not contravene [1.0]
# it will consider financial help to greece [1.0]
# armed drones [1.0]
# greenpeace activists ' ship was carrying illegal drugs [1.0]
# foils plot [1.0]
# stranded in ice [1.0]
# 2 mission teams [1.0]
# u.s. backs party of war in kiev urges ceasefire [1.0]
# tragedy [1.0]
# 40 mortar shells hit russian territory on friday ria [1.0]
# damascus act of terrorism [1.0]
# us gps stations [1.0]
# ukrainian affairs [1.0]
# commercial capital [1.0]
# using f-16 fighter jets and patriot missiles from jordan [1.0]
# islamic state leader al baghdadi [1.0]
# conflict with turkey iran [1.0]
# talks to extend syrian lull in fighting to aleppo [1.0]
# u.s georgian military exercises could destabilize caucasus [1.0]
# has violated [1.0]
# u.s. withdrawal from afghanistan [1.0]
# by canceling summit over snowden [1.0]
# attempts to undermine peace efforts [1.0]
# source gas turbines [1.0]
# killed in dagestan siege [1.0]
# is offensive [1.0]
# a move that could ease tension in the worst east west standoff since the cold war [1.0]
# one of its airstrikes in syria [1.0]
# one of its airstrikes in syria killed isis spokesman mohammad al adnani a claim that a us official called preposterous [1.0]
# us missile system breaches nuclear inf treaty [1.0]
# one of its attack helicopters [1.0]
# it does n't mind if assad stays or steps down [1.0]
# fighting to aleppo [1.0]
# washington ria [1.0]
# unperturbed [1.0]
# already shaky [1.0]
# were taking [1.0]
# western airlines [1.0]
# mulls [1.0]
# all st petersburg metro bombing suspects from central asia [1.0]
# it can deploy nuclear arms to crimea [1.0]
# they are deeply worried by turkish operation in syria [1.0]
# syria conflict with turkey iran [1.0]
# to halt a surge of violence in its former commercial capital [1.0]
# downed jet [1.0]
# it does n't have special forces in egypt interfax [1.0]
# unperturbed by china ’s missile deployment [1.0]
# are deeply worried [1.0]
# sinai plane disaster was an act of terror after traces of explosives were found in debris at crash site [1.0]
# georgian [1.0]
# controversial separatist elections [1.0]
# it 's planning joint isis operations with france [1.0]
# first case [1.0]
# any attempt to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan would violate international law [1.0]
# u.s. withdrawal from afghanistan would worsen situation ifax [1.0]
# mid air incidents [1.0]
# ukraine ’s debt [1.0]
# do not consider [1.0]
# kerry ’s accusation [1.0]
# cut off over crimea [1.0]
# ceasefire under threat [1.0]
# warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago [1.0]
# it views the arrival of more than 3,000 us soldiers in poland as a threat to its own security [1.0]
# discussion on the syrian conflict [1.0]
# will deter [1.0]
# more than 3,000 us soldiers [1.0]
# to nato troop rotations in east [1.0]
# does not contravene un resolution [1.0]
# un vote [1.0]
# yacht detained by north korea [1.0]
# altering [1.0]
# controversial separatist elections in eastern ukraine [1.0]
# us led air attack in eastern syria [1.0]
# iran talks [1.0]
# gps stations [1.0]
# at nemtsov shooting [1.0]
# no fly zone over syria [1.0]
# air strikes in syria would be act of aggression without u.n. vote [1.0]
# facing moment of truth over ukraine [1.0]
# trial in armenia [1.0]
# it owes [1.0]
# international tribunal creates myth serbs solely to blame for war crimes in former yugoslavia [1.0]
# us astronauts [1.0]
# off japan 's northern coast [1.0]
# crisis trio talks [1.0]
# syrian army planning offensives [1.0]
# in some western parts of the country [1.0]
# cynical [1.0]
# north korean fisherman [1.0]
# when russian border guards opened fire on a fishing trawler [1.0]
# are claimed by [1.0]
# hurt in blaze on nuclear sub [1.0]
# iskander [1.0]
# satellite photos [1.0]
# of its attack helicopters [1.0]
# to pay for gas within a week [1.0]
# should control [1.0]
# only proxy talks on syria planned in geneva interfax [1.0]
# nato complicit in downing of plane [1.0]
# despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago [1.0]
# steps down [1.0]
# are fully established [1.0]
# aggression without u.n. vote [1.0]
# if new eu sanctions are imposed [1.0]
# army plan [1.0]
# some western parts of the country [1.0]
# illegal oil trade with isis [1.0]
# found in state computer networks [1.0]
# chemical arsenal [1.0]
# them terrorist organization [1.0]
# of terror [1.0]
# ukraine truce to hold [1.0]
# us inviting terror attack by de facto support for terrorism in syria [1.0]
# civilian targets in syria [1.0]
# from snowden [1.0]
# syrian army fulfil truce deal [1.0]
# had put [1.0]
# crash in sinai [1.0]
# u.s. backs party of war in kiev [1.0]
# for world war two anniversary celebrations [1.0]
# satellite images kiev published carry altered time stamps [1.0]
# registers first case [1.0]
# naval base in syria [1.0]
# surge of violence in its former commercial capital [1.0]
# infected with zika virus [1.0]
# after traces of explosives were found in debris at crash site [1.0]
# airbus [1.0]
# oddest [1.0]
# soviet era military bases in cuba and vietnam [1.0]
# it will be a month before de escalation zones are fully established as syrian opposition voices concern [1.0]
# a spy [1.0]
# it has killed islamist insurgency chief [1.0]
# militants seized with bomb in south [1.0]
# could be hurt [1.0]
# u.s. should push ukrainian leader to halt violence [1.0]
# future of truce in doubt [1.0]
# training exercise [1.0]
# pressure on its neighbor [1.0]
# france must fulfil mistral contract or return money agency [1.0]
# to use russian military in ukraine [1.0]
# exxon strikes oil [1.0]
# reduce oil smuggling [1.0]
# days after the mh17 tragedy [1.0]
# syria ceasefire under threat after us led strikes kill regime troops [1.0]
# with bombs [1.0]
# us sanctions extension against tehran [1.0]
# sanctions over the black sea peninsula 's annexation [1.0]
# samara [1.0]
# gunman opens fire in dagestan focus of isis recruiters [1.0]
# new us sanctions leave relations in uncharted territory | world news [1.0]
# that a us official called preposterous [1.0]
# lull in fighting [1.0]
# to greece [1.0]
# its airspace to western airlines [1.0]
# cuba and vietnam [1.0]
# own chemical arsenal [1.0]
# us satellite photos with image editor [1.0]
# ratcheting up [1.0]
# to normalize [1.0]
# ukraine ’s natural gas debt [1.0]
# is drafting roadmap [1.0]
# to undermine peace efforts [1.0]
# solely to blame for [1.0]
# an act of terror [1.0]
# a us led air attack in eastern syria that killed dozens of government troops fighting so called islamic state has endangered an already shaky ceasefire deal [1.0]
# cancels [1.0]
# source gas turbines for crimea power plant [1.0]
# the arrival of more than 3,000 us soldiers in poland [1.0]
# in debris [1.0]
# as its jets and syrian army troops fight off an is offensive in the historic syrian city [1.0]
# with exxon strikes oil [1.0]
# sanctions ' destructive [1.0]
# computer networks [1.0]
# in principle [1.0]
# ukraine crisis trio talks [1.0]
# its compatriots in crimea [1.0]
# is lying [1.0]
# to attend an international peace conference proposed by russia and the us [1.0]
# has not hit [1.0]
# mass graves and evidence of war crimes found in east of aleppo syria [1.0]
# to enforce syria cease fire [1.0]
# damascus act [1.0]
# that could ease tension in the worst east west standoff since the cold war [1.0]
# missile systems for syria will deter intervention [1.0]
# by a terrorist attack [1.0]
# foreign minister sergey lavrov and u.s. secretary of state john kerry [1.0]
# eu relations facing moment of truth over ukraine [1.0]
# so called islamic state [1.0]
# metro [1.0]
# all st petersburg metro bombing suspects [1.0]
# for washington strike government forces in syria [1.0]
# it has detained ukrainian saboteurs in crimea [1.0]
# would worsen [1.0]
# west acting in muslim world like monkey with grenade [1.0]
# us inviting terror attack [1.0]
# it loses billions to oil slump sanctions [1.0]
# what it called attempts to undermine peace efforts [1.0]
# military mission in ukraine [1.0]
# an air strike on assad militia [1.0]
# de escalation zones [1.0]
# eu sanctions [1.0]
# eu criticism over ukraine shift inappropriate [1.0]
# eu criticism over ukraine shift [1.0]
# it could sell missile defense systems to turkey [1.0]
# to undermine [1.0]
# special forces in egypt interfax [1.0]
# oil trade with islamic state [1.0]
# the united states and european union [1.0]
# altered time stamps [1.0]
# soldier who killed armenian family will face trial in armenia [1.0]
# money to pay for gas within a week [1.0]
# repayment [1.0]
# state computer networks [1.0]
# isis leader abu bakr al baghdadi [1.0]
# north korea 's leader has accepted an invitation to travel to moscow in may for world war two anniversary celebrations [1.0]
# syria cease fire [1.0]
# relations in uncharted territory [1.0]
# fulfilling [1.0]
# threat to its own security [1.0]
# the future of the black sea crimea region [1.0]
# government ifax [1.0]
# support for terrorism in syria [1.0]
# he was investigating cross border crime [1.0]
# ties with washington ria [1.0]
# on friday ria [1.0]
# nov. 24 deadline may not be met in iran talks interfax [1.0]
# mh17 crash investigation stalled [1.0]
# kiev 's request [1.0]
# planned in [1.0]
# an aggression by us [1.0]
# dissatisfied with u.s. talks over arms treaty concerns [1.0]
# yemen ambassador [1.0]
# the $ 3 billion debt it owes [1.0]
# nato troop rotations in east [1.0]
# was not shot [1.0]
# it will keep selling missiles to syria [1.0]
# to halt gas supplies to ukraine mulling coal cut off over crimea [1.0]
# joint isis operations [1.0]
# 2021 [1.0]
# nov. 24 deadline [1.0]
# convenient target [1.0]
# it will respond to nato troop rotations in east [1.0]
# force in syria [1.0]
# planned in geneva interfax [1.0]
# aleppo latakia [1.0]
# at world cup stadium in city of samara [1.0]
# its embassy [1.0]
# isis operations [1.0]
# it is drafting roadmap to resolve syria conflict with turkey iran [1.0]
# acting in muslim world like monkey with grenade [1.0]
# international tribunal [1.0]
# will arrest [1.0]
# sea crimea [1.0]
# u.s. withdrawal from afghanistan would worsen situation [1.0]
# syrian government and opposition in talks ifax [1.0]
# damascus act of terrorism | reuters [1.0]
# syria to ship chemical arms as civilians flee bombs [1.0]
# an invitation to travel to moscow in may for world war two anniversary celebrations [1.0]
# openly tourists [1.0]
# is protecting [1.0]
# future in doubt [1.0]
# teams up with turkey for first time to bomb syrian militants [1.0]
# eu should be ashamed over sanctions [1.0]
# plane crash in sinai was terrorist attack vows vengeance [1.0]
# inviting terror attack [1.0]
# not maintain [1.0]
# china ’s missile deployment [1.0]
# soviet era military bases [1.0]
# us astronauts could be hurt by ukraine sanctions [1.0]
# crash investigation [1.0]
# for a chemical weapons attack [1.0]
# kiev published [1.0]
# nuclear sub [1.0]
# mulling coal cut off over crimea [1.0]
# to almost $ 2 billion [1.0]
# a convenient target [1.0]
# viktor [1.0]
# greenpeace activists ' ship [1.0]
# russia gunmen seize parliament [1.0]
# s-300 air defense missile systems [1.0]
# its own mistral warships [1.0]
# national governments should control the internet [1.0]
# to attack chemical arms facility [1.0]
# its own security [1.0]
# cessation of hostilities in syria violated 29 times in past 24 hours [1.0]
# turkey is protecting oil trade with islamic state [1.0]
# u.s. missiles in poland [1.0]
# fires iskander m ballistic missile during training exercise [1.0]
# the black sea peninsula 's annexation [1.0]
# a sign of intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# it would not hand back crimea to ukraine despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago [1.0]
# soldier who killed armenian family [1.0]
# in most intense raids [1.0]
# trawler [1.0]
# ready to move fast to fix ties with washington ria [1.0]
# in aleppo latakia [1.0]
# air units [1.0]
# an air strike [1.0]
# all of aleppo has fallen to syrian government control [1.0]
# international community not ukraine [1.0]
# a claim that a us official called preposterous [1.0]
# near on syria flights [1.0]
# lethal aid to ukraine [1.0]
# proposed by russia and the us [1.0]
# all st petersburg suspects [1.0]
# arms treaty concerns [1.0]
# will not drop [1.0]
# turkey iran [1.0]
# u.s. missiles in poland romania would violate treaty [1.0]
# to bomb syrian militants [1.0]
# group:''we [1.0]
# its embassy in damascus act of terrorism | reuters [1.0]
# syrian lull [1.0]
# states on syria [1.0]
# shelling of its embassy in damascus act of terrorism | reuters [1.0]
# trade with isis [1.0]
# to move fast to fix [1.0]
# ashuluk [1.0]
# tension in the worst east west standoff since the cold war [1.0]
# the mh17 tragedy [1.0]
# turkish leadership involved in illegal oil trade with isis [1.0]
# friday ria [1.0]
# tourists [1.0]
# to deploy security forces to syria [1.0]
# japan 's northern coast [1.0]
# united states on syria [1.0]
# assad ready to share power with opposition [1.0]
# military agreement near with u.s. on syria flights [1.0]
# well drilled [1.0]
# its strikes [1.0]
# supplies may be cut [1.0]
# a fishing trawler [1.0]
# criticism over ukraine shift [1.0]
# of aleppo [1.0]
# syrian government control [1.0]
# isis leader may have been liquidated by strike [1.0]
# surge in its former commercial capital [1.0]
# syria airstrike an aggression by us [1.0]
# russia and the us [1.0]
# cut over crimea [1.0]
# after russia gunmen seize parliament [1.0]
# ukraine 's fugitive president viktor yanukovych asked putin to use russian military in ukraine [1.0]
# world cup stadium in city of samara [1.0]
# to move fast to fix ties with washington ria [1.0]
# on slavyansk [1.0]
# to ship [1.0]
# to extend syrian lull in fighting to aleppo [1.0]
# altered [1.0]
# strike government forces in syria [1.0]
# almost $ 2 billion [1.0]
# missile during training exercise [1.0]
# in fighting to aleppo [1.0]
# international monitors [1.0]
# a u.s. official [1.0]
# ready to consider more ways to normalize situation in syria 's aleppo [1.0]
# to pay for [1.0]
# to oil slump sanctions [1.0]
# good faith talks with ukraine over the $ 3 billion debt it owes [1.0]
# for edward snowden [1.0]
# kerry ’s accusation moscow is lying “ beyond diplomatic ethics [1.0]
# any attempt [1.0]
# by turkish operation in syria [1.0]
# if u.s. supplies lethal aid to ukraine [1.0]
# oil smuggling [1.0]
# estonian police officer [1.0]
# arms facility [1.0]
# have held [1.0]
# protecting al qaeda in syria [1.0]
# the black sea crimea region [1.0]
# using coordinates supplied by “ opposition representatives [1.0]
# spyware found in state computer networks [1.0]
# openly gay tourists [1.0]
# links with egypt [1.0]
# on brink of civil war [1.0]
# russian border guards [1.0]
# it wo n't intervene in ukraine [1.0]
# war crimes found in east of aleppo syria [1.0]
# turkish troops [1.0]
# 24 targets in syria [1.0]
# security cameras were n't pointing at nemtsov shooting [1.0]
# of isis recruiters [1.0]
# cross border crime [1.0]
# is drafting [1.0]
# should push [1.0]
# north korea 's leader [1.0]
# aggression by us [1.0]
# f-16 fighter jets and [1.0]
# only proxy talks [1.0]
# 24 targets [1.0]
# an invitation [1.0]
# syria flights [1.0]
# urges ceasefire [1.0]
# editors [1.0]
# plane for [1.0]
# off australia [1.0]
# yemen ambassador was not shot and killed [1.0]
# f-16 fighter jets and patriot missiles from jordan [1.0]
# protest of ukraine sanctions [1.0]
# interfax [1.0]
# act of aggression without u.n. vote [1.0]
# as close to civil war [1.0]
# air units deploying south to ashuluk for drills [1.0]
# zone over syria [1.0]
# syria 's ancient palmyra cleared mines [1.0]
# new tragedies [1.0]
# with turkey [1.0]
# security cameras [1.0]
# other states ' affairs [1.0]
# mid air incidents over syria [1.0]
# uk aircraft carrier [1.0]
# it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month [1.0]
# obama hurting himself by canceling summit over snowden [1.0]
# civilian targets [1.0]
# contacts and relations with them [1.0]
# tallinn [1.0]
# hostilities in syria [1.0]
# back to base [1.0]
# to travel to [1.0]
# opposition in talks [1.0]
# could sell [1.0]
# airbus a321 plane over egypt [1.0]
# end support of terrorism [1.0]
# s-300 systems [1.0]
# new tragedies possible if u.s. supplies lethal aid to ukraine [1.0]
# it will keep out of ukrainian affairs [1.0]
# its strikes reduce oil smuggling to turkey [1.0]
# has endangered [1.0]
# the historic syrian city [1.0]
# over the $ 3 billion debt it owes [1.0]
# it may have killed isis leader abu bakr al baghdadi [1.0]
# it 's compiled 100-page report blaming syrian rebels for a chemical weapons attack [1.0]
# it may abandon space station by 2020 [1.0]
# its controversial contract [1.0]
# after us led strikes kill regime troops [1.0]
# st petersburg suspects [1.0]
# response to us strike [1.0]
# as civilians [1.0]
# worst standoff since the cold war [1.0]
# blaming syrian rebels for a chemical weapons attack [1.0]
# dozens of government troops [1.0]
# ukrainian saboteurs [1.0]
# if assad stays or steps down [1.0]
# ukraine ’s natural gas debt climbed to almost $ 2 billion [1.0]
# no reason given [1.0]
# u.s. talks over arms treaty concerns [1.0]
# more than 3,000 us soldiers in poland [1.0]
# were n't pointing [1.0]
# deir al zor raqqa ria [1.0]
# for washington [1.0]
# dealer bout [1.0]
# for 72 hours [1.0]
# temporary lull in fighting [1.0]
# foreign minister sergey lavrov and u.s. secretary of state john kerry have held a telephone discussion on the syrian conflict [1.0]
# cleared mines [1.0]
# as a threat to its own security [1.0]
# insurgency chief [1.0]
# systems for syria [1.0]
# of intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# flee bombs [1.0]
# moment of truth over ukraine [1.0]
# phosphorus bombs [1.0]
# without government approval [1.0]
# illegal drugs [1.0]
# had pulled [1.0]
# optimistic about ukraine crisis trio talks [1.0]
# one of its attack helicopters crashes in syria [1.0]
# teams up with turkey [1.0]
# one north korean fisherman was killed [1.0]
# supplied by “ opposition representatives [1.0]
# open to good faith talks with ukraine over the $ 3 billion debt it owes [1.0]
# led kill [1.0]
# it had pulled some troops back from near ukraine 's eastern border a move that could ease tension in the worst east west standoff since the cold war [1.0]
# white house and kremlin [1.0]
# myths [1.0]
# scorched earth policy [1.0]
# ukraine monitors [1.0]
# aid to ukraine [1.0]
# submarine launched missile for first time [1.0]
# no decision on repayment [1.0]
# telephone discussion on the syrian conflict [1.0]
# will resume selling gas to ukraine following an official request from kiev [1.0]
# in schools [1.0]
# roadmap [1.0]
# syrian army troops [1.0]
# cynical u.s. policy pushing world toward new cold war [1.0]
# as civilians flee bombs [1.0]
# syrian militants [1.0]
# own security [1.0]
# former yugoslavia [1.0]
# should control the internet [1.0]
# missiles in poland [1.0]
# us secretary of state john kerry [1.0]
# turkish leadership [1.0]
# financial help [1.0]
# a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan [1.0]
# opposition voices [1.0]
# that they will not drop sanctions over the black sea peninsula 's annexation a year ago [1.0]
# may aggravate [1.0]
# for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month [1.0]
# assad militia [1.0]
# unperturbed by [1.0]
# it will have armed drones by 2020 [1.0]
# war crimes in former yugoslavia [1.0]
# are from days after the mh17 tragedy [1.0]
# would not hand back [1.0]
# 40 mortar shells [1.0]
# are imposed [1.0]
# serbs [1.0]
# syrian opposition voices [1.0]
# it 's set to deploy security forces to syria [1.0]
# fabricated by [1.0]
# u.s. coerces kiev [1.0]
# bomb did down airbus a321 plane over egypt last month [1.0]
# image editor [1.0]
# army troops [1.0]
# are deeply [1.0]
# islamic state [1.0]
# ukraine on brink of civil war [1.0]
# un resolution proposal ' unacceptable [1.0]
# an international peace conference proposed by russia and the us [1.0]
# registers [1.0]
# ukraine should find money to pay for gas within a week [1.0]
# kills 300 militants in syria in most intense raids yet [1.0]
# syrian government ifax [1.0]
# an already shaky ceasefire deal [1.0]
# greenpeace [1.0]
# destructive [1.0]
# arctic well drilled with exxon strikes oil [1.0]
# in own interests [1.0]
# it will expand its military presence on the kuril islands which lie off japan 's northern coast and are claimed by japan [1.0]
# pushing world toward new cold war [1.0]
# downing of plane [1.0]
# has not received asylum application [1.0]
# it will arrest openly gay tourists [1.0]
# isis spokesman mohammad al adnani [1.0]
# regional autonomy [1.0]
# in south [1.0]
# undercover intelligence mission [1.0]
# ready to share power with opposition [1.0]
# for scientists stranded in ice [1.0]
# its embassy in damascus act of terrorism [1.0]
# syria 's aleppo [1.0]
# his plane [1.0]
# coal cut off over crimea [1.0]
# us talks [1.0]
# to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan [1.0]
# us led strikes kill [1.0]
# satellite images kiev published carry altered time stamps and are from days after the mh17 tragedy [1.0]
# missile deployment [1.0]
# it will build bridge to crimea [1.0]
# reports of syria hospital strike fake [1.0]
# request from kiev [1.0]
# 300 militants [1.0]
# loan terms [1.0]
# foils plot to attack chemical arms facility [1.0]
# is planned [1.0]
# by march [1.0]
# dissatisfied [1.0]
# nemtsov shooting [1.0]
# new uk aircraft carrier a convenient target [1.0]
# was investigating cross border crime [1.0]
# can deploy [1.0]
# most intense raids [1.0]
# did down [1.0]
# it may have killed islamic state leader al baghdadi [1.0]
# situation ifax [1.0]
# by international community not ukraine [1.0]
# can examine [1.0]
# may have been liquidated [1.0]
# are from [1.0]
# it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month [1.0]
# detained is [1.0]
# out of ukrainian affairs [1.0]
# should find [1.0]
# not responsible for strike on school in syria 's idlib [1.0]
# is fully mobilized [1.0]
# turkey should pay compensation for downed jet [1.0]
# as close [1.0]
# cessation of hostilities in syria [1.0]
# toward new cold war [1.0]
# ifax [1.0]
# government control [1.0]
# fulfil truce deal [1.0]
# 29 times [1.0]
# strikes would harm [1.0]
# could ease [1.0]
# ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region [1.0]
# declared by [1.0]
# which lie off japan 's northern coast and are claimed by japan [1.0]
# uncharted territory [1.0]
# mortar shells [1.0]
# isis recruiters [1.0]
# seize parliament [1.0]
# of war crimes found in east of aleppo syria [1.0]
# talks were taking place to include aleppo in a temporary lull in fighting declared by the syrian army in some western parts of the country a sign of intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# inf treaty [1.0]
# them a terrorist organization [1.0]
# climate research [1.0]
# geneva interfax [1.0]
# no direct contacts yet [1.0]
# decision on repayment [1.0]
# within a week [1.0]
# direct contacts [1.0]
# islamist insurgency chief [1.0]
# over the future of the black sea crimea region [1.0]
# 100-page report [1.0]
# missile defense systems [1.0]
# signaled [1.0]
# in the historic syrian city [1.0]
# ceasefire deal [1.0]
# hezbollah not a terrorist group:''we maintain contacts and relations with them because we do not consider them a terrorist organization [1.0]
# like monkey with grenade [1.0]
# after the u.s. military carried out an air strike on assad militia last month [1.0]
# kohver [1.0]
# of more than 3,000 us soldiers in poland [1.0]
# in ukraine where 2 mission teams are missing [1.0]
# kiev forces [1.0]
# kazan [1.0]
# fugitive president [1.0]
# assad ready [1.0]
# as syrian opposition voices concern [1.0]
# resolution proposal unacceptable [1.0]
# selling gas [1.0]
# us satellite photos [1.0]
# any attempt to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan [1.0]
# preposterous [1.0]
# fight off [1.0]
# eastern border [1.0]
# to normalize situation in syria 's aleppo [1.0]
# could close [1.0]
# us missile system breaches [1.0]
# military mission in ukraine is there at kiev 's request [1.0]
# declared by the syrian army in some western parts of the country [1.0]
# it hit islamic state with submarine launched missile for first time [1.0]
# the kuril islands which lie off japan 's northern coast and are claimed by japan [1.0]
# as they scrap over the future of the black sea crimea region [1.0]
# intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# armenian family [1.0]
# assad ready to support ceasefire [1.0]
# russian border guards opened fire [1.0]
# dagestan siege [1.0]
# to prevent mid air incidents over syria in response to us strike [1.0]
# to consider more ways to normalize situation in syria 's aleppo [1.0]
# white phosphorus bombs [1.0]
# eu relations [1.0]
# new uk aircraft carrier a convenient target bbc news [1.0]
# assad was behind chemical attack [1.0]
# to resolve syria conflict with turkey iran [1.0]
# images carry [1.0]
# syria gas incident caused by rebels ' own chemical arsenal [1.0]
# peninsula 's [1.0]
# air force has not hit civilian targets in syria [1.0]
# support of terrorism [1.0]
# a federation [1.0]
# will resume selling [1.0]
# radar evading nukes [1.0]
# entrenched in [1.0]
# its jets [1.0]
# separatist elections [1.0]
# a year ago [1.0]
# its jets and syrian army troops fight off [1.0]
# monkey with grenade [1.0]
# beyond diplomatic ethics [1.0]
# russia gunmen [1.0]
# which lie off japan 's northern coast [1.0]
# allowing regional autonomy [1.0]
# eu does not want ukraine truce to hold [1.0]
# undercover [1.0]
# school in syria 's idlib [1.0]
# does n't mind [1.0]
# will resume selling gas to ukraine following an official request from kiev [1.0]
# are claimed by japan [1.0]
# it would consider asylum for edward snowden [1.0]
# to halt [1.0]
# its jets bombed 24 targets in syria tuesday using coordinates supplied by “ opposition representatives [1.0]
# the results [1.0]
# will honor [1.0]
# ashuluk for drills [1.0]
# ukraine election may aggravate crisis [1.0]
# scientists stranded in ice [1.0]
# crimean [1.0]
# could destabilize [1.0]
# one north korean fisherman was killed and eight others injured when russian border guards opened fire on a fishing trawler [1.0]
# a chemical weapons attack [1.0]
# a temporary lull in fighting declared by the syrian army in some western parts of the country [1.0]
# probe should be done [1.0]
# to halt violence [1.0]
# geneva peace talks [1.0]
# to deliver s-300 air defense missile systems to syria [1.0]
# relations with them [1.0]
# trade with islamic state [1.0]
# turkey must stop meddling in other states ' affairs end support of terrorism [1.0]
# ukrainian leader [1.0]
# mistral warships [1.0]
# truce extended for 72 hours in aleppo latakia [1.0]
# pilot of kazan crash had put the plane into nosedive [1.0]
# no proof assad was behind chemical attack [1.0]
# missiles from jordan [1.0]
# within their borders [1.0]
# its jets and syrian army troops [1.0]
# a month before de escalation zones are fully established as syrian opposition voices concern [1.0]
# in iran talks [1.0]
# support in syria [1.0]
# detained estonian police officer is a spy | moscow holds eston kohver for undercover intelligence mission while tallinn says he was investigating cross border crime [1.0]
# iskander m ballistic missile during training exercise [1.0]
# hurt on nuclear sub [1.0]
# involved in illegal oil trade with isis [1.0]
# yemen ambassador was not shot [1.0]
# to syrian government control [1.0]
# time stamps [1.0]
# is struggling [1.0]
# a us led air attack in eastern syria that killed dozens of government troops fighting [1.0]
# solely to blame for war crimes in former yugoslavia [1.0]
# canceling summit over snowden [1.0]
# it could close its airspace to western airlines if new eu sanctions are imposed [1.0]
# crimea power plant [1.0]
# no country [1.0]
# on a fishing trawler [1.0]
# world war two anniversary celebrations [1.0]
# syrian base [1.0]
# more ways to normalize situation in syria 's aleppo [1.0]
# signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region [1.0]
# opposition representatives [1.0]
# ukraine sanctions [1.0]
# mission in ukraine [1.0]
# u.s. is conducting scorched earth policy [1.0]
# air defense system [1.0]
# inf [1.0]
# chemical arms facility [1.0]
# standoff since the cold war [1.0]
# at crash site [1.0]
# international monitors should stay in ukraine where 2 mission teams are missing [1.0]
# will be restored [1.0]
# one north korean fisherman [1.0]
# on syrian army [1.0]
# its military presence on the kuril islands which lie off japan 's northern coast and are claimed by japan [1.0]
# detained by north korea [1.0]
# u.s. strikes on syrian army would harm fight against islamists [1.0]
# it may reopen soviet era military bases in cuba and vietnam [1.0]
# own mistral warships [1.0]
# on the kuril islands which lie off japan 's northern coast and are claimed by japan [1.0]
# a telephone discussion on the syrian conflict [1.0]
# mistral contract [1.0]
# nato troop rotations [1.0]
# patriot [1.0]
# selling missiles to syria [1.0]
# to travel to moscow in may for world war two anniversary celebrations [1.0]
# gas incident [1.0]
# terrorist group:''we [1.0]
# good faith talks [1.0]
# its planes are carrying military goods to syria [1.0]
# historic syrian city [1.0]
# ready for talks with united states on syria [1.0]
# threat from turkey [1.0]
# slavyansk [1.0]
# shaky [1.0]
# may act [1.0]
# pilot of kazan crash [1.0]
# were taking place [1.0]
# syria 's assad is ready to share power with opposition [1.0]
# to include aleppo in a temporary lull in fighting declared by the syrian army in some western parts of the country a sign of intensified efforts to halt a surge of violence in its former commercial capital [1.0]
# to good faith talks with ukraine over the $ 3 billion debt it owes [1.0]
# lull [1.0]
# coordinates supplied by “ opposition representatives [1.0]
# if assad stays [1.0]
# acting in [1.0]
# entrenched in syria [1.0]
# to source gas turbines for crimea power plant [1.0]
# syrian government officials [1.0]
# more ways [1.0]
# no fly zone over syria would be illegal [1.0]
# reason given [1.0]
# it may act alone to enforce syria cease fire [1.0]
# terrorism | reuters [1.0]
# 2 billion [1.0]
# extension against tehran [1.0]
# embassy naval base in syria working as normal [1.0]
# to share power with opposition [1.0]
# is suspending [1.0]
# the internet [1.0]
# has not received [1.0]
# regime troops [1.0]
# bridge to crimea [1.0]
# syria hospital strike fake [1.0]
# missile for first time [1.0]
# terrorist organization [1.0]
# to support ceasefire [1.0]
# supplied by [1.0]
# ukraine ’s natural gas debt climbed to almost $ 2 billion and signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region [1.0]
# us protecting al qaeda in syria [1.0]
# plane crash in sinai [1.0]
# plane over egypt [1.0]
# the worst standoff since the cold war [1.0]
# will deter intervention [1.0]
# vows vengeance [1.0]
# may be cut [1.0]
# 100-page report blaming syrian rebels for a chemical weapons attack [1.0]
# air attack in eastern syria [1.0]
# attack in eastern syria [1.0]
# where 2 mission teams are missing [1.0]
# opens fire in dagestan [1.0]
# in a temporary lull in fighting declared by the syrian army in some western parts of the country [1.0]
# federation [1.0]
# arms treaty [1.0]
# the debt [1.0]
# france must fulfil mistral contract [1.0]
# shelling of its embassy in damascus act of terrorism [1.0]
# ukraine where 2 mission teams are missing [1.0]
# the results of controversial separatist elections in eastern ukraine [1.0]
# to sell air defense system to syria [1.0]
# meddling in [1.0]
# eston kohver for undercover intelligence mission [1.0]
# 300 militants are killed as its jets and syrian army troops fight off an is offensive in the historic syrian city [1.0]
# ukraine monitors biased [1.0]
# no direct contacts yet between white house and kremlin [1.0]
# no country can use military force in syria without government approval [1.0]
# must fulfil mistral contract [1.0]
# national governments [1.0]
# a321 [1.0]
# situation in syria 's aleppo [1.0]
# forbid us gps stations within its borders in protest of ukraine sanctions [1.0]
# violates arms treaties [1.0]
# it will have radar evading nukes by 2021 [1.0]
# moment over ukraine [1.0]
# inflation could hit 17 % by march [1.0]
# u.s. coerces kiev and violates arms treaties [1.0]
# sinai plane crash was caused by a terrorist attack [1.0]
# its attack helicopters [1.0]
# airspace to western airlines [1.0]
# because we do not consider them a terrorist organization [1.0]
# party of war in kiev [1.0]
# vengeance [1.0]
# its airstrikes [1.0]
# ancient palmyra [1.0]
# fight against islamists [1.0]
# turkish troops entrenched in syria [1.0]
# eight others injured when russian border guards opened fire on a fishing trawler [1.0]
# stamp [1.0]
# eston [1.0]
# meddling in other states ' affairs [1.0]
# government approval [1.0]
# with submarine launched missile for first time [1.0]
# airlift is planned for scientists stranded in ice [1.0]
# summit over snowden [1.0]
# gay athletes [1.0]
# may not be met [1.0]
# of ukrainian affairs [1.0]
# its airstrikes in syria [1.0]
# coercing [1.0]
# it is suspending deal with u.s. to prevent mid air incidents over syria in response to us strike [1.0]
# ballistic missile during training exercise [1.0]
# mission teams [1.0]
# for climate research [1.0]
# person infected with zika virus [1.0]
# who killed armenian family [1.0]
# embassy naval base in syria [1.0]
# unprecedented threat from turkey [1.0]
# back from near 's [1.0]
# to ashuluk for drills [1.0]
# f-16 fighter jets [1.0]
# ashamed over sanctions [1.0]
# slump [1.0]
# some western parts [1.0]
# ukraine shift [1.0]
# to get syrian army to fulfil truce deal [1.0]
# syrian army planning offensives on deir al zor raqqa ria [1.0]
# the rights of its compatriots in crimea [1.0]
# its neighbors [1.0]
# ...
# 28 foreign led terrorists [1.0]
# last week 's xinjiang violence that killed 25 [1.0]
# set for [1.0]
# crackdown on civil society [1.0]
# central government [1.0]
# 2 extremists detonated explosives in xinjiang in apparent suicide blast [1.0]
# internet freedom [1.0]
# for illegal mining [1.0]
# on human rights [1.0]
# again carries out [1.0]
# regional peace [1.0]
# buddhism [1.0]
# united states should brush up on south china sea history [1.0]
# dangerous and irresponsible [1.0]
# it will punish carmakers by restricting their production and publicly naming them if they fail to meet fuel consumption requirements on passenger vehicles set for 2015 [1.0]
# set a target for electric cars to make up at least 30 percent of government vehicle purchases by 2016 [1.0]
# from injuries [1.0]
# mh17 attack [1.0]
# several nations [1.0]
# warns on [1.0]
# serious polluters [1.0]
# it will produce over 300 of its new large military transport aircraft y-20 within 10 years surpassing the us in technology [1.0]
# funeral strippers [1.0]
# activist from taiwan [1.0]
# to stop blocking [1.0]
# u.s. bomber 's flight a serious military provocation [1.0]
# to celebrate ramadan [1.0]
# reference to the recently announced russian maritime doctrine [1.0]
# it wo n't take any more foreign garbage [1.0]
# military parade will involve 12,000 troops 200 aircraft [1.0]
# important for relations with russia [1.0]
# cleans [1.0]
# further reforms on way [1.0]
# cubic meters [1.0]
# disputed islands [1.0]
# detained in zambia for illegal mining [1.0]
# nkorea could suspend nukes for halt in us drills [1.0]
# xi and trump discuss north korea syria by phone [1.0]
# communication mechanism with taiwan [1.0]
# philippines ' request [1.0]
# u.s. routinely hacks defense ministry websites [1.0]
# more islands in south china sea [1.0]
# the us is militarizing the south china sea [1.0]
# red notice [1.0]
# 31 nationals detained in zambia for illegal mining [1.0]
# to develop rustbelt regions [1.0]
# it seized u.s. drone to ensure safety of its ships [1.0]
# last week 's violence [1.0]
# south china sea defences [1.0]
# it will make it easier for environmental groups to sue polluters [1.0]
# was provoked [1.0]
# turkey will decide in its own interests on missile system [1.0]
# a deceptive actor after brain comments in last week tonight with john oliver [1.0]
# in ship borne trade [1.0]
# about 3,000 refugees who have entered its territory to escape from myanmar fighting [1.0]
# on their own [1.0]
# global war on terror should also target uighur militants [1.0]
# hostile forces [1.0]
# web site [1.0]
# nearly 100 deaths [1.0]
# regional tensions [1.0]
# economic growth [1.0]
# it is building second aircraft carrier [1.0]
# it has handed over u.s drone taken in south china sea [1.0]
# assessing effects [1.0]
# about draft law that requires them to turn over source code and build back doors [1.0]
# mass fish deaths [1.0]
# to assess impact of possible punitive u.s. tariffs [1.0]
# are arrested [1.0]
# percent of government vehicle purchases [1.0]
# fortress against separatism [1.0]
# attitudes [1.0]
# political provocation in south china sea [1.0]
# it has arrested more terrorism suspects after clash in western region killed 21 [1.0]
# in hunt [1.0]
# the latest show of tension between the two [1.0]
# rights activist from taiwan [1.0]
# defense budget [1.0]
# with conventional weapons using nuclear submarines [1.0]
# for about 3,000 refugees who have entered its territory to escape from myanmar fighting [1.0]
# new large aircraft [1.0]
# as leader of taiwan [1.0]
# one china ' principle [1.0]
# mass fish deaths unrelated to tianjin blasts [1.0]
# 60 percent [1.0]
# searches for pregnancy tips soar [1.0]
# by 60 percent [1.0]
# north korea nuke program on its own [1.0]
# no one should bring chaos to korean peninsula [1.0]
# a taiwanese ngo worker and human rights activist on suspicion of endangering national security [1.0]
# a trade barrier [1.0]
# invading chinese airspace [1.0]
# would impact peace [1.0]
# will spend $ 275 billion [1.0]
# after clash in western region killed 21 [1.0]
# the u.s. missile defense system [1.0]
# that requires them to turn over source code and build back doors [1.0]
# will never send [1.0]
# myanmar fighting [1.0]
# restricting their production [1.0]
# dalai lama a deceptive actor after brain comments in last week tonight with john oliver [1.0]
# conflict’ in south china sea [1.0]
# its recent gas discovery in the politically volatile south china sea [1.0]
# new north korea nuclear test possible [1.0]
# japan ties should be based on cooperation not confrontation [1.0]
# scene of an increasingly ugly spat with vietnam over an oil rig in the south china sea [1.0]
# refusal of the self ruled island 's new government [1.0]
# violating south china sea code [1.0]
# steady progress [1.0]
# dalai lama obama meeting [1.0]
# the self ruled island 's [1.0]
# muslims free [1.0]
# the recently announced russian maritime doctrine [1.0]
# space lab [1.0]
# web censorship [1.0]
# minor incident could spark war in south china sea [1.0]
# will damage [1.0]
# pterosaur ii drone [1.0]
# it will boost investment in tourism with plans to develop rustbelt regions and upgrade public toilets high on its to do list as it looks to lift the sector 's contribution to economic growth [1.0]
# fight in tibet [1.0]
# xinjiang attack that led to nearly 100 deaths [1.0]
# tpp rcep direction [1.0]
# as shanghai infections rise [1.0]
# 275 billion [1.0]
# vigilance [1.0]
# self ruled island 's [1.0]
# nuke program [1.0]
# it would not bend the rules [1.0]
# world 's freest shipping lanes [1.0]
# china ’s central government [1.0]
# polluters [1.0]
# investment in tourism [1.0]
# 315 [1.0]
# of political provocation in south china sea [1.0]
# a taiwanese ngo worker [1.0]
# production themselves [1.0]
# it would not bend the rules and allow india membership as it had not signed the proliferation treaty npt [1.0]
# if us ‘ stirs up any conflict’ in south china sea [1.0]
# it nationwide [1.0]
# for treatment source [1.0]
# green investments [1.0]
# by doubting his reincarnation [1.0]
# world standards [1.0]
# dangerous irresponsible [1.0]
# it will never send military forces to the scene of an increasingly ugly spat with vietnam over an oil rig in the south china sea [1.0]
# no such thing as man made islands in south china sea [1.0]
# as envoys meet [1.0]
# it fired 2 flares at vietnamese fishing boats [1.0]
# u.s. needs attitude adjustment in south china sea [1.0]
# war in south china sea [1.0]
# its shendiao drone [1.0]
# a new strain of deadly bird flu that has killed three people as japan and hong kong stepped up vigilance against the virus and vietnam banned imports of chinese poultry [1.0]
# nuclear reactor ready by next year [1.0]
# it was mobilising resources nationwide to combat a new strain of deadly bird flu that has killed three people as japan and hong kong stepped up vigilance against the virus and vietnam banned imports of chinese poultry [1.0]
# xinjiang mine attackers [1.0]
# sanctions alone [1.0]
# rustbelt regions [1.0]
# it 's building new homegrown aircraft carrier [1.0]
# tourists attacked in turkey during anti china protests [1.0]
# internet security [1.0]
# tracked u.s. warship in south china sea [1.0]
# graft fight in tibet also aimed at religion [1.0]
# any conflict’ in south china sea [1.0]
# publicly naming them if they fail to meet fuel consumption requirements on passenger vehicles set for 2015 [1.0]
# dalai lama obama meeting will damage bilateral ties [1.0]
# graft [1.0]
# u.s. and south korea will pay the price for thaad missile system [1.0]
# as indonesia speaks out [1.0]
# worsening relations between beijing and taipei and an ongoing crackdown on civil society [1.0]
# to escape from [1.0]
# mechanisms [1.0]
# in beijing attack [1.0]
# between beijing and taipei [1.0]
# no foreign link found in last week 's xinjiang violence that killed 25 [1.0]
# infections [1.0]
# could set up [1.0]
# recoveries [1.0]
# naval ties with united states [1.0]
# must respect constitution [1.0]
# to celebrate [1.0]
# its ivory trade [1.0]
# nanjing more worthy of remembrance than hiroshima [1.0]
# by philippines ' request for un arbitration- calls international dispute resolution illegal and unreasonable [1.0]
# 21 of its nationals in singapore infected with zika [1.0]
# to finish some land reclamation in south china sea [1.0]
# over 300 of its new large military transport aircraft [1.0]
# appropriate handling of ukraine [1.0]
# recently announced russian maritime doctrine [1.0]
# wo n't take [1.0]
# cardiac arrest [1.0]
# to do list [1.0]
# shendiao [1.0]
# kerry 's call for internet freedom [1.0]
# to korean peninsula [1.0]
# speaks out [1.0]
# swimmer mack horton [1.0]
# clean energy development [1.0]
# any way [1.0]
# an oil rig in the south china sea [1.0]
# an ongoing crackdown on civil society [1.0]
# practical reality [1.0]
# would impact [1.0]
# the sector 's contribution to economic growth [1.0]
# as japan and hong kong stepped up vigilance against the virus and vietnam banned imports of chinese poultry [1.0]
# u.s. missile defense system [1.0]
# it will punish journalists just for talking about “ state secrets [1.0]
# a maritime talks proposal [1.0]
# north korea was behind sony cyberattack [1.0]
# using nuclear submarines [1.0]
# some land reclamation in south china sea [1.0]
# us island sail by dangerous and irresponsible [1.0]
# hopes ties [1.0]
# cuts in overcapacity [1.0]
# discovery in the politically volatile south china sea [1.0]
# on pollution [1.0]
# was mobilising [1.0]
# trouble on [1.0]
# is caring [1.0]
# by 2017 and further military reforms on way [1.0]
# shipping lanes [1.0]
# shoal [1.0]
# afp.com [1.0]
# first recovery from bird flu [1.0]
# turn over source code [1.0]
# restricting their production and publicly naming them if they fail to meet fuel consumption requirements on passenger vehicles set for 2015 [1.0]
# it is now able to attack the us homeland with conventional weapons using nuclear submarines [1.0]
# xinjiang religious schools [1.0]
# war with u.s. a practical reality [1.0]
# its own interests on missile system [1.0]
# it wo n't budge on south china sea sovereignty [1.0]
# uighurs [1.0]
# philippines ' duterte to visit again as ties warm up [1.0]
# air force again carries out drills in pacific the express tribune [1.0]
# in apparent suicide blast [1.0]
# dalai lama profanes buddhism by doubting his reincarnation [1.0]
# chinese president [1.0]
# regardless of [1.0]
# tycoon guo wengui [1.0]
# global war on terror [1.0]
# in any way it can [1.0]
# the proliferation treaty npt [1.0]
# power sector emissions [1.0]
# on fringes of civilisation [1.0]
# who reportedly killed four dies from injuries [1.0]
# will punish carmakers [1.0]
# constructive role [1.0]
# rcep [1.0]
# it has been restrained by not seizing more islands in south china sea [1.0]
# consumption growth will remain fast in 2016 [1.0]
# philippine fishermen [1.0]
# it easier for environmental groups to sue polluters [1.0]
# on suspicion of endangering national security [1.0]
# its new pterosaur ii drone [1.0]
# in scrubbing internet clean [1.0]
# terrorism suspects [1.0]
# state group [1.0]
# thaad missile system [1.0]
# at slowest pace [1.0]
# warns on taiwan [1.0]
# 12,000 troops 200 aircraft [1.0]
# safety of its ships [1.0]
# n.korea nuclear issue [1.0]
# will involve [1.0]
# ngo worker [1.0]
# an increasingly ugly spat with vietnam over an oil rig in the south china sea [1.0]
# it leads the world in submarine power systems [1.0]
# us summit [1.0]
# warship in south china sea [1.0]
# would not bend [1.0]
# u.s. a practical reality [1.0]
# four dies [1.0]
# cremated [1.0]
# its recent gas discovery in the politically volatile south china sea could yield 100 billion cubic meters of natural gas underlining beijing 's determination to extract resources from waters claimed by several nations [1.0]
# build back doors [1.0]
# un arbitration- calls international dispute resolution [1.0]
# fuel consumption requirements [1.0]
# face of united states [1.0]
# assessing [1.0]
# lack of palestinian state a terrible injustice [1.0]
# acres [1.0]
# within 10 years [1.0]
# chinese poultry [1.0]
# new world order [1.0]
# nukes for halt in us drills [1.0]
# none on missing plane [1.0]
# the price for thaad missile system [1.0]
# source code [1.0]
# worsening relations between beijing and taipei [1.0]
# to stop torture in the country [1.0]
# set for 2015 [1.0]
# is ignoring [1.0]
# laos [1.0]
# handling of ukraine [1.0]
# muslim uighurs have joined islamic state group [1.0]
# it could set up air defense zone in south china sea [1.0]
# a counter thaad exercise with new weapons [1.0]
# graft fight in tibet [1.0]
# its new large military transport aircraft [1.0]
# stirring up [1.0]
# could suspend [1.0]
# to escape from myanmar fighting [1.0]
# philippines ' request for un arbitration- calls international dispute resolution illegal and unreasonable [1.0]
# worsening relations [1.0]
# has apologized [1.0]
# stepped up [1.0]
# its largest foreign drone order xinhua [1.0]
# have entered [1.0]
# fire bombs [1.0]
# navy carries out drills in sea of japan [1.0]
# hiring funeral strippers [1.0]
# behind sony cyberattack [1.0]
# in submarine power systems [1.0]
# 19 march lee ming cheh [1.0]
# it will shut down its ivory trade in 2017 [1.0]
# for describing chinese president as leader of taiwan [1.0]
# should not implicate [1.0]
# south china sea defenses against us [1.0]
# top us diplomat [1.0]
# drone taken in south china sea [1.0]
# military weapons [1.0]
# willing to play constructive role over kashmir [1.0]
# sues [1.0]
# it will cut power sector emissions 60 % by 2020 [1.0]
# conventional weapons using nuclear submarines [1.0]
# that has killed three people as japan and hong kong stepped up vigilance against the virus and vietnam banned imports of chinese poultry [1.0]
# it is building its second aircraft carrier [1.0]
# amid worsening relations between beijing and taipei and an ongoing crackdown on civil society [1.0]
# had not signed [1.0]
# needs attitude [1.0]
# it is caring for about 3,000 refugees who have entered its territory to escape from myanmar fighting [1.0]
# muslims free to celebrate ramadan [1.0]
# it will ignore south china sea lawsuit decision [1.0]
# 18 suspects [1.0]
# ongoing crackdown on civil society [1.0]
# panchen lama [1.0]
# it was provoked by philippines ' request for un arbitration- calls international dispute resolution illegal and unreasonable [1.0]
# not seizing [1.0]
# in trade deals [1.0]
# 275 [1.0]
# it is planning a counter thaad exercise with new weapons as south korea confirmed the u.s. missile defense system was operational [1.0]
# agreement with asean over disputed south china sea [1.0]
# will participate [1.0]
# should be based [1.0]
# electric cars [1.0]
# ca n't solve [1.0]
# really needs [1.0]
# mack [1.0]
# bilateral ties [1.0]
# north korea and china u.s. trade [1.0]
# over kashmir [1.0]
# it will cooperate with trump [1.0]
# damage to one china ' principle would impact peace [1.0]
# it has detained a taiwanese ngo worker and human rights activist on suspicion of endangering national security amid worsening relations between beijing and taipei and an ongoing crackdown on civil society [1.0]
# he warned [1.0]
# vietnamese fishing boats [1.0]
# disputed shoal [1.0]
# despite weak data [1.0]
# environmental groups [1.0]
# defense system [1.0]
# is advanced [1.0]
# should not focus [1.0]
# such thing [1.0]
# japan and hong kong [1.0]
# ca n't end [1.0]
# draft law that requires them to turn over source code and build back doors [1.0]
# u.s. has apologized for describing chinese president as leader of taiwan [1.0]
# brain comments [1.0]
# peace prize [1.0]
# its nationals [1.0]
# in technology [1.0]
# because of the refusal of the self ruled island 's new government to recognize the one china principle [1.0]
# slowest pace [1.0]
# tiangong-1 space lab will fall to earth next year [1.0]
# john oliver [1.0]
# for mh17 attack [1.0]
# tension between the two [1.0]
# nobel laureate cremated [1.0]
# public toilets high on its to do list [1.0]
# u.s. tariffs [1.0]
# on south china sea case [1.0]
# manila stirring up trouble on disputed shoal [1.0]
# taking organs from executed inmates npr [1.0]
#
# COMMON_ACTORS
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b56b3c2916a3> in <module>()
#     106
#     107 print('COMMON_ACTORS')
# --> 108 show_actors_by_h(common_actors, decreasing=False)
#     109 print()
#
# NameError: name 'show_actors_by_h' is not defined

# %% [markdown]
# ### Conflict Topics

# %%
sorted_conflict_topics = sorted([(entity, entities[entity]['c']) for entity in entities], key=operator.itemgetter(1), reverse=True)

sorted_conflict_topics
# Out:
# [('syria/syn11910', 45),
#  ('ukraine/syn25', 23),
#  ('gaza/syn199', 17),
#  ('china/syn11901', 13),
#  ('bordering/syn1880', 13),
#  ('seas/syn98', 13),
#  ('south_china_sea/syn4186', 11),
#  ('eu/syn50', 11),
#  ('russia/syn11969', 10),
#  ('sanctions/syn311', 8),
#  ('bombings/syn330', 8),
#  ('iran/syn11989', 7),
#  ('war_crimes/syn12185', 7),
#  ('conflicts/syn84', 7),
#  ('cyber/syn30', 7),
#  ('palestinians/syn103', 7),
#  ('dispute/syn11', 7),
#  ('human_rights/syn4210', 7),
#  ('isis/syn8', 6),
#  ('islamic/syn148', 6),
#  ('crimea/syn476', 6),
#  ('killings/syn236', 6),
#  ('paris/syn52', 6),
#  ('provocation/syn27243', 6),
#  ('europe/syn12199', 5),
#  ('worsening/syn47032', 5),
#  ('refugees/syn130', 5),
#  ('bbc/syn40', 5),
#  ('lama/syn1813', 5),
#  ('damascus/syn16877', 5),
#  ('settlement/syn447', 5),
#  ('middle_east/syn4229', 5),
#  ('leaks/syn987', 5),
#  ('deploys/syn18076', 5),
#  ('israel/syn12009', 4),
#  ('jets/syn821', 4),
#  ('syrian/syn12358', 4),
#  ('kashmir/syn13200', 4),
#  ('rebels/syn13', 4),
#  ('embassy/syn76', 4),
#  ('abuses/syn196', 4),
#  ('warships/syn13533', 4),
#  ('gases/syn977', 4),
#  ('aleppo/syn12321', 4),
#  ('remarks/syn132', 4),
#  ('sovereignty/syn51394', 4),
#  ('palestine/syn19210', 4),
#  ('escalating/syn14258', 4),
#  ('sabotage/syn13792', 4),
#  ('undermining/syn59134', 4),
#  ('protesters/syn77', 3),
#  ('nato/syn17744', 3),
#  ('jerusalem/syn400', 3),
#  ('hamas/syn12784', 3),
#  ('raids/syn273', 3),
#  ('airstrikes/syn325', 3),
#  ('kurds/syn175', 3),
#  ('assad/syn15', 3),
#  ('chemical_weapons/syn13157', 3),
#  ('taliban/syn42', 3),
#  ('palestinian/syn218', 3),
#  ('convoy/syn265', 3),
#  ('eastern_ukraine/syn49567', 3),
#  ('taiwan/syn12598', 3),
#  ('hong/syn456', 3),
#  ('govt/syn397', 3),
#  ('coup/syn16', 3),
#  ('kabul/syn18954', 3),
#  ('rising_tensions/syn6267', 3),
#  ('treaty/syn1341', 3),
#  ('civilian_deaths/syn186926', 3),
#  ('cleansing/syn209', 3),
#  ('annexed/syn775', 3),
#  ('deployment/syn1457', 3),
#  ('prayers/syn1516', 3),
#  ('nazi/syn110', 3),
#  ('law_violations/syn1360745', 3),
#  ('double_standards/syn80656', 3),
#  ('hypocrisy/syn25487', 3),
#  ('rising_tensions_in_south_china_sea/syn1447504', 3),
#  ('our_enemies/syn93042', 3),
#  ('implementing/syn58290', 3),
#  ('air_defenses/syn5597', 3),
#  ('hyping_up/syn1345451', 3),
#  ('uk/syn10', 2),
#  ('india/syn12041', 2),
#  ('russian/syn12438', 2),
#  ('chemical_attack/syn4180', 2),
#  ('north_korea/syn15019', 2),
#  ('erdogan/syn17', 2),
#  ('separatists/syn976', 2),
#  ('venezuela/syn12558', 2),
#  ('jihadists/syn278', 2),
#  ('territories/syn975', 2),
#  ('afghanistan/syn14280', 2),
#  ('to_make/syn17901', 2),
#  ('probe/syn123', 2),
#  ('militants/syn28', 2),
#  ('amid/syn13089', 2),
#  ('european/syn44', 2),
#  ('yemen/syn14513', 2),
#  ('hostage/syn155', 2),
#  ('ceasefire/syn109', 2),
#  ('diplomat/syn64', 2),
#  ('abducted/syn93126', 2),
#  ('abandoning/syn12066', 2),
#  ('the_president/syn941', 2),
#  ('bookseller/syn121389', 2),
#  ('deportation/syn129', 2),
#  ('militia/syn999', 2),
#  ('debts/syn1162', 2),
#  ('fossil/syn14', 2),
#  ('proxy/syn1414', 2),
#  ('shia/syn66886', 2),
#  ('stoking/syn16869', 2),
#  ('africa/syn230', 2),
#  ('seizure/syn1486', 2),
#  ('budgets/syn1647', 2),
#  ('summit/syn171', 2),
#  ('demonstrations/syn120', 2),
#  ('referendum/syn728', 2),
#  ('islands/syn191', 2),
#  ('crossings/syn1537', 2),
#  ('east_ukraine/syn15141', 2),
#  ('arrests/syn39', 2),
#  ('kidnapped/syn18019', 2),
#  ('stampede/syn1858', 2),
#  ('assaults/syn1696', 2),
#  ('incidents/syn1704', 2),
#  ('airspace/syn223', 2),
#  ('targeted_by/syn73384', 2),
#  ('aid_convoy_in_syria/syn1448422', 2),
#  ('convoy_in_syria/syn736416', 2),
#  ('pact/syn780', 2),
#  ('washington/syn135', 2),
#  ('kurdish/syn12409', 2),
#  ('deadly_attack/syn4880', 2),
#  ('vows/syn44226', 2),
#  ('unity/syn895', 2),
#  ('peace_talks/syn4228', 2),
#  ('islamabad/syn13541', 2),
#  ('peninsula/syn54', 2),
#  ('imposes/syn18764', 2),
#  ('international_waters/syn61296', 2),
#  ('sparks/syn16980', 2),
#  ('sea_dispute/syn5276', 2),
#  ('russia_sanctions/syn4251', 2),
#  ('syrian_forces/syn149173', 2),
#  ('gulf/syn465', 2),
#  ('massacre/syn410', 2),
#  ('to_retake/syn57206', 2),
#  ('commitments/syn1958', 2),
#  ('world_news/syn4235', 2),
#  ('liu/syn1530', 2),
#  ('pilgrims/syn19336', 2),
#  ('crimean/syn34179', 2),
#  ('buddhist/syn520', 2),
#  ('south_china_sea_ruling/syn664132', 2),
#  ('sisi/syn121', 2),
#  ('bodyguards/syn306', 2),
#  ('gaza_conflict/syn5685', 2),
#  ('demolishes/syn30039', 2),
#  ('beirut/syn63156', 2),
#  ('interfering_in/syn97538', 2),
#  ('worker_rights/syn599773', 2),
#  ('isolation/syn71791', 2),
#  ('grave_situation/syn1447423', 2),
#  ("peninsula_'s_grave_situation/syn1447422", 2),
#  ('to_retake_all_of_syria/syn4652621', 2),
#  ('vow_to_retake_all_of_syria/syn4652620', 2),
#  ('double_standards_over_syria/syn1346606', 2),
#  ('cleansing_in_syria/syn8409', 2),
#  ('war_crimes_in_gaza/syn604461', 2),
#  ('1987/syn3506', 2),
#  ('drill_provocative/syn1470162', 2),
#  ('aggressive’_acts/syn1512103', 2),
#  ('video_message/syn170970', 2),
#  ('nuke_test/syn317223', 2),
#  ('lure/syn143812', 2),
#  ('alarming_provocations/syn1347165', 2),
#  ('pulling_out_of/syn432590', 2),
#  ('china_sea/syn107818', 2),
#  ('east_china_sea_dispute/syn1633012', 2),
#  ('commonwealth/syn88', 2),
#  ('state_in_syria/syn4934', 2),
#  ('plotting_against/syn1344750', 2),
#  ("violating_'s/syn586445", 2),
#  ('backing_kurdish_militia_in_syria/syn2613502', 2),
#  ('kurdish_militia_in_syria/syn533861', 2),
#  ('militia_in_syria/syn533862', 2),
#  ('chemical_weapons_use/syn100802', 2),
#  ('memorandum/syn1910', 2),
#  ('codes_for_syrian_air_defense/syn1345974', 2),
#  ('giving_israel_codes_for_syrian_air_defenses/syn1345973', 2),
#  ('spy_drone_report/syn1344625', 2),
#  ('militarization/syn66241', 2),
#  ('expanded_russia_sanctions/syn4752020', 2),
#  ('security_in_turkey/syn1447866', 2),
#  ('worsening_security_in_turkey/syn1447865', 2),
#  ('working_with/syn15977', 2),
#  ('nuclear_talks/syn4329', 1),
#  ('jordan/syn16781', 1),
#  ('tokyo/syn13287', 1),
#  ('trump/syn202', 1),
#  ('ebola/syn12314', 1),
#  ('warplanes/syn83', 1),
#  ('brexit/syn49', 1),
#  ('britain/syn12592', 1),
#  ('france/syn12543', 1),
#  ('cruise/syn15145', 1),
#  ('greece/syn12855', 1),
#  ('commander/syn167', 1),
#  ('at_least/syn30663', 1),
#  ('prosecutor/syn319', 1),
#  ('pacific/syn395', 1),
#  ('nuclear_strike/syn6941', 1),
#  ('xi/syn343', 1),
#  ('troubles/syn1551', 1),
#  ('snowden/syn378', 1),
#  ('surveillance/syn174', 1),
#  ('climate_change/syn13467', 1),
#  ('to_fight/syn14208', 1),
#  ('golan/syn38', 1),
#  ('israeli/syn15183', 1),
#  ('anniversary/syn558', 1),
#  ('saudi/syn75', 1),
#  ('afghan/syn12258', 1),
#  ('residents/syn614', 1),
#  ('killed_in/syn12927', 1),
#  ('cairo/syn18489', 1),
#  ('oil_prices/syn4462', 1),
#  ('the_country/syn14249', 1),
#  ('acrimony/syn227146', 1),
#  ('migrants/syn41', 1),
#  ('exports/syn17252', 1),
#  ('mh370/syn1258', 1),
#  ('ngo/syn22984', 1),
#  ('thursday/syn14753', 1),
#  ('plane_crash/syn4231', 1),
#  ('kiev/syn25759', 1),
#  ('ransom/syn152601', 1),
#  ('finances/syn477', 1),
#  ('west_bank/syn4205', 1),
#  ('swedish/syn13340', 1),
#  ('un_agency/syn5746', 1),
#  ('assange/syn86', 1),
#  ('iraq/syn12801', 1),
#  ('mosul/syn14253', 1),
#  ('manned/syn677', 1),
#  ('south_korea/syn13748', 1),
#  ('murders/syn1218', 1),
#  ('missing_in/syn243641', 1),
#  ('oceans/syn1077', 1),
#  ('planted/syn2160', 1),
#  ('sexes/syn2277', 1),
#  ('hong_kong_booksellers/syn5819', 1),
#  ('civil_war/syn4300', 1),
#  ('philippines/syn19', 1),
#  ('detained/syn48580', 1),
#  ('seized/syn23279', 1),
#  ('its_ships/syn117738', 1),
#  ('new_sanctions/syn62458', 1),
#  ('citizenship/syn13341', 1),
#  ('direct_contacts/syn1092277', 1),
#  ('malaysia/syn13223', 1),
#  ('japan/syn13284', 1),
#  ('declaration/syn14775', 1),
#  ('holy_site/syn4778', 1),
#  ('clashes/syn277', 1),
#  ('kurdish_fighters/syn5582', 1),
#  ('landslide/syn743', 1),
#  ('air_strikes/syn4179', 1),
#  ('stalls/syn16912', 1),
#  ('hardliners/syn89621', 1),
#  ('isil/syn91', 1),
#  ('dutch/syn3', 1),
#  ('navy/syn404', 1),
#  ('truce/syn12286', 1),
#  ('criticisms/syn3589', 1),
#  ('tillerson/syn725', 1),
#  ('stalemate/syn31', 1),
#  ('prisoners/syn81', 1),
#  ('sail/syn61553', 1),
#  ('scrambles/syn33989', 1),
#  ('intensifies/syn31443', 1),
#  ('intensified_conflicts/syn1448263', 1),
#  ('armenian/syn189', 1),
#  ('fifa/syn18631', 1),
#  ('libya/syn11883', 1),
#  ('manchester/syn26705', 1),
#  ('cia/syn446', 1),
#  ('ukrainian/syn16194', 1),
#  ('istanbul/syn13084', 1),
#  ('raqqa/syn13030', 1),
#  ('sanctions/syn16910', 1),
#  ('turkish/syn12357', 1),
#  ('bomber/syn305', 1),
#  ('smugglers/syn12795', 1),
#  ('aegean/syn1226', 1),
#  ('centres/syn613', 1),
#  ('three_soldiers/syn329770', 1),
#  ('new_report/syn61844', 1),
#  ('nsa/syn63', 1),
#  ('netherlands/syn331', 1),
#  ('expels/syn97531', 1),
#  ('reef/syn12', 1),
#  ('national_interests/syn4809', 1),
#  ('sons/syn1527', 1),
#  ('turkish_airspace/syn195383', 1),
#  ('refugees/syn488', 1),
#  ('assassination/syn972', 1),
#  ('usa/syn2326', 1),
#  ('pledge/syn17097', 1),
#  ('caucasus/syn180', 1),
#  ('sponsored/syn2015', 1),
#  ('paris_climate_agreement/syn9413', 1),
#  ('pkk/syn113', 1),
#  ('nuclear_test/syn15701', 1),
#  ('clinton/syn179', 1),
#  ('intercepted/syn117', 1),
#  ('terror_group/syn4188', 1),
#  ('taliban_militants/syn183699', 1),
#  ('extradition/syn39688', 1),
#  ('a_month/syn37676', 1),
#  ('spanish/syn20084', 1),
#  ('tourists/syn24058', 1),
#  ('beheading/syn134', 1),
#  ('peacekeepers/syn1945', 1),
#  ('reuters/syn243', 1),
#  ('eastern_province/syn4468', 1),
#  ('spying/syn61', 1),
#  ('programme/syn219', 1),
#  ('underwater_drone/syn579566', 1),
#  ('cold_war/syn4317', 1),
#  ('to_change/syn32588', 1),
#  ('to_stop/syn14142', 1),
#  ('proposal/syn736', 1),
#  ('daesh/syn13933', 1),
#  ('retaliation/syn15671', 1),
#  ('hacks/syn2361', 1),
#  ('its_citizens/syn108893', 1),
#  ('rally/syn111', 1),
#  ('cleric/syn341', 1),
#  ('breach/syn25762', 1),
#  ('terror_attack/syn4261', 1),
#  ('syrian_troops/syn84197', 1),
#  ('pyongyang/syn24605', 1),
#  ('living_in/syn16501', 1),
#  ('embassy_to_jerusalem/syn490290', 1),
#  ('beheaded/syn37893', 1),
#  ('peace_efforts/syn110003', 1),
#  ('airlines/syn13419', 1),
#  ('9_11/syn861', 1),
#  ('south_china_sea_dispute/syn6955', 1),
#  ('nuclear_threat/syn34806', 1),
#  ('24_hours/syn4421', 1),
#  ('asia/syn12203', 1),
#  ('gaza_border/syn191966', 1),
#  ('israelis/syn222', 1),
#  ('syrian_regime/syn5603', 1),
#  ('derails/syn102780', 1),
#  ('palestinian_land/syn4734', 1),
#  ('syrians/syn2251', 1),
#  ('accuses/syn27891', 1),
#  ('laden/syn93', 1),
#  ('darfur/syn77590', 1),
#  ('migrant_crisis/syn4359', 1),
#  ('vienna/syn13670', 1),
#  ('executes/syn101009', 1),
#  ('montenegro/syn11894', 1),
#  ('russian_hackers/syn112559', 1),
#  ('fatah/syn60493', 1),
#  ('barbarism/syn494199', 1),
#  ('hitler/syn12630', 1),
#  ('detention/syn186', 1),
#  ('more_sanctions/syn69253', 1),
#  ('soaring/syn24111', 1),
#  ('adding_to/syn54630', 1),
#  ('tanker/syn372', 1),
#  ('lebanon/syn13741', 1),
#  ('fomenting/syn49194', 1),
#  ('escalation/syn1534', 1),
#  ('to_start/syn58555', 1),
#  ('affairs/syn986', 1),
#  ('suburb/syn978', 1),
#  ('shameful/syn47223', 1),
#  ('election_victory/syn4645', 1),
#  ('his_family/syn16105', 1),
#  ('its_troops/syn104985', 1),
#  ('laundering/syn2431', 1),
#  ('pollution/syn48', 1),
#  ('emptive/syn263132', 1),
#  ('fresh_attack/syn214064', 1),
#  ('ukraine_conflict/syn31936', 1),
#  ('nuclear_missile/syn15673', 1),
#  ('bombardment/syn20257', 1),
#  ('jewish/syn11845', 1),
#  ('rabbi/syn286', 1),
#  ('palestinian_state/syn30473', 1),
#  ('turmoil/syn436', 1),
#  ('paris_climate_deal/syn60400', 1),
#  ('climate_deal/syn4458', 1),
#  ('undesirable/syn60954', 1),
#  ('their_president/syn28030', 1),
#  ('interfered/syn132864', 1),
#  ('defectors/syn1360', 1),
#  ('harbor/syn1372', 1),
#  ('far_right/syn5289', 1),
#  ('nazis/syn119', 1),
#  ('kaesong/syn2564', 1),
#  ('tunisia/syn13918', 1),
#  ('tehran/syn11987', 1),
#  ('supporting_terrorism/syn25827', 1),
#  ('terrorist_group/syn5088', 1),
#  ('istanbul_bombing/syn690909', 1),
#  ('nuclear_scientists/syn6729', 1),
#  ('accord/syn1324', 1),
#  ('ignites/syn79025', 1),
#  ('founder/syn727', 1),
#  ('its_interests/syn125528', 1),
#  ('shelters/syn2605', 1),
#  ('blacklist/syn2169', 1),
#  ('to_form/syn74046', 1),
#  ('maduro/syn619', 1),
#  ('halts/syn13974', 1),
#  ('meddling/syn1262', 1),
#  ('academy/syn18638', 1),
#  ('withdrawing_from/syn157630', 1),
#  ('peace_hopes/syn535235', 1),
#  ('dc/syn2553', 1),
#  ('its_people/syn34903', 1),
#  ('jazeera/syn14916', 1),
#  ('blockade/syn988', 1),
#  ('tripoli/syn31073', 1),
#  ('upi.com/syn484479', 1),
#  ('smuggling/syn29572', 1),
#  ('servicemen/syn25610', 1),
#  ('interference/syn983', 1),
#  ('pipeline/syn149', 1),
#  ('accession/syn1199', 1),
#  ('gibraltar/syn25555', 1),
#  ('mosul_civilian_deaths/syn2536029', 1),
#  ('baltic_sea/syn7001', 1),
#  ('deteriorating/syn58446', 1),
#  ('marines/syn2224', 1),
#  ('bailout/syn185', 1),
#  ('provoking/syn87308', 1),
#  ('wannacry/syn3430', 1),
#  ('crimes_against_humanity/syn36635', 1),
#  ('poisoning/syn132435', 1),
#  ('peshmerga/syn2439', 1),
#  ('napalm/syn227974', 1),
#  ('its_leaders/syn48342', 1),
#  ('killing_of/syn59460', 1),
#  ('historic/syn18695', 1),
#  ("shi'ite_pilgrims/syn185632", 1),
#  ('air_defense_zone/syn4438', 1),
#  ('descends/syn215817', 1),
#  ('evil_ways/syn2150595', 1),
#  ('to_control/syn85199', 1),
#  ('slain/syn33964', 1),
#  ('drone_experts/syn8078', 1),
#  ('sea_islands/syn184304', 1),
#  ('south_china_sea_islands/syn479556', 1),
#  ('american_forces/syn137972', 1),
#  ('anthrax/syn2494', 1),
#  ('toxic_gas/syn444984', 1),
#  ('instigating/syn282714', 1),
#  ('tiananmen/syn883', 1),
#  ('palestinian_authority/syn5586', 1),
#  ('nobel/syn15224', 1),
#  ('nobel_laureate/syn62708', 1),
#  ('laureate/syn51599', 1),
#  ('unilateral/syn16434', 1),
#  ('rights_violations/syn5793', 1),
#  ('global_conflict/syn477877', 1),
#  ('military_crackdown/syn253499', 1),
#  ('worshippers/syn149568', 1),
#  ('engagement/syn26642', 1),
#  ('regional_peace/syn171481', 1),
#  ('to_press/syn84390', 1),
#  ('devastating/syn12620', 1),
#  ('stirring_up/syn174605', 1),
#  ('harassing/syn92941', 1),
#  ('roma/syn810', 1),
#  ('as_deepens/syn30354', 1),
#  ('setback/syn17955', 1),
#  ('bail/syn268', 1),
#  ('jesuit/syn2375', 1),
#  ('defense_spending/syn89231', 1),
#  ('crematorium/syn103021', 1),
#  ('his_election/syn6051', 1),
#  ('to_demand/syn131909', 1),
#  ('valley/syn616', 1),
#  ('air_defence_zone/syn216963', 1),
#  ('syria_peace_talks/syn59074', 1),
#  ('tightens/syn26933', 1),
#  ('dictatorship/syn1549', 1),
#  ('palestinian_unity_government/syn577483', 1),
#  ('air_attacks/syn195221', 1),
#  ('sending_in/syn157225', 1),
#  ('casualties/syn671', 1),
#  ('palestinian_teen/syn4362', 1),
#  ('kunar/syn603620', 1),
#  ('manchester_suicide_bomber/syn407525', 1),
#  ('unlawful/syn43061', 1),
#  ('destructive/syn81956', 1),
#  ('collision/syn1793', 1),
#  ('syrian_kurdish_fighters/syn415076', 1),
#  ('apartheid/syn14475', 1),
#  ('paedophile/syn65', 1),
#  ('authorises/syn123732', 1),
#  ('syrian_soldiers/syn13872', 1),
#  ('footballer/syn44344', 1),
#  ('acknowledges/syn16218', 1),
#  ('incitement/syn13983', 1),
#  ('jihadi/syn320', 1),
#  ('buildup/syn2488', 1),
#  ('1989/syn144264', 1),
#  ('mentally_ill/syn14095', 1),
#  ('web_site/syn5295', 1),
#  ("gov't/syn512", 1),
#  ('wto/syn799', 1),
#  ('french_society/syn877645', 1),
#  ('killing_civilians/syn476649', 1),
#  ('natural_gas/syn24120', 1),
#  ('asia_pacific/syn5691', 1),
#  ('new_settlement/syn123820', 1),
#  ('meddling_in/syn66259', 1),
#  ('harbour/syn3252', 1),
#  ('brawl/syn27015', 1),
#  ('gaza_residents/syn116049', 1),
#  ('engaging_in/syn1123', 1),
#  ('failing_to/syn102500', 1),
#  ('2_billion/syn5111', 1),
#  ('roping/syn2526354', 1),
#  ('milking/syn1751351', 1),
#  ('emptive_strike_if_necessary/syn3353423', 1),
#  ('strike_if_necessary/syn3353424', 1),
#  ('ambiguous_stand’_on_yemen/syn2655454', 1),
#  ('ambiguous/syn1024503', 1),
#  ('heavy_price/syn56438', 1),
#  ('after_warplane_enters_turkish_airspace/syn2601652', 1),
#  ('deploying_troops_in_crimea/syn1347014', 1),
#  ('dutch_jesuit_priest/syn3324025', 1),
#  ('global_affairs/syn849643', 1),
#  ('north_caucasus_militants/syn1346436', 1),
#  ("having_had_direct_contacts_with_north_caucasus_militants_in_early_2000_'s/syn1346434",
#   1),
#  ('having_had/syn268137', 1),
#  ("early_2000_'s/syn1346438", 1),
#  ('direct_contacts_with_north_caucasus_militants/syn1346435', 1),
#  ('more_sanctions_on_pyongyang/syn2613935', 1),
#  ('imposing_more_sanctions_on_pyongyang/syn2613934', 1),
#  ('buddhist_meet_times_of_india/syn3081411', 1),
#  ('invite_to_dalai_lama_to_buddhist_meet_times_of_india/syn4749168', 1),
#  ('spark_row_with_netherlands/syn2184123', 1),
#  ('after_nazi_comments_spark_row_with_netherlands/syn2570220', 1),
#  ('spark_with_netherlands/syn2184124', 1),
#  ('buildup_in_asia/syn3469438', 1),
#  ('military_buildup_in_asia/syn3469437', 1),
#  ('opposition_of_planning_coup_for_thursday/syn1347256', 1),
#  ('brutal_gezi_park_protest_abuse/syn1343844', 1),
#  ('gezi/syn25846', 1),
#  ('alarming’_reports/syn8670', 1),
#  ('supersonic_bomber/syn1344652', 1),
#  ('deploying_supersonic_bomber/syn1344651', 1),
#  ('illegal_ivory/syn157845', 1),
#  ('south_stream_gas_pipeline/syn1209189', 1),
#  ('as_russia_abandons_plans_for_south_stream_gas_pipeline/syn1448215', 1),
#  ('plans_for_south_stream_gas_pipeline/syn1448216', 1),
#  ('reckless_mid_air_intercept_over_international_waters_near_hainan_island/syn1347153',
#   1),
#  ('intercept_over_international_waters_near_hainan_island/syn1347155', 1),
#  ('international_waters_near_hainan_island/syn1347156', 1),
#  ('hainan_island/syn1347157', 1),
#  ('reckless/syn44278', 1),
#  ('reckless_intercept_over_international_waters_near_hainan_island/syn1347154',
#   1),
#  ('fighter_of_reckless_mid_air_intercept_over_international_waters_near_hainan_island/syn1347152',
#   1),
#  ('interfering_in_bookseller_incident/syn3502590', 1),
#  ('bookseller_incident/syn3059864', 1),
#  ('maidan_2014_killings/syn1347056', 1),
#  ('maidan/syn38758', 1),
#  ('bring_tanks/syn1347027', 1),
#  ('letting_rebels_bring_in_tanks/syn1347024', 1),
#  ('rebels_bring_in_tanks/syn1347025', 1),
#  ('ukraine_rebel_vote/syn4651512', 1),
#  ('hinkley/syn2369', 1),
#  ('appointing_saudi_arabia_to_women_rights_body/syn3496470', 1),
#  ('appoints/syn82874', 1),
#  ('women_rights_body/syn3496472', 1),
#  ('air_pollution_in_uk_cities/syn1447471', 1),
#  ('trade_with_n._korea/syn2608946', 1),
#  ('nsg_south_china_sea/syn4366196', 1),
#  ('remarks_on_nsg_south_china_sea/syn4683507', 1),
#  ('south_korea_drills/syn5030742', 1),
#  ('leaking_identity_of_manchester_suicide_bomber/syn3503345', 1),
#  ('identity_of_manchester_suicide_bomber/syn3503346', 1),
#  ('interfering_in_the_affairs_of_eastern_european_countries_seeking_closer_ties_with_the_eu/syn1344273',
#   1),
#  ('the_affairs_of_eastern_european_countries_seeking_closer_ties_with_the_eu/syn1344274',
#   1),
#  ('eastern_european_countries_seeking_closer_ties_with_the_eu/syn1344276', 1),
#  ('regional_security_|_news_middle_east/syn1346663', 1),
#  ('undermining_regional_security_|_news_middle_east/syn1346662', 1),
#  ('security_|_news/syn1346664', 1),
#  ('environmental_trade_talks/syn1447969', 1),
#  ('wto_environmental_trade_talks_collapse/syn1447968', 1),
#  ('military_airbase/syn1448333', 1),
#  ('face_further_sanctions/syn3390099', 1),
#  ('to_change_tack_on_ukraine/syn4713067', 1),
#  ('tack/syn3079', 1),
#  ('to_change_tack_on_ukraine_or_face_further_sanctions/syn4713066', 1),
#  ('dangerous_alliance_between_u.s._and_russia/syn3030491', 1),
#  ('dangerous_alliance/syn3030492', 1),
#  ('provocative_‘_sandcastles’_in_south_china_sea/syn3851473', 1),
#  ('provocative/syn22282', 1),
#  ('that_allowed_priests_to_rape_children/syn1347130', 1),
#  ('rape_children/syn1347133', 1),
#  ('adopting_policies_that_allowed_priests_to_rape_children/syn1347128', 1),
#  ('policies_that_allowed_priests_to_rape_children/syn1347129', 1),
#  ('that_allows/syn23771', 1),
#  ('latest_south_china_sea_incident_|_reuters/syn1447940', 1),
#  ('latest_incident/syn92111', 1),
#  ('targeting_kin_of_murdered_palestinian_teen/syn1347184', 1),
#  ('kin/syn54538', 1),
#  ('kin_of_murdered_palestinian_teen/syn1347185', 1),
#  ("revoking_shia_cleric_'s_citizenship/syn4752676", 1),
#  ('revokes/syn115920', 1),
#  ('shia_citizenship/syn2135454', 1),
#  ("shia_cleric_'s_citizenship/syn2135453", 1),
#  ('tripoli_bombings/syn1447113', 1),
#  ('shia_worshippers/syn935857', 1),
#  ('its_currency/syn108691', 1),
#  ('to_form_government_with_hamas/syn1346031', 1),
#  ('palestinian_president/syn41849', 1),
#  ('sabotaging_peace_efforts_as_palestinian_president_moves_to_form_government_with_hamas/syn1346028',
#   1),
#  ('as_palestinian_president_moves_to_form_government_with_hamas/syn1346029',
#   1),
#  ('supporting_9_11_attacks_in_new_york_as_gulf_crisis_deepens/syn1346454', 1),
#  ('new_york/syn13178', 1),
#  ('9_11_attacks_in_new_york/syn1346455', 1),
#  ('as_gulf_crisis_deepens/syn1346456', 1),
#  ('extreme_islamism_and_daesh/syn660282', 1),
#  ('the_rise_of_extreme_islamism_and_daesh/syn1343989', 1),
#  ('rise_of_extreme_islamism_and_daesh/syn1343990', 1),
#  ('causing_the_rise_of_extreme_islamism_and_daesh/syn1343988', 1),
#  ('extreme_islamism/syn660283', 1),
#  ('eight_year_ban/syn775335', 1),
#  ('his_eight_year_fifa_ban/syn1447633', 1),
#  ('security_crises_and_turmoil_in_ukraine/syn1448257', 1),
#  ('turmoil_in_ukraine/syn1448258', 1),
#  ('security_crisis/syn510774', 1),
#  ('air_safety/syn346187', 1),
#  ('are_straining/syn1016297', 1),
#  ('its_actions_in_sea_disputes_are_straining_relations/syn2190488', 1),
#  ('actions_in_sea_disputes/syn2190491', 1),
#  ('its_actions_in_sea_disputes/syn2190490', 1),
#  ('that_killed_three_soldiers_but_america_points_finger_at_russia/syn1447888',
#   1),
#  ('three_soldiers_but_america_points_finger_at_russia/syn1447889', 1),
#  ('syria_strike_that_killed_three_soldiers_but_america_points_finger_at_russia/syn1447887',
#   1),
#  ('humanitarian_situation/syn621948', 1),
#  ("gaza_'s_humanitarian_situation/syn1447972", 1),
#  ('declaring_war/syn72368', 1),
#  ('hacking_us/syn1344329', 1),
#  ('killing_its_drone_expert_in_tunisia/syn1447998', 1),
#  ('reckless_intercept/syn1347161', 1),
#  ('military_escalation_in_gulf_row/syn1345427', 1),
#  ('military_escalation/syn40619', 1),
#  ('contested_islands/syn179507', 1),
#  ("islamic_state_'s_aleppo_advance/syn1265376", 1),
#  ("backing_islamic_state_'s_aleppo_advance/syn1265375", 1),
#  ('world_report/syn217471', 1),
#  ('violence_against_palestinians_in_annual_world_report/syn1345854', 1),
#  ('war_era/syn138190', 1),
#  ('excessive_force/syn497141', 1),
#  ('failing_to_meet/syn258513', 1),
#  ('failing_to_meet_chemical_weapons_commitments/syn3500417', 1),
#  ('burning_the_dead_bodies_in_large_crematorium_outside_damascus/syn1347236',
#   1),
#  ('dead_bodies/syn5122', 1),
#  ('crematorium_outside_damascus/syn1347239', 1),
#  ('large_crematorium_outside_damascus/syn1347238', 1),
#  ('killing_thousands_of_prisoners_and_burning_the_dead_bodies_in_large_crematorium_outside_damascus/syn1347234',
#   1),
#  ('afghan_refugee_returns/syn2548791', 1),
#  ('â\x80\x98forcedâ\x80\x99_afghan_refugee_returns/syn3494445', 1),
#  ('american_serviceman_in_iraq/syn2656462', 1),
#  ('serviceman_in_iraq/syn2656463', 1),
#  ('global_cyber_attack_that_hit_150_countries/syn1447570', 1),
#  ('150_countries/syn1198117', 1),
#  ('military_commander/syn4832', 1),
#  ("two_islamic_state_'_senior_military_commanders/syn4060168", 1),
#  ('under_schools/syn1512280', 1),
#  ('tunnel_under_schools_in_gaza/syn1512278', 1),
#  ('conducting_rocket_test/syn1346902', 1),
#  ('military_academy_outside_kabul/syn3844288', 1),
#  ('attack_on_military_academy_outside_kabul/syn3844287', 1),
#  ('academy_outside_kabul/syn3844289', 1),
#  ('as_thousands_rally_in_support_of_abdullah/syn2929179', 1),
#  ('abdullah/syn21736', 1),
#  ('hamas_of_committing_war_crimes_in_gaza/syn1345164', 1),
#  ('committing_war_crimes_in_gaza/syn1345166', 1),
#  ('spreading_ebola_and_choosing_africa_as_a_bio_weapon_testing_ground/syn1344694',
#   1),
#  ('a_bio_weapon_testing_ground/syn1344698', 1),
#  ('bio_weapon_testing_ground/syn1344699', 1),
#  ('bio/syn2664', 1),
#  ('testing_ground/syn1344700', 1),
#  ('choosing_africa_as_a_bio_weapon_testing_ground/syn1344696', 1),
#  ('gas_debts/syn1746791', 1),
#  ("ukraine_'s_gas_debts/syn1746790", 1),
#  ('proxy_wars_bbc_news/syn1343955', 1),
#  ('playing_proxy_wars_bbc_news/syn1343954', 1),
#  ('7_children/syn439369', 1),
#  ('killing_7_children_in_airstrike/syn1343793', 1),
#  ('unlawful_syria_raid_as_tillerson_visits/syn1346644', 1),
#  ('unlawful_raid/syn1346646', 1),
#  ('unlawful_syria_raid/syn1346645', 1),
#  ('after_american_forces_kill_dozens_of_syrian_soldiers/syn1347213', 1),
#  ('stunt/syn996', 1),
#  ('pulling_stunts_–_after_american_forces_kill_dozens_of_syrian_soldiers/syn1347211',
#   1),
#  ('deportations/syn1512056', 1),
#  ('deportations_to_china/syn1512055', 1),
#  ('warship_incident/syn859658', 1),
#  ('aegean_warship_incident/syn2547163', 1),
#  ('visa_deal/syn330152', 1),
#  ('migrant_pact/syn4233062', 1),
#  ('visa_deal_or_no_migrant_pact/syn4711265', 1),
#  ('promoting_terrorism/syn1344376', 1),
#  ('cyber_espionage/syn436182', 1),
#  ('to_take_out/syn128505', 1),
#  ('hiring_assassins_to_take_out_nuclear_scientists/syn1345969', 1),
#  ('to_take_out_nuclear_scientists/syn1345970', 1),
#  ('assassin/syn30026', 1),
#  ('serious_breach_of_treaty/syn1345471', 1),
#  ('serious_breach_of_treaty_over_removed_hong_kong_booksellers/syn1345470', 1),
#  ('breach_of_treaty/syn1345472', 1),
#  ('removed_hong_kong_booksellers/syn1345473', 1),
#  ('1987_missile_treaty/syn1347222', 1),
#  ('violating_1987_missile_treaty/syn1347221', 1),
#  ('sending_spies_into_eastern_ukraine_to_create_chaos/syn1347218', 1),
#  ('to_create/syn27083', 1),
#  ('sex_tourists/syn1093378', 1),
#  ('child_voodoo_victims_sex_tourists/syn3172784', 1),
#  ('voodoo/syn427923', 1),
#  ('naval_patrols/syn1168170', 1),
#  ('fresh_naval_patrols_in_south_china_sea/syn2606716', 1),
#  ('inspections/syn31611', 1),
#  ('military_action/syn59380', 1),
#  ('lying_over_bailout_talks/syn1344430', 1),
#  ('lying_over/syn449491', 1),
#  ('civilian_deaths_in_syria/syn869473', 1),
#  ('playing_with/syn626887', 1),
#  ('playing_with_fire_in_syria/syn2614242', 1),
#  ('invite_to_dalai_lama_at_rashtrapati_bhavan/syn4749293', 1),
#  ('rashtrapati_bhavan/syn4118', 1),
#  ('dalai_lama_at_rashtrapati_bhavan/syn3253076', 1),
#  ('lama_at_rashtrapati_bhavan/syn2969943', 1),
#  ('saudi_visit/syn239275', 1),
#  ('warmongering/syn60532', 1),
#  ("iranophobia_warmongering_after_trump_'s_saudi_visit/syn1345996", 1),
#  ("trump_'s_saudi_visit/syn997325", 1),
#  ('iranophobia/syn102459', 1),
#  ('evidence_in_malaysia_airlines_flight_17_crash/syn1347019', 1),
#  ('malaysia_airlines_flight_crash/syn1347021', 1),
#  ('malaysia_airlines_flight_17_crash/syn1347020', 1),
#  ('helping_destroy/syn1347018', 1),
#  ('helping_destroy_evidence_in_malaysia_airlines_flight_17_crash/syn1347017',
#   1),
#  ('western_wall/syn4297', 1),
#  ('acknowledging_western_wall_is_jewish/syn3495429', 1),
#  ('worsening_middle_east_tensions/syn1448064', 1),
#  ('middle_east_tensions/syn1448065', 1),
#  ('creating_isis_amid_worsening_middle_east_tensions/syn1448062', 1),
#  ('increase_spending/syn4712251', 1),
#  ('increase_spending_or_we_might_moderate_support/syn4712250', 1),
#  ('moderate_support/syn2230200', 1),
#  ('fiery_attack_in_damascus/syn1448322', 1),
#  ('fiery/syn299575', 1),
#  ('gaza_war_crimes/syn505084', 1),
#  ('dominance/syn36343', 1),
#  ('dominance_in_ukraine/syn1346611', 1),
#  ('attempting_total_dominance_in_ukraine/syn1346609', 1),
#  ('total_dominance_in_ukraine/syn1346610', 1),
#  ('preemptive_attack/syn1344710', 1),
#  ('flooding_gaza_border/syn1345844', 1),
#  ('crippling_regional_peace/syn2605196', 1),
#  ('crippling/syn57593', 1),
#  ('prayer_services_for_protesters/syn3478568', 1),
#  ('coal_deliveries/syn729760', 1),
#  ('reducing_coal_deliveries_as_tensions_rise/syn1347037', 1),
#  ('as_tensions_rise/syn506792', 1),
#  ('that_almost_took_britain_to_war/syn1448318', 1),
#  ('almost_took/syn1448319', 1),
#  ('gouta/syn520438', 1),
#  ('nerve_gas_attack_in_gouta_that_almost_took_britain_to_war/syn1448316', 1),
#  ('setback_in_oil_prices/syn1448433', 1),
#  ('stealing_us_navy_drone_in_international_waters/syn1344130', 1),
#  ('us_navy_drone_in_international_waters/syn1344131', 1),
#  ('shirk/syn669501', 1),
#  ('to_fight_terrorism_over_syria/syn1346618', 1),
#  ('shirking_duty_to_fight_terrorism_over_syria/syn1346617', 1),
#  ('issued_to_gaza_residents/syn1346045', 1),
#  ('abusing_permits_issued_to_gaza_residents/syn1346043', 1),
#  ('issued_to/syn185527', 1),
#  ('permits_issued_to_gaza_residents/syn1346044', 1),
#  ('hypocrisy_over_human_rights_report/syn1346621', 1),
#  ('human_rights_report/syn1346622', 1),
#  ("helping_overthrow_cairo_'s_islamist_president/syn1346796", 1),
#  ("helping_overthrow_'s/syn1346797", 1),
#  ('islamist_president/syn35868', 1),
#  ('escalating_ukraine_conflict/syn1346259', 1),
#  ('publicising/syn982649', 1),
#  ('publicising_magnitsk/syn2614286', 1),
#  ('magnitsk/syn2614287', 1),
#  ('being_granted_bail_for_assaulting_her/syn2558918', 1),
#  ('being_granted/syn79555', 1),
#  ('bail_for_assaulting_her/syn2558919', 1),
#  ('a_month_after_being_granted_bail_for_assaulting_her/syn2558917', 1),
#  ('dangerously/syn2539', 1),
#  ('dangerously_worsening_syria_war/syn1347196', 1),
#  ('dangerously_worsening_war/syn1347197', 1),
#  ('dozens_of_gaza_school_deaths/syn1448407', 1),
#  ('school_deaths/syn1448409', 1),
#  ('gaza_school_deaths/syn1448408', 1),
#  ('trying_to_dominate/syn25883', 1),
#  ('trying_to_dominate_middle_east/syn2530940', 1),
#  ('dispute_with_japan/syn121800', 1),
#  ('sending_chinese_terrorists_to_slovakia/syn3508285', 1),
#  ('chinese_terrorists/syn3186873', 1),
#  ('slovakia/syn30298', 1),
#  ('abducting_its_citizens/syn1346727', 1),
#  ('jihadism/syn94008', 1),
#  ('military_scenarios/syn499301', 1),
#  ('working_on/syn75226', 1),
#  ("working_on_military_scenarios_near_russia_'s_borders/syn1346247", 1),
#  ("russia_'s_borders/syn395419", 1),
#  ("military_scenarios_near_russia_'s_borders/syn1346248", 1),
#  ('middle_east_war/syn760371', 1),
#  ('luring_congress_toward_middle_east_war/syn1346299', 1),
#  ('deal_opponents/syn1346298', 1),
#  ('deal_opponents_of_luring_congress_toward_middle_east_war/syn1346297', 1),
#  ('new_report_on_gaza_conflict/syn1343841', 1),
#  ('torturing_killing/syn1343839', 1),
#  ('torturing_killing_palestinians_in_new_report_on_gaza_conflict/syn1343838',
#   1),
#  ('naval_drills/syn496264', 1),
#  ('war_crimes_probe_of_israel/syn4750617', 1),
#  ('probe_of_israel/syn33940', 1),
#  ('landslide_election_victory/syn2568785', 1),
#  ('profane_call/syn1448374', 1),
#  ('leaking_profane_call_ukraine/syn1448373', 1),
#  ('leaked_f*ck_the_eu_call/syn1447844', 1),
#  ('leaked_f*ck_the_eu_ukraine_call/syn1447843', 1),
#  ('f*ck/syn484498', 1),
#  ('isolationism_and_xenophobia/syn2603975', 1),
#  ('isolationism_xenophobia/syn2603976', 1),
#  ('isolationism/syn32580', 1),
#  ('xenophobia/syn14677', 1),
#  ('italian_envoy/syn35261', 1),
#  ('smuggling_weapons_to_isis/syn1346599', 1),
#  ('sending_armor/syn1346984', 1),
#  ('sending_in_tanks_armor/syn1346983', 1),
#  ('in_tanks/syn1346985', 1),
#  ('conspiring_to_topple_nicolas_maduro/syn1347264', 1),
#  ('conspiring_to_topple/syn1343123', 1),
#  ('syria_turkey_border_bombs/syn1447869', 1),
#  ('gaza_schools/syn1053059', 1),
#  ('soaring_green_dream_costs/syn4657249', 1),
#  ('dream_costs/syn3307565', 1),
#  ('hungarian_democracy/syn1345266', 1),
#  ("clinton_'s_critique_of_hungarian_democracy/syn1345264", 1),
#  ("involvement_in_top_prosecutor_'s_killing/syn1345717", 1),
#  ("top_prosecutor_'s_killing/syn1345718", 1),
#  ('south_china_sea_tensions/syn370955', 1),
#  ('proxy_war_against_india/syn524701', 1),
#  ('deadly_attacks_in_tehran/syn58810', 1),
#  ('unidentified_drone/syn202761', 1),
#  ('wanting_ethnic_cleansing_in_syria/syn1345061', 1),
#  ('providing_succour_to_its_enemies/syn1346787', 1),
#  ('succour/syn102406', 1),
#  ('gaza_bombing/syn529500', 1),
#  ('more_support/syn38759', 1),
#  ("more_support_for_syria_'s_opposition/syn2605850", 1),
#  ('syrian_territory/syn80363', 1),
#  ('air_attack_news/syn1448430', 1),
#  ('un_aid_convoy_in_syria_targeted_by_air_attack_|_world_news/syn1448426', 1),
#  ('targeted_by_air_attack_|_world_news/syn1448427', 1),
#  ('battle_for_libya_oil_ports/syn1347202', 1),
#  ('aiding_warlord_in_battle_for_libya_oil_ports/syn1347200', 1),
#  ('warlord/syn110001', 1),
#  ('oil_ports/syn92843', 1),
#  ('libya_oil_ports/syn1081135', 1),
#  ('asylum_seeker_caps/syn2936287', 1),
#  ('that_asylum_seeker_caps_are_unlawful/syn5137136', 1),
#  ('eu_deal_-letter/syn2613912', 1),
#  ('deal_-letter/syn2613913', 1),
#  ('implementing_eu_deal_-letter/syn2613911', 1),
#  ('stonewalling_in/syn1344452', 1),
#  ('stonewalling_in_syria_peace_talks/syn1344451', 1),
#  ('as_usa_holds_back_aid_to_islamabad/syn1448167', 1),
#  ('proposing_to_block_refugees/syn3506283', 1),
#  ('proposing_to_block/syn3506284', 1),
#  ('dumping/syn752', 1),
#  ('dumping_in_the_meat_sector/syn1345785', 1),
#  ('meat_sector/syn1345787', 1),
#  ('wage_dumping_in_the_meat_sector/syn1345784', 1),
#  ('people_voted_for_hitler_and_then_he_destroyed_his_people/syn2802512', 1),
#  ('shoot_drones/syn81745', 1),
#  ('military_role/syn390168', 1),
#  ('missile_defence_programme_against_north_korea/syn4246275', 1),
#  ('programme_against_north_korea/syn2621551', 1),
#  ('defence_programme_against_north_korea/syn3274378', 1),
#  ('nazi_path/syn4298565', 1),
#  ('emek/syn2266190', 1),
#  ('emek_shilo_settlement/syn3351014', 1),
#  ('shilo/syn2266193', 1),
#  ('child_torture/syn1345192', 1),
#  ('magnitsky_act/syn7731', 1),
#  ('unfriendly/syn23992', 1),
#  ('blatantly_unfriendly_magnitsky_act/syn4751776', 1),
#  ('free_basics/syn1112321', 1),
#  ('family_of_murdered_palestine_teen/syn1347190', 1),
#  ('targeting_family_of_murdered_palestine_teen/syn1347189', 1),
#  ('murdered_palestine_teen/syn1347191', 1),
#  ('murdered_teen/syn1347192', 1),
#  ('racist_attacks/syn547305', 1),
#  ('black_minister/syn5241', 1),
#  ('racist_attacks_on_black_minister/syn3475508', 1),
#  ('deafening/syn153750', 1),
#  ('deafening_silence_over_beheaded_boy/syn1345985', 1),
#  ('jordan_valley_homes/syn1512288', 1),
#  ('destruction_of_jordan_valley_homes/syn1512287', 1),
#  ('russia_sanctions_bill/syn2655911', 1),
#  ('america_first_russia_sanctions_bill/syn2655910', 1),
#  ('iran_remark/syn3497676', 1),
#  ('bombing_syrian_troops_and_risking_ceasefire/syn1346639', 1),
#  ('undermining_isis_fight/syn1346793', 1),
#  ('meddling_over_reports_of_arbitrary_new_sanctions/syn1345991', 1),
#  ('illegal_meddling_over_reports_of_arbitrary_new_sanctions/syn1345990', 1),
#  ('poverty_rate/syn787922', 1),
#  ("intervening_in_syria_'s_civil_war/syn4656016", 1),
#  ("intervening_in_'s/syn4656017", 1),
#  ('spreading_propaganda/syn1346025', 1),
#  ('adding_air_defense_systems_inside_ukraine/syn1346913', 1),
#  ('air_defense_systems/syn558152', 1),
#  ('air_defense_systems_inside_ukraine/syn1346914', 1),
#  ('mistral_deal/syn1448268', 1),
#  ('cultural_racism/syn1346765', 1),
#  ('cultural_racism_over_eu_accession_remarks/syn1346764', 1),
#  ('eu_accession_remarks/syn1346766', 1),
#  ('oil_trading/syn1346567', 1),
#  ('illegal_isis_oil_trading/syn1346565', 1),
#  ('irish_nationalism/syn1344607', 1),
#  ('to_make_brexit_difficult/syn1344608', 1),
#  ('brexit_difficult/syn1344609', 1),
#  ('stoking_irish_nationalism_to_make_brexit_difficult/syn1344606', 1),
#  ('cia_“_black_sites/syn1510790', 1),
#  ('historic_ruling_on_cia_“_black_sites/syn1510788', 1),
#  ('102-year_old_man/syn2279510', 1),
#  ('102-year_old_man_and_his_family/syn2708639', 1),
#  ('102-year/syn98404', 1),
#  ('trying_to_get_saboteurs_into_crimea/syn1346636', 1),
#  ('trying_to_get/syn823835', 1),
#  ('saboteurs/syn236170', 1),
#  ('cybersecurity_demands/syn3250292', 1),
#  ("being_europe_'s_biggest_problem_child/syn1345803", 1),
#  ("being_'s/syn1345804", 1),
#  ('problem_child/syn1183445', 1),
#  ('palestine_pledge/syn4744978', 1),
#  ('after_warship_sails_near_south_china_sea_reef/syn1511590', 1),
#  ('south_china_reef/syn158062', 1),
#  ('warship_sails/syn1511592', 1),
#  ('south_china_sea_reef/syn158061', 1),
#  ('deploying_u.s._missile_defense/syn2613688', 1),
#  ('missile_defense/syn4391', 1),
#  ('fiasco/syn83373', 1),
#  ('jihadi_arrest_fiasco/syn1447977', 1),
#  ('arrest_fiasco/syn1447978', 1),
#  ('assassination_of_slain_hamas_terrorist/syn1448025', 1),
#  ('slain_hamas_terrorist/syn1448026', 1),
#  ('tasnim/syn128315', 1),
#  ('extraordinary_rendition/syn69348', 1),
#  ('prison_torture/syn233139', 1),
#  ('failing_to_root_out_prison_torture/syn1345378', 1),
#  ('laws_to_allow_its_troops_to_fight_abroad/syn4150058', 1),
#  ('to_allow_its_troops_to_fight_abroad/syn4150059', 1),
#  ('to_allow_to_fight/syn146293', 1),
#  ('conspiring_to_oust_sisi/syn1345721', 1),
#  ('conspiring_to_oust/syn1345722', 1),
#  ('death_of_hostages_in_raid/syn1447109', 1),
#  ('hostages_in_raid/syn1447110', 1),
#  ('comparisons_to_nazis/syn1511999', 1),
#  ('comparisons/syn1512000', 1),
#  ('ukraine_gas_debt/syn1603295', 1),
#  ('south_china_sea_trouble/syn1447906', 1),
#  ('fighting_racism/syn1345771', 1),
#  ('war_front/syn1347032', 1),
#  ("leaders_'_meeting/syn1347034", 1),
#  ("opening_new_war_front_before_leaders_'_meeting/syn1347030", 1),
#  ('five_nuclear_engineers_in_syria/syn1448030', 1),
#  ('killing_of_five_nuclear_engineers_in_syria/syn1448029', 1),
#  ('nuclear_engineer/syn186396', 1),
#  ('leaking_news_from_peace_talks/syn1346054', 1),
#  ("insulting_founder_'s_birthday/syn3502557", 1),
#  ("insulting_'s/syn488334", 1),
#  ('one_sided_syria_action/syn2610935', 1),
#  ('sided_action/syn2610937', 1),
#  ('calling_for_demonstrations_in_vienna/syn1345423', 1),
#  ...]

# %% [markdown]
# ### Conflict graph

# %%
topic = 'syria/syn11910'
conflict_pairs = entities[topic]['conflict_actors']
cactors = set()
for pair in conflict_pairs:
    cactors.add(syn_label(pair[0]))
    cactors.add(syn_label(pair[1]))

G = nx.DiGraph()
for actor in cactors:
    G.add_node(actor)
for edge in conflict_pairs:
    G.add_edge(syn_label(edge[0]), syn_label(edge[1]))
    
nx.write_gml(G, '%s.gml' % syn_label(topic))

# %% [markdown]
# ### Factions

# %%
class Factions:
    def __init__(self, topic):
        self.topic = topic
        self.edges = {}
        self.degrees = {}
        self.main_conflict = None
        self.actors = set()
        self.factions = (set(), set(), set())
        
    def attacks_faction(self, actor, faction):
        for actor2 in self.factions[faction]:
            edge = tuple(sorted((actor, actor2)))
            if edge in self.edges:
                return True
        return False

    def assign_faction(self, actor):
        if actor in self.actors:
            return
        self.actors.add(actor)
        if self.attacks_faction(actor, 0) and not self.attacks_faction(actor, 1):
            self.factions[1].add(actor)
        elif self.attacks_faction(actor, 1) and not self.attacks_faction(actor, 0):
            self.factions[0].add(actor)
        else:
            self.factions[2].add(actor)

    def process(self):
        conflict_pairs = entities[self.topic]['conflict_actors']

        for pair in conflict_pairs:
            edge = tuple(sorted(pair))
            if edge not in self.edges:
                self.edges[edge] = 0
            actor1, actor2 = edge
            if actor1 not in self.degrees:
                self.degrees[actor1] = 0
            self.degrees[actor1] += 1
            if actor2 not in self.degrees:
                self.degrees[actor2] = 0
            self.degrees[actor2] += 1
    
        for edge in self.edges:
            self.edges[edge] = min([self.degrees[actor] for actor in edge])

        sorted_edges = sorted([(edge[0], edge[1], self.edges[edge]) for edge in self.edges], key=operator.itemgetter(2), reverse=True)

        self.main_conflict = sorted_edges[0]
        self.actors.add(self.main_conflict[0])
        self.actors.add(self.main_conflict[1])
        self.factions[0].add(self.main_conflict[0])
        self.factions[1].add(self.main_conflict[1])

        for edge in sorted_edges[1:]:
            self.assign_faction(edge[0])
            self.assign_faction(edge[1])
            
    def get_faction(self, actor):
        if actor in self.factions[0]:
            return -1
        elif actor in self.factions[1]:
            return 1
        else:
            return 0
        
f = Factions('syria/syn11910')
f.process()
print(f.main_conflict)

print('FACTION A')
for actor in f.factions[0]:
    print(syn_label(actor))
print('FACTION B')
for actor in f.factions[1]:
    print(syn_label(actor))
print('UNDECIDED')
for actor in f.factions[2]:
    print(syn_label(actor))
# Out:
# ('russia/syn11969', 'u.s./syn26', 24)
# FACTION A
# russia
# iran
# hezbollah
# moscow
# saudi
# china
# putin
# damascus
# FACTION B
# germany
# turkish pm
# obama
# israel
# united states
# syria opposition
# benjamin
# france
# us
# turkey pm
# UNDECIDED
# saudi king
# assad
# john
# ankara
# un
# turkey

# %% [markdown]
# ### Generate topics data

# %%
json_data = {}

for topic, c in sorted_conflict_topics:
    if c > 1:
        f = Factions(topic)
        f.process()
    
        cactors = {}
        for actor in f.actors:
            cactor = {'faction': f.get_faction(actor), 'outdeg': 0, 'indeg': 0}
            lactor = syn_label(actor)
            cactors[lactor] = cactor
        
        for pair in entities[topic]['conflict_actors']:
            orig = syn_label(pair[0])
            targ = syn_label(pair[1])
            cactors[orig]['outdeg'] += 1
            cactors[targ]['indeg'] += 1
    
        main_conflict = [syn_label(f.main_conflict[0]), syn_label(f.main_conflict[1])]
    
        ltopic = syn_label(topic)
        json_data[ltopic] = {'conflictuality': c, 'actors': cactors, 'main_conflict': main_conflict}
        
with open('conflict_topics.json', 'wt') as out:
    res = j.dump(json_data, out, sort_keys=False, indent=4, separators=(',', ': '))

# %%
str2edge('(is/gb * * ...)')
# Out:
# ('is/gb', '*', '*', '...')
