# %% [markdown]
# # News Analysis

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import operator
import math
import progressbar
import json as j
from unidecode import unidecode
import networkx as nx
from gb.notebook import *
import gb.synonyms.synonyms as syn
import gb.nlp.parser as par
from gb.metrics.hyper_similarity import HyperSimilarity

# %% [markdown]
# ### HyperGraph, etc.

# %%
MAX_PROB = -12
hg = init_hypergraph('../reddit-worldnews-01012013-01082017-new-inference3.hg')
hs = HyperSimilarity(hg)
parser = par.Parser()

# %% [markdown]
# ### NLP funs

# %%
def is_compound_propn(edge):
    if len(edge) < 3:
        return False
    if edge[0] != '+/gb':
        return False
    for item in edge[1:]:
        if is_symbol(item):
            if symbol_namespace(item)[-5:] != 'propn':
                return False
        elif not is_compound_propn(item):
            return False
    return True

def is_adj(edge):
    if is_edge(edge):
        return False
    return symbol_namespace(edge)[-3:] == 'adj'

def is_adp(edge):
    return is_symbol(edge) and symbol_namespace(edge)[-3:] == 'adp'

def is_noun(edge):
    if is_edge(edge):
        return False
    return symbol_namespace(edge)[-5:] == 'propn' or symbol_namespace(edge)[-4:] == 'noun'

def has_noun(edge):
    if is_edge(edge):
        for item in edge:
            if has_noun(item):
                return True
    else:
        return is_noun(edge)
    return False

def is_adjective_and_noun(edge):
    if len(edge) != 3:
        return False
    if edge[0] != '+/gb':
        return False
    if not is_adj(edge[1]):
        return False
    if not is_noun(edge[2]):
        return False
    return True

def is_cconj(edge):
    if is_edge(edge):
        return False
    return symbol_namespace(edge)[-5:] == 'cconj'

# %% [markdown]
# ### Synonym funs

# %%
def syn_id(root):
    symbs = hg.symbols_with_root(root)
    for symb in symbs:
        if symbol_namespace(symb)[:3] == 'syn':
            return symb
    return None
        
def syn_label(syn_id):
    symbs = syn.synonyms(hg, syn_id)
    labels = []
    for symb in symbs:
        labels.append(hg.get_label(symb))
    best = None
    for label in labels:
        if best is None or len(label) < len(best):
            best = label
    parts = best.split('|')
    if len(parts) > 1:
        max_size = 0
        for part in parts:
            if len(part) > max_size:
                best = part.strip()
                max_size = len(best)
        
    return unidecode(best)

# %% [markdown]
# ### Topic funs

# %%
def is_topic(symbol):
    if is_symbol(symbol) and symbol_namespace(symbol)[:3] == 'syn':
        root = symbol_root(symbol)
        return root[0].isalnum() and root[-1].isalnum()
    return False

def subtopics(edge):
    stopics = set()
    if is_edge(edge):
        for item in edge:
            topic = syn.main_synonym(hg, item)
            if is_topic(topic):
                stopics.add(item)
    return stopics

def choose_topic1(edge):
    topic = syn.main_synonym(hg, edge)
    if is_edge(edge):
        if is_compound_propn(edge) or is_adjective_and_noun(edge):
            return topic
        stopics = subtopics(edge)
        if len(stopics) == 1:
            return choose_topic1(next(iter(stopics)))    
    return topic

def choose_topic(edge):
    if is_edge(edge) and edge[0] == '+/gb' and is_adp(edge[1]):
        if len(edge) == 3:
            return choose_topic(edge[2])
        elif len(edge) > 3:
            return choose_topic1(edge)
    return syn.main_synonym(hg, edge)

def common_word(edge):
    syns = syn.synonyms(hg, edge)
    for s in syns:
        label = symbol2str(s)
        if ' ' in label:
            return False
        word = parser.make_word(label)
        if word.prob < MAX_PROB:
            return False
    return True

def atomic_topic(edge):
    atopic = syn.main_synonym(hg, edge)
    if is_topic(atopic) and not common_word(atopic):
        return {atopic}
    return set()

def atomic_topics(edge):
    atopics = atomic_topic(edge)
    if is_edge(edge):
        if len(edge) == 3 and edge[0] == '+/gb' and is_adp(edge[1]):
            return atomic_topics(edge[2])
        elif is_compound_propn(edge) or is_adjective_and_noun(edge):
            return atopics
        else:
            subtopics = set()
            for item in edge:
                subtopics |= atomic_topics(item)
            if len(subtopics) == 1:
                atopics = subtopics
            else:
                atopics |= subtopics
    return atopics

def atomic_topics_old(edge):
    atopics = atomic_topic(edge)
    if is_edge(edge):
        if is_compound_propn(edge) or is_adjective_and_noun(edge):
            return atopics
        for item in edge:
            atopics |= atomic_topics(item)
        # if len(atopics) > 0:
        #     return atopics
        # else:
        #     return atomic_topic(edge)
    return atopics

def atomic_topics2(edge):
    atopics = atomic_topic(edge)
    if is_edge(edge):
        if len(edge) == 3 and edge[0] == '+/gb' and is_adp(edge[1]):
            return atomic_topics2(edge[2])
            
        subtopics = set()
        for item in edge:
            subtopics |= atomic_topics2(item)
        if len(subtopics) == 1:
            atopics = subtopics
        else:
            atopics |= subtopics
    return atopics

# %% [markdown]
# ### Entities, Actors and Conflicts

# %%
entities = {}
actors = {}
conflicts = {}
topic_actor = {}


def edge2actors(edge, check_actors=True):
    if is_edge(edge) and edge[0] == '+/gb':
        if is_adp(edge[1]) and len(edge) == 3:
            return edge2actors(edge[2])
        elif is_cconj(edge[1]) and len(edge) > 2:
            result = set()
            for item in edge[2:]:
                result |= edge2actors(item)
            return result
    if has_noun(edge):
        synact = syn.main_synonym(hg, edge, in_adp=True)
        if check_actors:
            if synact in actors and actors[synact] > 2:
                return {synact}
        else:
            return {synact}
    return set()


def add_to_table(table, item):
    if item not in table:
        table[item] = 0
    table[item] += 1


def add_entity(entity):
    if entity not in entities:
        entities[entity] = {'mentions': {},
                            'mentioned_by': {},
                            'conflict_towards': {},
                            'conflict_from': {},
                            'conflict_actors': []}

        
def add_mention(actor, concept):
    add_entity(actor)
    add_entity(concept)
    add_to_table(entities[actor]['mentions'], concept)
    add_to_table(entities[concept]['mentioned_by'], actor)
    

def add_conflict(orig, targ, concept):
    add_entity(orig)
    add_entity(targ)
    add_entity(concept)
    add_to_table(entities[orig]['conflict_towards'], targ)
    add_to_table(entities[targ]['conflict_from'], orig)
    entities[concept]['conflict_actors'].append((orig, targ))
   

def add_conflict_tuple(orig, targ, concept, source):
    if orig not in conflicts:
        conflicts[orig] = []
    if targ not in conflicts:
        conflicts[targ] = []
    conflict_tuple = (orig, targ, concept, source)
    conflicts[orig].append(conflict_tuple)
    conflicts[targ].append(conflict_tuple)

mention_edges = hg.pattern2edges(('mention/gb.inf', None, None))
conflict_edges = hg.pattern2edges(('conflict/gb.inf', None, None, None))
nclaims = len(mention_edges)
nconflicts = len(conflict_edges)
N = (nclaims + nconflicts) * 2

i = 0
with progressbar.ProgressBar(max_value=N) as bar:
    # find actors
    for edge in hg.pattern2edges(('mention/gb.inf', None, None)):
        origs = edge2actors(edge[1], check_actors=False)
        for orig in origs:
            if orig not in actors:
                actors[orig] = 0
            actors[orig] += 1
        i += 1
        bar.update(i)
        
    for edge in hg.pattern2edges(('conflict/gb.inf', None, None, None)):
        origs = edge2actors(edge[1], check_actors=False)
        for orig in origs:
            if orig not in actors:
                actors[orig] = 0
            actors[orig] += 1
        i += 1
        bar.update(i)


    # conflicts and mentions
    for edge in hg.pattern2edges(('mention/gb.inf', None, None)):
        origs = edge2actors(edge[1])
        topics = atomic_topics2(edge[2])
        for orig in origs:
            for topic in topics:
                add_mention(orig, topic)
                if topic not in topic_actor:
                    topic_actor[topic] = {}
                if orig not in topic_actor[topic]:
                    topic_actor[topic][orig] = {'related-topics': set(), 'edges': []}
                topic_actor[topic][orig]['related-topics'] |= topics - {topic}
                topic_actor[topic][orig]['edges'].append(edge[2])
        i += 1
        bar.update(i)
        
    for edge in hg.pattern2edges(('conflict/gb.inf', None, None, None)):
        origs = edge2actors(edge[1])
        targs = edge2actors(edge[2])
        topics = atomic_topics(edge[3])
        detailed_topic = choose_topic(edge[3])
        source = hg.pattern2edges(('source/gb.inf', edge, None)).pop()[2]
        for orig in origs:
            for targ in targs:
                add_conflict_tuple(orig, targ, detailed_topic, source)
                for topic in topics:
                    add_conflict(orig, targ, topic)
        i += 1
        bar.update(i)

print('claims: %s' % nclaims)
print('conflicts: %s' % nconflicts)
# Out:
# 100% (31474 of 31474) |##################| Elapsed Time: 0:01:56 Time:  0:01:56
# claims: 13100
# conflicts: 2637

# %% [markdown]
# ### Metrics

# %%
def compute_metrics(entity):
    mentioned_by = entities[entity]['mentioned_by']
    weights = [mentioned_by[item] for item in mentioned_by]
    total = sum(weights)
    h = 0.
    if total > 0:
        h_weights = [float(i) / float(total) for i in weights]
        h_weights = [i * i for i in h_weights]
        h = 1. / sum(h_weights)
    entities[entity]['h'] = h
    entities[entity]['total'] = total
    entities[entity]['degree'] = syn.synonyms_degree(hg, entity)
    
def metrics(concept):
    return {'h': entities[concept]['h'],
            'total': entities[concept]['total'],
            'degree': entities[concept]['degree']}

i = 0
with progressbar.ProgressBar(max_value=len(entities)) as bar:
    for entity in entities:
        compute_metrics(entity)
        i += 1
        bar.update(i)
# Out:
# 100% (38612 of 38612) |##################| Elapsed Time: 0:00:36 Time:  0:00:36

# %% [markdown]
# ### One Actor

# %%
# actor = syn_id('france')
actor = 'germany/syn12662'

lactor = hg.get_label(actor)
json_data = {}

for conflict_tuple in conflicts[actor]:
    other = conflict_tuple[0]
    direction = 'from'
    if other == actor:
        other = conflict_tuple[1]
        direction = 'to'
    topic = conflict_tuple[2]
    lother = hg.get_label(other)
    ltopic = syn_label(topic)
    if lother not in json_data:
        json_data[lother] = {}
    if ltopic not in json_data[lother]:
        json_data[lother][ltopic] = metrics(other)
        json_data[lother][ltopic]['from'] = 0
        json_data[lother][ltopic]['to'] = 0
    json_data[lother][ltopic][direction] += 1
    json_data[lother][ltopic]['source'] = conflict_tuple[3]

topics = {} 

for targ in json_data:
    concepts = set(json_data[targ].keys())
    for concept in concepts:
        if concept not in topics:
            topics[concept] = 0
        topics[concept] += 1
        
for targ in json_data:
    for concept in json_data[targ]:
        json_data[targ][concept]['local_degree'] = topics[concept]
        
with open('%s.json' % lactor, 'wt') as out:
    res = j.dump(json_data, out, sort_keys=False, indent=4, separators=(',', ': '))
    
json_data
# Out:
# {'turkeys': {'working against erdogan': {'h': 14.91167574107688,
#    'total': 157,
#    'degree': 3268,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'turkey/nlp.turkey.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('working_against/nlp.work.verb+nlp.against.adp',
#       'erdogan/nlp.erdogan.propn'))),
#    'local_degree': 1},
#   'backing failed coup': {'h': 14.91167574107688,
#    'total': 157,
#    'degree': 3268,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'turkey/nlp.turkey.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('backing_failed/nlp.back.verb+nlp.fail.verb', 'coup/nlp.coup.noun'))),
#    'local_degree': 1},
#   'cultural racism over eu accession remarks': {'h': 14.91167574107688,
#    'total': 157,
#    'degree': 3268,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'turkey/nlp.turkey.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'over/nlp.over.adp',
#       ('+/gb', 'cultural/nlp.cultural.adj', 'racism/nlp.racism.noun'),
#       ('+/gb',
#        'eu/nlp.eu.propn',
#        'accession/nlp.accession.noun',
#        'remarks/nlp.remark.noun')))),
#    'local_degree': 1},
#   'providing succour to its enemies': {'h': 14.91167574107688,
#    'total': 157,
#    'degree': 3268,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'turkey/nlp.turkey.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('providing/nlp.provide.verb',
#       'succour/nlp.succour.noun',
#       ('+/gb',
#        'to/nlp.to.adp',
#        ('+/gb', 'its/nlp.-pron-.adj', 'enemies/nlp.enemy.noun'))))),
#    'local_degree': 1},
#   "engaging in ' diplomatic rudeness' and ' double standards'": {'h': 14.91167574107688,
#    'total': 157,
#    'degree': 3268,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'turkey/nlp.turkey.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('engaging_in/nlp.engage.verb+nlp.in.adp',
#       ('+/gb',
#        '‘/nlp.‘.det',
#        ('+/gb', 'double/nlp.double.adj', 'standards’/nlp.standards’.noun'),
#        ('+/gb',
#         'and/nlp.and.cconj',
#         ('+/gb',
#          'diplomatic/nlp.diplomatic.adj',
#          'rudeness’/nlp.rudeness’.noun'),
#         '‘/nlp.‘.num'))))),
#    'local_degree': 1},
#   'over nazi jibes amid referendum row bbc news': {'h': 14.91167574107688,
#    'total': 157,
#    'degree': 3268,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'germany/nlp.germany.propn',
#     'turkey/nlp.turkey.propn',
#     ('+/gb',
#      ('+/gb', 'over/nlp.over.adp', 'nazi/nlp.nazi.propn'),
#      ('jibes_amid/nlp.jib.verb+nlp.amid.adp',
#       ('+/gb',
#        'referendum/nlp.referendum.noun',
#        ('+/gb',
#         'row/nlp.row.noun',
#         'news/nlp.news.propn',
#         'bbc/nlp.bbc.propn'))))),
#    'local_degree': 1},
#   'harbouring terrorists': {'h': 14.91167574107688,
#    'total': 157,
#    'degree': 3268,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'turkey/nlp.turkey.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('harbouring/nlp.harbour.verb', 'terrorists/nlp.terrorist.noun'))),
#    'local_degree': 1},
#   'providing succor to its enemies': {'h': 14.91167574107688,
#    'total': 157,
#    'degree': 3268,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'turkey/nlp.turkey.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('providing/nlp.provide.verb',
#       'succor/nlp.succor.noun',
#       ('+/gb',
#        'to/nlp.to.adp',
#        ('+/gb', 'its/nlp.-pron-.adj', 'enemies/nlp.enemy.noun'))))),
#    'local_degree': 1}},
#  'iea': {'soaring green dream costs': {'h': 0.0,
#    'total': 0,
#    'degree': 35,
#    'from': 1,
#    'to': 0,
#    'source': ('warns/nlp.warn.verb',
#     'iea/nlp.iea.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'on/nlp.on.adp',
#      ('soaring/nlp.soar.verb',
#       ('+/gb',
#        'green/nlp.green.adj',
#        ('+/gb', 'dream/nlp.dream.noun', 'costs/nlp.cost.noun'))))),
#    'local_degree': 1}},
#  'uk': {'eu migrants': {'h': 32.81818181818186,
#    'total': 76,
#    'degree': 1883,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'germany/nlp.germany.propn',
#     'uk/nlp.uk.propn',
#     ('+/gb',
#      'on/nlp.on.adp',
#      ('+/gb',
#       'for/nlp.for.adp',
#       'rules/nlp.rule.noun',
#       ('+/gb', 'eu/nlp.eu.propn', 'migrants/nlp.migrant.noun')))),
#    'local_degree': 1},
#   'leave eu': {'h': 32.81818181818186,
#    'total': 76,
#    'degree': 1883,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'germany/nlp.germany.propn',
#     'uk/nlp.uk.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('leaving/nlp.leave.verb', 'eu/nlp.eu.propn'))),
#    'local_degree': 1}},
#  'italy': {'undermining its economic efforts': {'h': 12.249999999999998,
#    'total': 14,
#    'degree': 716,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'italy/nlp.italy.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('undermining/nlp.undermine.verb',
#       ('+/gb',
#        'its/nlp.-pron-.adj',
#        ('+/gb',
#         'economic/nlp.economic.propn',
#         'efforts/nlp.efforts.propn'))))),
#    'local_degree': 1}},
#  'u.s.': {'expanded russia sanctions': {'h': 0.0,
#    'total': 0,
#    'degree': 7960,
#    'from': 0,
#    'to': 1,
#    'source': ('warn/nlp.warn.verb',
#     ('+/gb',
#      'and/nlp.and.cconj',
#      'germany/nlp.germany.propn',
#      'austria/nlp.austria.propn'),
#     'us/nlp.us.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('expanded/nlp.expand.verb',
#       ('+/gb', 'russia/nlp.russia.propn', 'sanctions/nlp.sanction.noun')))),
#    'local_degree': 1}},
#  'farage': {'air pollution in uk cities': {'h': 0.0,
#    'total': 0,
#    'degree': 102,
#    'from': 1,
#    'to': 0,
#    'source': ('blames/nlp.blame.verb',
#     ('+/gb', 'nigel/nlp.nigel.propn', 'farage/nlp.farage.propn'),
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('+/gb',
#       'in/nlp.in.adp',
#       ('+/gb', 'air/nlp.air.noun', 'pollution/nlp.pollution.noun'),
#       ('+/gb', 'uk/nlp.uk.propn', 'cities/nlp.city.noun')))),
#    'local_degree': 1}},
#  'france': {'wage dumping in the meat sector': {'h': 22.533333333333317,
#    'total': 52,
#    'degree': 2146,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'france/nlp.france.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'wage/nlp.wage.noun',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'dumping/nlp.dumping.noun',
#        ('+/gb',
#         'the/nlp.the.det',
#         ('+/gb', 'meat/nlp.meat.noun', 'sector/nlp.sector.noun')))))),
#    'local_degree': 1},
#   "being europe 's biggest problem child": {'h': 22.533333333333317,
#    'total': 52,
#    'degree': 2146,
#    'from': 0,
#    'to': 1,
#    'source': ('accuses/nlp.accuse.verb',
#     'germany/nlp.germany.propn',
#     'france/nlp.france.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ("being_'s/nlp.be.verb+nlp.'s.part",
#       ('+/gb',
#        'biggest/nlp.big.adj',
#        ('+/gb', 'problem/nlp.problem.noun', 'child/nlp.child.noun')),
#       'europe/nlp.europe.propn'))),
#    'local_degree': 1}},
#  'moscow': {"hushing up russian girl 's rape": {'h': 14.400000000000002,
#    'total': 24,
#    'degree': 530,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'moscow/nlp.moscow.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('hushing_up/nlp.hush.verb+nlp.up.part',
#       ('+/gb',
#        'russian/nlp.russian.adj',
#        ("'s/nlp.'s.part", 'girl/nlp.girl.noun'),
#        'rape/nlp.rape.noun')))),
#    'local_degree': 1}},
#  'u.n.': {"' institutional racism and racist stereotyping' against people of african descent": {'h': 0.0,
#    'total': 0,
#    'degree': 2873,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'un/nlp.un.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'and/nlp.and.cconj',
#       ('+/gb',
#        '‘/nlp.‘.det',
#        ('+/gb',
#         'institutional/nlp.institutional.adj',
#         'racism/nlp.racism.noun')),
#       ('+/gb',
#        'racist/nlp.racist.noun',
#        'stereotyping’/nlp.stereotyping’.adj',
#        ('+/gb',
#         'against/nlp.against.adp',
#         ('+/gb',
#          'of/nlp.of.adp',
#          'people/nlp.people.noun',
#          ('+/gb', 'african/nlp.african.adj', 'descent/nlp.descent.noun'))))))),
#    'local_degree': 1}},
#  'russia': {'halting arms deal': {'h': 20.268522744560986,
#    'total': 365,
#    'degree': 7510,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     'russia/nlp.russia.propn',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'for/nlp.for.adp',
#      ('halting/nlp.halt.verb',
#       ('+/gb', 'arms/nlp.arm.noun', 'deal/nlp.deal.noun')))),
#    'local_degree': 1},
#   'military engagement in syria': {'h': 20.268522744560986,
#    'total': 365,
#    'degree': 7510,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'germany/nlp.germany.propn',
#     'russia/nlp.russia.propn',
#     ('+/gb',
#      'against/nlp.against.adp',
#      ('+/gb',
#       'military/nlp.military.adj',
#       ('+/gb',
#        'in/nlp.in.adp',
#        'engagement/nlp.engagement.noun',
#        'syria/nlp.syria.propn')))),
#    'local_degree': 1}},
#  'turkish president': {'exclusive interview with france 24': {'h': 0.0,
#    'total': 0,
#    'degree': 98,
#    'from': 1,
#    'to': 0,
#    'source': ('slams/nlp.slam.verb',
#     ('+/gb', 'turkish/nlp.turkish.adj', 'president/nlp.president.propn'),
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'in/nlp.in.adp',
#      ('+/gb',
#       'exclusive/nlp.exclusive.adj',
#       'interview/nlp.interview.noun',
#       ('+/gb',
#        'with/nlp.with.adp',
#        ('+/gb', 'france/nlp.france.propn', '24/nlp.24.num'))))),
#    'local_degree': 1}},
#  'turkish minister': {'humanity': {'h': 0.0,
#    'total': 0,
#    'degree': 34,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     ('+/gb', 'turkish/nlp.turkish.adj', 'minister/nlp.minister.noun'),
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      'others/nlp.other.noun',
#      ('+/gb',
#       'against/nlp.against.adp',
#       'crimes/nlp.crime.noun',
#       'humanity/nlp.humanity.noun'))),
#    'local_degree': 1}},
#  'greece': {'debt commitments': {'h': 10.756097560975611,
#    'total': 21,
#    'degree': 866,
#    'from': 0,
#    'to': 1,
#    'source': ('warns/nlp.warn.verb',
#     'germany/nlp.germany.propn',
#     'greece/nlp.greece.propn',
#     ('+/gb',
#      'over/nlp.over.adp',
#      ('+/gb', 'debt/nlp.debt.noun', 'commitments/nlp.commitment.noun'))),
#    'local_degree': 1}},
#  'erdogan': {'nazi practices over blocked political rallies': {'h': 9.307692307692307,
#    'total': 11,
#    'degree': 989,
#    'from': 1,
#    'to': 0,
#    'source': ('accuses/nlp.accuse.verb',
#     'erdog\x9fan/nlp.erdog\x9fan.noun',
#     'germany/nlp.germany.propn',
#     ('+/gb',
#      'of/nlp.of.adp',
#      ('+/gb',
#       'over/nlp.over.adp',
#       ('+/gb', 'nazi/nlp.nazi.propn', 'practices/nlp.practice.noun'),
#       ('blocked/nlp.block.verb',
#        ('+/gb', 'political/nlp.political.adj', 'rallies/nlp.rally.noun'))))),
#    'local_degree': 1}}}

# %% [markdown]
# ## Two Actors

# %%
def mentions_intersection(actors):
    intersection = None
    for actor in actors:
        concepts = set(entities[actor]['mentions'].keys())
        if intersection is None:
            intersection = concepts
        else:
            intersection &= concepts
    return intersection

def show_by_h(concepts, decreasing=True):
    concepts_h = {}
    for concept in concepts:
        concepts_h[concept] = entities[concept]['h']

    sorted_h = sorted(concepts_h.items(), key=operator.itemgetter(1), reverse=decreasing)

    for concept, h in sorted_h:
        print('%s [%s]' % (syn_label(concept), h))

def metrics_and_commons(concept, actor1, actor2):
    m = metrics(concept)
    atoms1 = topic_actor[concept][actor1]['related-topics']
    atoms2 = topic_actor[concept][actor2]['related-topics']
    common_related_atoms = tuple(atoms1 & atoms2)
    m['common_related_atoms'] = [syn_label(atom) for atom in common_related_atoms]
    m['common_related_atoms_count'] = len(m['common_related_atoms'])
    topics1 = topic_actor[concept][actor1]['edges']
    topics2 = topic_actor[concept][actor2]['edges']
    m['topics'] = [[choose_topic(syn_label(topic)) for topic in topics1],
                   [choose_topic(syn_label(topic)) for topic in topics2]]
    return m


actor1 = syn_id('russia')
actor2 = syn_id('u.s.')

actor1_name = hg.get_label(actor1)
actor2_name = hg.get_label(actor2)

inter = mentions_intersection([actor1, actor2])

data = {'actors': [actor1_name, actor2_name],
        'common_concepts': {}}

for concept in inter:
    data['common_concepts'][syn_label(concept)] = metrics_and_commons(concept, actor1, actor2)

file_name = '%s-%s.json' % (actor1_name, actor2_name)
with open(file_name, 'wt') as out:
    res = j.dump(data, out, sort_keys=False, indent=4, separators=(',', ': '))

data
# Out:
# {'actors': ['russia', 'u.s.'],
#  'common_concepts': {'iran': {'h': 28.234856535600493,
#    'total': 163,
#    'degree': 4042,
#    'common_related_atoms': ['syria', 'resolution'],
#    'common_related_atoms_count': 2,
#    'topics': [['nov. 24 deadline may not be met in iran talks interfax',
#      'it is drafting roadmap to resolve syria conflict with turkey iran',
#      'iran missile test does not contravene un resolution'],
#     ["it 's not deterring foreign banks in iran",
#      'recognition of israel not part of iran nuke deal',
#      '$ 400 million to iran used as leverage for prisoners',
#      'iran sent arms to iraq to fight isis',
#      'iran complies with nuke deal but orders review on lifting sanctions',
#      'it is considering response to iran ballistic missile test',
#      "iran 's nuclear reactor plans deeply troubling",
#      'iran has ceased controversial nuclear practice',
#      'iran rocket test breaches u.n. resolution',
#      'north korea can learn from iran nuclear deal',
#      "iran wo n't attend peace talks on syria",
#      'we may strike iraq jihadists ally with foe iran']]},
#   'to share': {'h': 1.7999999999999998,
#    'total': 3,
#    'degree': 20,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['assad ready to share power with opposition',
#      "syria 's assad is ready to share power with opposition"],
#     ['ready to share burden of asian sea migrants from myanmmar']]},
#   'aid': {'h': 28.76036866359447,
#    'total': 79,
#    'degree': 124,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['new tragedies possible if u.s. supplies lethal aid to ukraine'],
#     ['it will not provide food aid to north korea during its worst drought in 100 years',
#      'aid package to philippines withheld over rights concerns',
#      'france spain aided nsa spying']]},
#   'france': {'h': 22.533333333333317,
#    'total': 52,
#    'degree': 2146,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['france must fulfil mistral contract or return money agency',
#      "it 's planning joint isis operations with france"],
#     ['france spain aided nsa spying', 'france spain aided nsa spying']]},
#   'president': {'h': 43.84132841328416,
#    'total': 109,
#    'degree': 1241,
#    'common_related_atoms': ['russian'],
#    'common_related_atoms_count': 1,
#    'topics': [["ukraine 's fugitive president viktor yanukovych asked putin to use russian military in ukraine"],
#     ['philippine president rodrigo duterte is sparking distress around the world',
#      "it was troubled by the growing number of extrajudicial killings in philippine president duterte 's war on drugs and called on manila to stick to its commitment to investigate them",
#      'it is open to work with new iranian president hussain rowhani',
#      'no evidence of promised pullback of forces by russian president']]},
#   'korea': {'h': 24.590243902439045,
#    'total': 213,
#    'degree': 431,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['yacht detained by north korea',
#      "north korea 's leader has accepted an invitation to travel to moscow in may for world war two anniversary celebrations"],
#     ["north korea 's nuclear ambitions on table in china talks",
#      'north korea can miniaturize a nuclear weapon',
#      'no talks with n. korea without focus on denuclearization',
#      'north korea should stop polluting the waters with missile launches and instead focus on feeding its people',
#      'it would not be surprised if north korea launches missiles',
#      'n. korea might have nuclear missile capability',
#      'strategy on north korea centers on sanctions open to talks',
#      'north korea sanctions step one in sony response',
#      'it takes north korea nuclear threats seriously',
#      'strike on syria would help deter north korea from using chemical weapons',
#      'it will not provide food aid to north korea during its worst drought in 100 years',
#      "trump ca n't imagine russia pleased with north korea missile",
#      'it will respond strongly in event of another north korea nuclear test',
#      "north korea 's ballistic missile threat matured from theory to practicality",
#      'u.n. sanctions will bite after north korea threatens nuclear attack',
#      'north korea test fires submarine launched missile',
#      'north korea can learn from iran nuclear deal']]},
#   'to enforce': {'h': 3.571428571428571,
#    'total': 5,
#    'degree': 13,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it may act alone to enforce syria cease fire',
#      'any attempt to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan would violate international law'],
#     ['french assault ships give russia power to enforce its will and may be used to launch missile attacks']]},
#   'zone': {'h': 23.113207547169804,
#    'total': 35,
#    'degree': 29,
#    'common_related_atoms': ['syria', 'jordan'],
#    'common_related_atoms_count': 2,
#    'topics': [['no fly zone over syria would be illegal',
#      'it will be a month before de escalation zones are fully established as syrian opposition voices concern',
#      'any attempt to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan would violate international law'],
#     ['no evidence jordan turkey considering syria buffer zones']]},
#   'russia': {'h': 20.268522744560986,
#    'total': 365,
#    'degree': 7510,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it will defend the rights of its compatriots in crimea after russia gunmen seize parliament',
#      'the syrian government has agreed in principle to attend an international peace conference proposed by russia and the us and criticised what it called attempts to undermine peace efforts'],
#     ['russia firing artillery across border at ukrainian military',
#      'russia has sent tanks to ukraine rebels',
#      "proxy war with russia not in ukraine 's interest",
#      'russia firing across border into ukraine',
#      'it can not coordinate with russia until they stop killing so many civilians and moderate rebels',
#      'exxon under tillerson violated russia sanctions in 2014',
#      'russia may have violated nuclear arms control treaty',
#      'russia has outright lied about ukraine',
#      "trump ca n't imagine russia pleased with north korea missile",
#      'french assault ships give russia power to enforce its will and may be used to launch missile attacks',
#      'russia tested cruise missile violating treaty',
#      'sanctions impact on russia to be longer term',
#      'ukraine crisis russia firing artillery at ukraine troops',
#      'russia willing to deploy monitors for syria ceasefire',
#      'g7 backs more sanctions if russia escalates ukraine crisis']]},
#   'sinai': {'h': 8.138461538461536,
#    'total': 23,
#    'degree': 49,
#    'common_related_atoms': ['sinai plane crash', 'plane crash'],
#    'common_related_atoms_count': 2,
#    'topics': [['plane crash in sinai was terrorist attack vows vengeance',
#      'sinai plane crash was caused by a terrorist attack',
#      'sinai plane disaster was an act of terror after traces of explosives were found in debris at crash site'],
#     ['sinai plane crash bomb may have hit airliner']]},
#   'washington': {'h': 13.714285714285719,
#    'total': 24,
#    'degree': 209,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month',
#      'ready to move fast to fix ties with washington ria'],
#     ['china not washington responsible for south china sea tensions']]},
#   'united': {'h': 25.817204301075268,
#    'total': 49,
#    'degree': 55,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month',
#      "it would not hand back crimea to ukraine despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago",
#      'ready for talks with united states on syria'],
#     ['some 360,000 refugee spots pledged at united nations']]},
#   'focus': {'h': 1.7999999999999998,
#    'total': 3,
#    'degree': 53,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['gunman opens fire in dagestan focus of isis recruiters'],
#     ['no talks with n. korea without focus on denuclearization',
#      "wants syria 's assad out despite focus on islamic state"]]},
#   'geneva': {'h': 6.4,
#    'total': 8,
#    'degree': 28,
#    'common_related_atoms': ['syria'],
#    'common_related_atoms_count': 1,
#    'topics': [['only proxy talks on syria planned in geneva interfax',
#      'syrian government officials will attend geneva peace talks'],
#     ['it did not seek direct negotiations with syria at geneva']]},
#   'damascus': {'h': 12.518518518518523,
#    'total': 26,
#    'degree': 92,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['shelling of its embassy in damascus act of terrorism',
#      'shelling of its embassy in damascus act of terrorism'],
#     ['assad regime has killed thousands of prisoners and burned bodies in crematorium outside damascus']]},
#   'arm': {'h': 23.86238532110093,
#    'total': 51,
#    'degree': 93,
#    'common_related_atoms': ['treaty'],
#    'common_related_atoms_count': 1,
#    'topics': [['syria to ship chemical arms as civilians flee bombs',
#      'case against convicted arms dealer bout fabricated by u.s.',
#      'foils plot to attack chemical arms facility',
#      'u.s. coerces kiev and violates arms treaties',
#      'it can deploy nuclear arms to crimea',
#      'dissatisfied with u.s. talks over arms treaty concerns'],
#     ['iran sent arms to iraq to fight isis',
#      'russia may have violated nuclear arms control treaty',
#      'they will work together at u.n to seriously explore russian plan for syrian chemical arms']]},
#   'raqqa': {'h': 5.12121212121212,
#    'total': 13,
#    'degree': 39,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['syrian army planning offensives on deir al zor raqqa ria'],
#     ['coalition is laying the groundwork to retake raqqa from isis']]},
#   'will respond': {'h': 4.999999999999999,
#    'total': 5,
#    'degree': 22,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it will respond to nato troop rotations in east'],
#     ['it will respond strongly in event of another north korea nuclear test']]},
#   'minister': {'h': 25.325581395348838,
#    'total': 33,
#    'degree': 881,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['foreign minister sergey lavrov and u.s. secretary of state john kerry have held a telephone discussion on the syrian conflict'],
#     ['modi will get a visa if elected prime minister']]},
#   'qaeda': {'h': 23.14814814814817,
#    'total': 50,
#    'degree': 404,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['us protecting al qaeda in syria'],
#     ['two top al qaeda leaders in afghanistan targeted in strikes',
#      'islamic charity officials gave millions to al qaeda',
#      'islamic charity officials gave millions to al qaeda']]},
#   'jet': {'h': 24.006451612903255,
#    'total': 61,
#    'degree': 171,
#    'common_related_atoms': ['bomb'],
#    'common_related_atoms_count': 1,
#    'topics': [['turkey should pay compensation for downed jet',
#      '300 militants are killed as its jets and syrian army troops fight off an is offensive in the historic syrian city',
#      'its jets bombed 24 targets in syria tuesday using coordinates supplied by " opposition representatives',
#      'any attempt to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan would violate international law'],
#     ["the u.s. military has sent fighter jets to afghanistan 's northern province of kunduz where taliban insurgents have launched a major offensive and overrun government checkpoints close to the main city",
#      'russian jet was downed by bomb',
#      'russian jet flew 10 ft from plane over black sea']]},
#   'nuke': {'h': 11.918918918918923,
#    'total': 21,
#    'degree': 37,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['odds of reaching nuke deal over 50 %'],
#     ['recognition of israel not part of iran nuke deal',
#      'iran complies with nuke deal but orders review on lifting sanctions']]},
#   'egypt': {'h': 21.551724137931057,
#    'total': 50,
#    'degree': 1934,
#    'common_related_atoms': ['bomb'],
#    'common_related_atoms_count': 1,
#    'topics': [['bomb did down airbus a321 plane over egypt last month',
#      "it does n't have special forces in egypt interfax",
#      'air link with egypt will be restored soon'],
#     ['russian plane crash in egypt may have been result of bomb',
#      "imposing egypt 's death sentences would be unconscionable"]]},
#   'power': {'h': 28.592356687898068,
#    'total': 67,
#    'degree': 200,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it is struggling to source gas turbines for crimea power plant',
#      'assad ready to share power with opposition',
#      "syria 's assad is ready to share power with opposition"],
#     ["it wo n't back new international coal fired power plants",
#      'french assault ships give russia power to enforce its will and may be used to launch missile attacks']]},
#   'assad': {'h': 28.921951219512213,
#    'total': 77,
#    'degree': 728,
#    'common_related_atoms': ['strike', 'syria', 'air strike', 'air'],
#    'common_related_atoms_count': 4,
#    'topics': [['assad ready to support ceasefire',
#      'assad ready to share power with opposition',
#      'it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month',
#      "syria 's assad is ready to share power with opposition",
#      'no proof assad was behind chemical attack',
#      "it does n't mind if assad stays or steps down"],
#     ['assad regime has killed thousands of prisoners and burned bodies in crematorium outside damascus',
#      'assad forces used chemical weapons against syria rebels',
#      'syria isis advance on aleppo aided by assad regime air strikes',
#      'assad preparing chemical weapons attack in syria',
#      'no role for assad following gas attack',
#      "wants syria 's assad out despite focus on islamic state",
#      "assad is ' root of all evil' after first drone strikes launch from turkey"]]},
#   'country': {'h': 55.05617977528077,
#    'total': 140,
#    'degree': 279,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['talks were taking place to include aleppo in a temporary lull in fighting declared by the syrian army in some western parts of the country a sign of intensified efforts to halt a surge of violence in its former commercial capital',
#      'no country can use military force in syria without government approval'],
#     ['countries must punish un troops for sexual abuse']]},
#   'offensive': {'h': 14.225806451612907,
#    'total': 21,
#    'degree': 42,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['syrian army planning offensives on deir al zor raqqa ria'],
#     ["the u.s. military has sent fighter jets to afghanistan 's northern province of kunduz where taliban insurgents have launched a major offensive and overrun government checkpoints close to the main city"]]},
#   'agreement': {'h': 26.272727272727277,
#    'total': 34,
#    'degree': 44,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['military agreement near with u.s. on syria flights'],
#     ['turkey iraq reach agreement in principle on mosul']]},
#   'crises': {'h': 26.694444444444464,
#    'total': 62,
#    'degree': 450,
#    'common_related_atoms': ['ukraine'],
#    'common_related_atoms_count': 1,
#    'topics': [['optimistic about ukraine crisis trio talks',
#      'ukraine election may aggravate crisis'],
#     ['ukraine crisis russia firing artillery at ukraine troops',
#      'g7 backs more sanctions if russia escalates ukraine crisis']]},
#   'was caused': {'h': 4.0,
#    'total': 4,
#    'degree': 14,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['sinai plane crash was caused by a terrorist attack'],
#     ['a mystery illness that killed more than 100 children a year in northern india was caused by eating lychees on an empty stomach']]},
#   'drug': {'h': 26.298701298701282,
#    'total': 45,
#    'degree': 77,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [["greenpeace activists ' ship was carrying illegal drugs"],
#     ['freed mexican drug lord still in business',
#      "it was troubled by the growing number of extrajudicial killings in philippine president duterte 's war on drugs and called on manila to stick to its commitment to investigate them"]]},
#   'evidence': {'h': 30.413793103448278,
#    'total': 42,
#    'degree': 135,
#    'common_related_atoms': ['syria'],
#    'common_related_atoms_count': 1,
#    'topics': [['mass graves and evidence of war crimes found in east of aleppo syria'],
#     ['no evidence jordan turkey considering syria buffer zones',
#      'no evidence of promised pullback of forces by russian president']]},
#   'afghanistan': {'h': 16.66666666666668,
#    'total': 50,
#    'degree': 391,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['u.s. withdrawal from afghanistan would worsen situation ifax',
#      'u.s. withdrawal from afghanistan would worsen situation'],
#     ['two top al qaeda leaders in afghanistan targeted in strikes',
#      "the u.s. military has sent fighter jets to afghanistan 's northern province of kunduz where taliban insurgents have launched a major offensive and overrun government checkpoints close to the main city"]]},
#   'submarine': {'h': 8.533333333333333,
#    'total': 16,
#    'degree': 35,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it hit islamic state with submarine launched missile for first time'],
#     ['north korea test fires submarine launched missile']]},
#   'treaty': {'h': 8.1,
#    'total': 18,
#    'degree': 32,
#    'common_related_atoms': ['arm'],
#    'common_related_atoms_count': 1,
#    'topics': [['u.s. missiles in poland romania would violate treaty',
#      'u.s. coerces kiev and violates arms treaties',
#      'dissatisfied with u.s. talks over arms treaty concerns',
#      'us missile system breaches nuclear inf treaty'],
#     ['russia may have violated nuclear arms control treaty',
#      'russia tested cruise missile violating treaty']]},
#   'zika': {'h': 15.125,
#    'total': 22,
#    'degree': 176,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['registers first case of person infected with zika virus'],
#     ['guantanamo base worker got zika after jamaica trip']]},
#   'air': {'h': 41.207357859531804,
#    'total': 111,
#    'degree': 162,
#    'common_related_atoms': ['strike', 'syria', 'air strike', 'assad'],
#    'common_related_atoms_count': 4,
#    'topics': [['air units deploying south to ashuluk for drills',
#      'no plans to sell air defense system to syria agency',
#      'air force has not hit civilian targets in syria',
#      'u.s. crossed red lines with strike on syrian air base',
#      'air strikes in syria would be act of aggression without u.n. vote',
#      'it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month',
#      'it is suspending deal with u.s. to prevent mid air incidents over syria in response to us strike',
#      'it will honor its controversial contract to deliver s-300 air defense missile systems to syria',
#      'a us led air attack in eastern syria that killed dozens of government troops fighting so called islamic state has endangered an already shaky ceasefire deal',
#      'air link with egypt will be restored soon'],
#     ['syria isis advance on aleppo aided by assad regime air strikes']]},
#   'ballistic': {'h': 6.2439024390243905,
#    'total': 32,
#    'degree': 79,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['fires iskander m ballistic missile during training exercise'],
#     ['it is considering response to iran ballistic missile test',
#      "north korea 's ballistic missile threat matured from theory to practicality"]]},
#   'islamic': {'h': 49.0140597539543,
#    'total': 167,
#    'degree': 1192,
#    'common_related_atoms': ['syria', 'turkey'],
#    'common_related_atoms_count': 2,
#    'topics': [['it hit islamic state with submarine launched missile for first time',
#      'a us led air attack in eastern syria that killed dozens of government troops fighting so called islamic state has endangered an already shaky ceasefire deal',
#      'turkey is protecting oil trade with islamic state',
#      'it may have killed islamic state leader al baghdadi'],
#     ['islamic charity officials gave millions to al qaeda',
#      'islamic charity officials gave millions to al qaeda',
#      'islamic state setting up libya training camps',
#      'turkey will allow use of its bases against islamic state',
#      'islamic state chief alive still leading',
#      "wants syria 's assad out despite focus on islamic state"]]},
#   'sanction': {'h': 21.196923076923095,
#    'total': 83,
#    'degree': 165,
#    'common_related_atoms': ['ukraine'],
#    'common_related_atoms_count': 1,
#    'topics': [['eu should be ashamed over sanctions',
#      'it may abandon space station by 2020 and forbid us gps stations within its borders in protest of ukraine sanctions',
#      'us astronauts could be hurt by ukraine sanctions',
#      "sanctions ' destructive will act in own interests",
#      'it could close its airspace to western airlines if new eu sanctions are imposed',
#      'it loses billions to oil slump sanctions',
#      'new us sanctions leave relations in uncharted territory',
#      "it would not hand back crimea to ukraine despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago"],
#     ['to ready sanctions against top venezuelans',
#      'iran complies with nuke deal but orders review on lifting sanctions',
#      'exxon under tillerson violated russia sanctions in 2014',
#      'strategy on north korea centers on sanctions open to talks',
#      'north korea sanctions step one in sony response',
#      'u.n. sanctions will bite after north korea threatens nuclear attack',
#      'sanctions impact on russia to be longer term',
#      'g7 backs more sanctions if russia escalates ukraine crisis']]},
#   'military': {'h': 30.942857142857147,
#    'total': 57,
#    'degree': 341,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [["ukraine 's fugitive president viktor yanukovych asked putin to use russian military in ukraine",
#      'it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month',
#      'military agreement near with u.s. on syria flights',
#      'u.s georgian military exercises could destabilize caucasus'],
#     ['russia firing artillery across border at ukrainian military',
#      "the u.s. military has sent fighter jets to afghanistan 's northern province of kunduz where taliban insurgents have launched a major offensive and overrun government checkpoints close to the main city"]]},
#   'diplomatic': {'h': 12.249999999999998,
#    'total': 14,
#    'degree': 14,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['kerry \'s accusation moscow is lying " beyond diplomatic ethics'],
#     ['that the target of a dec. 12th drone strike in yemen was the ringleader behind the summer plot that shuttered diplomatic posts across africa and the mideast']]},
#   'helicopter': {'h': 13.888888888888884,
#    'total': 25,
#    'degree': 80,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['one of its attack helicopters crashes in syria'],
#     ['apache helicopter carries out strike in iraq',
#      'a u.s. navy helicopter made an emergency landing near tokyo on monday injuring two crewmembers']]},
#   'killed in': {'h': 27.847999999999963,
#    'total': 59,
#    'degree': 14,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['four militants killed in dagestan siege'],
#     ['more than 140 killed in taliban attack on afghan army base']]},
#   'airstrike': {'h': 16.753846153846165,
#    'total': 66,
#    'degree': 104,
#    'common_related_atoms': ['syria', 'isis'],
#    'common_related_atoms_count': 2,
#    'topics': [['syria airstrike an aggression by us',
#      'us airstrike war crime',
#      'one of its airstrikes in syria killed isis spokesman mohammad al adnani a claim that a us official called preposterous'],
#     ['it has targeted khorasan group again in syria with airstrike',
#      'deadly doctors without borders hospital airstrike called for by afghans',
#      'airstrikes alone can not save kobane',
#      'nyt israel carried out airstrike in syria',
#      'airstrikes have killed 350 isis fighters in western iraq city ramadi',
#      'airstrikes aimed to kill isis leaders',
#      "isis ' emir of suicide bombers killed in coalition airstrike",
#      'more than 90 % of russian airstrikes in syria have not targeted isis']]},
#   'internet': {'h': 15.114285714285716,
#    'total': 23,
#    'degree': 86,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['national governments should control the internet'],
#     ['china internet censorship a burden for businesses']]},
#   'ukraine': {'h': 22.56097560975608,
#    'total': 185,
#    'degree': 2386,
#    'common_related_atoms': ['crises', 'border', 'troop', 'war', 'sanction'],
#    'common_related_atoms_count': 5,
#    'topics': [["it wo n't intervene in ukraine",
#      'eu criticism over ukraine shift inappropriate',
#      'eu does not want ukraine truce to hold',
#      'ukraine has violated loan terms no decision on repayment',
#      "ukraine is ' as close to civil war as you can get,'",
#      'it may abandon space station by 2020 and forbid us gps stations within its borders in protest of ukraine sanctions',
#      'will resume selling gas to ukraine following an official request from kiev',
#      'optimistic about ukraine crisis trio talks',
#      "ukraine 's fugitive president viktor yanukovych asked putin to use russian military in ukraine",
#      'new tragedies possible if u.s. supplies lethal aid to ukraine',
#      'us astronauts could be hurt by ukraine sanctions',
#      'eu relations facing moment of truth over ukraine',
#      'will resume selling gas to ukraine following an official request from kiev',
#      'open to good faith talks with ukraine over the $ 3 billion debt it owes',
#      'ukraine should find money to pay for gas within a week',
#      'ukraine monitors biased',
#      'it will recognise the results of controversial separatist elections in eastern ukraine',
#      "ukraine 's natural gas debt climbed to almost $ 2 billion and signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region",
#      "nato turning ukraine into ' frontline of confrontation'",
#      'ukraine on brink of civil war',
#      "military mission in ukraine is there at kiev 's request",
#      'to halt gas supplies to ukraine mulling coal cut off over crimea',
#      'ukraine election may aggravate crisis',
#      "it had pulled some troops back from near ukraine 's eastern border a move that could ease tension in the worst east west standoff since the cold war",
#      "it would not hand back crimea to ukraine despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago",
#      'ukraine must become a federation allowing regional autonomy',
#      'mh17 probe should be done by international community not ukraine',
#      'international monitors should stay in ukraine where 2 mission teams are missing'],
#     ['russia has sent tanks to ukraine rebels',
#      "proxy war with russia not in ukraine 's interest",
#      'russia firing across border into ukraine',
#      'ukraine is not a battleground between east and west telegraph',
#      'russia has outright lied about ukraine',
#      'ukraine crisis russia firing artillery at ukraine troops',
#      'g7 backs more sanctions if russia escalates ukraine crisis']]},
#   'right': {'h': 29.069767441860453,
#    'total': 50,
#    'degree': 114,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it will defend the rights of its compatriots in crimea after russia gunmen seize parliament'],
#     ['aid package to philippines withheld over rights concerns',
#      'it may pull out of u.n. human rights body citing member abuses treatment of israel']]},
#   'drone': {'h': 16.051428571428566,
#    'total': 53,
#    'degree': 174,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it will have armed drones by 2020'],
#     ['it shot down iranian made drone in syria',
#      'that the target of a dec. 12th drone strike in yemen was the ringleader behind the summer plot that shuttered diplomatic posts across africa and the mideast',
#      'only 116 civilians killed in drone strikes since 2009 in report on casualties outside war zones a number that is hundreds lower than even the lowest estimates by independent organisations',
#      "assad is ' root of all evil' after first drone strikes launch from turkey"]]},
#   'line': {'h': 15.210526315789478,
#    'total': 17,
#    'degree': 29,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['u.s. crossed red lines with strike on syrian air base'],
#     ['canadian special forces on the front lines with kurdish forces aiming to retake iraqi city from isil']]},
#   'ukrainian': {'h': 13.090909090909099,
#    'total': 24,
#    'degree': 123,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it has detained ukrainian saboteurs in crimea',
#      'it will keep out of ukrainian affairs',
#      'u.s. should push ukrainian leader to halt violence'],
#     ['russia firing artillery across border at ukrainian military']]},
#   'air strike': {'h': 23.058823529411757,
#    'total': 28,
#    'degree': 149,
#    'common_related_atoms': ['strike', 'syria', 'assad', 'air'],
#    'common_related_atoms_count': 4,
#    'topics': [['it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month'],
#     ['syria isis advance on aleppo aided by assad regime air strikes']]},
#   'black': {'h': 5.333333333333333,
#    'total': 8,
#    'degree': 39,
#    'common_related_atoms': ['sea', 'warning'],
#    'common_related_atoms_count': 2,
#    'topics': [["ukraine 's natural gas debt climbed to almost $ 2 billion and signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region",
#      "it would not hand back crimea to ukraine despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago"],
#     ['it will stay in black sea despite russian warning',
#      'russian jet flew 10 ft from plane over black sea']]},
#   'tie': {'h': 21.51219512195121,
#    'total': 42,
#    'degree': 50,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['ready to move fast to fix ties with washington ria'],
#     ["ties with pakistan vital but ' complicated' at times"]]},
#   'breach': {'h': 7.0,
#    'total': 7,
#    'degree': 72,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['us missile system breaches nuclear inf treaty'],
#     ['iran rocket test breaches u.n. resolution']]},
#   'syria': {'h': 47.39898348157563,
#    'total': 511,
#    'degree': 2283,
#    'common_related_atoms': ['iran',
#     'strike',
#     'aleppo',
#     'geneva',
#     'air strike',
#     'jordan',
#     'assad',
#     'airstrike',
#     'to deploy',
#     'isis',
#     'turkey',
#     'rebel',
#     'regime',
#     'air',
#     'evidence',
#     'islamic',
#     'ceasefire',
#     'zone'],
#    'common_related_atoms_count': 18,
#    'topics': [['syria to ship chemical arms as civilians flee bombs',
#      'us inviting terror attack by de facto support for terrorism in syria',
#      "syria gas incident caused by rebels ' own chemical arsenal",
#      'it may act alone to enforce syria cease fire',
#      'no plans to sell air defense system to syria agency',
#      'one of its attack helicopters crashes in syria',
#      'syria ceasefire under threat after us led strikes kill regime troops',
#      "ready to consider more ways to normalize situation in syria 's aleppo",
#      'it is drafting roadmap to resolve syria conflict with turkey iran',
#      'syria airstrike an aggression by us',
#      'kills 300 militants in syria in most intense raids yet',
#      'it will keep selling missiles to syria',
#      'air force has not hit civilian targets in syria',
#      'they are deeply worried by turkish operation in syria',
#      'only proxy talks on syria planned in geneva interfax',
#      'air strikes in syria would be act of aggression without u.n. vote',
#      'it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month',
#      'missile systems for syria will deter intervention',
#      'it is suspending deal with u.s. to prevent mid air incidents over syria in response to us strike',
#      'military agreement near with u.s. on syria flights',
#      'embassy naval base in syria working as normal',
#      'mass graves and evidence of war crimes found in east of aleppo syria',
#      'it will honor its controversial contract to deliver s-300 air defense missile systems to syria',
#      'cessation of hostilities in syria violated 29 times in past 24 hours',
#      "it 's set to deploy security forces to syria",
#      'one of its airstrikes in syria killed isis spokesman mohammad al adnani a claim that a us official called preposterous',
#      "not responsible for strike on school in syria 's idlib",
#      'a us led air attack in eastern syria that killed dozens of government troops fighting so called islamic state has endangered an already shaky ceasefire deal',
#      'its jets bombed 24 targets in syria tuesday using coordinates supplied by " opposition representatives',
#      "syria 's assad is ready to share power with opposition",
#      'no country can use military force in syria without government approval',
#      'no fly zone over syria would be illegal',
#      'turkish troops entrenched in syria',
#      'its planes are carrying military goods to syria',
#      'us protecting al qaeda in syria',
#      'reports of syria hospital strike fake',
#      "syria 's ancient palmyra cleared mines",
#      'any attempt to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan would violate international law',
#      'ready for talks with united states on syria'],
#     ['it has targeted khorasan group again in syria with airstrike',
#      'syria has been burning bodies to hide prison executions for years',
#      'it shot down iranian made drone in syria',
#      'claim it supported is in syria is ludicrous',
#      'syria built crematorium to clandestinely handle mass prisoner killings',
#      'no evidence jordan turkey considering syria buffer zones',
#      'syria has covered up prison executions by burning the bodies',
#      'assad forces used chemical weapons against syria rebels',
#      'nyt israel carried out airstrike in syria',
#      'syria isis advance on aleppo aided by assad regime air strikes',
#      'unable to conclusively say chemical weapons used in syria',
#      'assad preparing chemical weapons attack in syria',
#      'strike on syria would help deter north korea from using chemical weapons',
#      'syria has used chemical weapons twice',
#      "wants syria 's assad out despite focus on islamic state",
#      'u.s. china want quick binding u.n. resolution on syria',
#      'it did not seek direct negotiations with syria at geneva',
#      'syria at least 50 americans have joined extremist units',
#      "iran wo n't attend peace talks on syria",
#      'more than 90 % of russian airstrikes in syria have not targeted isis',
#      'russia willing to deploy monitors for syria ceasefire']]},
#   'ceasefire': {'h': 14.754385964912286,
#    'total': 29,
#    'degree': 117,
#    'common_related_atoms': ['syria'],
#    'common_related_atoms_count': 1,
#    'topics': [['syria ceasefire under threat after us led strikes kill regime troops',
#      'assad ready to support ceasefire',
#      'a us led air attack in eastern syria that killed dozens of government troops fighting so called islamic state has endangered an already shaky ceasefire deal',
#      'u.s. backs party of war in kiev urges ceasefire'],
#     ['russia willing to deploy monitors for syria ceasefire']]},
#   'yemen': {'h': 16.761557177615583,
#    'total': 83,
#    'degree': 470,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['yemen ambassador was not shot and killed'],
#     ['that the target of a dec. 12th drone strike in yemen was the ringleader behind the summer plot that shuttered diplomatic posts across africa and the mideast',
#      'it tried and failed to rescue hostage luke somers from captors in yemen',
#      'it will review support to saudi led coalition in yemen']]},
#   'weapon': {'h': 31.606837606837633,
#    'total': 86,
#    'degree': 88,
#    'common_related_atoms': ['rebel'],
#    'common_related_atoms_count': 1,
#    'topics': [["it 's compiled 100-page report blaming syrian rebels for a chemical weapons attack"],
#     ['north korea can miniaturize a nuclear weapon',
#      'assad forces used chemical weapons against syria rebels',
#      'unable to conclusively say chemical weapons used in syria',
#      'assad preparing chemical weapons attack in syria',
#      'strike on syria would help deter north korea from using chemical weapons',
#      'syria has used chemical weapons twice']]},
#   'aleppo': {'h': 17.340206185566988,
#    'total': 58,
#    'degree': 152,
#    'common_related_atoms': ['syria'],
#    'common_related_atoms_count': 1,
#    'topics': [['talks to extend syrian lull in fighting to aleppo',
#      "ready to consider more ways to normalize situation in syria 's aleppo",
#      'all of aleppo has fallen to syrian government control',
#      'talks were taking place to include aleppo in a temporary lull in fighting declared by the syrian army in some western parts of the country a sign of intensified efforts to halt a surge of violence in its former commercial capital',
#      'truce extended for 72 hours in aleppo latakia',
#      'mass graves and evidence of war crimes found in east of aleppo syria',
#      "syrian army ' suspends aleppo fighting'"],
#     ['syria isis advance on aleppo aided by assad regime air strikes']]},
#   'mar.': {'h': 18.18181818181817,
#    'total': 20,
#    'degree': 247,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['inflation could hit 17 % by march'],
#     ['mosul strike in march killed over 100 civilians']]},
#   'jordan': {'h': 9.799999999999999,
#    'total': 14,
#    'degree': 340,
#    'common_related_atoms': ['syria', 'zone'],
#    'common_related_atoms_count': 2,
#    'topics': [['any attempt to enforce a no fly zone over syria using f-16 fighter jets and patriot missiles from jordan would violate international law'],
#     ['no evidence jordan turkey considering syria buffer zones']]},
#   'territory': {'h': 16.030303030303035,
#    'total': 23,
#    'degree': 51,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['40 mortar shells hit russian territory on friday ria',
#      'new us sanctions leave relations in uncharted territory'],
#     ['isis has lost 25 percent of territory it once held in iraq',
#      'it will prevent china from taking over territory in international waters']]},
#   'sea': {'h': 16.060822898032185,
#    'total': 134,
#    'degree': 153,
#    'common_related_atoms': ['warning', 'black'],
#    'common_related_atoms_count': 2,
#    'topics': [["ukraine 's natural gas debt climbed to almost $ 2 billion and signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region",
#      "it would not hand back crimea to ukraine despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago"],
#     ['ready to share burden of asian sea migrants from myanmmar',
#      'more military transparency needed in south china sea',
#      'it will stay in black sea despite russian warning',
#      'russian jet flew 10 ft from plane over black sea',
#      'recon flight over sea of japan was safe lawful despite russian protest',
#      "china 's move on east china sea airspace destabilizing",
#      'china not washington responsible for south china sea tensions']]},
#   'airspace': {'h': 8.909090909090907,
#    'total': 14,
#    'degree': 35,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it could close its airspace to western airlines if new eu sanctions are imposed'],
#     ["china 's move on east china sea airspace destabilizing"]]},
#   'exxon': {'h': 4.0,
#    'total': 4,
#    'degree': 61,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['arctic well drilled with exxon strikes oil'],
#     ['exxon under tillerson violated russia sanctions in 2014']]},
#   'resolution': {'h': 7.0,
#    'total': 14,
#    'degree': 36,
#    'common_related_atoms': ['iran'],
#    'common_related_atoms_count': 1,
#    'topics': [['iran missile test does not contravene un resolution',
#      "un resolution proposal ' unacceptable"],
#     ['u.s. china want quick binding u.n. resolution on syria',
#      'palestinian draft resolution not constructive',
#      'iran rocket test breaches u.n. resolution',
#      'palestinian draft resolution not constructive']]},
#   'plane crash': {'h': 7.14285714285714,
#    'total': 10,
#    'degree': 77,
#    'common_related_atoms': ['sinai plane crash', 'sinai'],
#    'common_related_atoms_count': 2,
#    'topics': [['sinai plane crash was caused by a terrorist attack'],
#     ['sinai plane crash bomb may have hit airliner']]},
#   'bomb': {'h': 16.210485736314556,
#    'total': 145,
#    'degree': 406,
#    'common_related_atoms': ['egypt', 'jet'],
#    'common_related_atoms_count': 2,
#    'topics': [['syria to ship chemical arms as civilians flee bombs',
#      'bomb did down airbus a321 plane over egypt last month',
#      'its jets bombed 24 targets in syria tuesday using coordinates supplied by " opposition representatives',
#      'militants seized with bomb in south',
#      'kiev forces dropped white phosphorus bombs on slavyansk'],
#     ['sinai plane crash bomb may have hit airliner',
#      'russian plane crash in egypt may have been result of bomb',
#      'russian jet was downed by bomb']]},
#   'strike': {'h': 37.50410958904112,
#    'total': 117,
#    'degree': 134,
#    'common_related_atoms': ['air strike',
#     'assad',
#     'isis',
#     'air',
#     'syria',
#     'regime'],
#    'common_related_atoms_count': 6,
#    'topics': [['syria ceasefire under threat after us led strikes kill regime troops',
#      'u.s. crossed red lines with strike on syrian air base',
#      'air strikes in syria would be act of aggression without u.n. vote',
#      'it told the united states it was unacceptable for washington to strike government forces in syria after the u.s. military carried out an air strike on assad militia last month',
#      'it is suspending deal with u.s. to prevent mid air incidents over syria in response to us strike',
#      'its strikes reduce oil smuggling to turkey',
#      "not responsible for strike on school in syria 's idlib",
#      'isis leader may have been liquidated by strike',
#      'reports of syria hospital strike fake'],
#     ['two top al qaeda leaders in afghanistan targeted in strikes',
#      'mosul strike in march killed over 100 civilians',
#      'that the target of a dec. 12th drone strike in yemen was the ringleader behind the summer plot that shuttered diplomatic posts across africa and the mideast',
#      'syria isis advance on aleppo aided by assad regime air strikes',
#      'strike on syria would help deter north korea from using chemical weapons',
#      'apache helicopter carries out strike in iraq']]},
#   'sinai plane crash': {'h': 4.0,
#    'total': 4,
#    'degree': 10,
#    'common_related_atoms': ['sinai', 'plane crash'],
#    'common_related_atoms_count': 2,
#    'topics': [['sinai plane crash was caused by a terrorist attack'],
#     ['sinai plane crash bomb may have hit airliner']]},
#   'opposition': {'h': 19.512195121951212,
#    'total': 40,
#    'degree': 202,
#    'common_related_atoms': ['syrian'],
#    'common_related_atoms_count': 1,
#    'topics': [['syrian government and opposition in talks ifax',
#      'assad ready to share power with opposition',
#      'its jets bombed 24 targets in syria tuesday using coordinates supplied by " opposition representatives',
#      "syria 's assad is ready to share power with opposition",
#      'it will be a month before de escalation zones are fully established as syrian opposition voices concern'],
#     ['the long awaited coalition program to train the syrian moderate opposition could start in early spring']]},
#   'term': {'h': 12.999999999999996,
#    'total': 13,
#    'degree': 48,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['ukraine has violated loan terms no decision on repayment'],
#     ['sanctions impact on russia to be longer term']]},
#   'rebel': {'h': 27.74626865671638,
#    'total': 143,
#    'degree': 680,
#    'common_related_atoms': ['weapon', 'syria', 'syrian'],
#    'common_related_atoms_count': 3,
#    'topics': [["syria gas incident caused by rebels ' own chemical arsenal",
#      "it 's compiled 100-page report blaming syrian rebels for a chemical weapons attack"],
#     ['it can not coordinate with russia until they stop killing so many civilians and moderate rebels',
#      'assad forces used chemical weapons against syria rebels',
#      'turkey will train moderate syrian rebels but presses for details']]},
#   'mass': {'h': 18.241379310344833,
#    'total': 23,
#    'degree': 79,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['mass graves and evidence of war crimes found in east of aleppo syria'],
#     ['syrian crematory is hiding mass killings of prisoners']]},
#   'has killed': {'h': 10.57232704402516,
#    'total': 41,
#    'degree': 63,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it has killed islamist insurgency chief'],
#     ['assad regime has killed thousands of prisoners and burned bodies in crematorium outside damascus']]},
#   'supply': {'h': 13.564102564102566,
#    'total': 23,
#    'degree': 34,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [["ukraine 's natural gas debt climbed to almost $ 2 billion and signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region",
#      'to halt gas supplies to ukraine mulling coal cut off over crimea'],
#     ['iraq supplies kurds with ammunition in unprecedented move']]},
#   'proxy': {'h': 4.999999999999999,
#    'total': 5,
#    'degree': 28,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['only proxy talks on syria planned in geneva interfax'],
#     ["proxy war with russia not in ukraine 's interest"]]},
# ...
#      'it is using its influence to get syrian army to fulfil truce deal',
#      'the syrian government has agreed in principle to attend an international peace conference proposed by russia and the us and criticised what it called attempts to undermine peace efforts',
#      'it will be a month before de escalation zones are fully established as syrian opposition voices concern',
#      'syrian army planning offensives on deir al zor raqqa ria',
#      'syrian government officials will attend geneva peace talks'],
#     ["syrian officials ' panicked calls prove culpability",
#      'the long awaited coalition program to train the syrian moderate opposition could start in early spring',
#      'syrian crematory is hiding mass killings of prisoners',
#      'they will work together at u.n to seriously explore russian plan for syrian chemical arms',
#      'turkey will train moderate syrian rebels but presses for details']]},
#   'raid': {'h': 23.214876033057838,
#    'total': 53,
#    'degree': 152,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['kills 300 militants in syria in most intense raids yet'],
#     ['navy seals stage raid on somali militants kill leader',
#      'to raid isis prison in north iraq']]},
#   'border': {'h': 39.22714681440439,
#    'total': 119,
#    'degree': 77,
#    'common_related_atoms': ['ukraine'],
#    'common_related_atoms_count': 1,
#    'topics': [['it may abandon space station by 2020 and forbid us gps stations within its borders in protest of ukraine sanctions',
#      'one north korean fisherman was killed and eight others injured when russian border guards opened fire on a fishing trawler',
#      'moscow holds eston kohver for undercover intelligence mission while tallinn says he was investigating cross border crime',
#      "it had pulled some troops back from near ukraine 's eastern border a move that could ease tension in the worst east west standoff since the cold war"],
#     ['russia firing artillery across border at ukrainian military',
#      'russia firing across border into ukraine']]},
#   'monitor': {'h': 3.571428571428571,
#    'total': 5,
#    'degree': 170,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['ukraine monitors biased',
#      'international monitors should stay in ukraine where 2 mission teams are missing'],
#     ['russia willing to deploy monitors for syria ceasefire']]},
#   'threat': {'h': 44.73529411764708,
#    'total': 78,
#    'degree': 94,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it views the arrival of more than 3,000 us soldiers in poland as a threat to its own security',
#      'syria ceasefire under threat after us led strikes kill regime troops',
#      'putin is fully mobilized to tackle unprecedented threat from turkey'],
#     ['ready to defend against north korean nuclear threat',
#      'it takes north korea nuclear threats seriously',
#      "north korea 's ballistic missile threat matured from theory to practicality"]]},
#   'deploy': {'h': 5.999999999999999,
#    'total': 6,
#    'degree': 248,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['air units deploying south to ashuluk for drills'],
#     ['china deployed artillery on disputed island']]},
#   'a year': {'h': 10.314285714285713,
#    'total': 19,
#    'degree': 71,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [["it would not hand back crimea to ukraine despite warnings by the united states and european union that they will not drop sanctions over the black sea peninsula 's annexation a year ago"],
#     ['a mystery illness that killed more than 100 children a year in northern india was caused by eating lychees on an empty stomach']]},
#   'turkey': {'h': 14.91167574107688,
#    'total': 157,
#    'degree': 3268,
#    'common_related_atoms': ['syrian', 'syria', 'islamic'],
#    'common_related_atoms_count': 3,
#    'topics': [['it could sell missile defense systems to turkey',
#      'teams up with turkey for first time to bomb syrian militants',
#      'it is drafting roadmap to resolve syria conflict with turkey iran',
#      'turkey should pay compensation for downed jet',
#      'putin is fully mobilized to tackle unprecedented threat from turkey',
#      'its strikes reduce oil smuggling to turkey',
#      "turkey must stop meddling in other states ' affairs end support of terrorism",
#      'turkey is protecting oil trade with islamic state',
#      'turkey shot down plane for is oil'],
#     ['turkey iraq reach agreement in principle on mosul',
#      'turkey will allow use of its bases against islamic state',
#      'no evidence jordan turkey considering syria buffer zones',
#      'turkey must pull unauthorized forces from iraq',
#      "assad is ' root of all evil' after first drone strikes launch from turkey",
#      'turkey will train moderate syrian rebels but presses for details']]},
#   'russian': {'h': 32.66666666666661,
#    'total': 196,
#    'degree': 651,
#    'common_related_atoms': ['president'],
#    'common_related_atoms_count': 1,
#    'topics': [["ukraine 's fugitive president viktor yanukovych asked putin to use russian military in ukraine",
#      'one north korean fisherman was killed and eight others injured when russian border guards opened fire on a fishing trawler',
#      '40 mortar shells hit russian territory on friday ria'],
#     ['russian plane crash in egypt may have been result of bomb',
#      'it will stay in black sea despite russian warning',
#      'russian jet was downed by bomb',
#      'russian jet flew 10 ft from plane over black sea',
#      'recon flight over sea of japan was safe lawful despite russian protest',
#      'they will work together at u.n to seriously explore russian plan for syrian chemical arms',
#      'more than 90 % of russian airstrikes in syria have not targeted isis',
#      'no evidence of promised pullback of forces by russian president']]},
#   'militant': {'h': 19.07999999999996,
#    'total': 159,
#    'degree': 288,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['teams up with turkey for first time to bomb syrian militants',
#      'kills 300 militants in syria in most intense raids yet',
#      '300 militants are killed as its jets and syrian army troops fight off an is offensive in the historic syrian city',
#      'militants seized with bomb in south',
#      'four militants killed in dagestan siege'],
#     ["forms ' core coalition to counter iraq militants",
#      'it is forming core coalition to fight isis militants in iraq',
#      "pakistani ' charity front for banned militants",
#      'it was hunting militants on august 8']]},
#   'll': {'h': 3.0,
#    'total': 3,
#    'degree': 46,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['will resume selling gas to ukraine following an official request from kiev'],
#     ['french assault ships give russia power to enforce its will and may be used to launch missile attacks']]},
#   'to deploy': {'h': 5.999999999999999,
#    'total': 6,
#    'degree': 72,
#    'common_related_atoms': ['syria'],
#    'common_related_atoms_count': 1,
#    'topics': [["it 's set to deploy security forces to syria"],
#     ['russia willing to deploy monitors for syria ceasefire']]},
#   'isis': {'h': 32.14715359828138,
#    'total': 173,
#    'degree': 2635,
#    'common_related_atoms': ['strike', 'syria', 'airstrike'],
#    'common_related_atoms_count': 3,
#    'topics': [['turkish leadership involved in illegal oil trade with isis',
#      'it may have killed isis leader abu bakr al baghdadi',
#      'gunman opens fire in dagestan focus of isis recruiters',
#      'one of its airstrikes in syria killed isis spokesman mohammad al adnani a claim that a us official called preposterous',
#      'isis leader may have been liquidated by strike',
#      "it 's planning joint isis operations with france"],
#     ['isis has lost 25 percent of territory it once held in iraq',
#      'iran sent arms to iraq to fight isis',
#      'airstrikes have killed 350 isis fighters in western iraq city ramadi',
#      'it is forming core coalition to fight isis militants in iraq',
#      'syria isis advance on aleppo aided by assad regime air strikes',
#      "isis ramping up beheadings because it 's losing",
#      'isis revenue sources remain crucial target',
#      'it will form a core coalition to counter isis',
#      'airstrikes aimed to kill isis leaders',
#      "isis ' emir of suicide bombers killed in coalition airstrike",
#      'coalition is laying the groundwork to retake raqqa from isis',
#      'more than 90 % of russian airstrikes in syria have not targeted isis',
#      'to raid isis prison in north iraq']]},
#   'hezbollah': {'h': 9.756756756756758,
#    'total': 19,
#    'degree': 350,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [["hezbollah not a terrorist group:''we maintain contacts and relations with them because we do not consider them a terrorist organization"],
#     ['hezbollah in worst financial shape in decades']]},
#   'korean': {'h': 24.99999999999998,
#    'total': 45,
#    'degree': 136,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['one north korean fisherman was killed and eight others injured when russian border guards opened fire on a fishing trawler'],
#     ['ready to defend against north korean nuclear threat']]},
#   'pressure': {'h': 18.615384615384613,
#    'total': 22,
#    'degree': 115,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [["ukraine 's natural gas debt climbed to almost $ 2 billion and signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region"],
#     ["as many as 140 million people in bangladesh may be at risk from a huge earthquake as pressure builds beneath the surface of one of the world 's most densely populated nations"]]},
#   'chief': {'h': 23.684210526315788,
#    'total': 30,
#    'degree': 170,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it has killed islamist insurgency chief'],
#     ['islamic state chief alive still leading',
#      "al jazeera 's pakistan bureau chief an al qaida man"]]},
#   'base': {'h': 14.825503355704704,
#    'total': 47,
#    'degree': 27,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['u.s. crossed red lines with strike on syrian air base',
#      'it may reopen soviet era military bases in cuba and vietnam',
#      'embassy naval base in syria working as normal',
#      'experts can examine syrian base',
#      "can not order crimean ' self defense units back to base"],
#     ['guantanamo base worker got zika after jamaica trip',
#      'turkey will allow use of its bases against islamic state',
#      'more than 140 killed in taliban attack on afghan army base']]},
#   'gas': {'h': 30.508474576271215,
#    'total': 60,
#    'degree': 111,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [["syria gas incident caused by rebels ' own chemical arsenal",
#      'will resume selling gas to ukraine following an official request from kiev',
#      'it is struggling to source gas turbines for crimea power plant',
#      'will resume selling gas to ukraine following an official request from kiev',
#      'ukraine should find money to pay for gas within a week',
#      "ukraine 's natural gas debt climbed to almost $ 2 billion and signaled supplies may be cut ratcheting up pressure on its neighbor as they scrap over the future of the black sea crimea region",
#      'to halt gas supplies to ukraine mulling coal cut off over crimea'],
#     ['no role for assad following gas attack']]},
#   'protest': {'h': 18.5142857142857,
#    'total': 36,
#    'degree': 524,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['it may abandon space station by 2020 and forbid us gps stations within its borders in protest of ukraine sanctions'],
#     ['recon flight over sea of japan was safe lawful despite russian protest']]},
#   'china': {'h': 29.070312499999922,
#    'total': 244,
#    'degree': 8754,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [["unperturbed by china 's missile deployment"],
#     ["north korea 's nuclear ambitions on table in china talks",
#      'open to patrols with philippines in waters disputed with china',
#      'it will prevent china from taking over territory in international waters',
#      'more military transparency needed in south china sea',
#      "china 's cyberespionage putting enormous strain on relations",
#      'u.s. china want quick binding u.n. resolution on syria',
#      'china internet censorship a burden for businesses',
#      'southeast asia concern over china at all time high',
#      'china will be bound by maritime arbitration ruling',
#      'china deployed artillery on disputed island',
#      "china 's move on east china sea airspace destabilizing",
#      'china not washington responsible for south china sea tensions']]},
#   'war': {'h': 43.948604992657735,
#    'total': 173,
#    'degree': 307,
#    'common_related_atoms': ['ukraine'],
#    'common_related_atoms_count': 1,
#    'topics': [["ukraine is ' as close to civil war as you can get,'",
#      'us airstrike war crime',
#      'mass graves and evidence of war crimes found in east of aleppo syria',
#      "north korea 's leader has accepted an invitation to travel to moscow in may for world war two anniversary celebrations",
#      'international tribunal creates myth serbs solely to blame for war crimes in former yugoslavia',
#      'ukraine on brink of civil war',
#      "it had pulled some troops back from near ukraine 's eastern border a move that could ease tension in the worst east west standoff since the cold war",
#      'u.s. backs party of war in kiev urges ceasefire',
#      'cynical u.s. policy pushing world toward new cold war'],
#     ["proxy war with russia not in ukraine 's interest",
#      'only 116 civilians killed in drone strikes since 2009 in report on casualties outside war zones a number that is hundreds lower than even the lowest estimates by independent organisations',
#      "it was troubled by the growing number of extrajudicial killings in philippine president duterte 's war on drugs and called on manila to stick to its commitment to investigate them"]]},
#   'plan': {'h': 39.13043478260874,
#    'total': 60,
#    'degree': 250,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['no plans to sell air defense system to syria agency'],
#     ["iran 's nuclear reactor plans deeply troubling",
#      'they will work together at u.n to seriously explore russian plan for syrian chemical arms']]},
#   'regime': {'h': 19.199999999999996,
#    'total': 24,
#    'degree': 62,
#    'common_related_atoms': ['strike', 'syria'],
#    'common_related_atoms_count': 2,
#    'topics': [['syria ceasefire under threat after us led strikes kill regime troops'],
#     ['assad regime has killed thousands of prisoners and burned bodies in crematorium outside damascus',
#      'syria isis advance on aleppo aided by assad regime air strikes']]},
#   'army': {'h': 39.05405405405405,
#    'total': 85,
#    'degree': 376,
#    'common_related_atoms': [],
#    'common_related_atoms_count': 0,
#    'topics': [['u.s. strikes on syrian army would harm fight against islamists',
#      'talks were taking place to include aleppo in a temporary lull in fighting declared by the syrian army in some western parts of the country a sign of intensified efforts to halt a surge of violence in its former commercial capital',
#      '300 militants are killed as its jets and syrian army troops fight off an is offensive in the historic syrian city',
#      "syrian army ' suspends aleppo fighting'",
#      'it is using its influence to get syrian army to fulfil truce deal',
#      'syrian army planning offensives on deir al zor raqqa ria'],
#     ['more than 140 killed in taliban attack on afghan army base',
#      'iraqi army to cordon off falluja before tribes try to retake control']]}}}

# %% [markdown]
# ### Conflict Topics

# %%
sorted_conflict_topics = sorted([(entity, entities[entity]['c']) for entity in entities], key=operator.itemgetter(1), reverse=True)

sorted_conflict_topics
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-6b93fa83cb44> in <module>()
# ----> 1 sorted_conflict_topics = sorted([(entity, entities[entity]['c']) for entity in entities], key=operator.itemgetter(1), reverse=True)
#       2
#       3 sorted_conflict_topics
#
# <ipython-input-18-6b93fa83cb44> in <listcomp>(.0)
# ----> 1 sorted_conflict_topics = sorted([(entity, entities[entity]['c']) for entity in entities], key=operator.itemgetter(1), reverse=True)
#       2
#       3 sorted_conflict_topics
#
# KeyError: 'c'

# %% [markdown]
# ### Conflict graph

# %%
topic = 'syria/syn11910'
conflict_pairs = entities[topic]['conflict_actors']
cactors = set()
for pair in conflict_pairs:
    cactors.add(syn_label(pair[0]))
    cactors.add(syn_label(pair[1]))

G = nx.DiGraph()
for actor in cactors:
    G.add_node(actor)
for edge in conflict_pairs:
    G.add_edge(syn_label(edge[0]), syn_label(edge[1]))
    
nx.write_gml(G, '%s.gml' % syn_label(topic))

# %% [markdown]
# ### Factions

# %%
class Factions:
    def __init__(self, topic):
        self.topic = topic
        self.edges = {}
        self.degrees = {}
        self.main_conflict = None
        self.actors = set()
        self.factions = (set(), set(), set())
        
    def attacks_faction(self, actor, faction):
        for actor2 in self.factions[faction]:
            edge = tuple(sorted((actor, actor2)))
            if edge in self.edges:
                return True
        return False

    def assign_faction(self, actor):
        if actor in self.actors:
            return
        self.actors.add(actor)
        if self.attacks_faction(actor, 0) and not self.attacks_faction(actor, 1):
            self.factions[1].add(actor)
        elif self.attacks_faction(actor, 1) and not self.attacks_faction(actor, 0):
            self.factions[0].add(actor)
        else:
            self.factions[2].add(actor)

    def process(self):
        conflict_pairs = entities[self.topic]['conflict_actors']

        for pair in conflict_pairs:
            edge = tuple(sorted(pair))
            if edge not in self.edges:
                self.edges[edge] = 0
            actor1, actor2 = edge
            if actor1 not in self.degrees:
                self.degrees[actor1] = 0
            self.degrees[actor1] += 1
            if actor2 not in self.degrees:
                self.degrees[actor2] = 0
            self.degrees[actor2] += 1
    
        for edge in self.edges:
            self.edges[edge] = min([self.degrees[actor] for actor in edge])

        sorted_edges = sorted([(edge[0], edge[1], self.edges[edge]) for edge in self.edges], key=operator.itemgetter(2), reverse=True)

        self.main_conflict = sorted_edges[0]
        self.actors.add(self.main_conflict[0])
        self.actors.add(self.main_conflict[1])
        self.factions[0].add(self.main_conflict[0])
        self.factions[1].add(self.main_conflict[1])

        for edge in sorted_edges[1:]:
            self.assign_faction(edge[0])
            self.assign_faction(edge[1])
            
    def get_faction(self, actor):
        if actor in self.factions[0]:
            return -1
        elif actor in self.factions[1]:
            return 1
        else:
            return 0
        
f = Factions('syria/syn11910')
f.process()
print(f.main_conflict)

print('FACTION A')
for actor in f.factions[0]:
    print(syn_label(actor))
print('FACTION B')
for actor in f.factions[1]:
    print(syn_label(actor))
print('UNDECIDED')
for actor in f.factions[2]:
    print(syn_label(actor))
# Out:
# ('russia/syn11969', 'u.s./syn26', 24)
# FACTION A
# iran
# damascus
# moscow
# saudi
# hezbollah
# putin
# china
# russia
# FACTION B
# turkey pm
# united states
# obama
# turkish pm
# benjamin
# france
# germany
# us
# israel
# syria opposition
# UNDECIDED
# assad
# john
# turkey
# saudi king
# un
# ankara

# %% [markdown]
# ### Generate topics data

# %%
json_data = {}

for topic, c in sorted_conflict_topics:
    if c > 1:
        f = Factions(topic)
        f.process()
    
        cactors = {}
        for actor in f.actors:
            cactor = {'faction': f.get_faction(actor), 'outdeg': 0, 'indeg': 0}
            lactor = syn_label(actor)
            cactors[lactor] = cactor
        
        for pair in entities[topic]['conflict_actors']:
            orig = syn_label(pair[0])
            targ = syn_label(pair[1])
            cactors[orig]['outdeg'] += 1
            cactors[targ]['indeg'] += 1
    
        main_conflict = [syn_label(f.main_conflict[0]), syn_label(f.main_conflict[1])]
    
        ltopic = syn_label(topic)
        json_data[ltopic] = {'conflictuality': c, 'actors': cactors, 'main_conflict': main_conflict}
        
with open('conflict_topics.json', 'wt') as out:
    res = j.dump(json_data, out, sort_keys=False, indent=4, separators=(',', ': '))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-96b2508dcd67> in <module>()
#       1 json_data = {}
#       2
# ----> 3 for topic, c in sorted_conflict_topics:
#       4     if c > 1:
#       5         f = Factions(topic)
#
# NameError: name 'sorted_conflict_topics' is not defined

# %%
edge = str2edge('(accuses/nlp.accuse.verb us/nlp.us.propn israel/nlp.israel.propn (+/gb of/nlp.of.adp (targeting/nlp.target.verb (+/gb of/nlp.of.adp family/nlp.family.noun (+/gb palestine/nlp.palestine.propn (murdered/nlp.murder.verb teen/nlp.teen.noun))))))')
hg.get_str_attribute(edge, 'text')
edge2str(without_namespaces(edge))
# Out:
# '(accuses us israel (+ of (targeting (+ of family (+ palestine (murdered teen))))))'

# %% [markdown]
# ## Validation

# %%
all_claims = []
all_conflicts = []

for edge in hg.pattern2edges(('mention/gb.inf', None, None)):
    origs = edge2actors(edge[1])
    topics = atomic_topics2(edge[2])
    source = hg.pattern2edges(('source/gb.inf', edge, None)).pop()[2]
    text = hg.get_str_attribute(source, 'text')
    all_claims.append({'origs': origs,
                       'topics': topics,
                       'orig_raw': edge[1],
                       'topic_raw': edge[2],
                       'detailed_topic': choose_topic(edge[2]),
                       'sentence': text,
                       'edge': source})
    
    
for edge in hg.pattern2edges(('conflict/gb.inf', None, None, None)):
    origs = edge2actors(edge[1])
    targs = edge2actors(edge[2])
    topics = atomic_topics(edge[3])
    source = hg.pattern2edges(('source/gb.inf', edge, None)).pop()[2]
    text = hg.get_str_attribute(source, 'text')
    all_conflicts.append({'origs': origs,
                          'targs': targs,
                          'topics': topics,
                          'orig_raw': edge[1],
                          'targ_raw': edge[2],
                          'topic_raw': edge[3],
                          'detailed_topic': choose_topic(edge[3]),
                          'sentence': text,
                          'edge': source})

# %%
sample_claims = []
while len(sample_claims) < 100:
    choice = random.choice(all_claims)
    if choice not in sample_claims and choice['origs']:
        sample_claims.append(choice)

sample_conflicts = []
while len(sample_conflicts) < 100:
    choice = random.choice(all_conflicts)
    if choice not in sample_claims and choice['origs'] and choice['targs']:
        sample_conflicts.append(choice)

# %%
sample_claims[0]
# Out:
# {'origs': {'defense_chief/syn4184'},
#  'topics': {'asia/syn12203',
#   "gov't/syn512",
#   'to_stay_put_in/syn2167251',
#   'to_stay_put_in_asia/syn2167250',
#   'trump/syn202',
#   "trump_gov't/syn2167249",
#   "trump_gov't_to_stay_put_in_asia/syn2167248"},
#  'orig_raw': ('+/gb', 'defense/nlp.defense.noun', 'chief/nlp.chief.noun'),
#  'topic_raw': ('+/gb',
#   ('+/gb', 'trump/nlp.trump.propn', "gov't/nlp.gov't.verb"),
#   ('to_stay_put_in/nlp.to.part+nlp.stay.verb+nlp.put.verb+nlp.in.adp',
#    'asia/nlp.asia.propn')),
#  'detailed_topic': "trump_gov't_to_stay_put_in_asia/syn2167248",
#  'sentence': "Trump gov't to stay put in Asia, defense chief says.",
#  'edge': ('says/nlp.say.verb',
#   ('+/gb', 'defense/nlp.defense.noun', 'chief/nlp.chief.noun'),
#   ('+/gb',
#    ('+/gb', 'trump/nlp.trump.propn', "gov't/nlp.gov't.verb"),
#    ('to_stay_put_in/nlp.to.part+nlp.stay.verb+nlp.put.verb+nlp.in.adp',
#     'asia/nlp.asia.propn')))}

# %%
with open('claim_validation.csv', 'w') as f:
    f.write('sentence;edge;orig_raw;topic_raw;origs;topics;detailed_topic\n')
    for item in sample_claims:
        row = []
        row.append(item['sentence'].replace(';', ','))
        row.append(edge2str(item['edge'], namespaces=False))
        row.append(edge2str(item['orig_raw'], namespaces=False))
        row.append(edge2str(item['topic_raw'], namespaces=False))
        row.append('|'.join([syn_label(x) for x in item['origs']]))
        row.append('|'.join([syn_label(x) for x in item['topics']]))
        row.append(syn_label(item['detailed_topic']))
        f.write('%s\n' % ';'.join(row))

# %%
with open('conflict_validation.csv', 'w') as f:
    f.write('sentence;edge;orig_raw;targ_raw;topic_raw;origs;targs;topics;detailed_topic\n')
    for item in sample_conflicts:
        row = []
        row.append(item['sentence'].replace(';', ','))
        row.append(edge2str(item['edge'], namespaces=False))
        row.append(edge2str(item['orig_raw'], namespaces=False))
        row.append(edge2str(item['targ_raw'], namespaces=False))
        row.append(edge2str(item['topic_raw'], namespaces=False))
        row.append('|'.join([syn_label(x) for x in item['origs']]))
        row.append('|'.join([syn_label(x) for x in item['targs']]))
        row.append('|'.join([syn_label(x) for x in item['topics']]))
        row.append(syn_label(item['detailed_topic']))
        f.write('%s\n' % ';'.join(row))
